# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Fist, get the HTML

# %%
import requests
#page = requests.get('http://www.dominorecordco.com/live/')
#page_content = page.text
page_content = open('samples/domino.html').read()

# %% [markdown]
# We can list the repeating tagpaths, with or without classes or HTML IDs:

# %%
from collections import Counter
from sketchtml.repeats import TagPathClustering


clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False,
                               ignore_classes=('last-in-line',),
                               text_only=True
                              )
clustering._build_tagpaths()

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 0:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# (222) /html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveArtist.upperh4/a.upperh4
# (190) /html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveVenue/a
# (107) /html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li.greybg.greyborderbottom.margin10bottom.margin5top.pad5
# ( 27) /html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/select.col.pad2/option
# ( 23) /html/body/div/div/div/ul.menuButtons/li/ul/li.menuMain/a
# (  9) /html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/h2.margin10top/span
# (  9) /html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/ul.margin10bottom.noListStyle/li/h4/a
# (  7) /html/body/div/p/a
# (  6) /html/body/div/div/div/ul.menuButtons/li/a/span/span
# (  5) /html/body/div/div/a
# (  1) /html/head/title
# (  1) /html/body/div/div/div/a.cartEmpty
# (  1) /html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/h1/span
# (  1) /html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/h4.margin5bottom
# (  1) /html/body/div/p

# %% [markdown]
# ## Clustering of tagpaths
#
# Perform spectral clustering using the methom from ["Extracting Data Records from the Web Using Tag Path Clustering", 2009](http://www2009.wwwconference.org/proceedings/pdf/p981.pdf).
#
# > Miao, Gengxin & Tatemura, Junichi & Hsiung, Wang-Pin & Sawires, Arsany & Moser, Louise. (2009).
# > **Extracting data records from the Web using tag path clustering**. ACM WWW. 981-990. 10.1145/1526709.1526841.

# %%
clusters = clustering.clusters()

# %%
sorted(set(clustering.tagpaths))
# Out:
# ['/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/h1/span',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/h2.margin10top/span',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveArtist.upperh4/a.upperh4',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveVenue/a',
#  '/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/h4.margin5bottom',
#  '/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/select.col.pad2/option',
#  '/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/ul.margin10bottom.noListStyle/li/h4/a',
#  '/html/body/div/div/a',
#  '/html/body/div/div/div/a.cartEmpty',
#  '/html/body/div/div/div/ul.menuButtons/li/a/span/span',
#  '/html/body/div/div/div/ul.menuButtons/li/ul/li.menuMain/a',
#  '/html/body/div/p',
#  '/html/body/div/p/a',
#  '/html/head/title']

# %% [markdown]
# ## Plotting tagpaths "signals" can help chosing better `with_classes`, `with_ids` parameters

# %%
clustering.simhelper.plot_signals()

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body/div/div/div/ul.menuButtons/li/a/span/span',
#                  '/html/body/div/div/div/ul.menuButtons/li/ul/li.menuMain/a'],
#              1: ['/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/select.col.pad2/option'],
#              2: ['/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/ul.margin10bottom.noListStyle/li/h4/a'],
#              3: ['/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveArtist.upperh4/a.upperh4',
#                  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveVenue/a'],
#              4: ['/html/body/div/p/a'],
#              5: ['/html/body/div/div/a'],
#              6: ['/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/h2.margin10top/span'],
#              7: ['/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li.greybg.greyborderbottom.margin10bottom.margin5top.pad5']})

# %% [markdown]
# ## Let's build a trie to reconstruct the layout from a tagpath list (from one or more clusters or a chosen subset of tagpaths)

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
_node_repr = clustering._node_repr
# This if borrowed from https://towardsdatascience.com/implementing-a-trie-data-structure-in-python-in-less-than-100-lines-of-code-a877ea23c1a1

class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %% [markdown]
# To help chose the clusters we need, we can print out some of the text data for each tagpath in each cluster.

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('.//text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)[:100]
                if t or attribs:
                #if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = []
for i in [0,1,2,3,4,5,6,7]:
    for tp in clusters[i]:
        tps.append(tp)
tps
# Out:
# ['/html/body/div/div/div/ul.menuButtons/li/a/span/span',
#  '/html/body/div/div/div/ul.menuButtons/li/ul/li.menuMain/a',
#  '/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/select.col.pad2/option',
#  '/html/body/div.live/div.bord/div.main/div.articles.rightSingleCol/div.singleCol/ul.margin10bottom.noListStyle/li/h4/a',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveArtist.upperh4/a.upperh4',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom/h4.floatLeft.liveVenue/a',
#  '/html/body/div/p/a',
#  '/html/body/div/div/a',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li/h2.margin10top/span',
#  '/html/body/div.live/div.bord/div.main/div.articles.leftDoubleCol/ul.noListStyle/li.greybg.greyborderbottom.margin10bottom.margin5top.pad5']

# %%
tps = '''
'''.splitlines()

# %% [markdown]
# Now let's insert them into the trie:

# %%
root = TrieNode('')
for tp in tps:
    steps = tp.lstrip('/').split('/')
    for nl in nodelists[tp][:]:
        add(root, nl)

# %%
def layout(node, summary=True):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=len(set(node.elements)) if summary else set(node.elements),
        children=[layout(c, summary=summary) for c in node.children],
        word_finished=node.word_finished
    )

# %% [markdown]
# If we check the general structure of the trie, we can notice that some levels only have 1 child.

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1 and not trienode.word_finished:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
layout(root)
# Out:
# {'tag': '/html/body',
#  'element': 1,
#  'children': [{'tag': 'div',
#    'element': 2,
#    'children': [{'tag': 'div',
#      'element': 2,
#      'children': [{'tag': 'div/ul.menuButtons/li',
#        'element': 6,
#        'children': [{'tag': 'a/span/span',
#          'element': 6,
#          'children': [],
#          'word_finished': False},
#         {'tag': 'ul/li.menuMain/a',
#          'element': 23,
#          'children': [],
#          'word_finished': False}],
#        'word_finished': False},
#       {'tag': 'a', 'element': 5, 'children': [], 'word_finished': True}],
#      'word_finished': False},
#     {'tag': 'p/a', 'element': 7, 'children': [], 'word_finished': False}],
#    'word_finished': False},
#   {'tag': 'div.live/div.bord/div.main',
#    'element': 1,
#    'children': [{'tag': 'div.articles.rightSingleCol/div.singleCol',
#      'element': 1,
#      'children': [{'tag': 'select.col.pad2/option',
#        'element': 27,
#        'children': [],
#        'word_finished': False},
#       {'tag': 'ul.margin10bottom.noListStyle/li/h4/a',
#        'element': 9,
#        'children': [],
#        'word_finished': False}],
#      'word_finished': False},
#     {'tag': 'div.articles.leftDoubleCol/ul.noListStyle',
#      'element': 1,
#      'children': [{'tag': 'li',
#        'element': 199,
#        'children': [{'tag': 'ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom',
#          'element': 190,
#          'children': [{'tag': 'h4.floatLeft.liveArtist.upperh4/a.upperh4',
#            'element': 222,
#            'children': [],
#            'word_finished': False},
#           {'tag': 'h4.floatLeft.liveVenue/a',
#            'element': 190,
#            'children': [],
#            'word_finished': False}],
#          'word_finished': False},
#         {'tag': 'h2.margin10top/span',
#          'element': 9,
#          'children': [],
#          'word_finished': False}],
#        'word_finished': False},
#       {'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#        'element': 107,
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# We can collapse those branches:

# %% [markdown]
# The trie also keeps references to individual HTML nodes, with their document order so that we can re-build the data hierarchy:

# %%
layout(root, summary=False)
# Out:
# {'tag': '/html/body',
#  'element': {Node(tag='body', doc_order=28, child_position=1, attribs={}, element=<Element body at 0x7f3e189faf48>)},
#  'children': [{'tag': 'div',
#    'element': {Node(tag='div', doc_order=32, child_position=1, attribs={'id': 'header'}, element=<Element div at 0x7f3e52463c88>),
#     Node(tag='div', doc_order=1969, child_position=4, attribs={'id': 'footer'}, element=<Element div at 0x7f3e18994548>)},
#    'children': [{'tag': 'div',
#      'element': {Node(tag='div', doc_order=33, child_position=1, attribs={'id': 'otherSites'}, element=<Element div at 0x7f3e18a986c8>),
#       Node(tag='div', doc_order=39, child_position=2, attribs={'id': 'headerLeft'}, element=<Element div at 0x7f3e10280ec8>)},
#      'children': [{'tag': 'div/ul.menuButtons/li',
#        'element': {Node(tag='li', doc_order=46, child_position=1, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e102800c8>),
#         Node(tag='li', doc_order=50, child_position=2, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e102801c8>),
#         Node(tag='li', doc_order=54, child_position=3, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e10280388>),
#         Node(tag='li', doc_order=93, child_position=4, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e189980c8>),
#         Node(tag='li', doc_order=114, child_position=5, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e18998f08>),
#         Node(tag='li', doc_order=118, child_position=6, attribs={'style': 'background-image:url(/resources/sitewide/menu_button.gif);'}, element=<Element li at 0x7f3e18998088>)},
#        'children': [{'tag': 'a/span/span',
#          'element': {Node(tag='span', doc_order=49, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #10498e; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e10280f08>),
#           Node(tag='span', doc_order=53, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #fd0889; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e102807c8>),
#           Node(tag='span', doc_order=57, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #e52d2b; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e10280e88>),
#           Node(tag='span', doc_order=96, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #27c45b; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e18998848>),
#           Node(tag='span', doc_order=117, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #1a127f; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e18998348>),
#           Node(tag='span', doc_order=121, child_position=1, attribs={'style': 'font-family: DINWeb-Black, sans-serif; font-weight: normal; letter-spacing:0.2px; font-smooth: always; line-height: 20px; color: #f98e03; font-size: 10pt; width: 300px;'}, element=<Element span at 0x7f3e18998e88>)},
#          'children': [],
#          'word_finished': False},
#         {'tag': 'ul/li.menuMain/a',
#          'element': {Node(tag='a', doc_order=61, child_position=1, attribs={'href': '/uk/albums/', 'title': 'Albums', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280088>),
#           Node(tag='a', doc_order=63, child_position=1, attribs={'href': '/uk/singles/', 'title': 'Singles', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280d08>),
#           Node(tag='a', doc_order=65, child_position=1, attribs={'href': '/uk/ep/', 'title': 'EP', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e102805c8>),
#           Node(tag='a', doc_order=67, child_position=1, attribs={'href': '/uk/reissues/', 'title': 'Reissues', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280848>),
#           Node(tag='a', doc_order=69, child_position=1, attribs={'href': '/releases/clothing/', 'title': 'Clothing', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280408>),
#           Node(tag='a', doc_order=71, child_position=1, attribs={'href': '/uk/friends/', 'title': 'Friends', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280e08>),
#           Node(tag='a', doc_order=73, child_position=1, attribs={'href': '/uk/geographic/', 'title': 'Geographic', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e10280988>),
#           Node(tag='a', doc_order=75, child_position=1, attribs={'href': '/uk/fencecollective/', 'title': 'Fence Collective', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998148>),
#           Node(tag='a', doc_order=77, child_position=1, attribs={'href': '/uk/doublesix/', 'title': 'Double Six', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998908>),
#           Node(tag='a', doc_order=79, child_position=1, attribs={'href': '/uk/otherlabels/', 'title': 'Other labels', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998c08>),
#           Node(tag='a', doc_order=81, child_position=1, attribs={'href': '/uk/digitalsingle/', 'title': 'Digital Single', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998e48>),
#           Node(tag='a', doc_order=83, child_position=1, attribs={'href': '/uk/posters/', 'title': 'Posters', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e189989c8>),
#           Node(tag='a', doc_order=85, child_position=1, attribs={'href': '/uk/book/', 'title': 'Book', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998248>),
#           Node(tag='a', doc_order=87, child_position=1, attribs={'href': '/uk/bags/', 'title': 'Bags', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e189988c8>),
#           Node(tag='a', doc_order=89, child_position=1, attribs={'href': '/uk/dvds/', 'title': 'DVDs', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998388>),
#           Node(tag='a', doc_order=91, child_position=1, attribs={'href': '/uk/7boxset/', 'title': '7" Box set', 'style': 'color: #e52d2b'}, element=<Element a at 0x7f3e18998f48>),
#           Node(tag='a', doc_order=100, child_position=1, attribs={'href': '/mart/', 'title': 'Shop here & now', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998fc8>),
#           Node(tag='a', doc_order=102, child_position=1, attribs={'href': '/mart/newreleases/', 'title': 'New releases', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998cc8>),
#           Node(tag='a', doc_order=104, child_position=1, attribs={'href': '/mart/specialoffers/', 'title': 'Special Offers', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e189984c8>),
#           Node(tag='a', doc_order=106, child_position=1, attribs={'href': '/mart/preorders/', 'title': 'Pre-orders', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998288>),
#           Node(tag='a', doc_order=108, child_position=1, attribs={'href': '/mart/reissues/', 'title': 'Reissues', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998748>),
#           Node(tag='a', doc_order=110, child_position=1, attribs={'href': '/mart/tickets/', 'title': 'Tickets', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998048>),
#           Node(tag='a', doc_order=112, child_position=1, attribs={'href': '/mart/merch/', 'title': 'Merch', 'style': 'color: #27c45b'}, element=<Element a at 0x7f3e18998608>)},
#          'children': [],
#          'word_finished': False}],
#        'word_finished': False},
#       {'tag': 'a',
#        'element': {Node(tag='a', doc_order=34, child_position=1, attribs={'href': 'http://www.dominorecordco.us/?ses_key=5a9x0g4c&site=2&empty=true'}, element=<Element a at 0x7f3e10280dc8>),
#         Node(tag='a', doc_order=35, child_position=2, attribs={'href': 'http://www.dominopublishingco.com/?ses_key=5a9x0g4c&site=3&empty=true'}, element=<Element a at 0x7f3e10280548>),
#         Node(tag='a', doc_order=36, child_position=3, attribs={'href': 'http://www.dominorecordco.de/?ses_key=5a9x0g4c&site=12&empty=true'}, element=<Element a at 0x7f3e10280ac8>),
#         Node(tag='a', doc_order=37, child_position=4, attribs={'href': 'http://www.dominorecordco.fr/?ses_key=5a9x0g4c&site=13&empty=true'}, element=<Element a at 0x7f3e10280b48>),
#         Node(tag='a', doc_order=38, child_position=5, attribs={'href': 'http://www.dominopublishingco.com/publishing/blog'}, element=<Element a at 0x7f3e10280648>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False},
#     {'tag': 'p/a',
#      'element': {Node(tag='a', doc_order=1972, child_position=1, attribs={'href': 'http://www.infinitespark.com'}, element=<Element a at 0x7f3e10295188>),
#       Node(tag='a', doc_order=1973, child_position=2, attribs={'href': '/contact/', 'title': 'Contact'}, element=<Element a at 0x7f3e10295548>),
#       Node(tag='a', doc_order=1974, child_position=3, attribs={'href': 'https://www.dominomart.com/newsletters/subscribe/martnewsletter', 'title': 'Newsletters'}, element=<Element a at 0x7f3e0da1bb88>),
#       Node(tag='a', doc_order=1975, child_position=4, attribs={'href': '/policies/about/', 'title': 'About Domino'}, element=<Element a at 0x7f3e0da1e588>),
#       Node(tag='a', doc_order=1976, child_position=5, attribs={'href': '/policies/privacy/', 'title': 'Privacy policy'}, element=<Element a at 0x7f3e0da1e4c8>),
#       Node(tag='a', doc_order=1977, child_position=6, attribs={'href': '/newsfeeds/', 'title': 'RSS feeds'}, element=<Element a at 0x7f3e0da1e348>),
#       Node(tag='a', doc_order=1978, child_position=7, attribs={'href': '#top_bar'}, element=<Element a at 0x7f3e1899d148>)},
#      'children': [],
#      'word_finished': False}],
#    'word_finished': False},
#   {'tag': 'div.live/div.bord/div.main',
#    'element': {Node(tag='div', doc_order=141, child_position=1, attribs={'class': 'main'}, element=<Element div at 0x7f3e1899ac08>)},
#    'children': [{'tag': 'div.articles.rightSingleCol/div.singleCol',
#      'element': {Node(tag='div', doc_order=1897, child_position=1, attribs={'class': 'singleCol', 'id': 'rightPanel'}, element=<Element div at 0x7f3e1892fac8>)},
#      'children': [{'tag': 'select.col.pad2/option',
#        'element': {Node(tag='option', doc_order=1931, child_position=1, attribs={'value': '/live/'}, element=<Element option at 0x7f3e10225b08>),
#         Node(tag='option', doc_order=1932, child_position=2, attribs={'value': ''}, element=<Element option at 0x7f3e10225908>),
#         Node(tag='option', doc_order=1933, child_position=3, attribs={'value': '/live/alexis-taylor'}, element=<Element option at 0x7f3e10225ac8>),
#         Node(tag='option', doc_order=1934, child_position=4, attribs={'value': '/live/anna-calvi'}, element=<Element option at 0x7f3e10225c48>),
#         Node(tag='option', doc_order=1935, child_position=5, attribs={'value': '/live/arctic-monkeys'}, element=<Element option at 0x7f3e10225e88>),
#         Node(tag='option', doc_order=1936, child_position=6, attribs={'value': '/live/blood-orange'}, element=<Element option at 0x7f3e10225288>),
#         Node(tag='option', doc_order=1937, child_position=7, attribs={'value': '/live/bob-moses'}, element=<Element option at 0x7f3e10225dc8>),
#         Node(tag='option', doc_order=1938, child_position=8, attribs={'value': '/live/dan-deacon'}, element=<Element option at 0x7f3e10225588>),
#         Node(tag='option', doc_order=1939, child_position=9, attribs={'value': '/live/eugene-kelly'}, element=<Element option at 0x7f3e10225a88>),
#         Node(tag='option', doc_order=1940, child_position=10, attribs={'value': '/live/franz-ferdinand'}, element=<Element option at 0x7f3e50154688>),
#         Node(tag='option', doc_order=1941, child_position=11, attribs={'value': '/live/george-fitzgerald'}, element=<Element option at 0x7f3e50154908>),
#         Node(tag='option', doc_order=1942, child_position=12, attribs={'value': '/live/georgia'}, element=<Element option at 0x7f3e50154408>),
#         Node(tag='option', doc_order=1943, child_position=13, attribs={'value': '/live/hot-chip'}, element=<Element option at 0x7f3e18970388>),
#         Node(tag='option', doc_order=1944, child_position=14, attribs={'value': '/live/james-yorkston'}, element=<Element option at 0x7f3e18970b08>),
#         Node(tag='option', doc_order=1945, child_position=15, attribs={'value': '/live/jon-hopkins'}, element=<Element option at 0x7f3e101b9f48>),
#         Node(tag='option', doc_order=1946, child_position=16, attribs={'value': '/live/julia-holter'}, element=<Element option at 0x7f3e101b93c8>),
#         Node(tag='option', doc_order=1947, child_position=17, attribs={'value': '/live/panda-bear'}, element=<Element option at 0x7f3e101b94c8>),
#         Node(tag='option', doc_order=1948, child_position=18, attribs={'value': '/live/patrick-watson'}, element=<Element option at 0x7f3e101b9e08>),
#         Node(tag='option', doc_order=1949, child_position=19, attribs={'value': '/live/protomartyr'}, element=<Element option at 0x7f3e101b95c8>),
#         Node(tag='option', doc_order=1950, child_position=20, attribs={'value': '/live/real-estate'}, element=<Element option at 0x7f3e18963908>),
#         Node(tag='option', doc_order=1951, child_position=21, attribs={'value': '/live/seamus-fogarty'}, element=<Element option at 0x7f3e0da19888>),
#         Node(tag='option', doc_order=1952, child_position=22, attribs={'value': '/live/shirley-collins'}, element=<Element option at 0x7f3e18910288>),
#         Node(tag='option', doc_order=1953, child_position=23, attribs={'value': '/live/stephen-malkmus-and-the-jicks'}, element=<Element option at 0x7f3e10224f08>),
#         Node(tag='option', doc_order=1954, child_position=24, attribs={'value': '/live/steve-mason'}, element=<Element option at 0x7f3e102249c8>),
#         Node(tag='option', doc_order=1955, child_position=25, attribs={'value': '/live/superorganism'}, element=<Element option at 0x7f3e10224d08>),
#         Node(tag='option', doc_order=1956, child_position=26, attribs={'value': '/live/villagers'}, element=<Element option at 0x7f3e18992788>),
#         Node(tag='option', doc_order=1957, child_position=27, attribs={'value': '/live/yorkstonthornekhan'}, element=<Element option at 0x7f3e18992b88>)},
#        'children': [],
#        'word_finished': False},
#       {'tag': 'ul.margin10bottom.noListStyle/li/h4/a',
#        'element': {Node(tag='a', doc_order=1903, child_position=1, attribs={'href': '#live_December_2018'}, element=<Element a at 0x7f3e1892fc08>),
#         Node(tag='a', doc_order=1906, child_position=1, attribs={'href': '#live_January_2019'}, element=<Element a at 0x7f3e1892fcc8>),
#         Node(tag='a', doc_order=1909, child_position=1, attribs={'href': '#live_February_2019'}, element=<Element a at 0x7f3e1892fd88>),
#         Node(tag='a', doc_order=1912, child_position=1, attribs={'href': '#live_March_2019'}, element=<Element a at 0x7f3e1892fe48>),
#         Node(tag='a', doc_order=1915, child_position=1, attribs={'href': '#live_April_2019'}, element=<Element a at 0x7f3e1892ff08>),
#         Node(tag='a', doc_order=1918, child_position=1, attribs={'href': '#live_May_2019'}, element=<Element a at 0x7f3e1892ffc8>),
#         Node(tag='a', doc_order=1921, child_position=1, attribs={'href': '#live_June_2019'}, element=<Element a at 0x7f3e189210c8>),
#         Node(tag='a', doc_order=1924, child_position=1, attribs={'href': '#live_July_2019'}, element=<Element a at 0x7f3e18921188>),
#         Node(tag='a', doc_order=1927, child_position=1, attribs={'href': '#live_August_2019'}, element=<Element a at 0x7f3e1892ae08>)},
#        'children': [],
#        'word_finished': False}],
#      'word_finished': False},
#     {'tag': 'div.articles.leftDoubleCol/ul.noListStyle',
#      'element': {Node(tag='ul', doc_order=146, child_position=1, attribs={'class': 'noListStyle'}, element=<Element ul at 0x7f3e1899a188>)},
#      'children': [{'tag': 'li',
#        'element': {Node(tag='li', doc_order=147, child_position=1, attribs={}, element=<Element li at 0x7f3e1899a588>),
#         Node(tag='li', doc_order=151, child_position=3, attribs={}, element=<Element li at 0x7f3e1899ac88>),
#         Node(tag='li', doc_order=162, child_position=4, attribs={}, element=<Element li at 0x7f3e1899a048>),
#         Node(tag='li', doc_order=171, child_position=6, attribs={}, element=<Element li at 0x7f3e1899a388>),
#         Node(tag='li', doc_order=180, child_position=8, attribs={}, element=<Element li at 0x7f3e1899a948>),
#         Node(tag='li', doc_order=189, child_position=10, attribs={}, element=<Element li at 0x7f3e0da7ba08>),
#         Node(tag='li', doc_order=198, child_position=12, attribs={}, element=<Element li at 0x7f3e0da7b388>),
#         Node(tag='li', doc_order=207, child_position=14, attribs={}, element=<Element li at 0x7f3e0da7bb48>),
#         Node(tag='li', doc_order=215, child_position=15, attribs={}, element=<Element li at 0x7f3e0da7b4c8>),
#         Node(tag='li', doc_order=223, child_position=16, attribs={}, element=<Element li at 0x7f3e0da7b148>),
#         Node(tag='li', doc_order=227, child_position=18, attribs={}, element=<Element li at 0x7f3e0da7b748>),
#         Node(tag='li', doc_order=235, child_position=19, attribs={}, element=<Element li at 0x7f3e0da7b208>),
#         Node(tag='li', doc_order=244, child_position=21, attribs={}, element=<Element li at 0x7f3e0da7be88>),
#         Node(tag='li', doc_order=253, child_position=23, attribs={}, element=<Element li at 0x7f3e1898ff88>),
#         Node(tag='li', doc_order=262, child_position=25, attribs={}, element=<Element li at 0x7f3e1898f808>),
#         Node(tag='li', doc_order=271, child_position=27, attribs={}, element=<Element li at 0x7f3e1898f708>),
#         Node(tag='li', doc_order=280, child_position=29, attribs={}, element=<Element li at 0x7f3e1898fc88>),
#         Node(tag='li', doc_order=289, child_position=31, attribs={}, element=<Element li at 0x7f3e18a01108>),
#         Node(tag='li', doc_order=298, child_position=33, attribs={}, element=<Element li at 0x7f3e18a01388>),
#         Node(tag='li', doc_order=306, child_position=34, attribs={}, element=<Element li at 0x7f3e18a01848>),
#         Node(tag='li', doc_order=314, child_position=35, attribs={}, element=<Element li at 0x7f3e18a01c88>),
#         Node(tag='li', doc_order=323, child_position=37, attribs={}, element=<Element li at 0x7f3e18a01a88>),
#         Node(tag='li', doc_order=332, child_position=39, attribs={}, element=<Element li at 0x7f3e18a01d88>),
#         Node(tag='li', doc_order=340, child_position=40, attribs={}, element=<Element li at 0x7f3e18967c08>),
#         Node(tag='li', doc_order=349, child_position=42, attribs={}, element=<Element li at 0x7f3e18967e08>),
#         Node(tag='li', doc_order=357, child_position=43, attribs={}, element=<Element li at 0x7f3e1899c908>),
#         Node(tag='li', doc_order=365, child_position=44, attribs={}, element=<Element li at 0x7f3e1899c3c8>),
#         Node(tag='li', doc_order=373, child_position=45, attribs={}, element=<Element li at 0x7f3e1899cc88>),
#         Node(tag='li', doc_order=381, child_position=46, attribs={}, element=<Element li at 0x7f3e1899ca08>),
#         Node(tag='li', doc_order=389, child_position=47, attribs={}, element=<Element li at 0x7f3e1899c1c8>),
#         Node(tag='li', doc_order=398, child_position=49, attribs={}, element=<Element li at 0x7f3e1899cac8>),
#         Node(tag='li', doc_order=406, child_position=50, attribs={}, element=<Element li at 0x7f3e1899c108>),
#         Node(tag='li', doc_order=415, child_position=52, attribs={}, element=<Element li at 0x7f3e1899c388>),
#         Node(tag='li', doc_order=424, child_position=54, attribs={}, element=<Element li at 0x7f3e10223688>),
#         Node(tag='li', doc_order=432, child_position=55, attribs={}, element=<Element li at 0x7f3e1899cec8>),
#         Node(tag='li', doc_order=440, child_position=56, attribs={}, element=<Element li at 0x7f3e1898fd48>),
#         Node(tag='li', doc_order=448, child_position=57, attribs={}, element=<Element li at 0x7f3e18a01b48>),
#         Node(tag='li', doc_order=457, child_position=59, attribs={}, element=<Element li at 0x7f3e18a2eec8>),
#         Node(tag='li', doc_order=465, child_position=60, attribs={}, element=<Element li at 0x7f3e189fae48>),
#         Node(tag='li', doc_order=473, child_position=61, attribs={}, element=<Element li at 0x7f3e189e5dc8>),
#         Node(tag='li', doc_order=482, child_position=63, attribs={}, element=<Element li at 0x7f3e18998108>),
#         Node(tag='li', doc_order=490, child_position=64, attribs={}, element=<Element li at 0x7f3e1899af48>),
#         Node(tag='li', doc_order=498, child_position=65, attribs={}, element=<Element li at 0x7f3e1899ae48>),
#         Node(tag='li', doc_order=506, child_position=66, attribs={}, element=<Element li at 0x7f3e0da7b688>),
#         Node(tag='li', doc_order=515, child_position=68, attribs={}, element=<Element li at 0x7f3e0da866c8>),
#         Node(tag='li', doc_order=523, child_position=69, attribs={}, element=<Element li at 0x7f3e0da86908>),
#         Node(tag='li', doc_order=531, child_position=70, attribs={}, element=<Element li at 0x7f3e0da867c8>),
#         Node(tag='li', doc_order=539, child_position=71, attribs={}, element=<Element li at 0x7f3e0da86348>),
#         Node(tag='li', doc_order=547, child_position=72, attribs={}, element=<Element li at 0x7f3e0da86fc8>),
#         Node(tag='li', doc_order=556, child_position=74, attribs={}, element=<Element li at 0x7f3e10229908>),
#         Node(tag='li', doc_order=564, child_position=75, attribs={}, element=<Element li at 0x7f3e10229a88>),
#         Node(tag='li', doc_order=572, child_position=76, attribs={}, element=<Element li at 0x7f3e18969508>),
#         Node(tag='li', doc_order=580, child_position=77, attribs={}, element=<Element li at 0x7f3e1899f6c8>),
#         Node(tag='li', doc_order=589, child_position=79, attribs={}, element=<Element li at 0x7f3e1899f1c8>),
#         Node(tag='li', doc_order=597, child_position=80, attribs={}, element=<Element li at 0x7f3e1899f048>),
#         Node(tag='li', doc_order=606, child_position=82, attribs={}, element=<Element li at 0x7f3e189a2f48>),
#         Node(tag='li', doc_order=614, child_position=83, attribs={}, element=<Element li at 0x7f3e189a2308>),
#         Node(tag='li', doc_order=623, child_position=85, attribs={}, element=<Element li at 0x7f3e1013ce88>),
#         Node(tag='li', doc_order=631, child_position=86, attribs={}, element=<Element li at 0x7f3e1013c488>),
#         Node(tag='li', doc_order=640, child_position=88, attribs={}, element=<Element li at 0x7f3e1013cc08>),
#         Node(tag='li', doc_order=648, child_position=89, attribs={}, element=<Element li at 0x7f3e18999cc8>),
#         Node(tag='li', doc_order=657, child_position=91, attribs={}, element=<Element li at 0x7f3e18999948>),
#         Node(tag='li', doc_order=665, child_position=92, attribs={}, element=<Element li at 0x7f3e18999748>),
#         Node(tag='li', doc_order=673, child_position=93, attribs={}, element=<Element li at 0x7f3e189994c8>),
#         Node(tag='li', doc_order=681, child_position=94, attribs={}, element=<Element li at 0x7f3e18999c08>),
#         Node(tag='li', doc_order=689, child_position=95, attribs={}, element=<Element li at 0x7f3e18999f48>),
#         Node(tag='li', doc_order=693, child_position=97, attribs={}, element=<Element li at 0x7f3e189992c8>),
#         Node(tag='li', doc_order=701, child_position=98, attribs={}, element=<Element li at 0x7f3e18995688>),
#         Node(tag='li', doc_order=710, child_position=100, attribs={}, element=<Element li at 0x7f3e18995cc8>),
#         Node(tag='li', doc_order=718, child_position=101, attribs={}, element=<Element li at 0x7f3e18995b08>),
#         Node(tag='li', doc_order=726, child_position=102, attribs={}, element=<Element li at 0x7f3e18968f88>),
#         Node(tag='li', doc_order=738, child_position=104, attribs={}, element=<Element li at 0x7f3e18939608>),
#         Node(tag='li', doc_order=750, child_position=106, attribs={}, element=<Element li at 0x7f3e18939bc8>),
#         Node(tag='li', doc_order=759, child_position=108, attribs={}, element=<Element li at 0x7f3e0d9fca08>),
#         Node(tag='li', doc_order=768, child_position=110, attribs={}, element=<Element li at 0x7f3e0d9fc7c8>),
#         Node(tag='li', doc_order=776, child_position=111, attribs={}, element=<Element li at 0x7f3e0d9fcd48>),
#         Node(tag='li', doc_order=785, child_position=113, attribs={}, element=<Element li at 0x7f3e0d9fcb88>),
#         Node(tag='li', doc_order=793, child_position=114, attribs={}, element=<Element li at 0x7f3e18952d48>),
#         Node(tag='li', doc_order=805, child_position=116, attribs={}, element=<Element li at 0x7f3e18952208>),
#         Node(tag='li', doc_order=813, child_position=117, attribs={}, element=<Element li at 0x7f3e18952d88>),
#         Node(tag='li', doc_order=821, child_position=118, attribs={}, element=<Element li at 0x7f3e1019ea88>),
#         Node(tag='li', doc_order=833, child_position=120, attribs={}, element=<Element li at 0x7f3e1019ebc8>),
#         Node(tag='li', doc_order=845, child_position=122, attribs={}, element=<Element li at 0x7f3e10226a88>),
#         Node(tag='li', doc_order=853, child_position=123, attribs={}, element=<Element li at 0x7f3e10226208>),
#         Node(tag='li', doc_order=862, child_position=125, attribs={}, element=<Element li at 0x7f3e1021d188>),
#         Node(tag='li', doc_order=870, child_position=126, attribs={}, element=<Element li at 0x7f3e1021d548>),
#         Node(tag='li', doc_order=879, child_position=128, attribs={}, element=<Element li at 0x7f3e1021df48>),
#         Node(tag='li', doc_order=887, child_position=129, attribs={}, element=<Element li at 0x7f3e1021de48>),
#         Node(tag='li', doc_order=896, child_position=131, attribs={}, element=<Element li at 0x7f3e0da74048>),
#         Node(tag='li', doc_order=904, child_position=132, attribs={}, element=<Element li at 0x7f3e0da74388>),
#         Node(tag='li', doc_order=912, child_position=133, attribs={}, element=<Element li at 0x7f3e0da74548>),
#         Node(tag='li', doc_order=921, child_position=135, attribs={}, element=<Element li at 0x7f3e1021da88>),
#         Node(tag='li', doc_order=929, child_position=136, attribs={}, element=<Element li at 0x7f3e10226f08>),
#         Node(tag='li', doc_order=937, child_position=137, attribs={}, element=<Element li at 0x7f3e18939988>),
#         Node(tag='li', doc_order=945, child_position=138, attribs={}, element=<Element li at 0x7f3e18952dc8>),
#         Node(tag='li', doc_order=953, child_position=139, attribs={}, element=<Element li at 0x7f3e189fad88>),
#         Node(tag='li', doc_order=962, child_position=141, attribs={}, element=<Element li at 0x7f3e0da86388>),
#         Node(tag='li', doc_order=970, child_position=142, attribs={}, element=<Element li at 0x7f3e189a2488>),
#         Node(tag='li', doc_order=979, child_position=144, attribs={}, element=<Element li at 0x7f3e189990c8>),
#         Node(tag='li', doc_order=987, child_position=145, attribs={}, element=<Element li at 0x7f3e0da74c48>),
#         Node(tag='li', doc_order=995, child_position=146, attribs={}, element=<Element li at 0x7f3e0da74d88>),
#         Node(tag='li', doc_order=1004, child_position=148, attribs={}, element=<Element li at 0x7f3e0da74bc8>),
#         Node(tag='li', doc_order=1012, child_position=149, attribs={}, element=<Element li at 0x7f3e0da74588>),
#         Node(tag='li', doc_order=1020, child_position=150, attribs={}, element=<Element li at 0x7f3e0da743c8>),
#         Node(tag='li', doc_order=1029, child_position=152, attribs={}, element=<Element li at 0x7f3e101764c8>),
#         Node(tag='li', doc_order=1037, child_position=153, attribs={}, element=<Element li at 0x7f3e10176988>),
#         Node(tag='li', doc_order=1045, child_position=154, attribs={}, element=<Element li at 0x7f3e10176bc8>),
#         Node(tag='li', doc_order=1053, child_position=155, attribs={}, element=<Element li at 0x7f3e10176e08>),
#         Node(tag='li', doc_order=1062, child_position=157, attribs={}, element=<Element li at 0x7f3e10176548>),
#         Node(tag='li', doc_order=1070, child_position=158, attribs={}, element=<Element li at 0x7f3e101a3bc8>),
#         Node(tag='li', doc_order=1078, child_position=159, attribs={}, element=<Element li at 0x7f3e101a3a48>),
#         Node(tag='li', doc_order=1086, child_position=160, attribs={}, element=<Element li at 0x7f3e18963d08>),
#         Node(tag='li', doc_order=1095, child_position=162, attribs={}, element=<Element li at 0x7f3e18963dc8>),
#         Node(tag='li', doc_order=1103, child_position=163, attribs={}, element=<Element li at 0x7f3e18963648>),
#         Node(tag='li', doc_order=1112, child_position=165, attribs={}, element=<Element li at 0x7f3e0da19bc8>),
#         Node(tag='li', doc_order=1120, child_position=166, attribs={}, element=<Element li at 0x7f3e0da199c8>),
#         Node(tag='li', doc_order=1129, child_position=168, attribs={}, element=<Element li at 0x7f3e0da19b08>),
#         Node(tag='li', doc_order=1137, child_position=169, attribs={}, element=<Element li at 0x7f3e0da191c8>),
#         Node(tag='li', doc_order=1148, child_position=170, attribs={}, element=<Element li at 0x7f3e0da197c8>),
#         Node(tag='li', doc_order=1156, child_position=171, attribs={}, element=<Element li at 0x7f3e0da19c08>),
#         Node(tag='li', doc_order=1164, child_position=172, attribs={}, element=<Element li at 0x7f3e189109c8>),
#         Node(tag='li', doc_order=1173, child_position=174, attribs={}, element=<Element li at 0x7f3e18910c08>),
#         Node(tag='li', doc_order=1182, child_position=176, attribs={}, element=<Element li at 0x7f3e18910e48>),
#         Node(tag='li', doc_order=1191, child_position=178, attribs={}, element=<Element li at 0x7f3e18910048>),
#         Node(tag='li', doc_order=1202, child_position=179, attribs={}, element=<Element li at 0x7f3e18910648>),
#         Node(tag='li', doc_order=1210, child_position=180, attribs={}, element=<Element li at 0x7f3e189100c8>),
#         Node(tag='li', doc_order=1218, child_position=181, attribs={}, element=<Element li at 0x7f3e189104c8>),
#         Node(tag='li', doc_order=1227, child_position=183, attribs={}, element=<Element li at 0x7f3e10191148>),
#         Node(tag='li', doc_order=1238, child_position=184, attribs={}, element=<Element li at 0x7f3e10191548>),
#         Node(tag='li', doc_order=1247, child_position=186, attribs={}, element=<Element li at 0x7f3e500cb988>),
#         Node(tag='li', doc_order=1255, child_position=187, attribs={}, element=<Element li at 0x7f3e18966208>),
#         Node(tag='li', doc_order=1264, child_position=189, attribs={}, element=<Element li at 0x7f3e189663c8>),
#         Node(tag='li', doc_order=1272, child_position=190, attribs={}, element=<Element li at 0x7f3e1893a648>),
#         Node(tag='li', doc_order=1276, child_position=192, attribs={}, element=<Element li at 0x7f3e1893a948>),
#         Node(tag='li', doc_order=1287, child_position=193, attribs={}, element=<Element li at 0x7f3e1893a9c8>),
#         Node(tag='li', doc_order=1295, child_position=194, attribs={}, element=<Element li at 0x7f3e18997a48>),
#         Node(tag='li', doc_order=1303, child_position=195, attribs={}, element=<Element li at 0x7f3e18997d48>),
#         Node(tag='li', doc_order=1311, child_position=196, attribs={}, element=<Element li at 0x7f3e101dd708>),
#         Node(tag='li', doc_order=1320, child_position=198, attribs={}, element=<Element li at 0x7f3e101dd688>),
#         Node(tag='li', doc_order=1331, child_position=199, attribs={}, element=<Element li at 0x7f3e101dd048>),
#         Node(tag='li', doc_order=1339, child_position=200, attribs={}, element=<Element li at 0x7f3e101dd848>),
#         Node(tag='li', doc_order=1347, child_position=201, attribs={}, element=<Element li at 0x7f3e101dd108>),
#         Node(tag='li', doc_order=1356, child_position=203, attribs={}, element=<Element li at 0x7f3e101ddc08>),
#         Node(tag='li', doc_order=1368, child_position=205, attribs={}, element=<Element li at 0x7f3e10224e48>),
#         Node(tag='li', doc_order=1377, child_position=207, attribs={}, element=<Element li at 0x7f3e10224ac8>),
#         Node(tag='li', doc_order=1386, child_position=209, attribs={}, element=<Element li at 0x7f3e10224748>),
#         Node(tag='li', doc_order=1397, child_position=210, attribs={}, element=<Element li at 0x7f3e10224508>),
#         Node(tag='li', doc_order=1406, child_position=212, attribs={}, element=<Element li at 0x7f3e10224f48>),
#         Node(tag='li', doc_order=1414, child_position=213, attribs={}, element=<Element li at 0x7f3e10224a48>),
#         Node(tag='li', doc_order=1423, child_position=215, attribs={}, element=<Element li at 0x7f3e101ddf48>),
#         Node(tag='li', doc_order=1432, child_position=217, attribs={}, element=<Element li at 0x7f3e10191108>),
#         Node(tag='li', doc_order=1441, child_position=219, attribs={}, element=<Element li at 0x7f3e0da86448>),
#         Node(tag='li', doc_order=1450, child_position=221, attribs={}, element=<Element li at 0x7f3e101768c8>),
#         Node(tag='li', doc_order=1459, child_position=223, attribs={}, element=<Element li at 0x7f3e18963808>),
#         Node(tag='li', doc_order=1468, child_position=225, attribs={}, element=<Element li at 0x7f3e18910b88>),
#         Node(tag='li', doc_order=1477, child_position=227, attribs={}, element=<Element li at 0x7f3e10224e88>),
#         Node(tag='li', doc_order=1488, child_position=228, attribs={}, element=<Element li at 0x7f3e18992c48>),
#         Node(tag='li', doc_order=1496, child_position=229, attribs={}, element=<Element li at 0x7f3e18992d48>),
#         Node(tag='li', doc_order=1500, child_position=231, attribs={}, element=<Element li at 0x7f3e18992408>),
#         Node(tag='li', doc_order=1512, child_position=233, attribs={}, element=<Element li at 0x7f3e18992588>),
#         Node(tag='li', doc_order=1524, child_position=235, attribs={}, element=<Element li at 0x7f3e18992a08>),
#         Node(tag='li', doc_order=1536, child_position=237, attribs={}, element=<Element li at 0x7f3e18992508>),
#         Node(tag='li', doc_order=1548, child_position=239, attribs={}, element=<Element li at 0x7f3e18994408>),
#         Node(tag='li', doc_order=1557, child_position=241, attribs={}, element=<Element li at 0x7f3e189940c8>),
#         Node(tag='li', doc_order=1569, child_position=243, attribs={}, element=<Element li at 0x7f3e10295cc8>),
#         Node(tag='li', doc_order=1577, child_position=244, attribs={}, element=<Element li at 0x7f3e10295408>),
#         Node(tag='li', doc_order=1581, child_position=246, attribs={}, element=<Element li at 0x7f3e10295d48>),
#         Node(tag='li', doc_order=1593, child_position=248, attribs={}, element=<Element li at 0x7f3e0da1e608>),
#         Node(tag='li', doc_order=1605, child_position=250, attribs={}, element=<Element li at 0x7f3e1899d188>),
#         Node(tag='li', doc_order=1617, child_position=252, attribs={}, element=<Element li at 0x7f3e18965a88>),
#         Node(tag='li', doc_order=1629, child_position=254, attribs={}, element=<Element li at 0x7f3e189657c8>),
#         Node(tag='li', doc_order=1641, child_position=256, attribs={}, element=<Element li at 0x7f3e18965408>),
#         Node(tag='li', doc_order=1653, child_position=258, attribs={}, element=<Element li at 0x7f3e189655c8>),
#         Node(tag='li', doc_order=1665, child_position=260, attribs={}, element=<Element li at 0x7f3e18965cc8>),
#         Node(tag='li', doc_order=1677, child_position=262, attribs={}, element=<Element li at 0x7f3e10225808>),
#         Node(tag='li', doc_order=1686, child_position=264, attribs={}, element=<Element li at 0x7f3e10225408>),
#         Node(tag='li', doc_order=1698, child_position=266, attribs={}, element=<Element li at 0x7f3e10225e08>),
#         Node(tag='li', doc_order=1710, child_position=268, attribs={}, element=<Element li at 0x7f3e10225b88>),
#         Node(tag='li', doc_order=1722, child_position=270, attribs={}, element=<Element li at 0x7f3e50154c48>),
#         Node(tag='li', doc_order=1735, child_position=271, attribs={}, element=<Element li at 0x7f3e18970808>),
#         Node(tag='li', doc_order=1739, child_position=273, attribs={}, element=<Element li at 0x7f3e189708c8>),
#         Node(tag='li', doc_order=1748, child_position=275, attribs={}, element=<Element li at 0x7f3e18970d48>),
#         Node(tag='li', doc_order=1757, child_position=277, attribs={}, element=<Element li at 0x7f3e101b9b48>),
#         Node(tag='li', doc_order=1766, child_position=279, attribs={}, element=<Element li at 0x7f3e101b98c8>),
#         Node(tag='li', doc_order=1775, child_position=281, attribs={}, element=<Element li at 0x7f3e101b9288>),
#         Node(tag='li', doc_order=1784, child_position=283, attribs={}, element=<Element li at 0x7f3e101b9648>),
#         Node(tag='li', doc_order=1792, child_position=284, attribs={}, element=<Element li at 0x7f3e101b99c8>),
#         Node(tag='li', doc_order=1796, child_position=286, attribs={}, element=<Element li at 0x7f3e1892a448>),
#         Node(tag='li', doc_order=1805, child_position=288, attribs={}, element=<Element li at 0x7f3e1892a048>),
#         Node(tag='li', doc_order=1814, child_position=290, attribs={}, element=<Element li at 0x7f3e1892a588>),
#         Node(tag='li', doc_order=1823, child_position=292, attribs={}, element=<Element li at 0x7f3e1892a7c8>),
#         Node(tag='li', doc_order=1832, child_position=294, attribs={}, element=<Element li at 0x7f3e1892aa08>),
#         Node(tag='li', doc_order=1841, child_position=296, attribs={}, element=<Element li at 0x7f3e1892ac48>),
#         Node(tag='li', doc_order=1850, child_position=298, attribs={}, element=<Element li at 0x7f3e1892ae88>),
#         Node(tag='li', doc_order=1858, child_position=299, attribs={}, element=<Element li at 0x7f3e1892f0c8>),
#         Node(tag='li', doc_order=1866, child_position=300, attribs={}, element=<Element li at 0x7f3e1892f2c8>),
#         Node(tag='li', doc_order=1870, child_position=302, attribs={}, element=<Element li at 0x7f3e1892f3c8>),
#         Node(tag='li', doc_order=1879, child_position=304, attribs={}, element=<Element li at 0x7f3e1892f608>),
#         Node(tag='li', doc_order=1888, child_position=306, attribs={}, element=<Element li at 0x7f3e1892f848>)},
#        'children': [{'tag': 'ul.noListStyle.pad5left/li.floatLeft.liveLeft.margin10bottom',
#          'element': {Node(tag='li', doc_order=153, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899ab88>),
#           Node(tag='li', doc_order=164, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899a508>),
#           Node(tag='li', doc_order=173, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899a648>),
#           Node(tag='li', doc_order=182, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899abc8>),
#           Node(tag='li', doc_order=191, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7b888>),
#           Node(tag='li', doc_order=200, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7b8c8>),
#           Node(tag='li', doc_order=209, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7b348>),
#           Node(tag='li', doc_order=217, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7bc88>),
#           Node(tag='li', doc_order=229, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7bd48>),
#           Node(tag='li', doc_order=237, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7bac8>),
#           Node(tag='li', doc_order=246, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7bc48>),
#           Node(tag='li', doc_order=255, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1898fc08>),
#           Node(tag='li', doc_order=264, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1898f1c8>),
#           Node(tag='li', doc_order=273, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1898f188>),
#           Node(tag='li', doc_order=282, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1898f388>),
#           Node(tag='li', doc_order=291, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a01c08>),
#           Node(tag='li', doc_order=300, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a01908>),
#           Node(tag='li', doc_order=308, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a01a08>),
#           Node(tag='li', doc_order=316, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a01e48>),
#           Node(tag='li', doc_order=325, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a01348>),
#           Node(tag='li', doc_order=334, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e189674c8>),
#           Node(tag='li', doc_order=342, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18967608>),
#           Node(tag='li', doc_order=351, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18967248>),
#           Node(tag='li', doc_order=359, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899c488>),
#           Node(tag='li', doc_order=367, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899c648>),
#           Node(tag='li', doc_order=375, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899cb48>),
#           Node(tag='li', doc_order=383, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899cb08>),
#           Node(tag='li', doc_order=391, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899c848>),
#           Node(tag='li', doc_order=400, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899cf48>),
#           Node(tag='li', doc_order=408, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899c8c8>),
#           Node(tag='li', doc_order=417, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e10223988>),
#           Node(tag='li', doc_order=426, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e10223b48>),
#           Node(tag='li', doc_order=434, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899c188>),
#           Node(tag='li', doc_order=442, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1898f208>),
#           Node(tag='li', doc_order=450, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e503c7d08>),
#           Node(tag='li', doc_order=459, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18a2ee88>),
#           Node(tag='li', doc_order=467, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e189fa6c8>),
#           Node(tag='li', doc_order=475, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e102803c8>),
#           Node(tag='li', doc_order=484, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18998448>),
#           Node(tag='li', doc_order=492, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899ad48>),
#           Node(tag='li', doc_order=500, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899a108>),
#           Node(tag='li', doc_order=508, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da7b5c8>),
#           Node(tag='li', doc_order=517, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da863c8>),
#           Node(tag='li', doc_order=525, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da86148>),
#           Node(tag='li', doc_order=533, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da860c8>),
#           Node(tag='li', doc_order=541, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da86888>),
#           Node(tag='li', doc_order=549, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e0da86188>),
#           Node(tag='li', doc_order=558, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e10229e08>),
#           Node(tag='li', doc_order=566, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e10229408>),
#           Node(tag='li', doc_order=574, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18969f08>),
#           Node(tag='li', doc_order=582, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899fe48>),
#           Node(tag='li', doc_order=591, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899f248>),
#           Node(tag='li', doc_order=599, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1899f148>),
#           Node(tag='li', doc_order=608, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e189a2a08>),
#           Node(tag='li', doc_order=616, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e189a2fc8>),
#           Node(tag='li', doc_order=625, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1013c248>),
#           Node(tag='li', doc_order=633, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e1013cac8>),
#           Node(tag='li', doc_order=642, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18999808>),
#           Node(tag='li', doc_order=650, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18999408>),
#           Node(tag='li', doc_order=659, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18999b48>),
#           Node(tag='li', doc_order=667, child_position=1, attribs={'class': 'liveLeft floatLeft margin10bottom'}, element=<Element li at 0x7f3e18999dc8>),
# ...
#         Node(tag='li', doc_order=414, child_position=51, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1899c2c8>),
#         Node(tag='li', doc_order=423, child_position=53, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10223748>),
#         Node(tag='li', doc_order=456, child_position=58, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e523f1048>),
#         Node(tag='li', doc_order=481, child_position=62, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18998d48>),
#         Node(tag='li', doc_order=514, child_position=67, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da86e08>),
#         Node(tag='li', doc_order=555, child_position=73, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e102299c8>),
#         Node(tag='li', doc_order=588, child_position=78, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1899f388>),
#         Node(tag='li', doc_order=605, child_position=81, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e189a2608>),
#         Node(tag='li', doc_order=622, child_position=84, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1013cb08>),
#         Node(tag='li', doc_order=639, child_position=87, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1013c308>),
#         Node(tag='li', doc_order=656, child_position=90, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18999f88>),
#         Node(tag='li', doc_order=692, child_position=96, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18999288>),
#         Node(tag='li', doc_order=709, child_position=99, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18995fc8>),
#         Node(tag='li', doc_order=737, child_position=103, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e189394c8>),
#         Node(tag='li', doc_order=749, child_position=105, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18939688>),
#         Node(tag='li', doc_order=758, child_position=107, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0d9fc708>),
#         Node(tag='li', doc_order=767, child_position=109, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0d9fc6c8>),
#         Node(tag='li', doc_order=784, child_position=112, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0d9fcb08>),
#         Node(tag='li', doc_order=804, child_position=115, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18952688>),
#         Node(tag='li', doc_order=832, child_position=119, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1019e888>),
#         Node(tag='li', doc_order=844, child_position=121, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10226fc8>),
#         Node(tag='li', doc_order=861, child_position=124, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1021d108>),
#         Node(tag='li', doc_order=878, child_position=127, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1021d708>),
#         Node(tag='li', doc_order=895, child_position=130, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da74148>),
#         Node(tag='li', doc_order=920, child_position=134, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1021db48>),
#         Node(tag='li', doc_order=961, child_position=140, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da86588>),
#         Node(tag='li', doc_order=978, child_position=143, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18999d48>),
#         Node(tag='li', doc_order=1003, child_position=147, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da74e88>),
#         Node(tag='li', doc_order=1028, child_position=151, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10176fc8>),
#         Node(tag='li', doc_order=1061, child_position=156, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10176088>),
#         Node(tag='li', doc_order=1094, child_position=161, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18963188>),
#         Node(tag='li', doc_order=1111, child_position=164, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da198c8>),
#         Node(tag='li', doc_order=1128, child_position=167, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da19a08>),
#         Node(tag='li', doc_order=1172, child_position=173, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18910bc8>),
#         Node(tag='li', doc_order=1181, child_position=175, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18910e08>),
#         Node(tag='li', doc_order=1190, child_position=177, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18910fc8>),
#         Node(tag='li', doc_order=1226, child_position=182, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10191348>),
#         Node(tag='li', doc_order=1246, child_position=185, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e500cba48>),
#         Node(tag='li', doc_order=1263, child_position=188, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18966288>),
#         Node(tag='li', doc_order=1275, child_position=191, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1893a308>),
#         Node(tag='li', doc_order=1319, child_position=197, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101ddd08>),
#         Node(tag='li', doc_order=1355, child_position=202, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101ddec8>),
#         Node(tag='li', doc_order=1367, child_position=204, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10224988>),
#         Node(tag='li', doc_order=1376, child_position=206, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10224848>),
#         Node(tag='li', doc_order=1385, child_position=208, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10224a08>),
#         Node(tag='li', doc_order=1405, child_position=211, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10224f88>),
#         Node(tag='li', doc_order=1422, child_position=214, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101dd6c8>),
#         Node(tag='li', doc_order=1431, child_position=216, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10191e48>),
#         Node(tag='li', doc_order=1440, child_position=218, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e5031c108>),
#         Node(tag='li', doc_order=1449, child_position=220, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da74608>),
#         Node(tag='li', doc_order=1458, child_position=222, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e189631c8>),
#         Node(tag='li', doc_order=1467, child_position=224, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da19508>),
#         Node(tag='li', doc_order=1476, child_position=226, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18910188>),
#         Node(tag='li', doc_order=1499, child_position=230, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18992108>),
#         Node(tag='li', doc_order=1511, child_position=232, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18992c88>),
#         Node(tag='li', doc_order=1523, child_position=234, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18992d88>),
#         Node(tag='li', doc_order=1535, child_position=236, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18992188>),
#         Node(tag='li', doc_order=1547, child_position=238, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18994e88>),
#         Node(tag='li', doc_order=1556, child_position=240, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18994608>),
#         Node(tag='li', doc_order=1568, child_position=242, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10295fc8>),
#         Node(tag='li', doc_order=1580, child_position=245, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10295b88>),
#         Node(tag='li', doc_order=1592, child_position=247, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e0da1e548>),
#         Node(tag='li', doc_order=1604, child_position=249, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1899d288>),
#         Node(tag='li', doc_order=1616, child_position=251, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18965608>),
#         Node(tag='li', doc_order=1628, child_position=253, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18965308>),
#         Node(tag='li', doc_order=1640, child_position=255, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18965a08>),
#         Node(tag='li', doc_order=1652, child_position=257, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18965e88>),
#         Node(tag='li', doc_order=1664, child_position=259, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e189659c8>),
#         Node(tag='li', doc_order=1676, child_position=261, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e073f3e88>),
#         Node(tag='li', doc_order=1685, child_position=263, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10225308>),
#         Node(tag='li', doc_order=1697, child_position=265, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10225d88>),
#         Node(tag='li', doc_order=1709, child_position=267, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e102259c8>),
#         Node(tag='li', doc_order=1721, child_position=269, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e10225788>),
#         Node(tag='li', doc_order=1738, child_position=272, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18970dc8>),
#         Node(tag='li', doc_order=1747, child_position=274, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e18970f08>),
#         Node(tag='li', doc_order=1756, child_position=276, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101b9c88>),
#         Node(tag='li', doc_order=1765, child_position=278, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101b9708>),
#         Node(tag='li', doc_order=1774, child_position=280, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101b9188>),
#         Node(tag='li', doc_order=1783, child_position=282, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e101b9e48>),
#         Node(tag='li', doc_order=1795, child_position=285, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892a4c8>),
#         Node(tag='li', doc_order=1804, child_position=287, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892a2c8>),
#         Node(tag='li', doc_order=1813, child_position=289, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892a508>),
#         Node(tag='li', doc_order=1822, child_position=291, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892a788>),
#         Node(tag='li', doc_order=1831, child_position=293, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892a9c8>),
#         Node(tag='li', doc_order=1840, child_position=295, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892ac08>),
#         Node(tag='li', doc_order=1849, child_position=297, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892ae48>),
#         Node(tag='li', doc_order=1869, child_position=301, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892f388>),
#         Node(tag='li', doc_order=1878, child_position=303, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892f5c8>),
#         Node(tag='li', doc_order=1887, child_position=305, attribs={'class': 'greyborderbottom margin10bottom pad5 greybg margin5top'}, element=<Element li at 0x7f3e1892f808>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# ## Re-creating data hierarchy
#
# Below is the most interesting bit: how to re-create a dict/JSON document from repeating tagpaths.
#
# Using the trie, from the root of the tree, we loop over all HTML elements of a trie node, and recursively collect data from its children:

# %%
from collections import defaultdict
from operator import itemgetter
from lxml.html import tostring


def hydrate(node, docorder_min, docorder_max=None, include_html=False):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []

    for i, element in enumerate(elements, start=1):
        
        # filter out elements that are not within the parent document order range
        if not (docorder_min < element.doc_order):
            continue
        if (docorder_max is not None) and (element.doc_order > docorder_max):
            continue
        
        # here's where you extract data from the element
        # 1. node representation including tag and classes can tell us a bit about what it's about
        # 2. document order is purely informational
        # 3. child text nodes usually contain much of the information we want
        # 4. element attributes also can be useful (URL, data-* etc.)
        e = {'tag': _node_repr(element),
             '_doc_order': element.doc_order}
        
        # textual information
        _t = list(filter(bool, [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]))
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        _html = tostring(element.element, encoding='unicode')
        if _html:
            #e['html'] = _html
            pass
            
        _attrib = dict(element.element.attrib)
        if 'class' in _attrib:
            _attrib.pop('class')
        if _attrib:
            e['_attr'] = _attrib
        
        # loop through sub-nodes that are between the current node and the next one
        # Warning: recursivity!
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate(child, _order_min, _order_max)]))
        if children:
            e['children'] = sorted(children, key=itemgetter('_doc_order'))
            #e['children'] = children
        
        # if there's not "valuable" information, might as well skip the element
        if 'children' not in e and not(any(e.get(k) for k in ['text', '_attr'])):
            continue

        output.append(e)
        
    #return sorted(output, key=itemgetter('_doc_order'))
    return output

output = hydrate(root, 0)
pp(output)
# Out:
# [{'_doc_order': 28,
#   'children': [{'_attr': {'id': 'header'},
#                 '_doc_order': 32,
#                 'children': [{'_attr': {'id': 'otherSites'},
#                               '_doc_order': 33,
#                               'children': [{'_attr': {'href': 'http://www.dominorecordco.us/?ses_key=5a9x0g4c&site=2&empty=true'},
#                                             '_doc_order': 34,
#                                             'tag': 'a',
#                                             'text': 'Domino USA'},
#                                            {'_attr': {'href': 'http://www.dominopublishingco.com/?ses_key=5a9x0g4c&site=3&empty=true'},
#                                             '_doc_order': 35,
#                                             'tag': 'a',
#                                             'text': 'Domino Publishing'},
#                                            {'_attr': {'href': 'http://www.dominorecordco.de/?ses_key=5a9x0g4c&site=12&empty=true'},
#                                             '_doc_order': 36,
#                                             'tag': 'a',
#                                             'text': 'Domino Deutschland'},
#                                            {'_attr': {'href': 'http://www.dominorecordco.fr/?ses_key=5a9x0g4c&site=13&empty=true'},
#                                             '_doc_order': 37,
#                                             'tag': 'a',
#                                             'text': 'Domino France'},
#                                            {'_attr': {'href': 'http://www.dominopublishingco.com/publishing/blog'},
#                                             '_doc_order': 38,
#                                             'tag': 'a',
#                                             'text': 'Film + TV'}],
#                               'tag': 'div',
#                               'text': ['|', '|', '|', '|']},
#                              {'_attr': {'id': 'headerLeft'},
#                               '_doc_order': 39,
#                               'children': [{'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 46,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#10498e; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 49,
#                                                           'tag': 'span',
#                                                           'text': 'NEWS'}],
#                                             'tag': 'li'},
#                                            {'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 50,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#fd0889; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 53,
#                                                           'tag': 'span',
#                                                           'text': 'ARTISTS'}],
#                                             'tag': 'li'},
#                                            {'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 54,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#e52d2b; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 57,
#                                                           'tag': 'span',
#                                                           'text': 'RELEASES'},
#                                                          {'_attr': {'href': '/uk/albums/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Albums'},
#                                                           '_doc_order': 61,
#                                                           'tag': 'a',
#                                                           'text': 'Albums'},
#                                                          {'_attr': {'href': '/uk/singles/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Singles'},
#                                                           '_doc_order': 63,
#                                                           'tag': 'a',
#                                                           'text': 'Singles'},
#                                                          {'_attr': {'href': '/uk/ep/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'EP'},
#                                                           '_doc_order': 65,
#                                                           'tag': 'a',
#                                                           'text': 'EP'},
#                                                          {'_attr': {'href': '/uk/reissues/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Reissues'},
#                                                           '_doc_order': 67,
#                                                           'tag': 'a',
#                                                           'text': 'Reissues'},
#                                                          {'_attr': {'href': '/releases/clothing/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Clothing'},
#                                                           '_doc_order': 69,
#                                                           'tag': 'a',
#                                                           'text': 'Clothing'},
#                                                          {'_attr': {'href': '/uk/friends/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Friends'},
#                                                           '_doc_order': 71,
#                                                           'tag': 'a',
#                                                           'text': 'Friends'},
#                                                          {'_attr': {'href': '/uk/geographic/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Geographic'},
#                                                           '_doc_order': 73,
#                                                           'tag': 'a',
#                                                           'text': 'Geographic'},
#                                                          {'_attr': {'href': '/uk/fencecollective/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Fence '
#                                                                              'Collective'},
#                                                           '_doc_order': 75,
#                                                           'tag': 'a',
#                                                           'text': 'Fence '
#                                                                   'Collective'},
#                                                          {'_attr': {'href': '/uk/doublesix/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Double '
#                                                                              'Six'},
#                                                           '_doc_order': 77,
#                                                           'tag': 'a',
#                                                           'text': 'Double Six'},
#                                                          {'_attr': {'href': '/uk/otherlabels/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Other '
#                                                                              'labels'},
#                                                           '_doc_order': 79,
#                                                           'tag': 'a',
#                                                           'text': 'Other '
#                                                                   'labels'},
#                                                          {'_attr': {'href': '/uk/digitalsingle/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Digital '
#                                                                              'Single'},
#                                                           '_doc_order': 81,
#                                                           'tag': 'a',
#                                                           'text': 'Digital '
#                                                                   'Single'},
#                                                          {'_attr': {'href': '/uk/posters/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Posters'},
#                                                           '_doc_order': 83,
#                                                           'tag': 'a',
#                                                           'text': 'Posters'},
#                                                          {'_attr': {'href': '/uk/book/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Book'},
#                                                           '_doc_order': 85,
#                                                           'tag': 'a',
#                                                           'text': 'Book'},
#                                                          {'_attr': {'href': '/uk/bags/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'Bags'},
#                                                           '_doc_order': 87,
#                                                           'tag': 'a',
#                                                           'text': 'Bags'},
#                                                          {'_attr': {'href': '/uk/dvds/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': 'DVDs'},
#                                                           '_doc_order': 89,
#                                                           'tag': 'a',
#                                                           'text': 'DVDs'},
#                                                          {'_attr': {'href': '/uk/7boxset/',
#                                                                     'style': 'color: '
#                                                                              '#e52d2b',
#                                                                     'title': '7" '
#                                                                              'Box '
#                                                                              'set'},
#                                                           '_doc_order': 91,
#                                                           'tag': 'a',
#                                                           'text': '7" Box '
#                                                                   'set'}],
#                                             'tag': 'li'},
#                                            {'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 93,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#27c45b; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 96,
#                                                           'tag': 'span',
#                                                           'text': 'MART'},
#                                                          {'_attr': {'href': '/mart/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Shop '
#                                                                              'here '
#                                                                              '& '
#                                                                              'now'},
#                                                           '_doc_order': 100,
#                                                           'tag': 'a',
#                                                           'text': 'Shop here & '
#                                                                   'now'},
#                                                          {'_attr': {'href': '/mart/newreleases/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'New '
#                                                                              'releases'},
#                                                           '_doc_order': 102,
#                                                           'tag': 'a',
#                                                           'text': 'New '
#                                                                   'releases'},
#                                                          {'_attr': {'href': '/mart/specialoffers/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Special '
#                                                                              'Offers'},
#                                                           '_doc_order': 104,
#                                                           'tag': 'a',
#                                                           'text': 'Special '
#                                                                   'Offers'},
#                                                          {'_attr': {'href': '/mart/preorders/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Pre-orders'},
#                                                           '_doc_order': 106,
#                                                           'tag': 'a',
#                                                           'text': 'Pre-orders'},
#                                                          {'_attr': {'href': '/mart/reissues/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Reissues'},
#                                                           '_doc_order': 108,
#                                                           'tag': 'a',
#                                                           'text': 'Reissues'},
#                                                          {'_attr': {'href': '/mart/tickets/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Tickets'},
#                                                           '_doc_order': 110,
#                                                           'tag': 'a',
#                                                           'text': 'Tickets'},
#                                                          {'_attr': {'href': '/mart/merch/',
#                                                                     'style': 'color: '
#                                                                              '#27c45b',
#                                                                     'title': 'Merch'},
#                                                           '_doc_order': 112,
#                                                           'tag': 'a',
#                                                           'text': 'Merch'}],
#                                             'tag': 'li'},
#                                            {'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 114,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#1a127f; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 117,
#                                                           'tag': 'span',
#                                                           'text': 'LIVE'}],
#                                             'tag': 'li'},
#                                            {'_attr': {'style': 'background-image:url(/resources/sitewide/menu_button.gif);'},
#                                             '_doc_order': 118,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#f98e03; '
#                                                                              'font-size: '
#                                                                              '10pt; '
#                                                                              'width: '
#                                                                              '300px;'},
#                                                           '_doc_order': 121,
#                                                           'tag': 'span',
#                                                           'text': 'CONTACT'}],
#                                             'tag': 'li'}],
#                               'tag': 'div'}],
#                 'tag': 'div'},
#                {'_doc_order': 141,
#                 'children': [{'_doc_order': 146,
#                               'children': [{'_doc_order': 147,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#1a127f; '
#                                                                              'font-size: '
#                                                                              '16pt; '
#                                                                              'width: '
#                                                                              '620px;'},
#                                                           '_doc_order': 149,
#                                                           'tag': 'span',
#                                                           'text': 'DECEMBER '
#                                                                   '2018'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 150,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'WEDNESDAY 19TH'},
#                                            {'_doc_order': 151,
#                                             'children': [{'_doc_order': 153,
#                                                           'children': [{'_attr': {'href': '/artists/james-yorkston'},
#                                                                         '_doc_order': 155,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'James '
#                                                                                 'Yorkston'},
#                                                                        {'_attr': {'href': '/artists/james-yorkston'},
#                                                                         '_doc_order': 157,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'James '
#                                                                                 'Yorkston'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35403604-james-yorkston-at-lexington?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 160,
#                                                                         'tag': 'a',
#                                                                         'text': 'The '
#                                                                                 'Lexington, '
#                                                                                 'London, '
#                                                                                 'UK'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 162,
#                                             'children': [{'_doc_order': 164,
#                                                           'children': [{'_attr': {'href': '/artists/protomartyr'},
#                                                                         '_doc_order': 166,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Protomartyr'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35305449-protomartyr-at-regent-theater?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 168,
#                                                                         'tag': 'a',
#                                                                         'text': 'Regent '
#                                                                                 'Theater, '
#                                                                                 'Los '
#                                                                                 'Angeles, '
#                                                                                 'CA, '
#                                                                                 'US'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 170,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'FRIDAY 21ST'},
#                                            {'_doc_order': 171,
#                                             'children': [{'_doc_order': 173,
#                                                           'children': [{'_attr': {'href': '/artists/patrick-watson'},
#                                                                         '_doc_order': 175,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Patrick '
#                                                                                 'Watson'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35037964-rufus-wainwright-at-mtelus?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 177,
#                                                                         'tag': 'a',
#                                                                         'text': 'Mtelus, '
#                                                                                 'Montreal, '
#                                                                                 'QC, '
#                                                                                 'Canada'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 179,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'SATURDAY 22ND'},
#                                            {'_doc_order': 180,
#                                             'children': [{'_doc_order': 182,
#                                                           'children': [{'_attr': {'href': '/artists/seamus-fogarty'},
#                                                                         '_doc_order': 184,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Seamus '
#                                                                                 'Fogarty'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35197054-lost-brothers-at-town-hall-theatre?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 186,
#                                                                         'tag': 'a',
#                                                                         'text': 'Town '
#                                                                                 'Hall '
#                                                                                 'Theatre, '
#                                                                                 'Westport, '
#                                                                                 'Ireland'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 188,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'FRIDAY 28TH - MONDAY '
#                                                     '31ST'},
#                                            {'_doc_order': 189,
#                                             'children': [{'_doc_order': 191,
#                                                           'children': [{'_attr': {'href': '/artists/bob-moses'},
#                                                                         '_doc_order': 193,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Bob '
#                                                                                 'Moses'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/festivals/1141053-lost-paradise/id/35231969-lost-paradise-2018?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 195,
#                                                                         'tag': 'a',
#                                                                         'text': 'Glenworth '
#                                                                                 'Valley, '
#                                                                                 'Sydney, '
#                                                                                 'NSW, '
#                                                                                 'Australia'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 197,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'FRIDAY 28TH'},
#                                            {'_doc_order': 198,
#                                             'children': [{'_doc_order': 200,
#                                                           'children': [{'_attr': {'href': '/artists/bob-moses'},
#                                                                         '_doc_order': 202,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Bob '
#                                                                                 'Moses'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/festivals/2663344-rhythm-and-vine/id/35548764-rhythm-and-vine-2018?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 204,
#                                                                         'tag': 'a',
#                                                                         'text': 'Rhythm '
#                                                                                 'and '
#                                                                                 'Vine, '
#                                                                                 'Gisborne, '
#                                                                                 'New '
#                                                                                 'Zealand'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 206,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'MONDAY 31ST'},
#                                            {'_doc_order': 207,
#                                             'children': [{'_doc_order': 209,
#                                                           'children': [{'_attr': {'href': '/artists/franz-ferdinand'},
#                                                                         '_doc_order': 211,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Franz '
#                                                                                 'Ferdinand'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35188449-franz-ferdinand-at-unknown-venue?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 213,
#                                                                         'tag': 'a',
#                                                                         'text': ', '
#                                                                                 'Edinburgh, '
#                                                                                 'UK'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 215,
#                                             'children': [{'_doc_order': 217,
#                                                           'children': [{'_attr': {'href': '/artists/george-fitzgerald'},
#                                                                         '_doc_order': 219,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'George '
#                                                                                 'FitzGerald'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/concerts/35941389-mr-scruff-at-liquid-room?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 221,
#                                                                         'tag': 'a',
#                                                                         'text': 'The '
#                                                                                 'Liquid '
#                                                                                 'Room, '
#                                                                                 'Edinburgh, '
#                                                                                 'UK'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 223,
#                                             'children': [{'_attr': {'style': 'font-family: '
#                                                                              'DINWeb-Black, '
#                                                                              'sans-serif; '
#                                                                              'font-weight: '
#                                                                              'normal; '
#                                                                              'letter-spacing:0.2px; '
#                                                                              'font-smooth: '
#                                                                              'always; '
#                                                                              'line-height: '
#                                                                              '20px; '
#                                                                              'color: '
#                                                                              '#1a127f; '
#                                                                              'font-size: '
#                                                                              '16pt; '
#                                                                              'width: '
#                                                                              '620px;'},
#                                                           '_doc_order': 225,
#                                                           'tag': 'span',
#                                                           'text': 'JANUARY '
#                                                                   '2019'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 226,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
# ...
#                                                           'children': [{'_attr': {'href': '/artists/superorganism'},
#                                                                         '_doc_order': 1883,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Superorganism'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/festivals/608-sziget/id/35321799-sziget-festival-2019?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 1885,
#                                                                         'tag': 'a',
#                                                                         'text': 'Sziget '
#                                                                                 'Festival, '
#                                                                                 'Budapest, '
#                                                                                 'Hungary'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'},
#                                            {'_doc_order': 1887,
#                                             'tag': 'li.greybg.greyborderbottom.margin10bottom.margin5top.pad5',
#                                             'text': 'FRIDAY 9TH - SATURDAY '
#                                                     '10TH'},
#                                            {'_doc_order': 1888,
#                                             'children': [{'_doc_order': 1890,
#                                                           'children': [{'_attr': {'href': '/artists/superorganism'},
#                                                                         '_doc_order': 1892,
#                                                                         'tag': 'a.upperh4',
#                                                                         'text': 'Superorganism'},
#                                                                        {'_attr': {'href': 'http://www.songkick.com/festivals/123611-grape/id/36292004-grape-festival-2019?utm_source=6513&utm_medium=partner',
#                                                                                   'target': '_blank'},
#                                                                         '_doc_order': 1894,
#                                                                         'tag': 'a',
#                                                                         'text': 'Piešťany '
#                                                                                 'Airport '
#                                                                                 '/ '
#                                                                                 'Letisko '
#                                                                                 'Piešťany, '
#                                                                                 'Piestany, '
#                                                                                 'Slovakia'}],
#                                                           'tag': 'li.floatLeft.liveLeft.margin10bottom'}],
#                                             'tag': 'li'}],
#                               'tag': 'ul.noListStyle'},
#                              {'_attr': {'id': 'rightPanel'},
#                               '_doc_order': 1897,
#                               'children': [{'_attr': {'href': '#live_December_2018'},
#                                             '_doc_order': 1903,
#                                             'tag': 'a',
#                                             'text': 'December 2018'},
#                                            {'_attr': {'href': '#live_January_2019'},
#                                             '_doc_order': 1906,
#                                             'tag': 'a',
#                                             'text': 'January 2019'},
#                                            {'_attr': {'href': '#live_February_2019'},
#                                             '_doc_order': 1909,
#                                             'tag': 'a',
#                                             'text': 'February 2019'},
#                                            {'_attr': {'href': '#live_March_2019'},
#                                             '_doc_order': 1912,
#                                             'tag': 'a',
#                                             'text': 'March 2019'},
#                                            {'_attr': {'href': '#live_April_2019'},
#                                             '_doc_order': 1915,
#                                             'tag': 'a',
#                                             'text': 'April 2019'},
#                                            {'_attr': {'href': '#live_May_2019'},
#                                             '_doc_order': 1918,
#                                             'tag': 'a',
#                                             'text': 'May 2019'},
#                                            {'_attr': {'href': '#live_June_2019'},
#                                             '_doc_order': 1921,
#                                             'tag': 'a',
#                                             'text': 'June 2019'},
#                                            {'_attr': {'href': '#live_July_2019'},
#                                             '_doc_order': 1924,
#                                             'tag': 'a',
#                                             'text': 'July 2019'},
#                                            {'_attr': {'href': '#live_August_2019'},
#                                             '_doc_order': 1927,
#                                             'tag': 'a',
#                                             'text': 'August 2019'},
#                                            {'_attr': {'value': '/live/'},
#                                             '_doc_order': 1931,
#                                             'tag': 'option',
#                                             'text': 'All Artists'},
#                                            {'_attr': {'value': ''},
#                                             '_doc_order': 1932,
#                                             'tag': 'option',
#                                             'text': '-'},
#                                            {'_attr': {'value': '/live/alexis-taylor'},
#                                             '_doc_order': 1933,
#                                             'tag': 'option',
#                                             'text': 'Alexis Taylor'},
#                                            {'_attr': {'value': '/live/anna-calvi'},
#                                             '_doc_order': 1934,
#                                             'tag': 'option',
#                                             'text': 'Anna Calvi'},
#                                            {'_attr': {'value': '/live/arctic-monkeys'},
#                                             '_doc_order': 1935,
#                                             'tag': 'option',
#                                             'text': 'Arctic Monkeys'},
#                                            {'_attr': {'value': '/live/blood-orange'},
#                                             '_doc_order': 1936,
#                                             'tag': 'option',
#                                             'text': 'Blood Orange'},
#                                            {'_attr': {'value': '/live/bob-moses'},
#                                             '_doc_order': 1937,
#                                             'tag': 'option',
#                                             'text': 'Bob Moses'},
#                                            {'_attr': {'value': '/live/dan-deacon'},
#                                             '_doc_order': 1938,
#                                             'tag': 'option',
#                                             'text': 'Dan Deacon'},
#                                            {'_attr': {'value': '/live/eugene-kelly'},
#                                             '_doc_order': 1939,
#                                             'tag': 'option',
#                                             'text': 'Eugene Kelly'},
#                                            {'_attr': {'value': '/live/franz-ferdinand'},
#                                             '_doc_order': 1940,
#                                             'tag': 'option',
#                                             'text': 'Franz Ferdinand'},
#                                            {'_attr': {'value': '/live/george-fitzgerald'},
#                                             '_doc_order': 1941,
#                                             'tag': 'option',
#                                             'text': 'George FitzGerald'},
#                                            {'_attr': {'value': '/live/georgia'},
#                                             '_doc_order': 1942,
#                                             'tag': 'option',
#                                             'text': 'Georgia'},
#                                            {'_attr': {'value': '/live/hot-chip'},
#                                             '_doc_order': 1943,
#                                             'tag': 'option',
#                                             'text': 'Hot Chip'},
#                                            {'_attr': {'value': '/live/james-yorkston'},
#                                             '_doc_order': 1944,
#                                             'tag': 'option',
#                                             'text': 'James Yorkston'},
#                                            {'_attr': {'value': '/live/jon-hopkins'},
#                                             '_doc_order': 1945,
#                                             'tag': 'option',
#                                             'text': 'Jon Hopkins'},
#                                            {'_attr': {'value': '/live/julia-holter'},
#                                             '_doc_order': 1946,
#                                             'tag': 'option',
#                                             'text': 'Julia Holter'},
#                                            {'_attr': {'value': '/live/panda-bear'},
#                                             '_doc_order': 1947,
#                                             'tag': 'option',
#                                             'text': 'Panda Bear'},
#                                            {'_attr': {'value': '/live/patrick-watson'},
#                                             '_doc_order': 1948,
#                                             'tag': 'option',
#                                             'text': 'Patrick Watson'},
#                                            {'_attr': {'value': '/live/protomartyr'},
#                                             '_doc_order': 1949,
#                                             'tag': 'option',
#                                             'text': 'Protomartyr'},
#                                            {'_attr': {'value': '/live/real-estate'},
#                                             '_doc_order': 1950,
#                                             'tag': 'option',
#                                             'text': 'Real Estate'},
#                                            {'_attr': {'value': '/live/seamus-fogarty'},
#                                             '_doc_order': 1951,
#                                             'tag': 'option',
#                                             'text': 'Seamus Fogarty'},
#                                            {'_attr': {'value': '/live/shirley-collins'},
#                                             '_doc_order': 1952,
#                                             'tag': 'option',
#                                             'text': 'Shirley Collins'},
#                                            {'_attr': {'value': '/live/stephen-malkmus-and-the-jicks'},
#                                             '_doc_order': 1953,
#                                             'tag': 'option',
#                                             'text': 'Stephen Malkmus and The '
#                                                     'Jicks'},
#                                            {'_attr': {'value': '/live/steve-mason'},
#                                             '_doc_order': 1954,
#                                             'tag': 'option',
#                                             'text': 'Steve Mason'},
#                                            {'_attr': {'value': '/live/superorganism'},
#                                             '_doc_order': 1955,
#                                             'tag': 'option',
#                                             'text': 'Superorganism'},
#                                            {'_attr': {'value': '/live/villagers'},
#                                             '_doc_order': 1956,
#                                             'tag': 'option',
#                                             'text': 'Villagers'},
#                                            {'_attr': {'value': '/live/yorkstonthornekhan'},
#                                             '_doc_order': 1957,
#                                             'tag': 'option',
#                                             'text': 'Yorkston/Thorne/Khan'}],
#                               'tag': 'div.singleCol',
#                               'text': ['Near me (FR)', 'Worldwide']}],
#                 'tag': 'div.main'},
#                {'_attr': {'id': 'footer'},
#                 '_doc_order': 1969,
#                 'children': [{'_attr': {'href': 'http://www.infinitespark.com'},
#                               '_doc_order': 1972,
#                               'tag': 'a',
#                               'text': 'Infinitespark'},
#                              {'_attr': {'href': '/contact/',
#                                         'title': 'Contact'},
#                               '_doc_order': 1973,
#                               'tag': 'a',
#                               'text': 'Contact'},
#                              {'_attr': {'href': 'https://www.dominomart.com/newsletters/subscribe/martnewsletter',
#                                         'title': 'Newsletters'},
#                               '_doc_order': 1974,
#                               'tag': 'a',
#                               'text': 'Newsletters'},
#                              {'_attr': {'href': '/policies/about/',
#                                         'title': 'About Domino'},
#                               '_doc_order': 1975,
#                               'tag': 'a',
#                               'text': 'About Domino'},
#                              {'_attr': {'href': '/policies/privacy/',
#                                         'title': 'Privacy policy'},
#                               '_doc_order': 1976,
#                               'tag': 'a',
#                               'text': 'Privacy policy'},
#                              {'_attr': {'href': '/newsfeeds/',
#                                         'title': 'RSS feeds'},
#                               '_doc_order': 1977,
#                               'tag': 'a',
#                               'text': 'RSS feeds'},
#                              {'_attr': {'href': '#top_bar'},
#                               '_doc_order': 1978,
#                               'tag': 'a',
#                               'text': 'Back to top'}],
#                 'tag': 'div'}],
#   'tag': 'body'}]

# %% [markdown]
# The output data seems to present all the data we'd need for something like PyVideo.org.
#
# Let's just save for further processing.

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('pydata-berlin-2015.speakers.json', 'w') as fp:
    json.dump(output, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %% [markdown]
# ## Is there a way to automatically chose clusters?
#
# Spectral clustering does not always give the "best" results. It may be due to the similarity function, or some other parameters, I don't know yet really.
#
# Below is a just to see if hierarchical clustering of tagpaths would do a better job.

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter

import numpy as np

tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([237, 156, 236, 235, 245, 241, 147, 215, 231, 137, 229, 234, 167,
#        233, 126, 232, 227, 228, 230, 145, 190, 244, 193, 243, 242, 141,
#        214, 217, 212, 194, 218, 211, 186, 219, 209, 220, 160, 195, 124,
#        189, 221, 201, 222, 142, 196, 185, 223, 208, 224,  97, 192, 225,
#        210, 226, 110, 148, 216, 176, 107, 104, 213, 182, 240, 120, 136,
#        199, 173, 135, 207, 150, 127, 200,  94, 203, 191, 204, 171, 198,
#        205, 184, 164, 169, 206, 105,  99, 202,  92, 100,  96, 197, 116,
#        172, 109, 151, 179, 188, 187, 183,  91,  93, 163, 149, 159, 175,
#        181,  87, 180, 146,  89,  67, 165, 106, 177, 162, 178, 166, 123,
#        174, 102, 158,  86, 238,  85,  98, 117, 170, 138,  84,  73, 168,
#        132,  83,  95, 118, 103,  81, 112, 239, 161,  82,  80,  68,  79,
#        115,  39, 157, 140, 129, 154,  90, 155,  57,  77,  52,  44, 143,
#        139,  49, 131, 153,  58,  48, 101,  42, 152,  51,  75, 114,  74,
#         45,  36, 122, 121,  50, 111,  78,  69,  46,  72,  41, 144, 113,
#         20,  71,  24, 108,  40,  76,  88, 119,  43,  37,  35,  47,  21,
#         28,  70,  53,  34,  33,  38, 128, 133,  60,  54,  63,  59,  19,
#        134,  17,  55,  16,  66,  22,  25, 130,  56,  10,  65,  18,  27,
#         64,  23,  31,  61,  26,  32,  13,  15,   9,   8,   7,  29,   4,
#        125,  11,  12,  62,   3,  30,  14,   6,   5,   2,   1,   0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                , leaf_font_size=8
               )
