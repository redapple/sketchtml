# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Fist, get the HTML

# %%
import requests
#page = requests.get('http://www.dominorecordco.com/live/')
#page_content = page.text
page_content = open('samples/toutpartout.be.snippet.shows_search.php.html').read()

# %% [markdown]
# We can list the repeating tagpaths, with or without classes or HTML IDs:

# %%
from collections import Counter
from sketchtml.repeats import TagPathClustering


clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False,
                               ignore_classes=('last-in-line',),
                               text_only=False
                              )
clustering._build_tagpaths()

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 0:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# ( 45) /html/body/div
# ( 43) /html/body/div/div.hr_large_soft
# ( 43) /html/body/div/br
# ( 43) /html/body/div/h3
# ( 43) /html/body/div/h3/a
# ( 43) /html/body/div/a
# (  8) /html/body/div/span.colored_black
# (  2) /html/body/div.hr_large
# (  2) /html/body/div/span.colored
# (  1) /html
# (  1) /html/body
# (  1) /html/body/h2
# (  1) /html/body/h2/span.colored

# %% [markdown]
# ## Clustering of tagpaths
#
# Perform spectral clustering using the methom from ["Extracting Data Records from the Web Using Tag Path Clustering", 2009](http://www2009.wwwconference.org/proceedings/pdf/p981.pdf).
#
# > Miao, Gengxin & Tatemura, Junichi & Hsiung, Wang-Pin & Sawires, Arsany & Moser, Louise. (2009).
# > **Extracting data records from the Web using tag path clustering**. ACM WWW. 981-990. 10.1145/1526709.1526841.

# %%
clusters = clustering.clusters()

# %%
sorted(set(clustering.tagpaths))
# Out:
# ['/html',
#  '/html/body',
#  '/html/body/div',
#  '/html/body/div.hr_large',
#  '/html/body/div/a',
#  '/html/body/div/br',
#  '/html/body/div/div.hr_large_soft',
#  '/html/body/div/h3',
#  '/html/body/div/h3/a',
#  '/html/body/div/span.colored',
#  '/html/body/div/span.colored_black',
#  '/html/body/h2',
#  '/html/body/h2/span.colored']

# %% [markdown]
# ## Plotting tagpaths "signals" can help chosing better `with_classes`, `with_ids` parameters

# %%
clustering.simhelper.plot_signals()

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body/div', '/html/body/div.hr_large'],
#              1: ['/html/body/div/span.colored'],
#              2: ['/html/body/div/span.colored_black'],
#              3: ['/html/body/div/div.hr_large_soft'],
#              4: ['/html/body/div/h3'],
#              5: ['/html/body/div/br'],
#              6: ['/html/body/div/h3/a'],
#              7: ['/html/body/div/a']})

# %% [markdown]
# ## Let's build a trie to reconstruct the layout from a tagpath list (from one or more clusters or a chosen subset of tagpaths)

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
_node_repr = clustering._node_repr
# This if borrowed from https://towardsdatascience.com/implementing-a-trie-data-structure-in-python-in-less-than-100-lines-of-code-a877ea23c1a1

class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %% [markdown]
# To help chose the clusters we need, we can print out some of the text data for each tagpath in each cluster.

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 0:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('.//text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)[:100]
                if t or attribs:
                #if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass
# Out:
# ---- Cluster #0 ----
# ---
# /html/body/div
# (7, '2018 2019', {'style': 'margin-bottom: 4px; font-size: 14px;'})
# (10, 'Jan Feb Mar Apr May Jun Jul Aug', {})
# (19, '05.01.2019 And they spoke in Anthems Mixmas @ De Singel - \n\t\t\t\t\tAntwerp', {})
# (25, '05.01.2019 Condor Gruppe Merleyn - \n\t\t\t\t\tNijmegen', {})
# (31, '10.01.2019 BeraadGeslagen De Roma - \n\t\t\t\t\tAntwerpen', {})
# (37, '11.01.2019 MDC III 4AD - \n\t\t\t\t\tDiksmuide', {})
# (43, '11.01.2019 Krakow Loves Adana Hudson Bar - \n\t\t\t\t\tUlm', {})
# (49, '12.01.2019 Krakow Loves Adana Innen: Welt Festival - \n\t\t\t\t\tMunich', {})
# (55, '12.01.2019 Dijf Sanders Brussels Jazz Festival @ Flagey - \n\t\t\t\t\tBrussels', {})
# (61, '14.01.2019 Whispering Sons Transformer @ Muziekgieterij - \n\t\t\t\t\tMaastricht', {})
#
# ---
# /html/body/div.hr_large
# (4, '', {'style': 'margin-top:0px;'})
#
# ---- Cluster #1 ----
# ---
# /html/body/div/span.colored
# (9, '2019', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; ', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019');"})
# (11, 'Jan', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; ', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=01');"})
#
# ---- Cluster #2 ----
# ---
# /html/body/div/span.colored_black
# (8, '2018', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2018');"})
# (12, 'Feb', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=02');"})
# (13, 'Mar', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=03');"})
# (14, 'Apr', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=04');"})
# (15, 'May', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=05');"})
# (16, 'Jun', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=06');"})
# (17, 'Jul', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=07');"})
# (18, 'Aug', {'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=08');"})
#
# ---- Cluster #3 ----
# ---- Cluster #4 ----
# ---
# /html/body/div/h3
# (22, 'And they spoke in Anthems', {})
# (28, 'Condor Gruppe', {})
# (34, 'BeraadGeslagen', {})
# (40, 'MDC III', {})
# (46, 'Krakow Loves Adana', {})
# (52, 'Krakow Loves Adana', {})
# (58, 'Dijf Sanders', {})
# (64, 'Whispering Sons', {})
# (70, 'Niklas Paschburg', {})
# (76, 'MDC III', {})
#
# ---- Cluster #5 ----
# ---- Cluster #6 ----
# ---
# /html/body/div/h3/a
# (23, 'And they spoke in Anthems', {'href': '/Artists/And_they_spoke_in_Anthems'})
# (29, 'Condor Gruppe', {'href': '/Artists/Condor_Gruppe'})
# (35, 'BeraadGeslagen', {'href': '/Artists/BeraadGeslagen'})
# (41, 'MDC III', {'href': '/Artists/MDC_III'})
# (47, 'Krakow Loves Adana', {'href': '/Artists/Krakow_Loves_Adana'})
# (53, 'Krakow Loves Adana', {'href': '/Artists/Krakow_Loves_Adana'})
# (59, 'Dijf Sanders', {'href': '/Artists/Dijf_Sanders'})
# (65, 'Whispering Sons', {'href': '/Artists/Whispering_Sons'})
# (71, 'Niklas Paschburg', {'href': '/Artists/Niklas_Paschburg'})
# (77, 'MDC III', {'href': '/Artists/MDC_III'})
#
# ---- Cluster #7 ----
# ---
# /html/body/div/a
# (24, 'Mixmas @ De Singel', {'href': 'https://desingel.be/nl/programma/muziek/mixmass-2019-festival?id=a0J0N00002oiWLJUA2', 'target': '_blank'})
# (30, 'Merleyn', {'href': 'https://www.doornroosje.nl/event/condor-gruppe/', 'target': '_blank'})
# (36, 'De Roma', {'href': 'https://apps.ticketmatic.com/widgets/de_roma/addtickets?event=379352728297', 'target': '_blank'})
# (42, '4AD', {'href': 'http://www.4ad.be/nl/events/mdciii/', 'target': '_blank'})
# (48, 'Hudson Bar', {'href': 'https://www.facebook.com/events/284490252184757/', 'target': '_blank'})
# (54, 'Innen: Welt Festival', {'href': 'https://innen-aussen-raum.net/dabeisein?fbclid=IwAR3tOsOLtoD5NiMcMoK6JzWP-_HCY2pnSYZbT6tydQqq5Gocd8U0YwJHFQs', 'target': '_blank'})
# (60, 'Brussels Jazz Festival @ Flagey', {'href': 'https://www.flagey.be/nl/activity/4995-dijf-sanders', 'target': '_blank'})
# (66, 'Transformer @ Muziekgieterij', {'href': 'https://www.muziekgieterij.nl/', 'target': '_blank'})
# (72, 'Eurosonic', {'href': 'https://esns.nl/nl/', 'target': '_blank'})
# (78, 'Der Aa Theater @ Eurosonic', {'href': 'https://esns.nl/nl/', 'target': '_blank'})

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = []
for i in [0,1,2,3,4,5,6,7]:
    for tp in clusters[i]:
        tps.append(tp)
tps
# Out:
# ['/html/body/div',
#  '/html/body/div.hr_large',
#  '/html/body/div/span.colored',
#  '/html/body/div/span.colored_black',
#  '/html/body/div/div.hr_large_soft',
#  '/html/body/div/h3',
#  '/html/body/div/br',
#  '/html/body/div/h3/a',
#  '/html/body/div/a']

# %%
tps = '''
'''.splitlines()

# %% [markdown]
# Now let's insert them into the trie:

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
for tp in clustering.tagpath_nodes.keys():
    steps = tp.lstrip('/').split('/')
    for nl in nodelists[tp][:]:
        add(root, nl)

# %%
def layout(node, summary=True):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=len(set(node.elements)) if summary else set(node.elements),
        children=[layout(c, summary=summary) for c in node.children],
        word_finished=node.word_finished
    )

# %% [markdown]
# If we check the general structure of the trie, we can notice that some levels only have 1 child.

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1 and not trienode.word_finished:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
layout(root)
# Out:
# {'tag': '/html',
#  'element': 1,
#  'children': [{'tag': 'body',
#    'element': 1,
#    'children': [{'tag': 'div.hr_large',
#      'element': 2,
#      'children': [],
#      'word_finished': True},
#     {'tag': 'h2',
#      'element': 1,
#      'children': [{'tag': 'span.colored',
#        'element': 1,
#        'children': [],
#        'word_finished': True}],
#      'word_finished': True},
#     {'tag': 'div',
#      'element': 45,
#      'children': [{'tag': 'span.colored_black',
#        'element': 8,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'span.colored',
#        'element': 2,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'div.hr_large_soft',
#        'element': 43,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'br', 'element': 43, 'children': [], 'word_finished': True},
#       {'tag': 'h3',
#        'element': 43,
#        'children': [{'tag': 'a',
#          'element': 43,
#          'children': [],
#          'word_finished': True}],
#        'word_finished': True},
#       {'tag': 'a', 'element': 43, 'children': [], 'word_finished': True}],
#      'word_finished': True}],
#    'word_finished': True}],
#  'word_finished': False}

# %% [markdown]
# We can collapse those branches:

# %% [markdown]
# The trie also keeps references to individual HTML nodes, with their document order so that we can re-build the data hierarchy:

# %%
layout(root, summary=False)
# Out:
# {'tag': '/html',
#  'element': {Node(tag='html', doc_order=2, child_position=1, attribs={}, element=<Element html at 0x7f619b5aa408>)},
#  'children': [{'tag': 'body',
#    'element': {Node(tag='body', doc_order=3, child_position=1, attribs={}, element=<Element body at 0x7f619b59af08>)},
#    'children': [{'tag': 'div.hr_large',
#      'element': {Node(tag='div', doc_order=4, child_position=1, attribs={'class': 'hr_large', 'style': 'margin-top:0px;'}, element=<Element div at 0x7f61b23e7508>),
#       Node(tag='div', doc_order=277, child_position=47, attribs={'class': 'hr_large'}, element=<Element div at 0x7f619b52a048>)},
#      'children': [],
#      'word_finished': True},
#     {'tag': 'h2',
#      'element': {Node(tag='h2', doc_order=5, child_position=1, attribs={}, element=<Element h2 at 0x7f619b554888>)},
#      'children': [{'tag': 'span.colored',
#        'element': {Node(tag='span', doc_order=6, child_position=1, attribs={'class': 'colored'}, element=<Element span at 0x7f619b59a108>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': True},
#     {'tag': 'div',
#      'element': {Node(tag='div', doc_order=7, child_position=2, attribs={'style': 'margin-bottom: 4px; font-size: 14px;'}, element=<Element div at 0x7f619b59a788>),
#       Node(tag='div', doc_order=10, child_position=3, attribs={}, element=<Element div at 0x7f61abb9c7c8>),
#       Node(tag='div', doc_order=19, child_position=4, attribs={}, element=<Element div at 0x7f619b59ee08>),
#       Node(tag='div', doc_order=25, child_position=5, attribs={}, element=<Element div at 0x7f619b59e408>),
#       Node(tag='div', doc_order=31, child_position=6, attribs={}, element=<Element div at 0x7f61b6aca288>),
#       Node(tag='div', doc_order=37, child_position=7, attribs={}, element=<Element div at 0x7f619b5116c8>),
#       Node(tag='div', doc_order=43, child_position=8, attribs={}, element=<Element div at 0x7f619b511f48>),
#       Node(tag='div', doc_order=49, child_position=9, attribs={}, element=<Element div at 0x7f619b511808>),
#       Node(tag='div', doc_order=55, child_position=10, attribs={}, element=<Element div at 0x7f619b511508>),
#       Node(tag='div', doc_order=61, child_position=11, attribs={}, element=<Element div at 0x7f619b511908>),
#       Node(tag='div', doc_order=67, child_position=12, attribs={}, element=<Element div at 0x7f619b515708>),
#       Node(tag='div', doc_order=73, child_position=13, attribs={}, element=<Element div at 0x7f619b515dc8>),
#       Node(tag='div', doc_order=79, child_position=14, attribs={}, element=<Element div at 0x7f619b5156c8>),
#       Node(tag='div', doc_order=85, child_position=15, attribs={}, element=<Element div at 0x7f619b515c48>),
#       Node(tag='div', doc_order=91, child_position=16, attribs={}, element=<Element div at 0x7f619b515988>),
#       Node(tag='div', doc_order=97, child_position=17, attribs={}, element=<Element div at 0x7f619b515788>),
#       Node(tag='div', doc_order=103, child_position=18, attribs={}, element=<Element div at 0x7f619b5183c8>),
#       Node(tag='div', doc_order=109, child_position=19, attribs={}, element=<Element div at 0x7f619b5187c8>),
#       Node(tag='div', doc_order=115, child_position=20, attribs={}, element=<Element div at 0x7f619b518048>),
#       Node(tag='div', doc_order=121, child_position=21, attribs={}, element=<Element div at 0x7f619b518748>),
#       Node(tag='div', doc_order=127, child_position=22, attribs={}, element=<Element div at 0x7f619b518f08>),
#       Node(tag='div', doc_order=133, child_position=23, attribs={}, element=<Element div at 0x7f619b518e08>),
#       Node(tag='div', doc_order=139, child_position=24, attribs={}, element=<Element div at 0x7f619b518d48>),
#       Node(tag='div', doc_order=145, child_position=25, attribs={}, element=<Element div at 0x7f619b51e688>),
#       Node(tag='div', doc_order=151, child_position=26, attribs={}, element=<Element div at 0x7f619b51eec8>),
#       Node(tag='div', doc_order=157, child_position=27, attribs={}, element=<Element div at 0x7f619b51e608>),
#       Node(tag='div', doc_order=163, child_position=28, attribs={}, element=<Element div at 0x7f619b51ee08>),
#       Node(tag='div', doc_order=169, child_position=29, attribs={}, element=<Element div at 0x7f619b51eb48>),
#       Node(tag='div', doc_order=175, child_position=30, attribs={}, element=<Element div at 0x7f619b51e808>),
#       Node(tag='div', doc_order=181, child_position=31, attribs={}, element=<Element div at 0x7f619b522548>),
#       Node(tag='div', doc_order=187, child_position=32, attribs={}, element=<Element div at 0x7f619b522bc8>),
#       Node(tag='div', doc_order=193, child_position=33, attribs={}, element=<Element div at 0x7f619b522448>),
#       Node(tag='div', doc_order=199, child_position=34, attribs={}, element=<Element div at 0x7f619b522b08>),
#       Node(tag='div', doc_order=205, child_position=35, attribs={}, element=<Element div at 0x7f619b522688>),
#       Node(tag='div', doc_order=211, child_position=36, attribs={}, element=<Element div at 0x7f619b522648>),
#       Node(tag='div', doc_order=217, child_position=37, attribs={}, element=<Element div at 0x7f619b5260c8>),
#       Node(tag='div', doc_order=223, child_position=38, attribs={}, element=<Element div at 0x7f619b526a88>),
#       Node(tag='div', doc_order=229, child_position=39, attribs={}, element=<Element div at 0x7f619b526248>),
#       Node(tag='div', doc_order=235, child_position=40, attribs={}, element=<Element div at 0x7f619b526b88>),
#       Node(tag='div', doc_order=241, child_position=41, attribs={}, element=<Element div at 0x7f619b526788>),
#       Node(tag='div', doc_order=247, child_position=42, attribs={}, element=<Element div at 0x7f619b526ac8>),
#       Node(tag='div', doc_order=253, child_position=43, attribs={}, element=<Element div at 0x7f619b5a5088>),
#       Node(tag='div', doc_order=259, child_position=44, attribs={}, element=<Element div at 0x7f619b573b48>),
#       Node(tag='div', doc_order=265, child_position=45, attribs={}, element=<Element div at 0x7f619b5a1ec8>),
#       Node(tag='div', doc_order=271, child_position=46, attribs={}, element=<Element div at 0x7f619b52a148>)},
#      'children': [{'tag': 'span.colored_black',
#        'element': {Node(tag='span', doc_order=8, child_position=1, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2018');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59afc8>),
#         Node(tag='span', doc_order=12, child_position=2, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=02');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59e208>),
#         Node(tag='span', doc_order=13, child_position=3, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=03');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59e308>),
#         Node(tag='span', doc_order=14, child_position=4, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=04');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59eb08>),
#         Node(tag='span', doc_order=15, child_position=5, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=05');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59ef08>),
#         Node(tag='span', doc_order=16, child_position=6, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=06');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59e288>),
#         Node(tag='span', doc_order=17, child_position=7, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=07');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59ef48>),
#         Node(tag='span', doc_order=18, child_position=8, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; color: #FFFFFF', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=08');", 'class': 'colored_black'}, element=<Element span at 0x7f619b59ec08>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'span.colored',
#        'element': {Node(tag='span', doc_order=9, child_position=2, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; ', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019');", 'class': 'colored'}, element=<Element span at 0x7f61abb9c9c8>),
#         Node(tag='span', doc_order=11, child_position=1, attribs={'style': 'padding-right:6px; margin-right:3px; cursor:pointer; ', 'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); $('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=01');", 'class': 'colored'}, element=<Element span at 0x7f61abb9ca88>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'div.hr_large_soft',
#        'element': {Node(tag='div', doc_order=20, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b59edc8>),
#         Node(tag='div', doc_order=26, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b59ee88>),
#         Node(tag='div', doc_order=32, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f61b6aca2c8>),
#         Node(tag='div', doc_order=38, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b511888>),
#         Node(tag='div', doc_order=44, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b511308>),
#         Node(tag='div', doc_order=50, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b5119c8>),
#         Node(tag='div', doc_order=56, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b511788>),
#         Node(tag='div', doc_order=62, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b511c48>),
#         Node(tag='div', doc_order=68, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515748>),
#         Node(tag='div', doc_order=74, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515148>),
#         Node(tag='div', doc_order=80, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515808>),
#         Node(tag='div', doc_order=86, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515f88>),
#         Node(tag='div', doc_order=92, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515bc8>),
#         Node(tag='div', doc_order=98, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b515948>),
#         Node(tag='div', doc_order=104, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518448>),
#         Node(tag='div', doc_order=110, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518a08>),
#         Node(tag='div', doc_order=116, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518308>),
#         Node(tag='div', doc_order=122, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518948>),
#         Node(tag='div', doc_order=128, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518288>),
#         Node(tag='div', doc_order=134, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b518208>),
#         Node(tag='div', doc_order=140, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51e088>),
#         Node(tag='div', doc_order=146, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51e708>),
#         Node(tag='div', doc_order=152, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51ef48>),
#         Node(tag='div', doc_order=158, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51e648>),
#         Node(tag='div', doc_order=164, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51ee88>),
#         Node(tag='div', doc_order=170, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51edc8>),
#         Node(tag='div', doc_order=176, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b51eb08>),
#         Node(tag='div', doc_order=182, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b5225c8>),
#         Node(tag='div', doc_order=188, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b522c08>),
#         Node(tag='div', doc_order=194, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b5224c8>),
#         Node(tag='div', doc_order=200, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b522b88>),
#         Node(tag='div', doc_order=206, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b522848>),
#         Node(tag='div', doc_order=212, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b522808>),
#         Node(tag='div', doc_order=218, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526408>),
#         Node(tag='div', doc_order=224, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526c08>),
#         Node(tag='div', doc_order=230, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526348>),
#         Node(tag='div', doc_order=236, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526bc8>),
#         Node(tag='div', doc_order=242, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526b48>),
#         Node(tag='div', doc_order=248, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b526c88>),
#         Node(tag='div', doc_order=254, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b5ae708>),
#         Node(tag='div', doc_order=260, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b573288>),
#         Node(tag='div', doc_order=266, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b5a1208>),
#         Node(tag='div', doc_order=272, child_position=1, attribs={'class': 'hr_large_soft'}, element=<Element div at 0x7f619b52a188>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'br',
#        'element': {Node(tag='br', doc_order=21, child_position=1, attribs={}, element=<Element br at 0x7f619b59e4c8>),
#         Node(tag='br', doc_order=27, child_position=1, attribs={}, element=<Element br at 0x7f619b59ec88>),
#         Node(tag='br', doc_order=33, child_position=1, attribs={}, element=<Element br at 0x7f61b6aca1c8>),
#         Node(tag='br', doc_order=39, child_position=1, attribs={}, element=<Element br at 0x7f619b5118c8>),
#         Node(tag='br', doc_order=45, child_position=1, attribs={}, element=<Element br at 0x7f619b5112c8>),
#         Node(tag='br', doc_order=51, child_position=1, attribs={}, element=<Element br at 0x7f619b511a48>),
#         Node(tag='br', doc_order=57, child_position=1, attribs={}, element=<Element br at 0x7f619b511988>),
#         Node(tag='br', doc_order=63, child_position=1, attribs={}, element=<Element br at 0x7f619b515248>),
#         Node(tag='br', doc_order=69, child_position=1, attribs={}, element=<Element br at 0x7f619b515888>),
#         Node(tag='br', doc_order=75, child_position=1, attribs={}, element=<Element br at 0x7f619b5151c8>),
#         Node(tag='br', doc_order=81, child_position=1, attribs={}, element=<Element br at 0x7f619b515848>),
#         Node(tag='br', doc_order=87, child_position=1, attribs={}, element=<Element br at 0x7f619b515108>),
#         Node(tag='br', doc_order=93, child_position=1, attribs={}, element=<Element br at 0x7f619b515f08>),
#         Node(tag='br', doc_order=99, child_position=1, attribs={}, element=<Element br at 0x7f619b515b88>),
#         Node(tag='br', doc_order=105, child_position=1, attribs={}, element=<Element br at 0x7f619b5185c8>),
#         Node(tag='br', doc_order=111, child_position=1, attribs={}, element=<Element br at 0x7f619b518a48>),
#         Node(tag='br', doc_order=117, child_position=1, attribs={}, element=<Element br at 0x7f619b518348>),
#         Node(tag='br', doc_order=123, child_position=1, attribs={}, element=<Element br at 0x7f619b5189c8>),
#         Node(tag='br', doc_order=129, child_position=1, attribs={}, element=<Element br at 0x7f619b518508>),
#         Node(tag='br', doc_order=135, child_position=1, attribs={}, element=<Element br at 0x7f619b518488>),
#         Node(tag='br', doc_order=141, child_position=1, attribs={}, element=<Element br at 0x7f619b51e2c8>),
#         Node(tag='br', doc_order=147, child_position=1, attribs={}, element=<Element br at 0x7f619b51ea48>),
#         Node(tag='br', doc_order=153, child_position=1, attribs={}, element=<Element br at 0x7f619b51e208>),
#         Node(tag='br', doc_order=159, child_position=1, attribs={}, element=<Element br at 0x7f619b51e908>),
#         Node(tag='br', doc_order=165, child_position=1, attribs={}, element=<Element br at 0x7f619b51e188>),
#         Node(tag='br', doc_order=171, child_position=1, attribs={}, element=<Element br at 0x7f619b51efc8>),
#         Node(tag='br', doc_order=177, child_position=1, attribs={}, element=<Element br at 0x7f619b51ed48>),
#         Node(tag='br', doc_order=183, child_position=1, attribs={}, element=<Element br at 0x7f619b522788>),
#         Node(tag='br', doc_order=189, child_position=1, attribs={}, element=<Element br at 0x7f619b522e08>),
#         Node(tag='br', doc_order=195, child_position=1, attribs={}, element=<Element br at 0x7f619b5226c8>),
#         Node(tag='br', doc_order=201, child_position=1, attribs={}, element=<Element br at 0x7f619b522d08>),
#         Node(tag='br', doc_order=207, child_position=1, attribs={}, element=<Element br at 0x7f619b522ac8>),
#         Node(tag='br', doc_order=213, child_position=1, attribs={}, element=<Element br at 0x7f619b522a48>),
#         Node(tag='br', doc_order=219, child_position=1, attribs={}, element=<Element br at 0x7f619b5264c8>),
#         Node(tag='br', doc_order=225, child_position=1, attribs={}, element=<Element br at 0x7f619b526c48>),
#         Node(tag='br', doc_order=231, child_position=1, attribs={}, element=<Element br at 0x7f619b526608>),
#         Node(tag='br', doc_order=237, child_position=1, attribs={}, element=<Element br at 0x7f619b526d48>),
#         Node(tag='br', doc_order=243, child_position=1, attribs={}, element=<Element br at 0x7f619b526cc8>),
#         Node(tag='br', doc_order=249, child_position=1, attribs={}, element=<Element br at 0x7f61abb3cbc8>),
#         Node(tag='br', doc_order=255, child_position=1, attribs={}, element=<Element br at 0x7f619b596b08>),
#         Node(tag='br', doc_order=261, child_position=1, attribs={}, element=<Element br at 0x7f619b573148>),
#         Node(tag='br', doc_order=267, child_position=1, attribs={}, element=<Element br at 0x7f619b5a1348>),
#         Node(tag='br', doc_order=273, child_position=1, attribs={}, element=<Element br at 0x7f619b52a408>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'h3',
#        'element': {Node(tag='h3', doc_order=22, child_position=1, attribs={}, element=<Element h3 at 0x7f619b59e2c8>),
#         Node(tag='h3', doc_order=28, child_position=1, attribs={}, element=<Element h3 at 0x7f619b59efc8>),
#         Node(tag='h3', doc_order=34, child_position=1, attribs={}, element=<Element h3 at 0x7f619b511448>),
#         Node(tag='h3', doc_order=40, child_position=1, attribs={}, element=<Element h3 at 0x7f619b511a88>),
#         Node(tag='h3', doc_order=46, child_position=1, attribs={}, element=<Element h3 at 0x7f619b511548>),
#         Node(tag='h3', doc_order=52, child_position=1, attribs={}, element=<Element h3 at 0x7f619b511dc8>),
#         Node(tag='h3', doc_order=58, child_position=1, attribs={}, element=<Element h3 at 0x7f619b511d08>),
#         Node(tag='h3', doc_order=64, child_position=1, attribs={}, element=<Element h3 at 0x7f619b515288>),
#         Node(tag='h3', doc_order=70, child_position=1, attribs={}, element=<Element h3 at 0x7f619b5158c8>),
#         Node(tag='h3', doc_order=76, child_position=1, attribs={}, element=<Element h3 at 0x7f619b515448>),
#         Node(tag='h3', doc_order=82, child_position=1, attribs={}, element=<Element h3 at 0x7f619b5159c8>),
#         Node(tag='h3', doc_order=88, child_position=1, attribs={}, element=<Element h3 at 0x7f619b515388>),
#         Node(tag='h3', doc_order=94, child_position=1, attribs={}, element=<Element h3 at 0x7f619b515048>),
#         Node(tag='h3', doc_order=100, child_position=1, attribs={}, element=<Element h3 at 0x7f619b515e88>),
#         Node(tag='h3', doc_order=106, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518608>),
#         Node(tag='h3', doc_order=112, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518bc8>),
#         Node(tag='h3', doc_order=118, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518548>),
#         Node(tag='h3', doc_order=124, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518b48>),
#         Node(tag='h3', doc_order=130, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518688>),
#         Node(tag='h3', doc_order=136, child_position=1, attribs={}, element=<Element h3 at 0x7f619b518648>),
#         Node(tag='h3', doc_order=142, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51e348>),
#         Node(tag='h3', doc_order=148, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51eac8>),
#         Node(tag='h3', doc_order=154, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51e288>),
#         Node(tag='h3', doc_order=160, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51e9c8>),
#         Node(tag='h3', doc_order=166, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51e408>),
#         Node(tag='h3', doc_order=172, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51e148>),
#         Node(tag='h3', doc_order=178, child_position=1, attribs={}, element=<Element h3 at 0x7f619b51ef88>),
#         Node(tag='h3', doc_order=184, child_position=1, attribs={}, element=<Element h3 at 0x7f619b5227c8>),
#         Node(tag='h3', doc_order=190, child_position=1, attribs={}, element=<Element h3 at 0x7f619b522e48>),
#         Node(tag='h3', doc_order=196, child_position=1, attribs={}, element=<Element h3 at 0x7f619b522748>),
#         Node(tag='h3', doc_order=202, child_position=1, attribs={}, element=<Element h3 at 0x7f619b522d88>),
#         Node(tag='h3', doc_order=208, child_position=1, attribs={}, element=<Element h3 at 0x7f619b522cc8>),
#         Node(tag='h3', doc_order=214, child_position=1, attribs={}, element=<Element h3 at 0x7f619b522c88>),
#         Node(tag='h3', doc_order=220, child_position=1, attribs={}, element=<Element h3 at 0x7f619b526688>),
#         Node(tag='h3', doc_order=226, child_position=1, attribs={}, element=<Element h3 at 0x7f619b526f08>),
#         Node(tag='h3', doc_order=232, child_position=1, attribs={}, element=<Element h3 at 0x7f619b526648>),
#         Node(tag='h3', doc_order=238, child_position=1, attribs={}, element=<Element h3 at 0x7f619b526e48>),
#         Node(tag='h3', doc_order=244, child_position=1, attribs={}, element=<Element h3 at 0x7f619b526108>),
#         Node(tag='h3', doc_order=250, child_position=1, attribs={}, element=<Element h3 at 0x7f61abb16d88>),
#         Node(tag='h3', doc_order=256, child_position=1, attribs={}, element=<Element h3 at 0x7f619b5966c8>),
#         Node(tag='h3', doc_order=262, child_position=1, attribs={}, element=<Element h3 at 0x7f619b573ac8>),
#         Node(tag='h3', doc_order=268, child_position=1, attribs={}, element=<Element h3 at 0x7f619b52a1c8>),
#         Node(tag='h3', doc_order=274, child_position=1, attribs={}, element=<Element h3 at 0x7f619b52a448>)},
#        'children': [{'tag': 'a',
#          'element': {Node(tag='a', doc_order=23, child_position=1, attribs={'href': '/Artists/And_they_spoke_in_Anthems'}, element=<Element a at 0x7f619b59e6c8>),
#           Node(tag='a', doc_order=29, child_position=1, attribs={'href': '/Artists/Condor_Gruppe'}, element=<Element a at 0x7f61b23ef048>),
#           Node(tag='a', doc_order=35, child_position=1, attribs={'href': '/Artists/BeraadGeslagen'}, element=<Element a at 0x7f619b511148>),
#           Node(tag='a', doc_order=41, child_position=1, attribs={'href': '/Artists/MDC_III'}, element=<Element a at 0x7f619b511b08>),
#           Node(tag='a', doc_order=47, child_position=1, attribs={'href': '/Artists/Krakow_Loves_Adana'}, element=<Element a at 0x7f619b511588>),
#           Node(tag='a', doc_order=53, child_position=1, attribs={'href': '/Artists/Krakow_Loves_Adana'}, element=<Element a at 0x7f619b511e48>),
#           Node(tag='a', doc_order=59, child_position=1, attribs={'href': '/Artists/Dijf_Sanders'}, element=<Element a at 0x7f619b511488>),
#           Node(tag='a', doc_order=65, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b515548>),
#           Node(tag='a', doc_order=71, child_position=1, attribs={'href': '/Artists/Niklas_Paschburg'}, element=<Element a at 0x7f619b515b08>),
#           Node(tag='a', doc_order=77, child_position=1, attribs={'href': '/Artists/MDC_III'}, element=<Element a at 0x7f619b515488>),
#           Node(tag='a', doc_order=83, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b515a88>),
#           Node(tag='a', doc_order=89, child_position=1, attribs={'href': '/Artists/Borokov_Borokov'}, element=<Element a at 0x7f619b515648>),
#           Node(tag='a', doc_order=95, child_position=1, attribs={'href': '/Artists/Hilary_Woods'}, element=<Element a at 0x7f619b515308>),
#           Node(tag='a', doc_order=101, child_position=1, attribs={'href': '/Artists/Niklas_Paschburg'}, element=<Element a at 0x7f619b518108>),
#           Node(tag='a', doc_order=107, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b518788>),
#           Node(tag='a', doc_order=113, child_position=1, attribs={'href': '/Artists/Dur_Dur_Band'}, element=<Element a at 0x7f619b518c88>),
#           Node(tag='a', doc_order=119, child_position=1, attribs={'href': '/Artists/Birds_That_Change_Colour'}, element=<Element a at 0x7f619b518588>),
#           Node(tag='a', doc_order=125, child_position=1, attribs={'href': '/Artists/Wardrobe'}, element=<Element a at 0x7f619b518b88>),
#           Node(tag='a', doc_order=131, child_position=1, attribs={'href': '/Artists/Guy_Van_Nueten'}, element=<Element a at 0x7f619b518908>),
#           Node(tag='a', doc_order=137, child_position=1, attribs={'href': '/Artists/Mauro_Pawlowski'}, element=<Element a at 0x7f619b518888>),
#           Node(tag='a', doc_order=143, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b51e508>),
#           Node(tag='a', doc_order=149, child_position=1, attribs={'href': '/Artists/Hi_Hawaii'}, element=<Element a at 0x7f619b51ec08>),
#           Node(tag='a', doc_order=155, child_position=1, attribs={'href': '/Artists/Niklas_Paschburg'}, element=<Element a at 0x7f619b51e448>),
#           Node(tag='a', doc_order=161, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b51eb88>),
#           Node(tag='a', doc_order=167, child_position=1, attribs={'href': '/Artists/Zoot_Woman'}, element=<Element a at 0x7f619b51e5c8>),
#           Node(tag='a', doc_order=173, child_position=1, attribs={'href': '/Artists/MDC_III'}, element=<Element a at 0x7f619b51e3c8>),
#           Node(tag='a', doc_order=179, child_position=1, attribs={'href': '/Artists/Niklas_Paschburg'}, element=<Element a at 0x7f619b522208>),
#           Node(tag='a', doc_order=185, child_position=1, attribs={'href': '/Artists/PILL'}, element=<Element a at 0x7f619b522948>),
#           Node(tag='a', doc_order=191, child_position=1, attribs={'href': '/Artists/Crayon_Sun'}, element=<Element a at 0x7f619b522048>),
#           Node(tag='a', doc_order=197, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b522888>),
#           Node(tag='a', doc_order=203, child_position=1, attribs={'href': '/Artists/Public_Psyche'}, element=<Element a at 0x7f619b522fc8>),
#           Node(tag='a', doc_order=209, child_position=1, attribs={'href': '/Artists/Zoot_Woman'}, element=<Element a at 0x7f619b522f48>),
#           Node(tag='a', doc_order=215, child_position=1, attribs={'href': '/Artists/Borokov_Borokov'}, element=<Element a at 0x7f619b522f08>),
#           Node(tag='a', doc_order=221, child_position=1, attribs={'href': '/Artists/Pascal_Deweze'}, element=<Element a at 0x7f619b5266c8>),
#           Node(tag='a', doc_order=227, child_position=1, attribs={'href': '/Artists/STADT'}, element=<Element a at 0x7f619b526fc8>),
#           Node(tag='a', doc_order=233, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b5268c8>),
#           Node(tag='a', doc_order=239, child_position=1, attribs={'href': '/Artists/Tempers'}, element=<Element a at 0x7f619b526188>),
#           Node(tag='a', doc_order=245, child_position=1, attribs={'href': '/Artists/Tempers'}, element=<Element a at 0x7f619b526508>),
#           Node(tag='a', doc_order=251, child_position=1, attribs={'href': '/Artists/Whispering_Sons'}, element=<Element a at 0x7f619b5a5708>),
#           Node(tag='a', doc_order=257, child_position=1, attribs={'href': '/Artists/Borokov_Borokov'}, element=<Element a at 0x7f619b596c48>),
#           Node(tag='a', doc_order=263, child_position=1, attribs={'href': '/Artists/Tempers'}, element=<Element a at 0x7f619b573a08>),
#           Node(tag='a', doc_order=269, child_position=1, attribs={'href': '/Artists/Peter_Kernel'}, element=<Element a at 0x7f619b52a208>),
#           Node(tag='a', doc_order=275, child_position=1, attribs={'href': '/Artists/Surma'}, element=<Element a at 0x7f619b52a0c8>)},
#          'children': [],
#          'word_finished': True}],
#        'word_finished': True},
#       {'tag': 'a',
#        'element': {Node(tag='a', doc_order=24, child_position=1, attribs={'href': 'https://desingel.be/nl/programma/muziek/mixmass-2019-festival?id=a0J0N00002oiWLJUA2', 'target': '_blank'}, element=<Element a at 0x7f619b59eb48>),
#         Node(tag='a', doc_order=30, child_position=1, attribs={'href': 'https://www.doornroosje.nl/event/condor-gruppe/', 'target': '_blank'}, element=<Element a at 0x7f61b23ef2c8>),
#         Node(tag='a', doc_order=36, child_position=1, attribs={'href': 'https://apps.ticketmatic.com/widgets/de_roma/addtickets?event=379352728297', 'target': '_blank'}, element=<Element a at 0x7f619b511648>),
#         Node(tag='a', doc_order=42, child_position=1, attribs={'href': 'http://www.4ad.be/nl/events/mdciii/', 'target': '_blank'}, element=<Element a at 0x7f619b511ec8>),
#         Node(tag='a', doc_order=48, child_position=1, attribs={'href': 'https://www.facebook.com/events/284490252184757/', 'target': '_blank'}, element=<Element a at 0x7f619b5117c8>),
#         Node(tag='a', doc_order=54, child_position=1, attribs={'href': 'https://innen-aussen-raum.net/dabeisein?fbclid=IwAR3tOsOLtoD5NiMcMoK6JzWP-_HCY2pnSYZbT6tydQqq5Gocd8U0YwJHFQs', 'target': '_blank'}, element=<Element a at 0x7f619b511408>),
#         Node(tag='a', doc_order=60, child_position=1, attribs={'href': 'https://www.flagey.be/nl/activity/4995-dijf-sanders', 'target': '_blank'}, element=<Element a at 0x7f619b511708>),
#         Node(tag='a', doc_order=66, child_position=1, attribs={'href': 'https://www.muziekgieterij.nl/', 'target': '_blank'}, element=<Element a at 0x7f619b515588>),
#         Node(tag='a', doc_order=72, child_position=1, attribs={'href': 'https://esns.nl/nl/', 'target': '_blank'}, element=<Element a at 0x7f619b515d08>),
#         Node(tag='a', doc_order=78, child_position=1, attribs={'href': 'https://esns.nl/nl/', 'target': '_blank'}, element=<Element a at 0x7f619b515688>),
#         Node(tag='a', doc_order=84, child_position=1, attribs={'href': 'https://esns.nl/nl/', 'target': '_blank'}, element=<Element a at 0x7f619b515c08>),
#         Node(tag='a', doc_order=90, child_position=1, attribs={'href': 'https://esns.nl/nl/', 'target': '_blank'}, element=<Element a at 0x7f619b5157c8>),
#         Node(tag='a', doc_order=96, child_position=1, attribs={'href': 'https://esns.nl/', 'target': '_blank'}, element=<Element a at 0x7f619b515608>),
#         Node(tag='a', doc_order=102, child_position=1, attribs={'href': 'https://getaticket.nl/sneek/bestellen/s10209?fbclid=IwAR3Srj_0qit3PxCdfyAiVNbVwqLNmPXWtJcx648T-aocodn6p112cYuVlJo', 'target': '_blank'}, element=<Element a at 0x7f619b5181c8>),
#         Node(tag='a', doc_order=108, child_position=1, attribs={'href': 'https://www.eventim.de/whispering-sons-frankfurt-am-main-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$11008971&jumpIn=yTix&kuid=531235&from=erdetaila', 'target': '_blank'}, element=<Element a at 0x7f619b59e788>),
#         Node(tag='a', doc_order=114, child_position=1, attribs={'href': 'https://www.facebook.com/events/349641412278367/', 'target': '_blank'}, element=<Element a at 0x7f619b518f88>),
#         Node(tag='a', doc_order=120, child_position=1, attribs={'href': 'http://www.muziekcentrumdranouter.be/nl/2018-05-22/birds-change-colour', 'target': '_blank'}, element=<Element a at 0x7f619b5186c8>),
#         Node(tag='a', doc_order=126, child_position=1, attribs={'href': 'https://www.facebook.com/events/1602621396505027/', 'target': '_blank'}, element=<Element a at 0x7f619b518e88>),
#         Node(tag='a', doc_order=132, child_position=1, attribs={'href': 'https://apps.ticketmatic.com/widgets/handelsbeurs/addtickets?event=670909888343#/addtickets', 'target': '_blank'}, element=<Element a at 0x7f619b518b08>),
#         Node(tag='a', doc_order=138, child_position=1, attribs={'href': 'https://www.peer.be/activiteiten/detail/1865/toast-literair-met-mauro-pawlowski', 'target': '_blank'}, element=<Element a at 0x7f619b518a88>),
#         Node(tag='a', doc_order=144, child_position=1, attribs={'href': 'https://slowclub-freiburg.de/das-programm/aktuell/', 'target': '_blank'}, element=<Element a at 0x7f619b51e548>),
#         Node(tag='a', doc_order=150, child_position=1, attribs={'href': 'http://www.budakortrijk.be/en/film', 'target': '_blank'}, element=<Element a at 0x7f619b51ec88>),
#         Node(tag='a', doc_order=156, child_position=1, attribs={'href': 'https://www.tivolivredenburg.nl/agenda/niklas-paschburg-23-01-2019/', 'target': '_blank'}, element=<Element a at 0x7f619b51e4c8>),
#         Node(tag='a', doc_order=162, child_position=1, attribs={'href': 'https://www.facebook.com/events/316966268893596/', 'target': '_blank'}, element=<Element a at 0x7f619b51ebc8>),
#         Node(tag='a', doc_order=168, child_position=1, attribs={'href': 'https://www.rotown.nl/agenda/zoot-woman-1', 'target': '_blank'}, element=<Element a at 0x7f619b51e848>),
#         Node(tag='a', doc_order=174, child_position=1, attribs={'href': 'https://www.nostamusic.be/agenda/mdc-iii-esinam/?fbclid=IwAR0GcuVWfqlr3r0HTSfzaNIHXF1Hf-XuwZovS77voAZxqj6bdcdMOzEsKLQ', 'target': '_blank'}, element=<Element a at 0x7f619b51e588>),
#         Node(tag='a', doc_order=180, child_position=1, attribs={'href': 'https://www.facebook.com/events/486815978396484/', 'target': '_blank'}, element=<Element a at 0x7f619b5222c8>),
#         Node(tag='a', doc_order=186, child_position=1, attribs={'href': 'https://shop.botanique.be/widgets/botanique/addtickets?event=577329291385&l=en', 'target': '_blank'}, element=<Element a at 0x7f619b522988>),
#         Node(tag='a', doc_order=192, child_position=1, attribs={'href': 'https://www.muziekodroom.be/concert/crayon-sun', 'target': '_blank'}, element=<Element a at 0x7f619b5220c8>),
#         Node(tag='a', doc_order=198, child_position=1, attribs={'href': 'https://www.devilsatwork.de/Whispering-Sons-Album-Release-Tour-250119-Hamburg-Hafenklang', 'target': '_blank'}, element=<Element a at 0x7f619b522908>),
#         Node(tag='a', doc_order=204, child_position=1, attribs={'href': 'https://www.facebook.com/events/486945281826757/', 'target': '_blank'}, element=<Element a at 0x7f619b5223c8>),
#         Node(tag='a', doc_order=210, child_position=1, attribs={'href': 'https://www.ticketmaster.nl/event/227461?brand=nl_paradiso&camefrom=ams', 'target': '_blank'}, element=<Element a at 0x7f619b522388>),
#         Node(tag='a', doc_order=216, child_position=1, attribs={'href': 'https://www.facebook.com/events/728709684164856/', 'target': '_blank'}, element=<Element a at 0x7f619b526088>),
#         Node(tag='a', doc_order=222, child_position=1, attribs={'href': 'https://www.facebook.com/events/728709684164856/', 'target': '_blank'}, element=<Element a at 0x7f619b5269c8>),
#         Node(tag='a', doc_order=228, child_position=1, attribs={'href': 'https://www.rauwkost.online/2019/', 'target': '_blank'}, element=<Element a at 0x7f619b526048>),
#         Node(tag='a', doc_order=234, child_position=1, attribs={'href': 'https://www.eventim.de/whispering-sons-leipzig-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$11011173&jumpIn=yTix&kuid=531235&from=erdetaila', 'target': '_blank'}, element=<Element a at 0x7f619b526908>),
#         Node(tag='a', doc_order=240, child_position=1, attribs={'href': 'https://www.facebook.com/events/112633189658815/', 'target': '_blank'}, element=<Element a at 0x7f619b526588>),
#         Node(tag='a', doc_order=246, child_position=1, attribs={'href': 'https://www.tixforgigs.com/site/Pages/Shop/ShowEvent.aspx?ID=27901&fbclid=IwAR3jAVVKVP6HtwxYVNaINljy0iV1okIkOfKgSN7AaHFtG_tseYhJLxJOXb8', 'target': '_blank'}, element=<Element a at 0x7f619b526708>),
#         Node(tag='a', doc_order=252, child_position=1, attribs={'href': 'https://www.eventim.de/whispering-sons-hannover-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$10991446&jumpIn=yTix&kuid=531235&from=erdetaila', 'target': '_blank'}, element=<Element a at 0x7f619b5a5fc8>),
#         Node(tag='a', doc_order=258, child_position=1, attribs={'href': 'https://www.facebook.com/events/317751072283368/', 'target': '_blank'}, element=<Element a at 0x7f619b596f08>),
#         Node(tag='a', doc_order=264, child_position=1, attribs={'href': 'https://www.direct-ticket.de/produkte/596-tickets-tempers-kantine-am-berghain-berlin-am-31-01-2019?fbclid=IwAR3PJQa5rOukA5PjYCtC9QGTOdtz2fptkxxjjbNZtRIublnDDv4qIQimZV8', 'target': '_blank'}, element=<Element a at 0x7f619b573748>),
#         Node(tag='a', doc_order=270, child_position=1, attribs={'href': 'https://www.ment.si/lineup/', 'target': '_blank'}, element=<Element a at 0x7f619b52a508>),
#         Node(tag='a', doc_order=276, child_position=1, attribs={'href': 'https://www.ment.si/lineup/', 'target': '_blank'}, element=<Element a at 0x7f619b52a2c8>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': True}],
#    'word_finished': True}],
#  'word_finished': False}

# %% [markdown]
# ## Re-creating data hierarchy
#
# Below is the most interesting bit: how to re-create a dict/JSON document from repeating tagpaths.
#
# Using the trie, from the root of the tree, we loop over all HTML elements of a trie node, and recursively collect data from its children:

# %%
from collections import defaultdict
from operator import itemgetter
from lxml.html import tostring


def hydrate(node, docorder_min, docorder_max=None, include_html=False):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []

    for i, element in enumerate(elements, start=1):
        
        # filter out elements that are not within the parent document order range
        if not (docorder_min < element.doc_order):
            continue
        if (docorder_max is not None) and (element.doc_order > docorder_max):
            continue
        
        # here's where you extract data from the element
        # 1. node representation including tag and classes can tell us a bit about what it's about
        # 2. document order is purely informational
        # 3. child text nodes usually contain much of the information we want
        # 4. element attributes also can be useful (URL, data-* etc.)
        e = {'tag': _node_repr(element),
             '_doc_order': element.doc_order}
        
        # textual information
        _t = list(filter(bool, [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]))
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        _html = tostring(element.element, encoding='unicode')
        if _html:
            #e['html'] = _html
            pass
            
        _attrib = dict(element.element.attrib)
        if 'class' in _attrib:
            _attrib.pop('class')
        if _attrib:
            e['_attr'] = _attrib
        
        # loop through sub-nodes that are between the current node and the next one
        # Warning: recursivity!
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate(child, _order_min, _order_max)]))
        if children:
            e['children'] = sorted(children, key=itemgetter('_doc_order'))
            #e['children'] = children
        
        # if there's not "valuable" information, might as well skip the element
        if 'children' not in e and not(any(e.get(k) for k in ['text', '_attr'])):
            continue

        output.append(e)
        
    #return sorted(output, key=itemgetter('_doc_order'))
    return output

output = hydrate(root, 0)
pp(output)
# Out:
# [{'_doc_order': 2,
#   'children': [{'_doc_order': 3,
#                 'children': [{'_attr': {'style': 'margin-top:0px;'},
#                               '_doc_order': 4,
#                               'tag': 'div.hr_large'},
#                              {'_doc_order': 5,
#                               'children': [{'_doc_order': 6,
#                                             'tag': 'span.colored',
#                                             'text': 'Upcoming Shows'}],
#                               'tag': 'h2'},
#                              {'_attr': {'style': 'margin-bottom: 4px; '
#                                                  'font-size: 14px;'},
#                               '_doc_order': 7,
#                               'children': [{'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2018');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 8,
#                                             'tag': 'span.colored_black',
#                                             'text': '2018'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '},
#                                             '_doc_order': 9,
#                                             'tag': 'span.colored',
#                                             'text': '2019'}],
#                               'tag': 'div'},
#                              {'_doc_order': 10,
#                               'children': [{'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=01');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '},
#                                             '_doc_order': 11,
#                                             'tag': 'span.colored',
#                                             'text': 'Jan'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=02');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 12,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Feb'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=03');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 13,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Mar'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=04');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 14,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Apr'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=05');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 15,
#                                             'tag': 'span.colored_black',
#                                             'text': 'May'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=06');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 16,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Jun'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=07');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 17,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Jul'},
#                                            {'_attr': {'onclick': "$('#content_with_sidebar').html('<br><br><br><br><center>LOADING...</center>'); "
#                                                                  "$('#content_with_sidebar').load('/snippets/page/snippet.shows_search.php?date_year=2019&date_month=08');",
#                                                       'style': 'padding-right:6px; '
#                                                                'margin-right:3px; '
#                                                                'cursor:pointer; '
#                                                                'color: '
#                                                                '#FFFFFF'},
#                                             '_doc_order': 18,
#                                             'tag': 'span.colored_black',
#                                             'text': 'Aug'}],
#                               'tag': 'div'},
#                              {'_doc_order': 19,
#                               'children': [{'_doc_order': 22,
#                                             'children': [{'_attr': {'href': '/Artists/And_they_spoke_in_Anthems'},
#                                                           '_doc_order': 23,
#                                                           'tag': 'a',
#                                                           'text': 'And they '
#                                                                   'spoke in '
#                                                                   'Anthems'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://desingel.be/nl/programma/muziek/mixmass-2019-festival?id=a0J0N00002oiWLJUA2',
#                                                       'target': '_blank'},
#                                             '_doc_order': 24,
#                                             'tag': 'a',
#                                             'text': 'Mixmas @ De Singel'}],
#                               'tag': 'div',
#                               'text': ['05.01.2019', '- \n\t\t\t\t\tAntwerp']},
#                              {'_doc_order': 25,
#                               'children': [{'_doc_order': 28,
#                                             'children': [{'_attr': {'href': '/Artists/Condor_Gruppe'},
#                                                           '_doc_order': 29,
#                                                           'tag': 'a',
#                                                           'text': 'Condor '
#                                                                   'Gruppe'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.doornroosje.nl/event/condor-gruppe/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 30,
#                                             'tag': 'a',
#                                             'text': 'Merleyn'}],
#                               'tag': 'div',
#                               'text': ['05.01.2019', '- \n\t\t\t\t\tNijmegen']},
#                              {'_doc_order': 31,
#                               'children': [{'_doc_order': 34,
#                                             'children': [{'_attr': {'href': '/Artists/BeraadGeslagen'},
#                                                           '_doc_order': 35,
#                                                           'tag': 'a',
#                                                           'text': 'BeraadGeslagen'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://apps.ticketmatic.com/widgets/de_roma/addtickets?event=379352728297',
#                                                       'target': '_blank'},
#                                             '_doc_order': 36,
#                                             'tag': 'a',
#                                             'text': 'De Roma'}],
#                               'tag': 'div',
#                               'text': ['10.01.2019',
#                                        '- \n\t\t\t\t\tAntwerpen']},
#                              {'_doc_order': 37,
#                               'children': [{'_doc_order': 40,
#                                             'children': [{'_attr': {'href': '/Artists/MDC_III'},
#                                                           '_doc_order': 41,
#                                                           'tag': 'a',
#                                                           'text': 'MDC III'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'http://www.4ad.be/nl/events/mdciii/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 42,
#                                             'tag': 'a',
#                                             'text': '4AD'}],
#                               'tag': 'div',
#                               'text': ['11.01.2019',
#                                        '- \n\t\t\t\t\tDiksmuide']},
#                              {'_doc_order': 43,
#                               'children': [{'_doc_order': 46,
#                                             'children': [{'_attr': {'href': '/Artists/Krakow_Loves_Adana'},
#                                                           '_doc_order': 47,
#                                                           'tag': 'a',
#                                                           'text': 'Krakow '
#                                                                   'Loves '
#                                                                   'Adana'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/284490252184757/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 48,
#                                             'tag': 'a',
#                                             'text': 'Hudson Bar'}],
#                               'tag': 'div',
#                               'text': ['11.01.2019', '- \n\t\t\t\t\tUlm']},
#                              {'_doc_order': 49,
#                               'children': [{'_doc_order': 52,
#                                             'children': [{'_attr': {'href': '/Artists/Krakow_Loves_Adana'},
#                                                           '_doc_order': 53,
#                                                           'tag': 'a',
#                                                           'text': 'Krakow '
#                                                                   'Loves '
#                                                                   'Adana'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://innen-aussen-raum.net/dabeisein?fbclid=IwAR3tOsOLtoD5NiMcMoK6JzWP-_HCY2pnSYZbT6tydQqq5Gocd8U0YwJHFQs',
#                                                       'target': '_blank'},
#                                             '_doc_order': 54,
#                                             'tag': 'a',
#                                             'text': 'Innen: Welt Festival'}],
#                               'tag': 'div',
#                               'text': ['12.01.2019', '- \n\t\t\t\t\tMunich']},
#                              {'_doc_order': 55,
#                               'children': [{'_doc_order': 58,
#                                             'children': [{'_attr': {'href': '/Artists/Dijf_Sanders'},
#                                                           '_doc_order': 59,
#                                                           'tag': 'a',
#                                                           'text': 'Dijf '
#                                                                   'Sanders'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.flagey.be/nl/activity/4995-dijf-sanders',
#                                                       'target': '_blank'},
#                                             '_doc_order': 60,
#                                             'tag': 'a',
#                                             'text': 'Brussels Jazz Festival @ '
#                                                     'Flagey'}],
#                               'tag': 'div',
#                               'text': ['12.01.2019', '- \n\t\t\t\t\tBrussels']},
#                              {'_doc_order': 61,
#                               'children': [{'_doc_order': 64,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 65,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.muziekgieterij.nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 66,
#                                             'tag': 'a',
#                                             'text': 'Transformer @ '
#                                                     'Muziekgieterij'}],
#                               'tag': 'div',
#                               'text': ['14.01.2019',
#                                        '- \n\t\t\t\t\tMaastricht']},
#                              {'_doc_order': 67,
#                               'children': [{'_doc_order': 70,
#                                             'children': [{'_attr': {'href': '/Artists/Niklas_Paschburg'},
#                                                           '_doc_order': 71,
#                                                           'tag': 'a',
#                                                           'text': 'Niklas '
#                                                                   'Paschburg'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://esns.nl/nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 72,
#                                             'tag': 'a',
#                                             'text': 'Eurosonic'}],
#                               'tag': 'div',
#                               'text': ['17.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 73,
#                               'children': [{'_doc_order': 76,
#                                             'children': [{'_attr': {'href': '/Artists/MDC_III'},
#                                                           '_doc_order': 77,
#                                                           'tag': 'a',
#                                                           'text': 'MDC III'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://esns.nl/nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 78,
#                                             'tag': 'a',
#                                             'text': 'Der Aa Theater @ '
#                                                     'Eurosonic'}],
#                               'tag': 'div',
#                               'text': ['18.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 79,
#                               'children': [{'_doc_order': 82,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 83,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://esns.nl/nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 84,
#                                             'tag': 'a',
#                                             'text': 'Eurosonic'}],
#                               'tag': 'div',
#                               'text': ['18.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 85,
#                               'children': [{'_doc_order': 88,
#                                             'children': [{'_attr': {'href': '/Artists/Borokov_Borokov'},
#                                                           '_doc_order': 89,
#                                                           'tag': 'a',
#                                                           'text': 'Borokov '
#                                                                   'Borokov'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://esns.nl/nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 90,
#                                             'tag': 'a',
#                                             'text': 'Eurosonic @ Platform '
#                                                     'Theater'}],
#                               'tag': 'div',
#                               'text': ['18.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 91,
#                               'children': [{'_doc_order': 94,
#                                             'children': [{'_attr': {'href': '/Artists/Hilary_Woods'},
#                                                           '_doc_order': 95,
#                                                           'tag': 'a',
#                                                           'text': 'Hilary '
#                                                                   'Woods'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://esns.nl/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 96,
#                                             'tag': 'a',
#                                             'text': 'Der Aa-kerk @ ESNS'}],
#                               'tag': 'div',
#                               'text': ['18.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 97,
#                               'children': [{'_doc_order': 100,
#                                             'children': [{'_attr': {'href': '/Artists/Niklas_Paschburg'},
#                                                           '_doc_order': 101,
#                                                           'tag': 'a',
#                                                           'text': 'Niklas '
#                                                                   'Paschburg'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://getaticket.nl/sneek/bestellen/s10209?fbclid=IwAR3Srj_0qit3PxCdfyAiVNbVwqLNmPXWtJcx648T-aocodn6p112cYuVlJo',
#                                                       'target': '_blank'},
#                                             '_doc_order': 102,
#                                             'tag': 'a',
#                                             'text': 'Het Bolwerk'}],
#                               'tag': 'div',
#                               'text': ['19.01.2019', '- \n\t\t\t\t\tSneek']},
#                              {'_doc_order': 103,
#                               'children': [{'_doc_order': 106,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 107,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.eventim.de/whispering-sons-frankfurt-am-main-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$11008971&jumpIn=yTix&kuid=531235&from=erdetaila',
#                                                       'target': '_blank'},
#                                             '_doc_order': 108,
#                                             'tag': 'a',
#                                             'text': 'Dass Bett'}],
#                               'tag': 'div',
#                               'text': ['19.01.2019',
#                                        '- \n\t\t\t\t\tFrankfurt']},
#                              {'_doc_order': 109,
#                               'children': [{'_doc_order': 112,
#                                             'children': [{'_attr': {'href': '/Artists/Dur_Dur_Band'},
#                                                           '_doc_order': 113,
#                                                           'tag': 'a',
#                                                           'text': 'Dur Dur '
#                                                                   'Band'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/349641412278367/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 114,
#                                             'tag': 'a',
#                                             'text': "Gilles Peterson's "
#                                                     'Woldwide Awards @ Koko'}],
#                               'tag': 'div',
#                               'text': ['19.01.2019', '- \n\t\t\t\t\tLondon']},
#                              {'_doc_order': 115,
#                               'children': [{'_doc_order': 118,
#                                             'children': [{'_attr': {'href': '/Artists/Birds_That_Change_Colour'},
#                                                           '_doc_order': 119,
#                                                           'tag': 'a',
#                                                           'text': 'Birds That '
#                                                                   'Change '
#                                                                   'Colour'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'http://www.muziekcentrumdranouter.be/nl/2018-05-22/birds-change-colour',
#                                                       'target': '_blank'},
#                                             '_doc_order': 120,
#                                             'tag': 'a',
#                                             'text': 'Dranouter Centrum'}],
#                               'tag': 'div',
#                               'text': ['19.01.2019',
#                                        '- \n\t\t\t\t\tDranouter']},
#                              {'_doc_order': 121,
#                               'children': [{'_doc_order': 124,
#                                             'children': [{'_attr': {'href': '/Artists/Wardrobe'},
#                                                           '_doc_order': 125,
#                                                           'tag': 'a',
#                                                           'text': 'Wardrobe'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/1602621396505027/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 126,
#                                             'tag': 'a',
#                                             'text': 'Eurosonic'}],
#                               'tag': 'div',
#                               'text': ['19.01.2019',
#                                        '- \n\t\t\t\t\tGroningen']},
#                              {'_doc_order': 127,
#                               'children': [{'_doc_order': 130,
#                                             'children': [{'_attr': {'href': '/Artists/Guy_Van_Nueten'},
#                                                           '_doc_order': 131,
#                                                           'tag': 'a',
#                                                           'text': 'Guy Van '
#                                                                   'Nueten'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://apps.ticketmatic.com/widgets/handelsbeurs/addtickets?event=670909888343#/addtickets',
#                                                       'target': '_blank'},
#                                             '_doc_order': 132,
#                                             'tag': 'a',
#                                             'text': 'Foyer Matinee @ '
#                                                     'Handelsbeurs'}],
#                               'tag': 'div',
#                               'text': ['20.01.2019', '- \n\t\t\t\t\tGent']},
#                              {'_doc_order': 133,
#                               'children': [{'_doc_order': 136,
#                                             'children': [{'_attr': {'href': '/Artists/Mauro_Pawlowski'},
#                                                           '_doc_order': 137,
#                                                           'tag': 'a',
#                                                           'text': 'Mauro '
#                                                                   'Pawlowski'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.peer.be/activiteiten/detail/1865/toast-literair-met-mauro-pawlowski',
#                                                       'target': '_blank'},
#                                             '_doc_order': 138,
#                                             'tag': 'a',
#                                             'text': "Toast Literair @ 't "
#                                                     'Poorthuis'}],
#                               'tag': 'div',
#                               'text': ['20.01.2019', '- \n\t\t\t\t\tPeer']},
#                              {'_doc_order': 139,
#                               'children': [{'_doc_order': 142,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 143,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://slowclub-freiburg.de/das-programm/aktuell/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 144,
#                                             'tag': 'a',
#                                             'text': 'Slow Club'}],
#                               'tag': 'div',
#                               'text': ['20.01.2019', '- \n\t\t\t\t\tFreiburg']},
#                              {'_doc_order': 145,
#                               'children': [{'_doc_order': 148,
#                                             'children': [{'_attr': {'href': '/Artists/Hi_Hawaii'},
#                                                           '_doc_order': 149,
#                                                           'tag': 'a',
#                                                           'text': 'Hi Hawaii'}],
#                                             'tag': 'h3',
#                                             'text': '+ Live Track Cinema: '
#                                                     "'Songs From The Second "
#                                                     "Floor'"},
#                                            {'_attr': {'href': 'http://www.budakortrijk.be/en/film',
#                                                       'target': '_blank'},
#                                             '_doc_order': 150,
#                                             'tag': 'a',
#                                             'text': 'Budascoop'}],
#                               'tag': 'div',
#                               'text': ['23.01.2019', '- \n\t\t\t\t\tKortrijk']},
#                              {'_doc_order': 151,
#                               'children': [{'_doc_order': 154,
#                                             'children': [{'_attr': {'href': '/Artists/Niklas_Paschburg'},
#                                                           '_doc_order': 155,
#                                                           'tag': 'a',
#                                                           'text': 'Niklas '
#                                                                   'Paschburg'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.tivolivredenburg.nl/agenda/niklas-paschburg-23-01-2019/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 156,
#                                             'tag': 'a',
#                                             'text': 'Tivoli Vredenburg'}],
#                               'tag': 'div',
#                               'text': ['23.01.2019', '- \n\t\t\t\t\tUtrecht']},
#                              {'_doc_order': 157,
#                               'children': [{'_doc_order': 160,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 161,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/316966268893596/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 162,
#                                             'tag': 'a',
#                                             'text': 'Wilhelmina'}],
#                               'tag': 'div',
#                               'text': ['24.01.2019',
#                                        '- \n\t\t\t\t\tEindhoven']},
#                              {'_doc_order': 163,
#                               'children': [{'_doc_order': 166,
#                                             'children': [{'_attr': {'href': '/Artists/Zoot_Woman'},
#                                                           '_doc_order': 167,
#                                                           'tag': 'a',
#                                                           'text': 'Zoot '
#                                                                   'Woman'}],
#                                             'tag': 'h3',
#                                             'text': '+ Simonne Jones'},
#                                            {'_attr': {'href': 'https://www.rotown.nl/agenda/zoot-woman-1',
#                                                       'target': '_blank'},
#                                             '_doc_order': 168,
#                                             'tag': 'a',
#                                             'text': 'Rotown'}],
#                               'tag': 'div',
#                               'text': ['24.01.2019',
#                                        '- \n\t\t\t\t\tRotterdam']},
#                              {'_doc_order': 169,
#                               'children': [{'_doc_order': 172,
#                                             'children': [{'_attr': {'href': '/Artists/MDC_III'},
#                                                           '_doc_order': 173,
#                                                           'tag': 'a',
#                                                           'text': 'MDC III'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.nostamusic.be/agenda/mdc-iii-esinam/?fbclid=IwAR0GcuVWfqlr3r0HTSfzaNIHXF1Hf-XuwZovS77voAZxqj6bdcdMOzEsKLQ',
#                                                       'target': '_blank'},
#                                             '_doc_order': 174,
#                                             'tag': 'a',
#                                             'text': 'Nosta'}],
#                               'tag': 'div',
#                               'text': ['24.01.2019', '- \n\t\t\t\t\tOpwijk']},
#                              {'_doc_order': 175,
#                               'children': [{'_doc_order': 178,
#                                             'children': [{'_attr': {'href': '/Artists/Niklas_Paschburg'},
#                                                           '_doc_order': 179,
#                                                           'tag': 'a',
#                                                           'text': 'Niklas '
#                                                                   'Paschburg'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/486815978396484/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 180,
#                                             'tag': 'a',
#                                             'text': 'Westergasfabriek'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019',
#                                        '- \n\t\t\t\t\tAmsterdam']},
#                              {'_doc_order': 181,
#                               'children': [{'_doc_order': 184,
#                                             'children': [{'_attr': {'href': '/Artists/PILL'},
#                                                           '_doc_order': 185,
#                                                           'tag': 'a',
#                                                           'text': 'PILL'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://shop.botanique.be/widgets/botanique/addtickets?event=577329291385&l=en',
#                                                       'target': '_blank'},
#                                             '_doc_order': 186,
#                                             'tag': 'a',
#                                             'text': 'Botanique'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tBrussels']},
#                              {'_doc_order': 187,
#                               'children': [{'_doc_order': 190,
#                                             'children': [{'_attr': {'href': '/Artists/Crayon_Sun'},
#                                                           '_doc_order': 191,
#                                                           'tag': 'a',
#                                                           'text': 'Crayon '
#                                                                   'Sun'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.muziekodroom.be/concert/crayon-sun',
#                                                       'target': '_blank'},
#                                             '_doc_order': 192,
#                                             'tag': 'a',
#                                             'text': 'Muziekodroom'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tHasselt']},
#                              {'_doc_order': 193,
#                               'children': [{'_doc_order': 196,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 197,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.devilsatwork.de/Whispering-Sons-Album-Release-Tour-250119-Hamburg-Hafenklang',
#                                                       'target': '_blank'},
#                                             '_doc_order': 198,
#                                             'tag': 'a',
#                                             'text': 'Hafenklang'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tHamburg']},
#                              {'_doc_order': 199,
#                               'children': [{'_doc_order': 202,
#                                             'children': [{'_attr': {'href': '/Artists/Public_Psyche'},
#                                                           '_doc_order': 203,
#                                                           'tag': 'a',
#                                                           'text': 'Public '
#                                                                   'Psyche'}],
#                                             'tag': 'h3',
#                                             'text': '+ Peuk'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/486945281826757/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 204,
#                                             'tag': 'a',
#                                             'text': 'Charlatan'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tGent']},
#                              {'_doc_order': 205,
#                               'children': [{'_doc_order': 208,
#                                             'children': [{'_attr': {'href': '/Artists/Zoot_Woman'},
#                                                           '_doc_order': 209,
#                                                           'tag': 'a',
#                                                           'text': 'Zoot '
#                                                                   'Woman'}],
#                                             'tag': 'h3',
#                                             'text': '+ Simonne Jones'},
#                                            {'_attr': {'href': 'https://www.ticketmaster.nl/event/227461?brand=nl_paradiso&camefrom=ams',
#                                                       'target': '_blank'},
#                                             '_doc_order': 210,
#                                             'tag': 'a',
#                                             'text': 'Paradiso'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019',
#                                        '- \n\t\t\t\t\tAmsterdam']},
#                              {'_doc_order': 211,
#                               'children': [{'_doc_order': 214,
#                                             'children': [{'_attr': {'href': '/Artists/Borokov_Borokov'},
#                                                           '_doc_order': 215,
#                                                           'tag': 'a',
#                                                           'text': 'Borokov '
#                                                                   'Borokov'}],
#                                             'tag': 'h3',
#                                             'text': '+ Pascal Deweze'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/728709684164856/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 216,
#                                             'tag': 'a',
#                                             'text': 'Het Bos'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tAntwerp']},
#                              {'_doc_order': 217,
#                               'children': [{'_doc_order': 220,
#                                             'children': [{'_attr': {'href': '/Artists/Pascal_Deweze'},
#                                                           '_doc_order': 221,
#                                                           'tag': 'a',
#                                                           'text': 'Pascal '
#                                                                   'Deweze'}],
#                                             'tag': 'h3',
#                                             'text': '+ Borokov Borokov'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/728709684164856/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 222,
#                                             'tag': 'a',
#                                             'text': 'Het Bos'}],
#                               'tag': 'div',
#                               'text': ['25.01.2019', '- \n\t\t\t\t\tAntwerp']},
#                              {'_doc_order': 223,
#                               'children': [{'_doc_order': 226,
#                                             'children': [{'_attr': {'href': '/Artists/STADT'},
#                                                           '_doc_order': 227,
#                                                           'tag': 'a',
#                                                           'text': 'STADT'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.rauwkost.online/2019/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 228,
#                                             'tag': 'a',
#                                             'text': 'Rauwkost Festival'}],
#                               'tag': 'div',
#                               'text': ['26.01.2019',
#                                        '- \n\t\t\t\t\tDen Bosch']},
#                              {'_doc_order': 229,
#                               'children': [{'_doc_order': 232,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 233,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.eventim.de/whispering-sons-leipzig-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$11011173&jumpIn=yTix&kuid=531235&from=erdetaila',
#                                                       'target': '_blank'},
#                                             '_doc_order': 234,
#                                             'tag': 'a',
#                                             'text': 'Moritzbastei'}],
#                               'tag': 'div',
#                               'text': ['26.01.2019', '- \n\t\t\t\t\tLeipzig']},
#                              {'_doc_order': 235,
#                               'children': [{'_doc_order': 238,
#                                             'children': [{'_attr': {'href': '/Artists/Tempers'},
#                                                           '_doc_order': 239,
#                                                           'tag': 'a',
#                                                           'text': 'Tempers'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/112633189658815/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 240,
#                                             'tag': 'a',
#                                             'text': 'Café Glocksee'}],
#                               'tag': 'div',
#                               'text': ['29.01.2019', '- \n\t\t\t\t\tHannover']},
#                              {'_doc_order': 241,
#                               'children': [{'_doc_order': 244,
#                                             'children': [{'_attr': {'href': '/Artists/Tempers'},
#                                                           '_doc_order': 245,
#                                                           'tag': 'a',
#                                                           'text': 'Tempers'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.tixforgigs.com/site/Pages/Shop/ShowEvent.aspx?ID=27901&fbclid=IwAR3jAVVKVP6HtwxYVNaINljy0iV1okIkOfKgSN7AaHFtG_tseYhJLxJOXb8',
#                                                       'target': '_blank'},
#                                             '_doc_order': 246,
#                                             'tag': 'a',
#                                             'text': 'Hafenklang'}],
#                               'tag': 'div',
#                               'text': ['30.01.2019', '- \n\t\t\t\t\tHamburg']},
#                              {'_doc_order': 247,
#                               'children': [{'_doc_order': 250,
#                                             'children': [{'_attr': {'href': '/Artists/Whispering_Sons'},
#                                                           '_doc_order': 251,
#                                                           'tag': 'a',
#                                                           'text': 'Whispering '
#                                                                   'Sons'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.eventim.de/whispering-sons-hannover-tickets.html?affiliate=EVE&doc=artistPages/tickets&fun=artist&action=tickets&key=2017200$10991446&jumpIn=yTix&kuid=531235&from=erdetaila',
#                                                       'target': '_blank'},
#                                             '_doc_order': 252,
#                                             'tag': 'a',
#                                             'text': 'Lux'}],
#                               'tag': 'div',
#                               'text': ['31.01.2019', '- \n\t\t\t\t\tHannover']},
#                              {'_doc_order': 253,
#                               'children': [{'_doc_order': 256,
#                                             'children': [{'_attr': {'href': '/Artists/Borokov_Borokov'},
#                                                           '_doc_order': 257,
#                                                           'tag': 'a',
#                                                           'text': 'Borokov '
#                                                                   'Borokov'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.facebook.com/events/317751072283368/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 258,
#                                             'tag': 'a',
#                                             'text': 'Volta'}],
#                               'tag': 'div',
#                               'text': ['31.01.2019', '- \n\t\t\t\t\tBrussels']},
#                              {'_doc_order': 259,
#                               'children': [{'_doc_order': 262,
#                                             'children': [{'_attr': {'href': '/Artists/Tempers'},
#                                                           '_doc_order': 263,
#                                                           'tag': 'a',
#                                                           'text': 'Tempers'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.direct-ticket.de/produkte/596-tickets-tempers-kantine-am-berghain-berlin-am-31-01-2019?fbclid=IwAR3PJQa5rOukA5PjYCtC9QGTOdtz2fptkxxjjbNZtRIublnDDv4qIQimZV8',
#                                                       'target': '_blank'},
#                                             '_doc_order': 264,
#                                             'tag': 'a',
#                                             'text': 'Kantine Am Berghain'}],
#                               'tag': 'div',
#                               'text': ['31.01.2019', '- \n\t\t\t\t\tBerlin']},
#                              {'_doc_order': 265,
#                               'children': [{'_doc_order': 268,
#                                             'children': [{'_attr': {'href': '/Artists/Peter_Kernel'},
#                                                           '_doc_order': 269,
#                                                           'tag': 'a',
#                                                           'text': 'Peter '
#                                                                   'Kernel'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.ment.si/lineup/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 270,
#                                             'tag': 'a',
#                                             'text': 'Ment Festival'}],
#                               'tag': 'div',
#                               'text': ['31.01.2019',
#                                        '- \n\t\t\t\t\tLjubljana']},
#                              {'_doc_order': 271,
#                               'children': [{'_doc_order': 274,
#                                             'children': [{'_attr': {'href': '/Artists/Surma'},
#                                                           '_doc_order': 275,
#                                                           'tag': 'a',
#                                                           'text': 'Surma'}],
#                                             'tag': 'h3'},
#                                            {'_attr': {'href': 'https://www.ment.si/lineup/',
#                                                       'target': '_blank'},
#                                             '_doc_order': 276,
#                                             'tag': 'a',
#                                             'text': 'Ment Festival'}],
#                               'tag': 'div',
#                               'text': ['31.01.2019',
#                                        '- \n\t\t\t\t\tLjubljana']}],
#                 'tag': 'body'}],
#   'tag': 'html'}]

# %% [markdown]
# The output data seems to present all the data we'd need for something like PyVideo.org.
#
# Let's just save for further processing.

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('pydata-berlin-2015.speakers.json', 'w') as fp:
    json.dump(output, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %% [markdown]
# ## Is there a way to automatically chose clusters?
#
# Spectral clustering does not always give the "best" results. It may be due to the similarity function, or some other parameters, I don't know yet really.
#
# Below is a just to see if hierarchical clustering of tagpaths would do a better job.

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter

import numpy as np

tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([237, 156, 236, 235, 245, 241, 147, 215, 231, 137, 229, 234, 167,
#        233, 126, 232, 227, 228, 230, 145, 190, 244, 193, 243, 242, 141,
#        214, 217, 212, 194, 218, 211, 186, 219, 209, 220, 160, 195, 124,
#        189, 221, 201, 222, 142, 196, 185, 223, 208, 224,  97, 192, 225,
#        210, 226, 110, 148, 216, 176, 107, 104, 213, 182, 240, 120, 136,
#        199, 173, 135, 207, 150, 127, 200,  94, 203, 191, 204, 171, 198,
#        205, 184, 164, 169, 206, 105,  99, 202,  92, 100,  96, 197, 116,
#        172, 109, 151, 179, 188, 187, 183,  91,  93, 163, 149, 159, 175,
#        181,  87, 180, 146,  89,  67, 165, 106, 177, 162, 178, 166, 123,
#        174, 102, 158,  86, 238,  85,  98, 117, 170, 138,  84,  73, 168,
#        132,  83,  95, 118, 103,  81, 112, 239, 161,  82,  80,  68,  79,
#        115,  39, 157, 140, 129, 154,  90, 155,  57,  77,  52,  44, 143,
#        139,  49, 131, 153,  58,  48, 101,  42, 152,  51,  75, 114,  74,
#         45,  36, 122, 121,  50, 111,  78,  69,  46,  72,  41, 144, 113,
#         20,  71,  24, 108,  40,  76,  88, 119,  43,  37,  35,  47,  21,
#         28,  70,  53,  34,  33,  38, 128, 133,  60,  54,  63,  59,  19,
#        134,  17,  55,  16,  66,  22,  25, 130,  56,  10,  65,  18,  27,
#         64,  23,  31,  61,  26,  32,  13,  15,   9,   8,   7,  29,   4,
#        125,  11,  12,  62,   3,  30,  14,   6,   5,   2,   1,   0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                , leaf_font_size=8
               )
