# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re

import lxml.html
import numpy as np
from sketchtml.repeats import TagPathClustering

# %%
import requests

#page = requests.get('https://pycon.jp/2014/schedule/talks/list/')
#page_content = page.text
page_content = open('samples/PythonBrasil[14].html').read()

# %%
from collections import Counter

clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False)
clustering._build_tagpaths()

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 1:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# (142) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h3.schedule_speaker
# (135) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info
# (135) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name
# (135) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location
# (135) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location/i.material-icons
# (131) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_office
# ( 58) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article
# ( 58) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/h5.schedule_time
# ( 58) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.picture-container
# ( 58) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.picture-container/div.schedule_picture
# ( 58) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100
# ( 37) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.dev.schedule_category
# ( 31) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.data-science.schedule_category
# ( 19) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.pessoas.schedule_category
# ( 19) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.schedule_category.web
# ( 13) /html/head/meta
# ( 13) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule_info
# ( 13) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule_info/h2.schedule_name.w-100
# ( 12) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.devops.schedule_category
# ( 12) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item
# ( 10) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a
# (  7) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div
# (  6) /html/head/link
# (  6) /html/body/nav.header__nav-mobile/ul.nav__items/a.nav__anchor
# (  6) /html/body/nav.header__nav-mobile/ul.nav__items/a.nav__anchor/li.nav__item
# (  6) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content
# (  6) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.day-separator.tab-link
# (  6) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.day-separator.tab-link/span
# (  5) /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content/a.scroll.tab-link
# (  4) /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.nav__item
# (  3) /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.nav__item/a.nav__anchor
# (  3) /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.mdc-menu-anchor.nav__item.toolbar/div.mdc-menu/ul.mdc-list.mdc-menu__items/a.nav__item
# (  3) /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.mdc-menu-anchor.nav__item.toolbar/div.mdc-menu/ul.mdc-list.mdc-menu__items/a.nav__item/li.mdc-list-item
# (  3) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu
# (  3) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item
# (  3) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item/a
# (  3) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item/a/img
# (  2) /html/body/div.content-body/div.app-banners/p
# (  2) /html/body/div.content-body/div.app-banners/div.stores-banners/a
# (  2) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/h4.footer__nav__menu__title
# (  2) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a.scroll
# (  2) /html/body/div.content-body/footer.footer/div.container/div.row/div.col-12.footer-note/p

# %%
clusters = clustering.clusters()
#clusters

# %%
#clustering.simhelper.plot_signals()

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.nav__item',
#                  '/html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.nav__item/a.nav__anchor',
#                  '/html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.mdc-menu-anchor.nav__item.toolbar/div.mdc-menu/ul.mdc-list.mdc-menu__items/a.nav__item',
#                  '/html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.mdc-menu-anchor.nav__item.toolbar/div.mdc-menu/ul.mdc-list.mdc-menu__items/a.nav__item/li.mdc-list-item'],
#              1: ['/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/h5.schedule_time',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.picture-container',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.picture-container/div.schedule_picture',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100'],
#              2: ['/html/body/nav.header__nav-mobile/ul.nav__items/a.nav__anchor',
#                  '/html/body/nav.header__nav-mobile/ul.nav__items/a.nav__anchor/li.nav__item'],
#              3: ['/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/h4.footer__nav__menu__title',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a.scroll'],
#              4: ['/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h3.schedule_speaker',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location/i.material-icons',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_office',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.dev.schedule_category',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.data-science.schedule_category',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.pessoas.schedule_category',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.schedule_category.web',
#                  '/html/head/meta',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.devops.schedule_category',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div',
#                  '/html/head/link',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content/a.scroll.tab-link',
#                  '/html/body/div.content-body/div.app-banners/p',
#                  '/html/body/div.content-body/div.app-banners/div.stores-banners/a',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-12.footer-note/p'],
#              5: ['/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule_info',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule_info/h2.schedule_name.w-100'],
#              6: ['/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.day-separator.tab-link',
#                  '/html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.day-separator.tab-link/span'],
#              7: ['/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item/a',
#                  '/html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-xl-4.offset-lg-1/div.footer__actions/nav.social__nav/ul.social__nav__menu/li.social__nav__menu__item/a/img']})

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1
    
    def __repr__(self):
        return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = [
    #'/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.time',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title/a',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.speaker',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/div.badges',
                 #'/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-posters'
]
for tp in clusters[4]+clusters[6]:
    steps = tp.lstrip('/').split('/')
    #print(len(steps), tp)
    for nl in nodelists[tp][:]:
        #print(len(nl), [(n.element.tag, n.doc_order) for n in nl])
        add(root, nl)
    #print()

# %%
root
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-552c0ba71b10> in <module>
# ----> 1 root
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     255             self.start_displayhook()
#     256             self.write_output_prompt()
# --> 257             format_dict, md_dict = self.compute_format_data(result)
#     258             self.update_user_ns(result)
#     259             self.fill_exec_result(result)
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-10> in __call__(self, obj)
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ~/.virtualenvs/sketchtml/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     695     """A pprint that just redirects to the normal repr function."""
#     696     # Find newlines and replace them with p.break_()
# --> 697     output = repr(obj)
#     698     for idx,output_line in enumerate(output.splitlines()):
#     699         if idx:
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     208         stream.write('[')
#     209         self._format_items(object, stream, indent, allowance + 1,
# --> 210                            context, level)
#     211         stream.write(']')
#     212
#
# /usr/lib/python3.6/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     387             self._format(ent, stream, indent,
#     388                          allowance if last else 1,
# --> 389                          context, level)
#     390
#     391     def _repr(self, object, context, level):
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     208         stream.write('[')
#     209         self._format_items(object, stream, indent, allowance + 1,
# --> 210                            context, level)
#     211         stream.write(']')
#     212
#
# /usr/lib/python3.6/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     387             self._format(ent, stream, indent,
#     388                          allowance if last else 1,
# --> 389                          context, level)
#     390
#     391     def _repr(self, object, context, level):
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     208         stream.write('[')
#     209         self._format_items(object, stream, indent, allowance + 1,
# --> 210                            context, level)
#     211         stream.write(']')
#     212
#
# /usr/lib/python3.6/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     387             self._format(ent, stream, indent,
#     388                          allowance if last else 1,
# --> 389                          context, level)
#     390
#     391     def _repr(self, object, context, level):
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     512         for k, v in items:
#     513             krepr, kreadable, krecur = saferepr(k, context, maxlevels, level)
# --> 514             vrepr, vreadable, vrecur = saferepr(v, context, maxlevels, level)
#     515             append("%s: %s" % (krepr, vrepr))
#     516             readable = readable and kreadable and vreadable
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# /usr/lib/python3.6/pprint.py in pformat(object, indent, width, depth, compact)
#      56     """Format a Python object into a pretty-printed representation."""
#      57     return PrettyPrinter(indent=indent, width=width, depth=depth,
# ---> 58                          compact=compact).pformat(object)
#      59
#      60 def saferepr(object):
#
# /usr/lib/python3.6/pprint.py in pformat(self, object)
#     142     def pformat(self, object):
#     143         sio = _StringIO()
# --> 144         self._format(object, sio, 0, 0, {}, 0)
#     145         return sio.getvalue()
#     146
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     165             if p is not None:
#     166                 context[objid] = 1
# --> 167                 p(self, object, stream, indent, allowance, context, level + 1)
#     168                 del context[objid]
#     169                 return
#
# /usr/lib/python3.6/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     187             items = sorted(object.items(), key=_safe_tuple)
#     188             self._format_dict_items(items, stream, indent, allowance + 1,
# --> 189                                     context, level)
#     190         write('}')
#     191
#
# /usr/lib/python3.6/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     344             self._format(ent, stream, indent + len(rep) + 2,
#     345                          allowance if last else 1,
# --> 346                          context, level)
#     347             if not last:
#     348                 write(delimnl)
#
# /usr/lib/python3.6/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     159             self._readable = False
#     160             return
# --> 161         rep = self._repr(object, context, level)
#     162         max_width = self._width - indent - allowance
#     163         if len(rep) > max_width:
#
# /usr/lib/python3.6/pprint.py in _repr(self, object, context, level)
#     391     def _repr(self, object, context, level):
#     392         repr, readable, recursive = self.format(object, context.copy(),
# --> 393                                                 self._depth, level)
#     394         if not readable:
#     395             self._readable = False
#
# /usr/lib/python3.6/pprint.py in format(self, object, context, maxlevels, level)
#     403         and whether the object represents a recursive construct.
#     404         """
# --> 405         return _safe_repr(object, context, maxlevels, level)
#     406
#     407     def _pprint_default_dict(self, object, stream, indent, allowance, context, level):
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     544         level += 1
#     545         for o in object:
# --> 546             orepr, oreadable, orecur = _safe_repr(o, context, maxlevels, level)
#     547             append(orepr)
#     548             if not oreadable:
#
# /usr/lib/python3.6/pprint.py in _safe_repr(object, context, maxlevels, level)
#     553         return format % ", ".join(components), readable, recursive
#     554
# --> 555     rep = repr(object)
#     556     return rep, (rep and not rep.startswith('<')), False
#     557
#
# <ipython-input-84-ab190f4db7dc> in __repr__(self)
#      23
#      24     def __repr__(self):
# ---> 25         return pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))
#      26
#      27 def add(root, word):
#
# KeyboardInterrupt:

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1 and not trienode.word_finished:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
root
# Out:
# {'char_repr': '/html',
#  'children': [{'char_repr': 'body/div.content-body',
#  'children': [{'char_repr': 'section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div',
#  'children': [{'char_repr': 'article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info',
#  'children': [{'char_repr': 'h3.schedule_speaker', 'children': [], 'elements': 142},
#               {'char_repr': 'h2.schedule_name',
#  'children': [{'char_repr': 'span.dev.schedule_category', 'children': [], 'elements': 37},
#               {'char_repr': 'span.data-science.schedule_category',
#  'children': [],
#  'elements': 31},
#               {'char_repr': 'span.pessoas.schedule_category', 'children': [], 'elements': 19},
#               {'char_repr': 'span.schedule_category.web', 'children': [], 'elements': 19},
#               {'char_repr': 'span.devops.schedule_category', 'children': [], 'elements': 12}],
#  'elements': 135},
#               {'char_repr': 'h4.schedule_location',
#  'children': [{'char_repr': 'i.material-icons', 'children': [], 'elements': 135}],
#  'elements': 135},
#               {'char_repr': 'h4.schedule_office', 'children': [], 'elements': 131}],
#  'elements': 135},
#               {'char_repr': 'div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content',
#  'children': [{'char_repr': 'a.scroll.tab-link', 'children': [], 'elements': 5}],
#  'elements': 6},
#               {'char_repr': 'div.day-separator.tab-link',
#  'children': [{'char_repr': 'span', 'children': [], 'elements': 6}],
#  'elements': 6}],
#  'elements': 7},
#               {'char_repr': 'div.app-banners',
#  'children': [{'char_repr': 'p', 'children': [], 'elements': 2},
#               {'char_repr': 'div.stores-banners/a', 'children': [], 'elements': 2}],
#  'elements': 1},
#               {'char_repr': 'footer.footer/div.container/div.row/div.col-12.footer-note/p',
#  'children': [],
#  'elements': 2}],
#  'elements': 1},
#               {'char_repr': 'head',
#  'children': [{'char_repr': 'meta', 'children': [], 'elements': 13},
#               {'char_repr': 'link', 'children': [], 'elements': 6}],
#  'elements': 1}],
#  'elements': 1}

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('./text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)
                #if t or attribs:
                if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass
# Out:
# ---- Cluster #0 ----
# ---
# /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.mdc-menu-anchor.nav__item.toolbar/div.mdc-menu/ul.mdc-list.mdc-menu__items/a.nav__item/li.mdc-list-item
# (81, 'Quero Patrocinar', {'role': 'menuitem', 'tabindex': '0'})
# (83, 'Mídia Kit do Evento', {'role': 'menuitem', 'tabindex': '0'})
# (85, 'Patrocinadores', {'role': 'menuitem', 'tabindex': '0'})
#
# ---
# /html/body/div.content-body/header.header/nav.header__nav/ul.nav__items/li.nav__item/a.nav__anchor
# (73, 'Evento', {'href': 'https://2018.pythonbrasil.org.br/evento'})
# (75, 'Programação', {'href': 'https://2018.pythonbrasil.org.br/programacao'})
# (87, 'Blog', {'href': 'http://blog.pythonbrasil.org.br/', 'target': '_blank'})
#
# ---- Cluster #1 ----
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/h5.schedule_time
# (130, '08h00', {})
# (149, '12h00', {})
# (156, '14h00', {})
# (178, '08h00', {})
# (190, '09h00', {})
# (202, '12h00', {})
# (209, '14h00', {})
# (224, '08h00', {})
# (231, '08h45', {})
# (242, '09h25', {})
#
# ---- Cluster #3 ----
# ---
# /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/h4.footer__nav__menu__title
# (1398, 'Sobre', {})
# (1420, 'Patrocínio', {})
#
# ---
# /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a
# (1404, 'O Evento', {'href': 'https://2018.pythonbrasil.org.br/evento'})
# (1406, 'Programação', {'href': 'https://2018.pythonbrasil.org.br/programacao'})
# (1408, 'Código de conduta', {'href': 'https://2018.pythonbrasil.org.br/codigo-de-conduta'})
# (1412, 'A Cidade', {'disabled': '', 'href': 'https://2018.pythonbrasil.org.br/programacao/#'})
# (1414, 'O que fazer', {'disabled': '', 'href': 'https://2018.pythonbrasil.org.br/programacao/#'})
# (1416, 'Onde comer', {'disabled': '', 'href': 'https://2018.pythonbrasil.org.br/programacao/#'})
# (1418, 'Transporte', {'disabled': '', 'href': 'https://2018.pythonbrasil.org.br/programacao/#'})
# (1422, 'Quero patrocinar', {'href': 'https://2018.pythonbrasil.org.br/quero-patrocinar'})
# (1424, 'Mídia Kit do evento', {'href': 'https://2018.pythonbrasil.org.br/documents/PythonBR14-MidiaKit.zip'})
# (1426, 'Patrocinadores', {'href': 'https://2018.pythonbrasil.org.br/patrocinadores'})
#
# ---
# /html/body/div.content-body/footer.footer/div.container/div.row/div.col-lg-12.col-md-12.col-sm-12.col-xl-6/nav.footer__nav/ul.footer__nav__menu/li.footer__nav__menu__item/a.scroll
# (1400, 'Local', {'href': 'https://2018.pythonbrasil.org.br/evento#location'})
# (1402, 'Keynotes', {'href': 'https://2018.pythonbrasil.org.br/#keynotes'})
#
# ---- Cluster #4 ----
# ---
# /html/body/div.content-body/div.app-banners/p
# (89, 'Baixe o app da Python Brasil 2018 para acompanhar a grade do evento em tempo real, escolher suas atividades favoritas e receber notificações.', {})
#
# ---
# /html/body/div.content-body/footer.footer/div.container/div.row/div.col-12.footer-note/p
# (1444, 'PythonBrasil is a non-profit volunteer-driven conference for promoting the open-source Python programming language. It is supported by the Brazilian Python Association (APyB) and by the Python Software Foundation (PSF).', {})
# (1445, 'Google Play e o logotipo do Google Play são marcas registradas da Google LLC.', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name
# (135, 'Hands on Análise de Sentimentos', {})
# (142, 'Desenvolvendo Web Crawlers com Scrapy', {})
# (161, '[CANCELADO] Construindo API REST com Django REST Framework', {})
# (168, 'Pensamento Computacional com Python: Uma abordagem de ensino-aprendizagem de programação (4h)', {})
# (183, 'Não é Bruxaria, é Pandas', {})
# (195, 'Django Girls', {})
# (214, 'Estrutura de Dados é ❤', {})
# (236, 'Keynote', {})
# (254, '2 anos de trabalho remoto - o lado bom e os problemas', {})
# (261, 'O casamento sagrado entre o Pipfile, pip e Virtualenv', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.data-science.schedule_category
# (302, 'Data Science', {})
# (335, 'Data Science', {})
# (368, 'Data Science', {})
# (408, 'Data Science', {})
# (420, 'Data Science', {})
# (507, 'Data Science', {})
# (540, 'Data Science', {})
# (697, 'Data Science', {})
# (718, 'Data Science', {})
# (730, 'Data Science', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.dev.schedule_category
# (281, 'Dev', {})
# (347, 'Dev', {})
# (354, 'Dev', {})
# (361, 'Dev', {})
# (387, 'Dev', {})
# (394, 'Dev', {})
# (441, 'Dev', {})
# (453, 'Dev', {})
# (474, 'Dev', {})
# (486, 'Dev', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.devops.schedule_category
# (262, 'DevOPS', {})
# (288, 'DevOPS', {})
# (321, 'DevOPS', {})
# (460, 'DevOPS', {})
# (500, 'DevOPS', {})
# (652, 'DevOPS', {})
# (685, 'DevOPS', {})
# (857, 'DevOPS', {})
# (876, 'DevOPS', {})
# (909, 'DevOPS', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.pessoas.schedule_category
# (255, 'Pessoas', {})
# (314, 'Pessoas', {})
# (328, 'Pessoas', {})
# (467, 'Pessoas', {})
# (519, 'Pessoas', {})
# (526, 'Pessoas', {})
# (552, 'Pessoas', {})
# (559, 'Pessoas', {})
# (631, 'Pessoas', {})
# (638, 'Pessoas', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h2.schedule_name/span.schedule_category.web
# (269, 'Web', {})
# (295, 'Web', {})
# (401, 'Web', {})
# (427, 'Web', {})
# (434, 'Web', {})
# (744, 'Web', {})
# (836, 'Web', {})
# (850, 'Web', {})
# (869, 'Web', {})
# (916, 'Web', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h3.schedule_speaker
# (136, 'Duração: 4h', {})
# (137, 'Betina Manoel da Costa', {})
# (143, 'Duração: 4h', {})
# (144, 'Renne Rocha', {})
# (162, 'Duração: 4h', {})
# (163, 'Werberth Vinícius Souza Gomes', {})
# (169, 'Duração: 4h', {})
# (170, 'Lidiane de Souza Monteiro', {})
# (184, 'Duração: 4h', {})
# (185, 'Fernando Masanori', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location
# (139, 'Sala Ginga', {})
# (146, 'Sala Rapadura', {})
# (165, 'Sala Ginga', {})
# (172, 'Sala Rapadura', {})
# (187, 'Sala Rapadura', {})
# (199, 'Sala Cuscuz', {})
# (218, 'Sala Rapadura', {})
# (239, 'Sala Tapioca', {})
# (258, 'Sala Jerimum', {})
# (265, 'Sala Macaxeira', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_location/i.material-icons
# (140, 'location_on', {})
# (147, 'location_on', {})
# (166, 'location_on', {})
# (173, 'location_on', {})
# (188, 'location_on', {})
# (200, 'location_on', {})
# (219, 'location_on', {})
# (240, 'location_on', {})
# (259, 'location_on', {})
# (266, 'location_on', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info/h4.schedule_office
# (138, 'Desenvolvedora na ThoughtWorks', {})
# (145, 'Desenvolvedor', {})
# (164, 'Co-organizador do Grupo de Usuário de Python de Parnaíba', {})
# (171, 'Desenvolvedora de Software na Fundaj', {})
# (186, 'Docente da FATEC São José dos Campos', {})
# (198, 'Organização internacional para mulheres', {})
# (217, 'Docente da FATEC São José dos Campos', {})
# (238, 'Consultora de Desenvolvimento sênior na Thoughtworks', {})
# (257, 'Desenvolvedor Python e Fotógrafo', {})
# (264, 'Coordenador do GruPy-RN', {})
#
# ---
# /html/body/div.content-body/section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div/div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content/a.scroll.tab-link
# (109, '17', {'href': 'https://2018.pythonbrasil.org.br/programacao/#day17'})
# (111, '18', {'href': 'https://2018.pythonbrasil.org.br/programacao/#day18'})
# (115, '20', {'href': 'https://2018.pythonbrasil.org.br/programacao/#day20'})
# (117, '21', {'href': 'https://2018.pythonbrasil.org.br/programacao/#day21'})
# (119, '22', {'href': 'https://2018.pythonbrasil.org.br/programacao/#day22'})
#
# ---- Cluster #7 ----

# %%
def hydrate_trie(node):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=set(node.elements),
        children=[hydrate_trie(c) for c in node.children],
        word_finished=node.word_finished
    )
hydrate_trie(root)
# Out:
# {'tag': '/html',
#  'element': {Node(tag='html', doc_order=2, child_position=1, attribs={'prefix': 'og: http://ogp.me/ns#'}, element=<Element html at 0x7fc53f5af708>)},
#  'children': [{'tag': 'body/div.content-body',
#    'element': {Node(tag='div', doc_order=59, child_position=3, attribs={'id': 'top', 'class': 'content-body'}, element=<Element div at 0x7fc53ccef4c8>)},
#    'children': [{'tag': 'section.page-content/div.container-fluid.p-0/section.schedule-page/div.schedule-page__content/div/div/div',
#      'element': {Node(tag='div', doc_order=104, child_position=1, attribs={}, element=<Element div at 0x7fc53ccdfc48>),
#       Node(tag='div', doc_order=126, child_position=2, attribs={'id': 'day17'}, element=<Element div at 0x7fc52b36eb88>),
#       Node(tag='div', doc_order=174, child_position=3, attribs={'id': 'day18'}, element=<Element div at 0x7fc53ccd66c8>),
#       Node(tag='div', doc_order=220, child_position=4, attribs={'id': 'day19'}, element=<Element div at 0x7fc52b347248>),
#       Node(tag='div', doc_order=596, child_position=5, attribs={'id': 'day20'}, element=<Element div at 0x7fc52b2fc348>),
#       Node(tag='div', doc_order=992, child_position=6, attribs={'id': 'day21'}, element=<Element div at 0x7fc52b30e7c8>),
#       Node(tag='div', doc_order=1378, child_position=7, attribs={'id': 'day22'}, element=<Element div at 0x7fc52b245608>)},
#      'children': [{'tag': 'article.schedule_article/div.row.w-100/div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info',
#        'element': {Node(tag='div', doc_order=134, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b36e0c8>),
#         Node(tag='div', doc_order=141, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52ee37c08>),
#         Node(tag='div', doc_order=160, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52ee37448>),
#         Node(tag='div', doc_order=167, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52ee8d908>),
#         Node(tag='div', doc_order=182, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53cce1048>),
#         Node(tag='div', doc_order=194, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53cce18c8>),
#         Node(tag='div', doc_order=213, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3475c8>),
#         Node(tag='div', doc_order=235, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b36b448>),
#         Node(tag='div', doc_order=253, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b359448>),
#         Node(tag='div', doc_order=260, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b359708>),
#         Node(tag='div', doc_order=267, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b36aec8>),
#         Node(tag='div', doc_order=279, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b36abc8>),
#         Node(tag='div', doc_order=286, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3e1648>),
#         Node(tag='div', doc_order=293, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3e1688>),
#         Node(tag='div', doc_order=300, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3e15c8>),
#         Node(tag='div', doc_order=312, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328ac8>),
#         Node(tag='div', doc_order=319, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328e08>),
#         Node(tag='div', doc_order=326, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328408>),
#         Node(tag='div', doc_order=333, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328388>),
#         Node(tag='div', doc_order=345, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3289c8>),
#         Node(tag='div', doc_order=352, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328e48>),
#         Node(tag='div', doc_order=359, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328648>),
#         Node(tag='div', doc_order=366, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b328c88>),
#         Node(tag='div', doc_order=385, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b32ab08>),
#         Node(tag='div', doc_order=392, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b32b4c8>),
#         Node(tag='div', doc_order=399, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b32be08>),
#         Node(tag='div', doc_order=406, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b32be48>),
#         Node(tag='div', doc_order=418, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53cce2fc8>),
#         Node(tag='div', doc_order=425, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccdef48>),
#         Node(tag='div', doc_order=432, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccde688>),
#         Node(tag='div', doc_order=439, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccdecc8>),
#         Node(tag='div', doc_order=451, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52ee7dbc8>),
#         Node(tag='div', doc_order=458, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b4aa388>),
#         Node(tag='div', doc_order=465, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b4aa488>),
#         Node(tag='div', doc_order=472, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b4aa608>),
#         Node(tag='div', doc_order=484, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccd9a48>),
#         Node(tag='div', doc_order=491, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccd9c08>),
#         Node(tag='div', doc_order=498, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc53ccd9848>),
#         Node(tag='div', doc_order=505, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3f3148>),
#         Node(tag='div', doc_order=517, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3f3b08>),
#         Node(tag='div', doc_order=524, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3f3e08>),
#         Node(tag='div', doc_order=531, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3f3a88>),
#         Node(tag='div', doc_order=538, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b322e88>),
#         Node(tag='div', doc_order=550, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b322408>),
#         Node(tag='div', doc_order=557, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b322c08>),
#         Node(tag='div', doc_order=564, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b322548>),
#         Node(tag='div', doc_order=571, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b322508>),
#         Node(tag='div', doc_order=590, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2fc1c8>),
#         Node(tag='div', doc_order=611, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2fc708>),
#         Node(tag='div', doc_order=629, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2fcb88>),
#         Node(tag='div', doc_order=636, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2fcd48>),
#         Node(tag='div', doc_order=643, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2fcf08>),
#         Node(tag='div', doc_order=650, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302108>),
#         Node(tag='div', doc_order=662, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302408>),
#         Node(tag='div', doc_order=669, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3025c8>),
#         Node(tag='div', doc_order=676, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302788>),
#         Node(tag='div', doc_order=683, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302948>),
#         Node(tag='div', doc_order=695, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302c48>),
#         Node(tag='div', doc_order=702, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302e08>),
#         Node(tag='div', doc_order=709, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b302fc8>),
#         Node(tag='div', doc_order=716, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3041c8>),
#         Node(tag='div', doc_order=728, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3044c8>),
#         Node(tag='div', doc_order=735, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b304688>),
#         Node(tag='div', doc_order=742, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b304848>),
#         Node(tag='div', doc_order=749, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b304a08>),
#         Node(tag='div', doc_order=768, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b304ec8>),
#         Node(tag='div', doc_order=775, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3060c8>),
#         Node(tag='div', doc_order=782, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306288>),
#         Node(tag='div', doc_order=789, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306448>),
#         Node(tag='div', doc_order=801, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306748>),
#         Node(tag='div', doc_order=808, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306908>),
#         Node(tag='div', doc_order=815, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306ac8>),
#         Node(tag='div', doc_order=822, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306c88>),
#         Node(tag='div', doc_order=834, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b306f88>),
#         Node(tag='div', doc_order=841, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30b188>),
#         Node(tag='div', doc_order=848, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30b348>),
#         Node(tag='div', doc_order=855, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30b508>),
#         Node(tag='div', doc_order=867, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30b808>),
#         Node(tag='div', doc_order=874, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30b9c8>),
#         Node(tag='div', doc_order=881, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30bb88>),
#         Node(tag='div', doc_order=888, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30bd48>),
#         Node(tag='div', doc_order=900, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30d088>),
#         Node(tag='div', doc_order=907, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30d248>),
#         Node(tag='div', doc_order=914, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30d408>),
#         Node(tag='div', doc_order=921, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30d5c8>),
#         Node(tag='div', doc_order=933, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30d8c8>),
#         Node(tag='div', doc_order=940, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30da88>),
#         Node(tag='div', doc_order=947, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30dc48>),
#         Node(tag='div', doc_order=954, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30de08>),
#         Node(tag='div', doc_order=966, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30e148>),
#         Node(tag='div', doc_order=976, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30e3c8>),
#         Node(tag='div', doc_order=986, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30e648>),
#         Node(tag='div', doc_order=1007, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b30eb88>),
#         Node(tag='div', doc_order=1025, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312048>),
#         Node(tag='div', doc_order=1032, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312208>),
#         Node(tag='div', doc_order=1039, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3123c8>),
#         Node(tag='div', doc_order=1051, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3126c8>),
#         Node(tag='div', doc_order=1058, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312888>),
#         Node(tag='div', doc_order=1065, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312a48>),
#         Node(tag='div', doc_order=1072, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312c08>),
#         Node(tag='div', doc_order=1084, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b312f08>),
#         Node(tag='div', doc_order=1091, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b316108>),
#         Node(tag='div', doc_order=1098, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b3162c8>),
#         Node(tag='div', doc_order=1105, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b316488>),
#         Node(tag='div', doc_order=1117, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2ee408>),
#         Node(tag='div', doc_order=1124, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2ee588>),
#         Node(tag='div', doc_order=1131, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2ee748>),
#         Node(tag='div', doc_order=1138, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2ee908>),
#         Node(tag='div', doc_order=1157, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2eedc8>),
#         Node(tag='div', doc_order=1164, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2eef88>),
#         Node(tag='div', doc_order=1171, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234188>),
#         Node(tag='div', doc_order=1178, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234348>),
#         Node(tag='div', doc_order=1190, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234648>),
#         Node(tag='div', doc_order=1197, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234808>),
#         Node(tag='div', doc_order=1204, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2349c8>),
#         Node(tag='div', doc_order=1211, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234b88>),
#         Node(tag='div', doc_order=1223, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b234e88>),
#         Node(tag='div', doc_order=1230, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238088>),
#         Node(tag='div', doc_order=1237, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238248>),
#         Node(tag='div', doc_order=1244, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238408>),
#         Node(tag='div', doc_order=1256, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238708>),
#         Node(tag='div', doc_order=1263, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2388c8>),
#         Node(tag='div', doc_order=1270, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238a88>),
#         Node(tag='div', doc_order=1277, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238c48>),
#         Node(tag='div', doc_order=1289, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b238f48>),
#         Node(tag='div', doc_order=1296, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b237148>),
#         Node(tag='div', doc_order=1303, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b237308>),
#         Node(tag='div', doc_order=1310, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2374c8>),
#         Node(tag='div', doc_order=1322, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2377c8>),
#         Node(tag='div', doc_order=1329, child_position=2, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b237988>),
#         Node(tag='div', doc_order=1336, child_position=3, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b237b48>),
#         Node(tag='div', doc_order=1343, child_position=4, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b237d08>),
#         Node(tag='div', doc_order=1355, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b245048>),
#         Node(tag='div', doc_order=1365, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b2452c8>),
#         Node(tag='div', doc_order=1386, child_position=1, attribs={'class': 'schedule_info col-xl-3 col-lg-6 col-sm-12 schedule-highlight'}, element=<Element div at 0x7fc52b245808>)},
#        'children': [{'tag': 'h3.schedule_speaker',
#          'element': {Node(tag='h3', doc_order=136, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b5f7388>),
#           Node(tag='h3', doc_order=137, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee37b88>),
#           Node(tag='h3', doc_order=143, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee37a08>),
#           Node(tag='h3', doc_order=144, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee37808>),
#           Node(tag='h3', doc_order=162, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee37488>),
#           Node(tag='h3', doc_order=163, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee379c8>),
#           Node(tag='h3', doc_order=169, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee8d188>),
#           Node(tag='h3', doc_order=170, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee8dac8>),
#           Node(tag='h3', doc_order=184, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53cce1348>),
#           Node(tag='h3', doc_order=185, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53cce10c8>),
#           Node(tag='h3', doc_order=196, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b347f08>),
#           Node(tag='h3', doc_order=197, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b347788>),
#           Node(tag='h3', doc_order=215, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3472c8>),
#           Node(tag='h3', doc_order=216, child_position=2, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b347748>),
#           Node(tag='h3', doc_order=237, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b36b388>),
#           Node(tag='h3', doc_order=256, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b359bc8>),
#           Node(tag='h3', doc_order=263, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b359648>),
#           Node(tag='h3', doc_order=270, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b36a4c8>),
#           Node(tag='h3', doc_order=282, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b36ab08>),
#           Node(tag='h3', doc_order=289, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3e11c8>),
#           Node(tag='h3', doc_order=296, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3e1708>),
#           Node(tag='h3', doc_order=303, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b382d88>),
#           Node(tag='h3', doc_order=315, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328d48>),
#           Node(tag='h3', doc_order=322, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328788>),
#           Node(tag='h3', doc_order=329, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328588>),
#           Node(tag='h3', doc_order=336, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328888>),
#           Node(tag='h3', doc_order=348, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328308>),
#           Node(tag='h3', doc_order=355, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3281c8>),
#           Node(tag='h3', doc_order=362, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b328d08>),
#           Node(tag='h3', doc_order=369, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b32a908>),
#           Node(tag='h3', doc_order=388, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b32a108>),
#           Node(tag='h3', doc_order=395, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b32be88>),
#           Node(tag='h3', doc_order=402, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b32b288>),
#           Node(tag='h3', doc_order=409, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b32b688>),
#           Node(tag='h3', doc_order=421, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53cce2cc8>),
#           Node(tag='h3', doc_order=428, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccdef08>),
#           Node(tag='h3', doc_order=435, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccde088>),
#           Node(tag='h3', doc_order=442, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccdee88>),
#           Node(tag='h3', doc_order=454, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee7d588>),
#           Node(tag='h3', doc_order=461, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b4aa288>),
#           Node(tag='h3', doc_order=468, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b4aa2c8>),
#           Node(tag='h3', doc_order=475, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52ee55708>),
#           Node(tag='h3', doc_order=487, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccd9cc8>),
#           Node(tag='h3', doc_order=494, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccd9d08>),
#           Node(tag='h3', doc_order=501, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc53ccd9dc8>),
#           Node(tag='h3', doc_order=508, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3f34c8>),
#           Node(tag='h3', doc_order=520, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3f3c48>),
#           Node(tag='h3', doc_order=527, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3f3f88>),
#           Node(tag='h3', doc_order=534, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b322d08>),
#           Node(tag='h3', doc_order=541, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3222c8>),
#           Node(tag='h3', doc_order=553, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b322748>),
#           Node(tag='h3', doc_order=560, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b322e08>),
#           Node(tag='h3', doc_order=567, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b322bc8>),
#           Node(tag='h3', doc_order=574, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b322b88>),
#           Node(tag='h3', doc_order=592, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2fc248>),
#           Node(tag='h3', doc_order=613, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2fc788>),
#           Node(tag='h3', doc_order=632, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2fcc48>),
#           Node(tag='h3', doc_order=639, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2fce08>),
#           Node(tag='h3', doc_order=646, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2fcfc8>),
#           Node(tag='h3', doc_order=653, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3021c8>),
#           Node(tag='h3', doc_order=665, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3024c8>),
#           Node(tag='h3', doc_order=672, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b302688>),
#           Node(tag='h3', doc_order=679, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b302848>),
#           Node(tag='h3', doc_order=686, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b302a08>),
#           Node(tag='h3', doc_order=698, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b302d08>),
#           Node(tag='h3', doc_order=705, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b302ec8>),
#           Node(tag='h3', doc_order=712, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3040c8>),
#           Node(tag='h3', doc_order=719, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304288>),
#           Node(tag='h3', doc_order=731, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304588>),
#           Node(tag='h3', doc_order=738, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304748>),
#           Node(tag='h3', doc_order=745, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304908>),
#           Node(tag='h3', doc_order=752, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304ac8>),
#           Node(tag='h3', doc_order=771, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b304f88>),
#           Node(tag='h3', doc_order=778, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306188>),
#           Node(tag='h3', doc_order=785, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306348>),
#           Node(tag='h3', doc_order=792, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306508>),
#           Node(tag='h3', doc_order=804, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306808>),
#           Node(tag='h3', doc_order=811, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3069c8>),
#           Node(tag='h3', doc_order=818, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306b88>),
#           Node(tag='h3', doc_order=825, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b306d48>),
#           Node(tag='h3', doc_order=837, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30b088>),
#           Node(tag='h3', doc_order=844, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30b248>),
#           Node(tag='h3', doc_order=851, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30b408>),
#           Node(tag='h3', doc_order=858, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30b5c8>),
#           Node(tag='h3', doc_order=870, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30b8c8>),
#           Node(tag='h3', doc_order=877, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30ba88>),
#           Node(tag='h3', doc_order=884, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30bc48>),
#           Node(tag='h3', doc_order=891, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30be08>),
#           Node(tag='h3', doc_order=903, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30d148>),
#           Node(tag='h3', doc_order=910, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30d308>),
#           Node(tag='h3', doc_order=917, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30d4c8>),
#           Node(tag='h3', doc_order=924, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30d688>),
#           Node(tag='h3', doc_order=936, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30d988>),
#           Node(tag='h3', doc_order=943, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30db48>),
#           Node(tag='h3', doc_order=950, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30dd08>),
#           Node(tag='h3', doc_order=957, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30dec8>),
#           Node(tag='h3', doc_order=968, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30e1c8>),
#           Node(tag='h3', doc_order=978, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30e448>),
#           Node(tag='h3', doc_order=988, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30e6c8>),
#           Node(tag='h3', doc_order=1009, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b30ec08>),
#           Node(tag='h3', doc_order=1028, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312108>),
#           Node(tag='h3', doc_order=1035, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3122c8>),
#           Node(tag='h3', doc_order=1042, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312488>),
#           Node(tag='h3', doc_order=1054, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312788>),
#           Node(tag='h3', doc_order=1061, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312948>),
#           Node(tag='h3', doc_order=1068, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312b08>),
#           Node(tag='h3', doc_order=1075, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312cc8>),
#           Node(tag='h3', doc_order=1087, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b312fc8>),
#           Node(tag='h3', doc_order=1094, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b3161c8>),
#           Node(tag='h3', doc_order=1101, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b316388>),
#           Node(tag='h3', doc_order=1108, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b316548>),
#           Node(tag='h3', doc_order=1120, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2ee4c8>),
#           Node(tag='h3', doc_order=1127, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2ee648>),
#           Node(tag='h3', doc_order=1134, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2ee808>),
#           Node(tag='h3', doc_order=1141, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2ee9c8>),
#           Node(tag='h3', doc_order=1160, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2eee88>),
#           Node(tag='h3', doc_order=1167, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234088>),
#           Node(tag='h3', doc_order=1174, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234248>),
#           Node(tag='h3', doc_order=1181, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234408>),
#           Node(tag='h3', doc_order=1193, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234708>),
#           Node(tag='h3', doc_order=1200, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2348c8>),
#           Node(tag='h3', doc_order=1207, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234a88>),
#           Node(tag='h3', doc_order=1214, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234c48>),
#           Node(tag='h3', doc_order=1226, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b234f48>),
#           Node(tag='h3', doc_order=1233, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b238148>),
#           Node(tag='h3', doc_order=1240, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b238308>),
#           Node(tag='h3', doc_order=1247, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2384c8>),
#           Node(tag='h3', doc_order=1259, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2387c8>),
#           Node(tag='h3', doc_order=1266, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b238988>),
#           Node(tag='h3', doc_order=1273, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b238b48>),
#           Node(tag='h3', doc_order=1280, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b238d08>),
#           Node(tag='h3', doc_order=1292, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237048>),
#           Node(tag='h3', doc_order=1299, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237208>),
#           Node(tag='h3', doc_order=1306, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2373c8>),
#           Node(tag='h3', doc_order=1313, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237588>),
#           Node(tag='h3', doc_order=1325, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237888>),
#           Node(tag='h3', doc_order=1332, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237a48>),
#           Node(tag='h3', doc_order=1339, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237c08>),
#           Node(tag='h3', doc_order=1346, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b237dc8>),
#           Node(tag='h3', doc_order=1357, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b2450c8>),
#           Node(tag='h3', doc_order=1367, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b245348>),
#           Node(tag='h3', doc_order=1388, child_position=1, attribs={'class': 'schedule_speaker'}, element=<Element h3 at 0x7fc52b245888>)},
#          'children': [],
#          'word_finished': True},
#         {'tag': 'h2.schedule_name',
#          'element': {Node(tag='h2', doc_order=135, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc582043888>),
#           Node(tag='h2', doc_order=142, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52ee370c8>),
#           Node(tag='h2', doc_order=161, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52ee37308>),
#           Node(tag='h2', doc_order=168, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52ee8d888>),
#           Node(tag='h2', doc_order=183, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc53cce1748>),
#           Node(tag='h2', doc_order=195, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc53cce1bc8>),
#           Node(tag='h2', doc_order=214, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b3474c8>),
#           Node(tag='h2', doc_order=236, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b36bd48>),
#           Node(tag='h2', doc_order=254, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b359c88>),
#           Node(tag='h2', doc_order=261, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b359788>),
#           Node(tag='h2', doc_order=268, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b36a3c8>),
#           Node(tag='h2', doc_order=280, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b36a088>),
#           Node(tag='h2', doc_order=287, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b3e14c8>),
#           Node(tag='h2', doc_order=294, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b3e1088>),
#           Node(tag='h2', doc_order=301, child_position=1, attribs={'class': 'schedule_name'}, element=<Element h2 at 0x7fc52b3e1588>),
# ...
#           Node(tag='h4', doc_order=925, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30d6c8>),
#           Node(tag='h4', doc_order=937, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30d9c8>),
#           Node(tag='h4', doc_order=944, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30db88>),
#           Node(tag='h4', doc_order=951, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30dd48>),
#           Node(tag='h4', doc_order=958, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30df08>),
#           Node(tag='h4', doc_order=989, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30e708>),
#           Node(tag='h4', doc_order=1010, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b30ec48>),
#           Node(tag='h4', doc_order=1029, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b312148>),
#           Node(tag='h4', doc_order=1036, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b312308>),
#           Node(tag='h4', doc_order=1043, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b3124c8>),
#           Node(tag='h4', doc_order=1055, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b3127c8>),
#           Node(tag='h4', doc_order=1062, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b312988>),
#           Node(tag='h4', doc_order=1069, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b312b48>),
#           Node(tag='h4', doc_order=1076, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b312d08>),
#           Node(tag='h4', doc_order=1088, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b316048>),
#           Node(tag='h4', doc_order=1095, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b316208>),
#           Node(tag='h4', doc_order=1102, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b3163c8>),
#           Node(tag='h4', doc_order=1109, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b316588>),
#           Node(tag='h4', doc_order=1121, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2ee508>),
#           Node(tag='h4', doc_order=1128, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2ee688>),
#           Node(tag='h4', doc_order=1135, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2ee848>),
#           Node(tag='h4', doc_order=1142, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2eea08>),
#           Node(tag='h4', doc_order=1161, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2eeec8>),
#           Node(tag='h4', doc_order=1168, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2340c8>),
#           Node(tag='h4', doc_order=1175, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234288>),
#           Node(tag='h4', doc_order=1182, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234448>),
#           Node(tag='h4', doc_order=1194, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234748>),
#           Node(tag='h4', doc_order=1201, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234908>),
#           Node(tag='h4', doc_order=1208, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234ac8>),
#           Node(tag='h4', doc_order=1215, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234c88>),
#           Node(tag='h4', doc_order=1227, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b234f88>),
#           Node(tag='h4', doc_order=1234, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238188>),
#           Node(tag='h4', doc_order=1241, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238348>),
#           Node(tag='h4', doc_order=1248, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238508>),
#           Node(tag='h4', doc_order=1260, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238808>),
#           Node(tag='h4', doc_order=1267, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2389c8>),
#           Node(tag='h4', doc_order=1274, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238b88>),
#           Node(tag='h4', doc_order=1281, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b238d48>),
#           Node(tag='h4', doc_order=1293, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237088>),
#           Node(tag='h4', doc_order=1300, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237248>),
#           Node(tag='h4', doc_order=1307, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237408>),
#           Node(tag='h4', doc_order=1314, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2375c8>),
#           Node(tag='h4', doc_order=1326, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b2378c8>),
#           Node(tag='h4', doc_order=1333, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237a88>),
#           Node(tag='h4', doc_order=1340, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237c48>),
#           Node(tag='h4', doc_order=1347, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b237e08>),
#           Node(tag='h4', doc_order=1368, child_position=1, attribs={'class': 'schedule_office'}, element=<Element h4 at 0x7fc52b245388>)},
#          'children': [],
#          'word_finished': True}],
#        'word_finished': False},
#       {'tag': 'div.filters/ul.accordion-tabs.schedule_category_days/li.tab-header-and-content',
#        'element': {Node(tag='li', doc_order=108, child_position=1, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b4aef88>),
#         Node(tag='li', doc_order=110, child_position=2, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b4aeec8>),
#         Node(tag='li', doc_order=112, child_position=3, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b4aedc8>),
#         Node(tag='li', doc_order=114, child_position=4, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b36e248>),
#         Node(tag='li', doc_order=116, child_position=5, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b36e348>),
#         Node(tag='li', doc_order=118, child_position=6, attribs={'class': 'tab-header-and-content'}, element=<Element li at 0x7fc52b36e808>)},
#        'children': [{'tag': 'a.scroll.tab-link',
#          'element': {Node(tag='a', doc_order=109, child_position=1, attribs={'href': 'https://2018.pythonbrasil.org.br/programacao/#day17', 'class': 'tab-link scroll'}, element=<Element a at 0x7fc52b4aed08>),
#           Node(tag='a', doc_order=111, child_position=1, attribs={'href': 'https://2018.pythonbrasil.org.br/programacao/#day18', 'class': 'tab-link scroll'}, element=<Element a at 0x7fc52b4aee08>),
#           Node(tag='a', doc_order=115, child_position=1, attribs={'href': 'https://2018.pythonbrasil.org.br/programacao/#day20', 'class': 'tab-link scroll'}, element=<Element a at 0x7fc52b36e2c8>),
#           Node(tag='a', doc_order=117, child_position=1, attribs={'href': 'https://2018.pythonbrasil.org.br/programacao/#day21', 'class': 'tab-link scroll'}, element=<Element a at 0x7fc52b36e788>),
#           Node(tag='a', doc_order=119, child_position=1, attribs={'href': 'https://2018.pythonbrasil.org.br/programacao/#day22', 'class': 'tab-link scroll'}, element=<Element a at 0x7fc52b36e888>)},
#          'children': [],
#          'word_finished': True}],
#        'word_finished': False},
#       {'tag': 'div.day-separator.tab-link',
#        'element': {Node(tag='div', doc_order=127, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc52b36e508>),
#         Node(tag='div', doc_order=175, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc53ccd6808>),
#         Node(tag='div', doc_order=221, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc52b36b188>),
#         Node(tag='div', doc_order=597, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc52b2fc388>),
#         Node(tag='div', doc_order=993, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc52b30e808>),
#         Node(tag='div', doc_order=1379, child_position=1, attribs={'class': 'day-separator tab-link'}, element=<Element div at 0x7fc52b245648>)},
#        'children': [{'tag': 'span',
#          'element': {Node(tag='span', doc_order=128, child_position=1, attribs={}, element=<Element span at 0x7fc52b36ea48>),
#           Node(tag='span', doc_order=176, child_position=1, attribs={}, element=<Element span at 0x7fc53ccd6708>),
#           Node(tag='span', doc_order=222, child_position=1, attribs={}, element=<Element span at 0x7fc52b36b208>),
#           Node(tag='span', doc_order=598, child_position=1, attribs={}, element=<Element span at 0x7fc52b2fc3c8>),
#           Node(tag='span', doc_order=994, child_position=1, attribs={}, element=<Element span at 0x7fc52b30e848>),
#           Node(tag='span', doc_order=1380, child_position=1, attribs={}, element=<Element span at 0x7fc52b245688>)},
#          'children': [],
#          'word_finished': True}],
#        'word_finished': True}],
#      'word_finished': False},
#     {'tag': 'div.app-banners',
#      'element': {Node(tag='div', doc_order=88, child_position=1, attribs={'class': 'app-banners'}, element=<Element div at 0x7fc52b329948>)},
#      'children': [{'tag': 'p',
#        'element': {Node(tag='p', doc_order=89, child_position=1, attribs={}, element=<Element p at 0x7fc52b329e08>),
#         Node(tag='p', doc_order=90, child_position=2, attribs={}, element=<Element p at 0x7fc52b329e88>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'div.stores-banners/a',
#        'element': {Node(tag='a', doc_order=92, child_position=1, attribs={'target': '_blank', 'href': 'https://play.google.com/store/apps/details?id=org.pythonbrasil.pybr2018'}, element=<Element a at 0x7fc52b329808>),
#         Node(tag='a', doc_order=94, child_position=2, attribs={'target': '_blank', 'href': 'https://itunes.apple.com/us/app/python-brasil-2018/id1439521365?ls=1&mt=8'}, element=<Element a at 0x7fc52b329208>)},
#        'children': [],
#        'word_finished': False}],
#      'word_finished': False},
#     {'tag': 'footer.footer/div.container/div.row/div.col-12.footer-note/p',
#      'element': {Node(tag='p', doc_order=1444, child_position=1, attribs={}, element=<Element p at 0x7fc52b2416c8>),
#       Node(tag='p', doc_order=1445, child_position=2, attribs={}, element=<Element p at 0x7fc52b241708>)},
#      'children': [],
#      'word_finished': False}],
#    'word_finished': False},
#   {'tag': 'head',
#    'element': {Node(tag='head', doc_order=3, child_position=1, attribs={}, element=<Element head at 0x7fc549765d88>)},
#    'children': [{'tag': 'meta',
#      'element': {Node(tag='meta', doc_order=4, child_position=1, attribs={'http-equiv': 'Content-Type', 'content': 'text/html; charset=UTF-8'}, element=<Element meta at 0x7fc52b41d048>),
#       Node(tag='meta', doc_order=8, child_position=2, attribs={'name': 'twitter:card', 'content': 'summary_large_image'}, element=<Element meta at 0x7fc54932fdc8>),
#       Node(tag='meta', doc_order=9, child_position=3, attribs={'name': 'twitter:site', 'content': '@pythonbrasil'}, element=<Element meta at 0x7fc53ccdd448>),
#       Node(tag='meta', doc_order=10, child_position=4, attribs={'name': 'twitter:image', 'content': 'https://2018.pythonbrasil.org.br/./assets/242d582d169012952f39df817f46b817.png'}, element=<Element meta at 0x7fc53ccdd3c8>),
#       Node(tag='meta', doc_order=11, child_position=5, attribs={'name': 'twitter:description', 'content': 'A PythonBrasil é o maior evento sobre linguagem de programação Python do Brasil. Este ano organizada pela comunidade Python de NATAL/RN com o apoio da APyB (Associação Python Brasil).'}, element=<Element meta at 0x7fc53ccdd348>),
#       Node(tag='meta', doc_order=12, child_position=6, attribs={'property': 'og:url', 'content': 'https://2018.pythonbrasil.org.br'}, element=<Element meta at 0x7fc53ccddf08>),
#       Node(tag='meta', doc_order=13, child_position=7, attribs={'property': 'og:type', 'content': 'website'}, element=<Element meta at 0x7fc53ccddcc8>),
#       Node(tag='meta', doc_order=14, child_position=8, attribs={'property': 'og:title', 'content': 'Python Brasil 2018'}, element=<Element meta at 0x7fc52ee91b08>),
#       Node(tag='meta', doc_order=15, child_position=9, attribs={'property': 'og:description', 'content': 'A PythonBrasil é o maior evento sobre linguagem de programação Python do Brasil. Este ano organizada pela comunidade Python de NATAL/RN com o apoio da APyB (Associação Python Brasil).'}, element=<Element meta at 0x7fc52ee915c8>),
#       Node(tag='meta', doc_order=16, child_position=10, attribs={'property': 'og:image:type', 'content': 'image/png'}, element=<Element meta at 0x7fc52ee91a08>),
#       Node(tag='meta', doc_order=17, child_position=11, attribs={'property': 'og:image', 'content': 'https://2018.pythonbrasil.org.br/./assets/659d2f554a53d7375c98c1ce2ff95db1.png'}, element=<Element meta at 0x7fc52ee91988>),
#       Node(tag='meta', doc_order=21, child_position=12, attribs={'name': 'viewport', 'content': 'width=device-width'}, element=<Element meta at 0x7fc52ee91bc8>),
#       Node(tag='meta', doc_order=22, child_position=13, attribs={'name': 'theme-color', 'content': '#102E46'}, element=<Element meta at 0x7fc52b365a88>)},
#      'children': [],
#      'word_finished': True},
#     {'tag': 'link',
#      'element': {Node(tag='link', doc_order=5, child_position=1, attribs={'target': '_blank', 'href': './PythonBrasil[14]_files/css', 'rel': 'stylesheet'}, element=<Element link at 0x7fc572730148>),
#       Node(tag='link', doc_order=6, child_position=2, attribs={'href': './PythonBrasil[14]_files/css(1)', 'rel': 'stylesheet'}, element=<Element link at 0x7fc53ccc8f08>),
#       Node(tag='link', doc_order=7, child_position=3, attribs={'href': './PythonBrasil[14]_files/icon', 'rel': 'stylesheet'}, element=<Element link at 0x7fc53ccc8e48>),
#       Node(tag='link', doc_order=18, child_position=4, attribs={'rel': 'manifest', 'href': 'https://2018.pythonbrasil.org.br/manifest.json'}, element=<Element link at 0x7fc52ee91248>),
#       Node(tag='link', doc_order=19, child_position=5, attribs={'rel': 'shortcut icon', 'type': 'image/x-icon', 'href': 'https://2018.pythonbrasil.org.br/assets/1c14c20d9014206828a1a15ba7f2418b.ico'}, element=<Element link at 0x7fc52ee91388>),
#       Node(tag='link', doc_order=23, child_position=6, attribs={'href': './PythonBrasil[14]_files/2ee75f924240f9a7bcd1670c1cb351e1.css', 'rel': 'stylesheet'}, element=<Element link at 0x7fc52b365b08>)},
#      'children': [],
#      'word_finished': True}],
#    'word_finished': False}],
#  'word_finished': False}

# %%
from collections import defaultdict
from operator import itemgetter

def hydrate_trie2(node, docorder_min, docorder_max=None):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []
    for i, element in enumerate(elements, start=1):
        if not (docorder_min < element.doc_order):
            continue
        if docorder_max is not None and (element.doc_order > docorder_max):
            continue
        e = {'tag': _node_repr(element),
             'doc_order': element.doc_order}
        _t = [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        #print((element, _order_min, _order_max))
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate_trie2(child, _order_min, _order_max)]))
        if children:
            e['children'] = sorted(children, key=itemgetter('doc_order'))
            
        if 'children' not in e and 'text' not in e:
            continue
        #if len(children) == 1:
            #e = children[0]
            #e['tag'] = '{}/{}'.format(_node_repr(element), e['tag'])
        output.append(e)
    #if len(output) == 1:
    #    return output[0]
    return sorted(output, key=itemgetter('doc_order'))
pp(hydrate_trie2(root, 0))
# Out:
# [{'children': [{'children': [{'children': [{'doc_order': 89,
#                                             'tag': 'p',
#                                             'text': 'Baixe o app da Python '
#                                                     'Brasil 2018 para '
#                                                     'acompanhar a grade do '
#                                                     'evento em tempo real, '
#                                                     'escolher suas atividades '
#                                                     'favoritas e receber '
#                                                     'notificações.'}],
#                               'doc_order': 88,
#                               'tag': 'div.app-banners'},
#                              {'children': [{'children': [{'doc_order': 109,
#                                                           'tag': 'a.scroll.tab-link',
#                                                           'text': '17'}],
#                                             'doc_order': 108,
#                                             'tag': 'li.tab-header-and-content'},
#                                            {'children': [{'doc_order': 111,
#                                                           'tag': 'a.scroll.tab-link',
#                                                           'text': '18'}],
#                                             'doc_order': 110,
#                                             'tag': 'li.tab-header-and-content'},
#                                            {'children': [{'doc_order': 115,
#                                                           'tag': 'a.scroll.tab-link',
#                                                           'text': '20'}],
#                                             'doc_order': 114,
#                                             'tag': 'li.tab-header-and-content'},
#                                            {'children': [{'doc_order': 117,
#                                                           'tag': 'a.scroll.tab-link',
#                                                           'text': '21'}],
#                                             'doc_order': 116,
#                                             'tag': 'li.tab-header-and-content'},
#                                            {'children': [{'doc_order': 119,
#                                                           'tag': 'a.scroll.tab-link',
#                                                           'text': '22'}],
#                                             'doc_order': 118,
#                                             'tag': 'li.tab-header-and-content'}],
#                               'doc_order': 104,
#                               'tag': 'div'},
#                              {'children': [{'children': [{'doc_order': 128,
#                                                           'tag': 'span',
#                                                           'text': 'Tutoriais'}],
#                                             'doc_order': 127,
#                                             'tag': 'div.day-separator.tab-link',
#                                             'text': 'Dia 17 –'},
#                                            {'children': [{'doc_order': 135,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Hands on '
#                                                                   'Análise de '
#                                                                   'Sentimentos'},
#                                                          {'doc_order': 136,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 137,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Betina '
#                                                                   'Manoel da '
#                                                                   'Costa'},
#                                                          {'doc_order': 138,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedora '
#                                                                   'na '
#                                                                   'ThoughtWorks'},
#                                                          {'children': [{'doc_order': 140,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 139,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Ginga'}],
#                                             'doc_order': 134,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 142,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Desenvolvendo '
#                                                                   'Web '
#                                                                   'Crawlers '
#                                                                   'com Scrapy'},
#                                                          {'doc_order': 143,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 144,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Renne '
#                                                                   'Rocha'},
#                                                          {'doc_order': 145,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedor'},
#                                                          {'children': [{'doc_order': 147,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 146,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 141,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 161,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': '[CANCELADO] '
#                                                                   'Construindo '
#                                                                   'API REST '
#                                                                   'com Django '
#                                                                   'REST '
#                                                                   'Framework'},
#                                                          {'doc_order': 162,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 163,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Werberth '
#                                                                   'Vinícius '
#                                                                   'Souza '
#                                                                   'Gomes'},
#                                                          {'doc_order': 164,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Co-organizador '
#                                                                   'do Grupo de '
#                                                                   'Usuário de '
#                                                                   'Python de '
#                                                                   'Parnaíba'},
#                                                          {'children': [{'doc_order': 166,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 165,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Ginga'}],
#                                             'doc_order': 160,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 168,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Pensamento '
#                                                                   'Computacional '
#                                                                   'com Python: '
#                                                                   'Uma '
#                                                                   'abordagem '
#                                                                   'de '
#                                                                   'ensino-aprendizagem '
#                                                                   'de '
#                                                                   'programação '
#                                                                   '(4h)'},
#                                                          {'doc_order': 169,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 170,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Lidiane de '
#                                                                   'Souza '
#                                                                   'Monteiro'},
#                                                          {'doc_order': 171,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedora '
#                                                                   'de Software '
#                                                                   'na Fundaj'},
#                                                          {'children': [{'doc_order': 173,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 172,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 167,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'}],
#                               'doc_order': 126,
#                               'tag': 'div'},
#                              {'children': [{'children': [{'doc_order': 176,
#                                                           'tag': 'span',
#                                                           'text': 'Tutoriais'}],
#                                             'doc_order': 175,
#                                             'tag': 'div.day-separator.tab-link',
#                                             'text': 'Dia 18 –'},
#                                            {'children': [{'doc_order': 183,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Não é '
#                                                                   'Bruxaria, é '
#                                                                   'Pandas'},
#                                                          {'doc_order': 184,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 185,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Fernando '
#                                                                   'Masanori'},
#                                                          {'doc_order': 186,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Docente da '
#                                                                   'FATEC São '
#                                                                   'José dos '
#                                                                   'Campos'},
#                                                          {'children': [{'doc_order': 188,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 187,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 182,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 195,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Django '
#                                                                   'Girls'},
#                                                          {'doc_order': 196,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '8h'},
#                                                          {'doc_order': 197,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Django '
#                                                                   'Girls'},
#                                                          {'doc_order': 198,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Organização '
#                                                                   'internacional '
#                                                                   'para '
#                                                                   'mulheres'},
#                                                          {'children': [{'doc_order': 200,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 199,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Cuscuz'}],
#                                             'doc_order': 194,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 214,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Estrutura '
#                                                                   'de Dados é '
#                                                                   '❤'},
#                                                          {'doc_order': 215,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Duração: '
#                                                                   '4h'},
#                                                          {'doc_order': 216,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Fernando '
#                                                                   'Masanori'},
#                                                          {'doc_order': 217,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Docente da '
#                                                                   'FATEC São '
#                                                                   'José dos '
#                                                                   'Campos'},
#                                                          {'children': [{'doc_order': 219,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 218,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 213,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'}],
#                               'doc_order': 174,
#                               'tag': 'div'},
#                              {'children': [{'children': [{'doc_order': 222,
#                                                           'tag': 'span',
#                                                           'text': 'Palestras'}],
#                                             'doc_order': 221,
#                                             'tag': 'div.day-separator.tab-link',
#                                             'text': 'Dia 19 –'},
#                                            {'children': [{'doc_order': 236,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Keynote'},
#                                                          {'doc_order': 237,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Daniela '
#                                                                   'Petruzalek'},
#                                                          {'doc_order': 238,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Consultora '
#                                                                   'de '
#                                                                   'Desenvolvimento '
#                                                                   'sênior na '
#                                                                   'Thoughtworks'},
#                                                          {'children': [{'doc_order': 240,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 239,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Tapioca'}],
#                                             'doc_order': 235,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 255,
#                                                                         'tag': 'span.pessoas.schedule_category',
#                                                                         'text': 'Pessoas'}],
#                                                           'doc_order': 254,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': '2 anos de '
#                                                                   'trabalho '
#                                                                   'remoto - o '
#                                                                   'lado bom e '
#                                                                   'os '
#                                                                   'problemas'},
#                                                          {'doc_order': 256,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Julio Cesar '
#                                                                   'Eiras '
#                                                                   'Melanda'},
#                                                          {'doc_order': 257,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedor '
#                                                                   'Python e '
#                                                                   'Fotógrafo'},
#                                                          {'children': [{'doc_order': 259,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 258,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Jerimum'}],
#                                             'doc_order': 253,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 262,
#                                                                         'tag': 'span.devops.schedule_category',
#                                                                         'text': 'DevOPS'}],
#                                                           'doc_order': 261,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'O casamento '
#                                                                   'sagrado '
#                                                                   'entre o '
#                                                                   'Pipfile, '
#                                                                   'pip e '
#                                                                   'Virtualenv'},
#                                                          {'doc_order': 263,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Allythy '
#                                                                   'Rennan '
#                                                                   'Medeiros de '
#                                                                   'Souza'},
#                                                          {'doc_order': 264,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Coordenador '
#                                                                   'do '
#                                                                   'GruPy-RN'},
#                                                          {'children': [{'doc_order': 266,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 265,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Macaxeira'}],
#                                             'doc_order': 260,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 269,
#                                                                         'tag': 'span.schedule_category.web',
#                                                                         'text': 'Web'}],
#                                                           'doc_order': 268,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Perdendo o '
#                                                                   'medo da Web '
#                                                                   'com Django'},
#                                                          {'doc_order': 270,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Ryllari '
#                                                                   'Raianne '
#                                                                   'Marques de '
#                                                                   'Santana'},
#                                                          {'doc_order': 271,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Co-organizadora '
#                                                                   'do PyLadies '
#                                                                   'Fortaleza e '
#                                                                   'Desenvolvedora '
#                                                                   'na Morphus '
#                                                                   'Segurança '
#                                                                   'da '
#                                                                   'Informação'},
#                                                          {'children': [{'doc_order': 273,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 272,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 267,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 281,
#                                                                         'tag': 'span.dev.schedule_category',
#                                                                         'text': 'Dev'}],
#                                                           'doc_order': 280,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Python: '
#                                                                   'Acelerando '
#                                                                   'Soluções '
#                                                                   'Utilizando '
#                                                                   'GPU'},
#                                                          {'doc_order': 282,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Paulo '
#                                                                   'Sergio '
#                                                                   'Lemes '
#                                                                   'Queiroz'},
#                                                          {'doc_order': 283,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Unix '
#                                                                   'engineer '
#                                                                   'and '
#                                                                   'Developer'},
#                                                          {'children': [{'doc_order': 285,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 284,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Jerimum'}],
#                                             'doc_order': 279,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 288,
#                                                                         'tag': 'span.devops.schedule_category',
#                                                                         'text': 'DevOPS'}],
#                                                           'doc_order': 287,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Ansible '
#                                                                   '101'},
#                                                          {'doc_order': 289,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Jairo da '
#                                                                   'Silva '
#                                                                   'Junior'},
#                                                          {'doc_order': 290,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Arquiteto '
#                                                                   'na Red Hat '
#                                                                   'e '
#                                                                   'contribuidor '
#                                                                   'em projetos '
#                                                                   'open '
#                                                                   'source'},
#                                                          {'children': [{'doc_order': 292,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 291,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Macaxeira'}],
#                                             'doc_order': 286,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 295,
#                                                                         'tag': 'span.schedule_category.web',
#                                                                         'text': 'Web'}],
#                                                           'doc_order': 294,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Criando '
#                                                                   'clients '
#                                                                   'inteligentes '
#                                                                   'com o '
#                                                                   'simple-rest-client'},
#                                                          {'doc_order': 296,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Allisson '
#                                                                   'Geraldo '
#                                                                   'Alves '
#                                                                   'Azevedo'},
#                                                          {'doc_order': 297,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedor '
#                                                                   'sênior na '
#                                                                   'Olist'},
#                                                          {'children': [{'doc_order': 299,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 298,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 293,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 302,
#                                                                         'tag': 'span.data-science.schedule_category',
#                                                                         'text': 'Data '
#                                                                                 'Science'}],
#                                                           'doc_order': 301,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Web '
#                                                                   'crawling e '
#                                                                   'scraping '
#                                                                   'com Scrapy '
#                                                                   'e Scrapy '
#                                                                   'Cloud'},
#                                                          {'doc_order': 303,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Lidiane '
#                                                                   'Mayra '
#                                                                   'Taquehara'},
#                                                          {'doc_order': 304,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedora '
#                                                                   'Back-end na '
#                                                                   'Love '
#                                                                   'Mondays'},
#                                                          {'children': [{'doc_order': 306,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 305,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Tapioca'}],
#                                             'doc_order': 300,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 314,
#                                                                         'tag': 'span.pessoas.schedule_category',
#                                                                         'text': 'Pessoas'}],
#                                                           'doc_order': 313,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Comunidade '
#                                                                   'e fazer '
#                                                                   'dinheiro, é '
#                                                                   'possível a '
#                                                                   'convivência?'},
#                                                          {'doc_order': 315,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Renzo dos '
#                                                                   'Santos '
#                                                                   'Nuccitelli'},
#                                                          {'doc_order': 316,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Diretor de '
#                                                                   'Tecnologia '
#                                                                   'na Pricez'},
#                                                          {'children': [{'doc_order': 318,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 317,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Jerimum'}],
#                                             'doc_order': 312,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 321,
#                                                                         'tag': 'span.devops.schedule_category',
#                                                                         'text': 'DevOPS'}],
#                                                           'doc_order': 320,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Configurações '
#                                                                   'de '
#                                                                   'aplicações '
#                                                                   'distribuidas '
#                                                                   'com etcd'},
#                                                          {'doc_order': 322,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Wilson '
#                                                                   'Pinto '
#                                                                   'Júnior'},
#                                                          {'doc_order': 323,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Trabalha na '
#                                                                   'Globo.com, '
#                                                                   'Apaixonado '
#                                                                   'por Python '
#                                                                   'e GO'},
#                                                          {'children': [{'doc_order': 325,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 324,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Macaxeira'}],
#                                             'doc_order': 319,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 328,
#                                                                         'tag': 'span.pessoas.schedule_category',
#                                                                         'text': 'Pessoas'}],
#                                                           'doc_order': 327,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Como '
#                                                                   'consegui o '
#                                                                   'meu '
#                                                                   'primeiro '
#                                                                   'emprego com '
#                                                                   'Python'},
#                                                          {'doc_order': 329,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Késsia '
#                                                                   'Castro'},
#                                                          {'doc_order': 330,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Consultora '
#                                                                   'de '
#                                                                   'Desenvolvimento '
#                                                                   'na '
#                                                                   'ThoughtWorks'},
# ...
#                                            {'children': [{'children': [{'doc_order': 1331,
#                                                                         'tag': 'span.dev.schedule_category',
#                                                                         'text': 'Dev'}],
#                                                           'doc_order': 1330,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Não é '
#                                                                   'magia, é '
#                                                                   'tecnologia'},
#                                                          {'doc_order': 1332,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Rafael '
#                                                                   'Reimberg '
#                                                                   'Lima'},
#                                                          {'doc_order': 1333,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Engenheiro '
#                                                                   'de '
#                                                                   'Software'},
#                                                          {'children': [{'doc_order': 1335,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1334,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Macaxeira'}],
#                                             'doc_order': 1329,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 1338,
#                                                                         'tag': 'span.data-science.schedule_category',
#                                                                         'text': 'Data '
#                                                                                 'Science'}],
#                                                           'doc_order': 1337,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Python IoT '
#                                                                   '– Detecção '
#                                                                   'e '
#                                                                   'Reconhecimento '
#                                                                   'de Faces, '
#                                                                   'aplicações '
#                                                                   'na '
#                                                                   'sociedade'},
#                                                          {'doc_order': 1339,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Erlon '
#                                                                   'Dantas da '
#                                                                   'Nóbrega '
#                                                                   'Júnior'},
#                                                          {'doc_order': 1340,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Pesquisador '
#                                                                   'em '
#                                                                   'Segurança '
#                                                                   'da '
#                                                                   'Informação'},
#                                                          {'children': [{'doc_order': 1342,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1341,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 1336,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'children': [{'doc_order': 1345,
#                                                                         'tag': 'span.data-science.schedule_category',
#                                                                         'text': 'Data '
#                                                                                 'Science'}],
#                                                           'doc_order': 1344,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Python: O '
#                                                                   'canivete '
#                                                                   'suiço da '
#                                                                   'análise de '
#                                                                   'dados'},
#                                                          {'doc_order': 1346,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Paulo '
#                                                                   'Ribeiro '
#                                                                   'Lins '
#                                                                   'Júnior'},
#                                                          {'doc_order': 1347,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Professor '
#                                                                   'de '
#                                                                   'Estatística, '
#                                                                   'TIC e '
#                                                                   'Métodos '
#                                                                   'Numéricos '
#                                                                   'no IFPB'},
#                                                          {'children': [{'doc_order': 1349,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1348,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Tapioca'}],
#                                             'doc_order': 1343,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 1356,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Apresentação '
#                                                                   'Python '
#                                                                   'Brasil'},
#                                                          {'doc_order': 1357,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Apresentação '
#                                                                   'Python '
#                                                                   'Brasil'},
#                                                          {'children': [{'doc_order': 1359,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1358,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Tapioca'}],
#                                             'doc_order': 1355,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'},
#                                            {'children': [{'doc_order': 1366,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Keynote'},
#                                                          {'doc_order': 1367,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Betina '
#                                                                   'Manoel'},
#                                                          {'doc_order': 1368,
#                                                           'tag': 'h4.schedule_office',
#                                                           'text': 'Desenvolvedora '
#                                                                   'na '
#                                                                   'ThoughtWorks'},
#                                                          {'children': [{'doc_order': 1370,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1369,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Sala '
#                                                                   'Tapioca'}],
#                                             'doc_order': 1365,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'}],
#                               'doc_order': 992,
#                               'tag': 'div'},
#                              {'children': [{'children': [{'doc_order': 1380,
#                                                           'tag': 'span',
#                                                           'text': 'Sprints'}],
#                                             'doc_order': 1379,
#                                             'tag': 'div.day-separator.tab-link',
#                                             'text': 'Dia 22 –'},
#                                            {'children': [{'doc_order': 1387,
#                                                           'tag': 'h2.schedule_name',
#                                                           'text': 'Sprints'},
#                                                          {'doc_order': 1388,
#                                                           'tag': 'h3.schedule_speaker',
#                                                           'text': 'Os sprints '
#                                                                   'são uma '
#                                                                   'tradição da '
#                                                                   'comunidade '
#                                                                   'Python. É '
#                                                                   'um momento '
#                                                                   'em que os '
#                                                                   'participantes '
#                                                                   'têm a '
#                                                                   'oportunidade '
#                                                                   'de '
#                                                                   'interagir e '
#                                                                   'contribuir '
#                                                                   'de forma '
#                                                                   'conjunta na '
#                                                                   'melhoria de '
#                                                                   'projetos '
#                                                                   'open '
#                                                                   'source.'},
#                                                          {'children': [{'doc_order': 1390,
#                                                                         'tag': 'i.material-icons',
#                                                                         'text': 'location_on'}],
#                                                           'doc_order': 1389,
#                                                           'tag': 'h4.schedule_location',
#                                                           'text': 'Holiday Inn '
#                                                                   'Natal - '
#                                                                   'Sala '
#                                                                   'Rapadura'}],
#                                             'doc_order': 1386,
#                                             'tag': 'div.col-lg-6.col-sm-12.col-xl-3.schedule-highlight.schedule_info'}],
#                               'doc_order': 1378,
#                               'tag': 'div'},
#                              {'doc_order': 1444,
#                               'tag': 'p',
#                               'text': 'PythonBrasil is a non-profit '
#                                       'volunteer-driven conference for '
#                                       'promoting the open-source Python '
#                                       'programming language. It is supported '
#                                       'by the Brazilian Python Association '
#                                       '(APyB) and by the Python Software '
#                                       'Foundation (PSF).'},
#                              {'doc_order': 1445,
#                               'tag': 'p',
#                               'text': 'Google Play e o logotipo do Google Play '
#                                       'são marcas registradas da Google LLC.'}],
#                 'doc_order': 59,
#                 'tag': 'div.content-body'}],
#   'doc_order': 2,
#   'tag': 'html'}]

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter


tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([21, 25, 24, 22, 23, 14, 19, 15, 10, 26, 16,  7, 17, 12, 11, 18,  8,
#        20, 13,  6,  3,  9,  4,  5,  1,  2,  0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                #, leaf_font_size=8
               )

# %%
root = TrieNode()

# %%
# borrowed from https://stackoverflow.com/questions/8484943/construct-a-tree-from-list-os-file-paths-python-performance-dependent
from collections import defaultdict

FILE_MARKER = '<files>'

def attach(branch, trunk):
    '''
    Insert a branch of directories on its trunk.
    '''
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
        return trunk
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []), ('<paths>', []), ('<texts>', [])))
        return attach(others, trunk[node])

def prettify(d, indent=0):
    '''
    Print the file tree structure with proper indentation.
    '''
    for key, value in d.items():
        if key == FILE_MARKER:
            if value:
                print('  ' * indent + str(value))
        elif key in ('<paths>', '<texts>'):
            if value:
                print('\n'.join('  ' * indent + v for v in value))
        else:
            print('  ' * indent + str(key))
            if isinstance(value, dict):
                prettify(value, indent+1)
            else:
                print('  ' * (indent+1) + str(value))

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue
    print('-------')
    print('Cluster #{}'.format(n))
    tree = defaultdict(dict, ((FILE_MARKER, []),))
    for tp in cluster:
        branch = attach(tp, tree)
        branch['<paths>'].append(tp)
        for nodepath in clustering.tagpath_nodes[tp][:10]:
            node = nodepath[-1]
            
            e = node.element
            texts = [s.strip() for s in e.xpath('./text()[normalize-space()]')]
            attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
            t = ' '.join(texts)
            if t.strip():
                branch['<texts>'].append(t)
    prettify(tree)
# Out:
# -------
# Cluster #1
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table.dataframe
#             tbody
#               tr
#                 td
#                   ['br', 'a', 'b']
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/br
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/a
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/b
#                   How to drive business decisions with AI
#                   Python in medicine: signal processing - learning and visualization of temporal data
#                   Felix Wick
#                   Annalisa Barla
# -------
# Cluster #2
#
#   html
#     head
#       ['link', 'meta']
#       /html/head/link
#       /html/head/meta
#     body
#       div.row
#         div.columns.large-9
#           ['h3', 'p']
#           /html/body/div.row/div.columns.large-9/h3
#           /html/body/div.row/div.columns.large-9/p
#           Program
#           Tuesday, 28 August
#           Wednesday, 29 August
#           Thursday, 30 August
#           Friday, 31 August
#           Tutorials last either 90 minutes or 180 minutes. In the latter case, they are split in two sessions.
# The exact hours are subject to change to account for the logistics of coffee and lunch
# breaks.
# Tutorial istructions can be found under
#           table.dataframe
#             tbody
#               ['td']
#               /html/body/div.row/div.columns.large-9/table.dataframe/tbody/td
#               16:00
#               Lightning Talks
# -------
# Cluster #3
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           ['table.dataframe']
#           /html/body/div.row/div.columns.large-9/table.dataframe
#           table.dataframe
#             ['thead', 'tbody']
#             /html/body/div.row/div.columns.large-9/table.dataframe/thead
#             /html/body/div.row/div.columns.large-9/table.dataframe/tbody
#             thead
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table.dataframe/thead/tr
#               tr
#                 ['th']
#                 /html/body/div.row/div.columns.large-9/table.dataframe/thead/tr/th
#                 Time
#                 Track 1
#                 Track 2
#                 Time
#                 Track 1
#                 Track 2
# -------
# Cluster #4
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table
#             ['tbody']
#             /html/body/div.row/div.columns.large-9/table/tbody
#             tbody
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table/tbody/tr
#               tr
#                 ['td']
#                 /html/body/div.row/div.columns.large-9/table/tbody/tr/td
#                 9:00
#                 Introduction to Jupyter, M. Muller
#                 Databases for Scientists / SQL Intro, Alexander CS Hendorf
#                 Doing bioinformatics with scikit-bio and BioPython, Joris Vankerschaver
#                 10:30
#                 Coffee Break
#                 Coffee Break
#                 Coffee Break
#                 11:00
#                 Introduction to Python, M. Rastgoo & G. Lemaitre
# -------
# Cluster #6
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table.dataframe
#             tbody
#               tr
#                 ['td.has-link']
#                 /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link
#                 Scikit-learn and tabular data: closing the gap
#                 Deep Learning for Human Pose Estimation
#                 Numpy - where we are and where we want to be
#                 GMDH Neural Network for Short-term Electricity Load Forecasting
#                 Extending Python 3.7s Data Classes
#                 modAL: A modular active learning framework for Python
#                 Searching efficiently through (genomic) sequences with vantage point trees
#                 Imbalanced-learn: a scikit-learn-contrib to tackle learning from imbalanced data set
#                 ModelXplore, a python based model exploration
#                 Efficient Biomedical Named Entity Recognition in Python
#                 td.has-link
#                   ['br', 'i']
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i
#                   Joris Van den Bossche
#                   Ale Solano
#                   Matti Picus
#                   Kostas Passadis
#                   Geir Arne Hjelle
#                   Tivadar Danka
#                   Joris Vankerschaver
#                   Guillaume Lemaitre
#                   Nicolas Cellier
#                   Tilia Ellendorff
# -------
# Cluster #7
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           ['table']
#           /html/body/div.row/div.columns.large-9/table
#           table
#             ['thead']
#             /html/body/div.row/div.columns.large-9/table/thead
#             thead
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table/thead/tr
#               tr
#                 ['th']
#                 /html/body/div.row/div.columns.large-9/table/thead/tr/th
#                 Time
#                 Introductory
#                 Advanced
#                 Applications
#                 Time
#                 Introductory
#                 Advanced
#                 Applications

# %%
from collections import defaultdict, Counter
from functools import partial
import hashlib

import pygtrie
from pprint import pprint as pp
from pprint import pformat as pf

from html2text import html2text
from lxml.html import tostring
from slugify import slugify
import html_text

tohtml = partial(tostring, encoding='unicode')
totxt = html_text.extract_text

def hydrate(tree, doc, parent_path, merge_keys=True):
    relative_path = '>'.join(
        tree['_path'][len(parent_path):]
    ).lstrip('>')
    data = []
    _key = None
    for e in doc.cssselect(relative_path):
        if _key is None:
            _key = slugify(' '.join(filter(bool, [e.tag] + [re.sub(r'[\-\d]+', '', a)
                                                            for a in e.attrib.get('class', '').split()])), to_lower=True, separator='_')
            _key = relative_path.split('>')[-1]
            h = hashlib.sha256()
            h.update(_key.encode('utf8'))
            _key = '{}_{}'.format(e.tag, h.hexdigest()[:4])
        record = {}
        children_groups = list(filter(bool, [
                hydrate(child, e, tree['_path'], merge_keys=merge_keys)
                for child in tree['_children']
            ]))
        if children_groups:
            if merge_keys:
                for group in children_groups:
                    children = defaultdict(list)
                    for child in group:
                        key = child.pop('_key')
                        _attr = child.get('_attribs')
                        if _attr:
                            _cls = _attr.get('class')
                            if _cls:
                                _attr.pop('class')
                                key = _cls
                            child.update(child.pop('_attribs'))
                        children[key].append(child)
                    record.update(children)
            else:
                record['_children'] = children_groups
        if tree['_value']:
            _t = ' '.join([re.sub(r'\s+', ' ', s)
                           for s in e.xpath('self::*[not(self::script) and not(self::style)]/text()[normalize-space()]')]).strip()
            #_t = totxt(tohtml(e))
            if _t:
                record['_text'] = _t
            #elif not record.get('_children'):
            elif not children_groups:
                #_t = '__NO-CHILDREN__'+e.xpath('normalize-space()').strip()
                _t = ' '.join([re.sub(r'\s+', ' ', s)
                    for s in e.xpath('self::*[not(self::script) and not(self::style)]/text()[normalize-space()]')]).strip()+_t
                #_t = totxt(tohtml(e))
                if _t:
                    if len(_t) > 50:
                        record['_text'] = _t[:50]+'...'
                    else:
                        record['_text'] = _t
            _a = {k: re.sub('\s+', ' ', v.strip())
                                      for k, v in e.attrib.items()
                                      if k not in  (
                                          #'class',
                                          'style',
                                      )}
            if _a:
                record['_attribs'] = _a
        if record:
            record['_key'] = _key
            data.append(record)
    #if data and len(data) == 1:
    #    return data[0]
    return data
    #return {d.pop('_key'): d for d in data}

def make(path_conv, path, children, value=None):
    children = list(children)
    if value is None and len(children) == 1:
        # There is only one prefix.
        return children[0]
    else:
        return {'_children': children,
                #'_value': value[:64]+'...'+value[-64:] if value else value,
                '_value': value,
                '_path': path}

# %%
for i, cluster in clusters.items():
    print('Cluster {}'.format(i))
    #print()
    c = Counter([len(tp.split('/')) for tp in cluster])
    #print(dict(c))
    print('Cluster size: {}, cluster depths: {} ({}), depth_diff={}'.format(len(cluster), c, len(c), (max(c) - min(c))))
    print()
# Out:
# Cluster 4
# Cluster size: 3, cluster depths: Counter({9: 1, 8: 1, 7: 1}) (3), depth_diff=2
#
# Cluster 5
# Cluster size: 2, cluster depths: Counter({9: 1, 8: 1}) (2), depth_diff=1
#
# Cluster 6
# Cluster size: 3, cluster depths: Counter({10: 2, 9: 1}) (2), depth_diff=1
#
# Cluster 7
# Cluster size: 4, cluster depths: Counter({9: 1, 6: 1, 7: 1, 8: 1}) (4), depth_diff=3
#
# Cluster 0
# Cluster size: 2, cluster depths: Counter({8: 1, 9: 1}) (2), depth_diff=1
#
# Cluster 3
# Cluster size: 5, cluster depths: Counter({7: 2, 9: 1, 6: 1, 8: 1}) (4), depth_diff=3
#
# Cluster 2
# Cluster size: 5, cluster depths: Counter({4: 2, 6: 2, 8: 1}) (3), depth_diff=4
#
# Cluster 1
# Cluster size: 3, cluster depths: Counter({10: 3}) (1), depth_diff=0

# %%
doc = lxml.html.fromstring(page_content)
for n, cluster in sorted(clusters.items()):
    size = len(cluster)
    #if size < 2 and size > 30:
    #    continue
    c = Counter([len(tp.split('/')) for tp in cluster])
    depth_diff = max(c) - min(c)
    #if depth_diff > 10:
    #    continue
    print("Cluster {}".format(n))
    tagpaths_trie = pygtrie.Trie()
    for tp in cluster:
        tagpaths_trie[tp.split('/')] = tp
        
    r = tagpaths_trie.traverse(make)
    
    o = hydrate(r, doc, '', merge_keys=False)
    print('Size {}'.format(len(o)))
    s = pf(o)
    print(s)

# %%
doc = lxml.html.fromstring(page_content)
tagpaths_trie = pygtrie.Trie()
for tp in clusters[6]:
    tagpaths_trie[tp.split('/')] = tp
additional_tps = [
    '/html/body/div.row/div.columns.large-9/h3',
]
for tp in additional_tps: 
    tagpaths_trie[tp.split('/')] = tp
    pass

r = tagpaths_trie.traverse(make)

o = hydrate(r, doc, '', merge_keys=True)
s = pf(o)

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('test.euroscipy2018.json', 'w') as fp:
    json.dump(o, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %%
def pretty(path_conv, path, children, value=None):
    print((path_conv, path, children, value))

tagpaths_trie.traverse(pretty)
# Out:
# (<bound method Trie._key_from_path of Trie(((('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link', 'br'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link', 'i'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'h3'), '/html/body/div.row/div.columns.large-9/h3'),))>, (), <generator object _Node.traverse.<locals>.children at 0x7f6652efb0f8>, None)

# %%
def make2(path_conv, path, children, value=None):
    #print(path_conv)
    children = list(children)
    if value is None and len(children) == 1:
        # There is only one prefix.
        return children[0]
    else:
        o = {}
        if children:
            o['_children'] = children
        if value:
            o['_value'] = value
        return o
        return {
                #'_value': value[:64]+'...'+value[-64:] if value else value,
                '_value': value,
                '_path': '/'.join(path)}
    
pp(tagpaths_trie.traverse(make2))
# Out:
# {'_children': [{'_children': [{'_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br'},
#                               {'_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i'}],
#                 '_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link'},
#                {'_value': '/html/body/div.row/div.columns.large-9/h3'}]}

# %%
p = '>'.join(additional_tps[0].split('/')).lstrip('>')
doc.cssselect(p)
# Out:
# [<Element img at 0x7f0efbc88a98>,
#  <Element img at 0x7f0efbc88278>,
#  <Element img at 0x7f0efbc88228>,
#  <Element img at 0x7f0efbb4b638>,
#  <Element img at 0x7f0efbb4b5e8>,
#  <Element img at 0x7f0efbb4b688>,
#  <Element img at 0x7f0efbb4b6d8>,
#  <Element img at 0x7f0efbb4b728>,
#  <Element img at 0x7f0efbb4b778>,
#  <Element img at 0x7f0efbb4b7c8>,
#  <Element img at 0x7f0efbb4b818>,
#  <Element img at 0x7f0efbb4b868>,
#  <Element img at 0x7f0efbb4b8b8>,
#  <Element img at 0x7f0efbb4b908>,
#  <Element img at 0x7f0efbb4b958>,
#  <Element img at 0x7f0efbb4b9a8>,
#  <Element img at 0x7f0efbb4b9f8>,
#  <Element img at 0x7f0efbb4ba48>,
#  <Element img at 0x7f0efbb4ba98>,
#  <Element img at 0x7f0efbb4bae8>]
