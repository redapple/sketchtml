# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Fist, get the HTML

# %%
import requests
page = requests.get('http://www.paperandironbooking.com/dates/')
page_content = page.text
#page_content = open('samples/toutpartout.be.snippet.shows_search.php.html').read()

# %% [markdown]
# We can list the repeating tagpaths, with or without classes or HTML IDs:

# %%
from collections import Counter
from sketchtml.repeats import TagPathClustering


clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False,
                               ignore_classes=('gigpress-alt',),
                               text_only=True
                              )
clustering._build_tagpaths()

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 1:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# (244) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a
# (122) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-date
# (122) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city
# (122) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-country
# (122) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/a.gigpress-links-toggle
# (113) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue/a
# ( 82) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item/a.gigpress-tickets-link
# ( 26) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/h3.gigpress-artist-heading/a
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-date
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-city
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-venue
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-country
# (  9) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue
# (  3) /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/footer/div/div.clearfix.container/div/a

# %%
clusters = clustering.clusters()

# %%
clustering.simhelper.plot_signals()

# %%
sorted(set(clustering.tagpaths))
# Out:
# ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div.et_social_pin_images_outer/div.et_social_pinterest_window/div.et_social_modal_header/h3',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/h3.gigpress-artist-heading/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/a.gigpress-links-toggle',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item/a.gigpress-tickets-link',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-country',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-date',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-city',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-country',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-date',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-venue',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/footer/div/div.clearfix.container/div',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/footer/div/div.clearfix.container/div/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/div/div.closed.mobile_nav/span.select_page',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.current-menu-item.current_page_item.menu-item.menu-item-3962.menu-item-object-page.menu-item-type-post_type.page-item-82.page_item/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.menu-item.menu-item-3957.menu-item-object-page.menu-item-type-post_type/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.menu-item.menu-item-3958.menu-item-object-page.menu-item-type-post_type/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.menu-item.menu-item-3959.menu-item-object-page.menu-item-type-post_type/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.menu-item.menu-item-7415.menu-item-object-page.menu-item-type-post_type/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/header/div.clearfix.container.et_menu_container/div/nav/ul.nav/li.menu-item.menu-item-771.menu-item-home.menu-item-object-custom.menu-item-type-custom/a',
#  '/html/head/title']

# %%
len(set(clustering.tagpaths))
# Out:
# 25

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item'],
#              1: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/h3.gigpress-artist-heading/a',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-city',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-country',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-date',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-venue'],
#              2: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/footer/div/div.clearfix.container/div/a'],
#              3: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue'],
#              4: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item/a.gigpress-tickets-link'],
#              5: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-date'],
#              6: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue/a'],
#              7: ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/a.gigpress-links-toggle',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a',
#                  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-country']})

# %% [markdown]
# ## Let's build a trie to reconstruct the layout from a tagpath list (from one or more clusters or a chosen subset of tagpaths)

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
_node_repr = clustering._node_repr
# This if borrowed from https://towardsdatascience.com/implementing-a-trie-data-structure-in-python-in-less-than-100-lines-of-code-a877ea23c1a1

class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %% [markdown]
# To help chose the clusters we need, we can print out some of the text data for each tagpath in each cluster.

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 0:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('./text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)[:100]
                if t or attribs:
                #if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass
# Out:
# ---- Cluster #0 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item
# (173, 'Free', {})
# (294, 'Free', {})
# (373, 'Reservation only', {})
# (410, 'Free', {})
# (466, 'Free', {})
# (569, 'Free', {})
# (737, 'Open House (free, early)', {})
# (816, 'Celtic Connections', {})
# (837, 'Sold out', {})
# (953, 'Donation', {})
#
# ---- Cluster #1 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/h3.gigpress-artist-heading/a
# (85, 'Andy Jenkins', {'href': 'https://www.paperandironbooking.com/andy-jenkins'})
# (130, 'Anna St. Louis', {'href': 'http://www.paperandironbooking.com/roster/anna-st-louis/'})
# (503, 'Buke and Gase', {'href': 'http://www.paperandironbooking.com/artists/buke-and-gase/'})
# (711, 'Daniel Knox', {'href': 'http://www.paperandironbooking.com/roster/danielknox'})
# (1125, 'David Nance', {'href': 'http://www.paperandironbooking.com/roster/david-nance'})
# (1420, 'River Whyless', {'href': 'http://www.paperandironbooking.com/roster/river-whyless'})
# (1469, 'Ryley Walker', {'href': 'http://www.paperandironbooking.com/artists/ryley-walker/'})
# (1798, 'Screaming Females', {'href': 'http://www.paperandironbooking.com/roster/screaming-females/'})
# (2300, 'Tanukichan', {'href': 'http://www.paperandironbooking.com/roster/tanukichan/'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-city
# (90, 'City', {'scope': 'col'})
# (135, 'City', {'scope': 'col'})
# (508, 'City', {'scope': 'col'})
# (716, 'City', {'scope': 'col'})
# (1130, 'City', {'scope': 'col'})
# (1425, 'City', {'scope': 'col'})
# (1474, 'City', {'scope': 'col'})
# (1803, 'City', {'scope': 'col'})
# (2305, 'City', {'scope': 'col'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-country
# (92, 'Country', {'scope': 'col'})
# (137, 'Country', {'scope': 'col'})
# (510, 'Country', {'scope': 'col'})
# (718, 'Country', {'scope': 'col'})
# (1132, 'Country', {'scope': 'col'})
# (1427, 'Country', {'scope': 'col'})
# (1476, 'Country', {'scope': 'col'})
# (1805, 'Country', {'scope': 'col'})
# (2307, 'Country', {'scope': 'col'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-date
# (89, 'Date', {'scope': 'col'})
# (134, 'Date', {'scope': 'col'})
# (507, 'Date', {'scope': 'col'})
# (715, 'Date', {'scope': 'col'})
# (1129, 'Date', {'scope': 'col'})
# (1424, 'Date', {'scope': 'col'})
# (1473, 'Date', {'scope': 'col'})
# (1802, 'Date', {'scope': 'col'})
# (2304, 'Date', {'scope': 'col'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-venue
# (91, 'Venue', {'scope': 'col'})
# (136, 'Venue', {'scope': 'col'})
# (509, 'Venue', {'scope': 'col'})
# (717, 'Venue', {'scope': 'col'})
# (1131, 'Venue', {'scope': 'col'})
# (1426, 'Venue', {'scope': 'col'})
# (1475, 'Venue', {'scope': 'col'})
# (1804, 'Venue', {'scope': 'col'})
# (2306, 'Venue', {'scope': 'col'})
#
# ---- Cluster #2 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/footer/div/div.clearfix.container/div/a
# (2548, 'Impressum', {'href': 'https://www.paperandironbooking.com/impressum/'})
# (2549, 'Datenschutz', {'href': 'https://www.paperandironbooking.com/datenschutz/'})
# (2550, 'Jobs', {'href': 'https://www.paperandironbooking.com/jobs/'})
#
# ---- Cluster #3 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue
# (160, 'Hy Brasil Music Club', {})
# (433, 'Theater der Wohngemeinschaft', {})
# (489, 'TBD', {})
# (920, 'St Denijs Church', {})
# (1093, 'TBD', {})
# (1849, 'Urban Rock Concept', {})
# (1888, 'Pérgola de La Marina', {})
# (2224, 'Hus 7', {})
# (2468, 'Venue TBD', {})
#
# ---- Cluster #4 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item/a.gigpress-tickets-link
# (175, 'Buy Tickets', {'href': 'http://hdfst.uk/E50140', 'target': '_blank'})
# (195, 'Buy Tickets', {'href': 'https://www.thehugandpint.com/events/3990c120-c3fb-0136-57a0-564c66862112', 'target': '_blank'})
# (215, 'Buy Tickets', {'href': 'https://www.lunatickets.co.uk/event/anna-st-louis/hyde-park-book-club/1291530', 'target': '_blank'})
# (235, 'Buy Tickets', {'href': 'http://bit.ly/AStLouis', 'target': '_blank'})
# (255, 'Buy Tickets', {'href': 'https://rockfeedback.seetickets.com/event/anna-st-louis/the-slaughtered-lamb/1292908', 'target': '_blank'})
# (275, 'Buy Tickets', {'href': 'https://motelmozaique.nl/festival/tickets/', 'target': '_blank'})
# (314, 'Buy Tickets', {'href': 'https://puschen.tickets.de/de/event/1001424', 'target': '_blank'})
# (334, 'Buy Tickets', {'href': 'https://www.tixforgigs.com/site/Pages/Shop/ShowEvent.aspx?ID=27821', 'target': '_blank'})
# (354, 'Buy Tickets', {'href': 'https://www.love-your-artist.de/de/artmeetsart/live-anna-st-louis/', 'target': '_blank'})
# (447, 'Buy Tickets', {'href': 'https://www.eventbrite.de/e/anna-st-louis-tickets-53010603141', 'target': '_blank'})
#
# ---- Cluster #5 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city
# (96, 'Copenhagen (DK)', {})
# (114, 'Glasgow (UK)', {})
# (141, 'Sheffield', {})
# (159, 'Bristol (UK)', {})
# (179, 'Glasgow (UK)', {})
# (199, 'Leeds', {})
# (219, 'Brighton (UK)', {})
# (239, 'London (UK)', {})
# (259, 'Rotterdam (NL)', {})
# (279, 'Offenbach (DE)', {})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-date
# (95, '25/01/19', {})
# (113, '29/01/19', {})
# (140, '13/04/19', {})
# (158, '14/04/19', {})
# (178, '15/04/19', {})
# (198, '16/04/19', {})
# (218, '17/04/19', {})
# (238, '18/04/19', {})
# (258, '18/04/19\t\t\t - 20/04/19', {})
# (278, '21/04/19', {})
#
# ---- Cluster #6 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue/a
# (98, 'Huset', {'href': 'http://www.huset-kbh.dk/', 'target': '_blank'})
# (116, 'The Hug & Pint', {'href': 'https://www.facebook.com/TheHugandPint', 'target': '_blank'})
# (143, 'Picture House Social', {'href': 'http://picture-house-social.com/', 'target': '_blank'})
# (181, 'The Hug & Pint', {'href': 'https://www.facebook.com/TheHugandPint', 'target': '_blank'})
# (201, 'Hyde Park Book Club', {'href': 'http://www.hydeparkbookclub.co.uk/', 'target': '_blank'})
# (221, 'The Hope & Ruin', {'href': 'http://www.drinkinbrighton.co.uk/hope', 'target': '_blank'})
# (241, 'Slaughtered Lamb', {'href': 'http://www.theslaughteredlambpub.com/', 'target': '_blank'})
# (261, 'Motel Mozaique', {'href': 'http://www.motelmozaique.nl/', 'target': '_blank'})
# (281, 'Hafen 2', {'href': 'http://www.hafen2.net', 'target': '_blank'})
# (300, 'Monarch', {'href': 'http://www.kottimonarch.de/', 'target': '_blank'})
#
# ---- Cluster #7 ----
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/a.gigpress-links-toggle
# (103, 'Add', {'href': '#calendar-links-4666'})
# (121, 'Add', {'href': '#calendar-links-4667'})
# (148, 'Add', {'href': '#calendar-links-4720'})
# (165, 'Add', {'href': '#calendar-links-4721'})
# (186, 'Add', {'href': '#calendar-links-4706'})
# (206, 'Add', {'href': '#calendar-links-4707'})
# (226, 'Add', {'href': '#calendar-links-4708'})
# (246, 'Add', {'href': '#calendar-links-4709'})
# (266, 'Add', {'href': '#calendar-links-4705'})
# (286, 'Add', {'href': '#calendar-links-4710'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a
# (107, 'Add to Google Calendar', {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Andy+Jenkins+at+Huset&dates=20190125/20190125&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Andy+Jenkins&location=Huset%2C+Copenhagen+%28DK%29%2C+DK&details=&trp=true;'})
# (109, 'Download iCal', {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4666'})
# (125, 'Add to Google Calendar', {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Andy+Jenkins+at+The+Hug+%26+Pint&dates=20190129/20190129&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Andy+Jenkins&location=The+Hug+%26+Pint%2C+Glasgow+%28UK%29%2C+UK&details=&trp=true;'})
# (127, 'Download iCal', {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4667'})
# (152, 'Add to Google Calendar', {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Picture+House+Social&dates=20190413/20190413&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Picture+House+Social%2C+Sheffield%2C+UK&details=&trp=true;'})
# (154, 'Download iCal', {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4720'})
# (169, 'Add to Google Calendar', {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Hy+Brasil+Music+Club&dates=20190414/20190414&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Hy+Brasil+Music+Club%2C+Bristol+%28UK%29%2C+UK&details=Notes%3A+Free+&trp=true;'})
# (171, 'Download iCal', {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4721'})
# (190, 'Add to Google Calendar', {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+The+Hug+%26+Pint&dates=20190415/20190415&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=The+Hug+%26+Pint%2C+Glasgow+%28UK%29%2C+UK&details=&trp=true;'})
# (192, 'Download iCal', {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4706'})
#
# ---
# /html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-country
# (99, 'Denmark', {})
# (117, 'United Kingdom', {})
# (144, 'United Kingdom', {})
# (161, 'United Kingdom', {})
# (182, 'United Kingdom', {})
# (202, 'United Kingdom', {})
# (222, 'United Kingdom', {})
# (242, 'United Kingdom', {})
# (262, 'Netherlands', {})
# (282, 'Germany', {})

# %%
/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city
/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-alt.gigpress-row/td.gigpress-city

# %%
clustering.plot_affinity_matrix()

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = []
for i in [1, 0, 3, 4, 5, 6, 7]:
    for tp in clusters[i]:
        tps.append(tp)
tps
# Out:
# ['/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/h3.gigpress-artist-heading/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-city',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-country',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-date',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.gigpress-header/th.gigpress-venue',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td/span.gigpress-info-item/a.gigpress-tickets-link',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-city',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-date',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-venue/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/a.gigpress-links-toggle',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-info/td.gigpress-links-cell/div.gigpress-calendar-add/div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a',
#  '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner/table.gigpress-table.upcoming/tbody/tr.active.gigpress-row/td.gigpress-country']

# %%
tps = [
     '/html/body/div/div/div/article/div/ul/li/article',
 '/html/body/div/div/div/article/div/ul/li/article/div',
 '/html/body/div/div/div/article/div/ul/li/article/div/a',
 '/html/body/div/div/div/article/div/ul/li/article/div/button',
 '/html/body/div/div/div/article/div/ul/li/article/header',
 '/html/body/div/div/div/article/div/ul/li/article/header/a',
 '/html/body/div/div/div/article/div/ul/li/article/header/a/img',
 '/html/body/div/div/div/article/div/ul/li/article/header/h2',
 '/html/body/div/div/div/article/div/ul/li/article/header/h2/a',
 '/html/body/div/div/div/article/div/ul/li/article/header/time',
 '/html/body/div/div/div/article/div/ul/li/article/section',
 '/html/body/div/div/div/article/div/ul/li/article/section/p',
 '/html/body/div/div/div/article/div/ul/li/article/section/p/a',
 '/html/body/div/div/div/article/div/ul/li/article/section/p/br',
]

# %% [markdown]
# Now let's insert them into the trie:

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
for tp in tps:
    steps = tp.lstrip('/').split('/')
    for nl in nodelists[tp][:]:
        add(root, nl)

# %%
def layout(node, summary=True):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=len(set(node.elements)) if summary else set(node.elements),
        children=[layout(c, summary=summary) for c in node.children],
        word_finished=node.word_finished
    )

# %% [markdown]
# If we check the general structure of the trie, we can notice that some levels only have 1 child.

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1 and not trienode.word_finished:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
layout(root)
# Out:
# {'tag': '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner',
#  'element': 1,
#  'children': [{'tag': 'h3.gigpress-artist-heading/a',
#    'element': 9,
#    'children': [],
#    'word_finished': False},
#   {'tag': 'table.gigpress-table.upcoming/tbody',
#    'element': 131,
#    'children': [{'tag': 'tr.gigpress-header',
#      'element': 9,
#      'children': [{'tag': 'th.gigpress-city',
#        'element': 9,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-country',
#        'element': 9,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-date',
#        'element': 9,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-venue',
#        'element': 9,
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False},
#     {'tag': 'tr.active.gigpress-info',
#      'element': 122,
#      'children': [{'tag': 'td/span.gigpress-info-item',
#        'element': 108,
#        'children': [{'tag': 'a.gigpress-tickets-link',
#          'element': 82,
#          'children': [],
#          'word_finished': True}],
#        'word_finished': False},
#       {'tag': 'td.gigpress-links-cell/div.gigpress-calendar-add',
#        'element': 122,
#        'children': [{'tag': 'a.gigpress-links-toggle',
#          'element': 122,
#          'children': [],
#          'word_finished': True},
#         {'tag': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a',
#          'element': 244,
#          'children': [],
#          'word_finished': False}],
#        'word_finished': False}],
#      'word_finished': False},
#     {'tag': 'tr.active.gigpress-row',
#      'element': 122,
#      'children': [{'tag': 'td.gigpress-venue',
#        'element': 122,
#        'children': [{'tag': 'a',
#          'element': 113,
#          'children': [],
#          'word_finished': True}],
#        'word_finished': True},
#       {'tag': 'td.gigpress-city',
#        'element': 122,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'td.gigpress-date',
#        'element': 122,
#        'children': [],
#        'word_finished': True},
#       {'tag': 'td.gigpress-country',
#        'element': 122,
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# We can collapse those branches:

# %% [markdown]
# The trie also keeps references to individual HTML nodes, with their document order so that we can re-build the data hierarchy:

# %%
layout(root, summary=False)
# Out:
# {'tag': '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner',
#  'element': {Node(tag='div', doc_order=83, child_position=1, attribs={'class': 'et_pb_text_inner'}, element=<Element div at 0x7fd7e6420888>)},
#  'children': [{'tag': 'h3.gigpress-artist-heading/a',
#    'element': {Node(tag='a', doc_order=85, child_position=1, attribs={'href': 'https://www.paperandironbooking.com/andy-jenkins'}, element=<Element a at 0x7fd7e66c7348>),
#     Node(tag='a', doc_order=130, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/anna-st-louis/'}, element=<Element a at 0x7fd7e63e1a08>),
#     Node(tag='a', doc_order=503, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/artists/buke-and-gase/'}, element=<Element a at 0x7fd7e64d2748>),
#     Node(tag='a', doc_order=711, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/danielknox'}, element=<Element a at 0x7fd7e64aa348>),
#     Node(tag='a', doc_order=1125, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/david-nance'}, element=<Element a at 0x7fd7e62b4948>),
#     Node(tag='a', doc_order=1420, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/river-whyless'}, element=<Element a at 0x7fd7e6326088>),
#     Node(tag='a', doc_order=1469, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/artists/ryley-walker/'}, element=<Element a at 0x7fd7f95db308>),
#     Node(tag='a', doc_order=1798, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/screaming-females/'}, element=<Element a at 0x7fd7e6aeaf88>),
#     Node(tag='a', doc_order=2300, child_position=1, attribs={'href': 'http://www.paperandironbooking.com/roster/tanukichan/'}, element=<Element a at 0x7fd7e640a548>)},
#    'children': [],
#    'word_finished': False},
#   {'tag': 'table.gigpress-table.upcoming/tbody',
#    'element': {Node(tag='tbody', doc_order=87, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e657ffc8>),
#     Node(tag='tbody', doc_order=93, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e62f69c8>),
#     Node(tag='tbody', doc_order=111, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e6659448>),
#     Node(tag='tbody', doc_order=132, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e63e1ac8>),
#     Node(tag='tbody', doc_order=138, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e63e1208>),
#     Node(tag='tbody', doc_order=156, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e6488548>),
#     Node(tag='tbody', doc_order=176, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e65f7548>),
#     Node(tag='tbody', doc_order=196, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e63d9108>),
#     Node(tag='tbody', doc_order=216, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e630f548>),
#     Node(tag='tbody', doc_order=236, child_position=7, attribs={}, element=<Element tbody at 0x7fd821147ac8>),
#     Node(tag='tbody', doc_order=256, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e637ec88>),
#     Node(tag='tbody', doc_order=276, child_position=9, attribs={}, element=<Element tbody at 0x7fd7ea39f488>),
#     Node(tag='tbody', doc_order=295, child_position=10, attribs={}, element=<Element tbody at 0x7fd7f95e40c8>),
#     Node(tag='tbody', doc_order=315, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e64e3b08>),
#     Node(tag='tbody', doc_order=335, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e64a1508>),
#     Node(tag='tbody', doc_order=355, child_position=13, attribs={}, element=<Element tbody at 0x7fd804de5d08>),
#     Node(tag='tbody', doc_order=374, child_position=14, attribs={}, element=<Element tbody at 0x7fd7e6358648>),
#     Node(tag='tbody', doc_order=392, child_position=15, attribs={}, element=<Element tbody at 0x7fd7e6337208>),
#     Node(tag='tbody', doc_order=411, child_position=16, attribs={}, element=<Element tbody at 0x7fd7da4b51c8>),
#     Node(tag='tbody', doc_order=429, child_position=17, attribs={}, element=<Element tbody at 0x7fd7ea2fdf88>),
#     Node(tag='tbody', doc_order=448, child_position=18, attribs={}, element=<Element tbody at 0x7fd7e65b5948>),
#     Node(tag='tbody', doc_order=467, child_position=19, attribs={}, element=<Element tbody at 0x7fd7e65b5848>),
#     Node(tag='tbody', doc_order=485, child_position=20, attribs={}, element=<Element tbody at 0x7fd7e644f688>),
#     Node(tag='tbody', doc_order=505, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e64d2a08>),
#     Node(tag='tbody', doc_order=511, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e6510d08>),
#     Node(tag='tbody', doc_order=531, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e6464548>),
#     Node(tag='tbody', doc_order=551, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e6464108>),
#     Node(tag='tbody', doc_order=570, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e6a4dcc8>),
#     Node(tag='tbody', doc_order=590, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e645fb88>),
#     Node(tag='tbody', doc_order=610, child_position=7, attribs={}, element=<Element tbody at 0x7fd7e64c8e88>),
#     Node(tag='tbody', doc_order=630, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e6611ec8>),
#     Node(tag='tbody', doc_order=650, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e6402688>),
#     Node(tag='tbody', doc_order=670, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e6447d48>),
#     Node(tag='tbody', doc_order=690, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e6447448>),
#     Node(tag='tbody', doc_order=713, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e47f09c8>),
#     Node(tag='tbody', doc_order=719, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e47f0308>),
#     Node(tag='tbody', doc_order=738, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e646b9c8>),
#     Node(tag='tbody', doc_order=758, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e646ba48>),
#     Node(tag='tbody', doc_order=778, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e644d648>),
#     Node(tag='tbody', doc_order=798, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e644dc88>),
#     Node(tag='tbody', doc_order=819, child_position=7, attribs={}, element=<Element tbody at 0x7fd7f95df988>),
#     Node(tag='tbody', doc_order=838, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e6457548>),
#     Node(tag='tbody', doc_order=858, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e6621d88>),
#     Node(tag='tbody', doc_order=876, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e6621048>),
#     Node(tag='tbody', doc_order=896, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e65c9fc8>),
#     Node(tag='tbody', doc_order=916, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e65bd088>),
#     Node(tag='tbody', doc_order=935, child_position=13, attribs={}, element=<Element tbody at 0x7fd7e65bd688>),
#     Node(tag='tbody', doc_order=954, child_position=14, attribs={}, element=<Element tbody at 0x7fd7e6a3ad08>),
#     Node(tag='tbody', doc_order=973, child_position=15, attribs={}, element=<Element tbody at 0x7fd7e6a49d48>),
#     Node(tag='tbody', doc_order=992, child_position=16, attribs={}, element=<Element tbody at 0x7fd7f96a8c88>),
#     Node(tag='tbody', doc_order=1010, child_position=17, attribs={}, element=<Element tbody at 0x7fd7e6632d08>),
#     Node(tag='tbody', doc_order=1030, child_position=18, attribs={}, element=<Element tbody at 0x7fd7e66326c8>),
#     Node(tag='tbody', doc_order=1050, child_position=19, attribs={}, element=<Element tbody at 0x7fd7e63981c8>),
#     Node(tag='tbody', doc_order=1069, child_position=20, attribs={}, element=<Element tbody at 0x7fd7f95e0248>),
#     Node(tag='tbody', doc_order=1089, child_position=21, attribs={}, element=<Element tbody at 0x7fd7e632e388>),
#     Node(tag='tbody', doc_order=1106, child_position=22, attribs={}, element=<Element tbody at 0x7fd7e632e948>),
#     Node(tag='tbody', doc_order=1127, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e62b41c8>),
#     Node(tag='tbody', doc_order=1133, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e62b4dc8>),
#     Node(tag='tbody', doc_order=1152, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e632b7c8>),
#     Node(tag='tbody', doc_order=1171, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e632b548>),
#     Node(tag='tbody', doc_order=1189, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e63cd188>),
#     Node(tag='tbody', doc_order=1207, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e63cddc8>),
#     Node(tag='tbody', doc_order=1225, child_position=7, attribs={}, element=<Element tbody at 0x7fd7e63cd448>),
#     Node(tag='tbody', doc_order=1245, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e6614048>),
#     Node(tag='tbody', doc_order=1265, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e643a688>),
#     Node(tag='tbody', doc_order=1284, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e643a808>),
#     Node(tag='tbody', doc_order=1304, child_position=11, attribs={}, element=<Element tbody at 0x7fd7f95d67c8>),
#     Node(tag='tbody', doc_order=1322, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e648ba48>),
#     Node(tag='tbody', doc_order=1340, child_position=13, attribs={}, element=<Element tbody at 0x7fd7e63f5088>),
#     Node(tag='tbody', doc_order=1359, child_position=14, attribs={}, element=<Element tbody at 0x7fd7e63f5e48>),
#     Node(tag='tbody', doc_order=1379, child_position=15, attribs={}, element=<Element tbody at 0x7fd7e65c3c88>),
#     Node(tag='tbody', doc_order=1399, child_position=16, attribs={}, element=<Element tbody at 0x7fd7e6326788>),
#     Node(tag='tbody', doc_order=1422, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e6326108>),
#     Node(tag='tbody', doc_order=1428, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e6326fc8>),
#     Node(tag='tbody', doc_order=1448, child_position=3, attribs={}, element=<Element tbody at 0x7fd7f95db988>),
#     Node(tag='tbody', doc_order=1471, child_position=1, attribs={}, element=<Element tbody at 0x7fd7f95db208>),
#     Node(tag='tbody', doc_order=1477, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e63b41c8>),
#     Node(tag='tbody', doc_order=1497, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e63b4888>),
#     Node(tag='tbody', doc_order=1517, child_position=4, attribs={}, element=<Element tbody at 0x7fd7f95dadc8>),
#     Node(tag='tbody', doc_order=1537, child_position=5, attribs={}, element=<Element tbody at 0x7fd7f95da3c8>),
#     Node(tag='tbody', doc_order=1557, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e649d688>),
#     Node(tag='tbody', doc_order=1577, child_position=7, attribs={}, element=<Element tbody at 0x7fd7e63f1388>),
#     Node(tag='tbody', doc_order=1597, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e63a0a88>),
#     Node(tag='tbody', doc_order=1617, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e62b63c8>),
#     Node(tag='tbody', doc_order=1637, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e62b6848>),
#     Node(tag='tbody', doc_order=1657, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e4789c48>),
#     Node(tag='tbody', doc_order=1677, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e4789588>),
#     Node(tag='tbody', doc_order=1697, child_position=13, attribs={}, element=<Element tbody at 0x7fd7e63613c8>),
#     Node(tag='tbody', doc_order=1717, child_position=14, attribs={}, element=<Element tbody at 0x7fd7e65ce888>),
#     Node(tag='tbody', doc_order=1737, child_position=15, attribs={}, element=<Element tbody at 0x7fd7e65cee48>),
#     Node(tag='tbody', doc_order=1757, child_position=16, attribs={}, element=<Element tbody at 0x7fd7e6ac6188>),
#     Node(tag='tbody', doc_order=1777, child_position=17, attribs={}, element=<Element tbody at 0x7fd7e6625e48>),
#     Node(tag='tbody', doc_order=1800, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e6aeaa08>),
#     Node(tag='tbody', doc_order=1806, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e6aea448>),
#     Node(tag='tbody', doc_order=1825, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e6aeaa48>),
#     Node(tag='tbody', doc_order=1845, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e63b8888>),
#     Node(tag='tbody', doc_order=1864, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e65b99c8>),
#     Node(tag='tbody', doc_order=1884, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e64eeb08>),
#     Node(tag='tbody', doc_order=1902, child_position=7, attribs={}, element=<Element tbody at 0x7fd7e6495088>),
#     Node(tag='tbody', doc_order=1922, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e6495e48>),
#     Node(tag='tbody', doc_order=1940, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e47b8188>),
#     Node(tag='tbody', doc_order=1960, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e47b8f88>),
#     Node(tag='tbody', doc_order=1980, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e6609fc8>),
#     Node(tag='tbody', doc_order=2000, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e6469488>),
#     Node(tag='tbody', doc_order=2020, child_position=13, attribs={}, element=<Element tbody at 0x7fd7e64d6488>),
#     Node(tag='tbody', doc_order=2040, child_position=14, attribs={}, element=<Element tbody at 0x7fd7e662a4c8>),
#     Node(tag='tbody', doc_order=2060, child_position=15, attribs={}, element=<Element tbody at 0x7fd7e662a988>),
#     Node(tag='tbody', doc_order=2080, child_position=16, attribs={}, element=<Element tbody at 0x7fd7e64917c8>),
#     Node(tag='tbody', doc_order=2100, child_position=17, attribs={}, element=<Element tbody at 0x7fd7e6491c48>),
#     Node(tag='tbody', doc_order=2120, child_position=18, attribs={}, element=<Element tbody at 0x7fd7f9639e08>),
#     Node(tag='tbody', doc_order=2140, child_position=19, attribs={}, element=<Element tbody at 0x7fd7e635b408>),
#     Node(tag='tbody', doc_order=2160, child_position=20, attribs={}, element=<Element tbody at 0x7fd7e6321888>),
#     Node(tag='tbody', doc_order=2180, child_position=21, attribs={}, element=<Element tbody at 0x7fd7e63211c8>),
#     Node(tag='tbody', doc_order=2200, child_position=22, attribs={}, element=<Element tbody at 0x7fd7e631dc88>),
#     Node(tag='tbody', doc_order=2220, child_position=23, attribs={}, element=<Element tbody at 0x7fd7e645b1c8>),
#     Node(tag='tbody', doc_order=2239, child_position=24, attribs={}, element=<Element tbody at 0x7fd7e4791dc8>),
#     Node(tag='tbody', doc_order=2259, child_position=25, attribs={}, element=<Element tbody at 0x7fd7e4791388>),
#     Node(tag='tbody', doc_order=2279, child_position=26, attribs={}, element=<Element tbody at 0x7fd7e4791408>),
#     Node(tag='tbody', doc_order=2302, child_position=1, attribs={}, element=<Element tbody at 0x7fd7e640a108>),
#     Node(tag='tbody', doc_order=2308, child_position=2, attribs={}, element=<Element tbody at 0x7fd7e640a648>),
#     Node(tag='tbody', doc_order=2328, child_position=3, attribs={}, element=<Element tbody at 0x7fd7e661a488>),
#     Node(tag='tbody', doc_order=2348, child_position=4, attribs={}, element=<Element tbody at 0x7fd7e661a708>),
#     Node(tag='tbody', doc_order=2369, child_position=5, attribs={}, element=<Element tbody at 0x7fd7e661e808>),
#     Node(tag='tbody', doc_order=2388, child_position=6, attribs={}, element=<Element tbody at 0x7fd7e661e3c8>),
#     Node(tag='tbody', doc_order=2407, child_position=7, attribs={}, element=<Element tbody at 0x7fd7e496bbc8>),
#     Node(tag='tbody', doc_order=2426, child_position=8, attribs={}, element=<Element tbody at 0x7fd7e496b5c8>),
#     Node(tag='tbody', doc_order=2445, child_position=9, attribs={}, element=<Element tbody at 0x7fd7e6408cc8>),
#     Node(tag='tbody', doc_order=2464, child_position=10, attribs={}, element=<Element tbody at 0x7fd7e6408e48>),
#     Node(tag='tbody', doc_order=2482, child_position=11, attribs={}, element=<Element tbody at 0x7fd7e6306548>),
#     Node(tag='tbody', doc_order=2502, child_position=12, attribs={}, element=<Element tbody at 0x7fd7e6350b48>),
#     Node(tag='tbody', doc_order=2522, child_position=13, attribs={}, element=<Element tbody at 0x7fd804e1e208>)},
#    'children': [{'tag': 'tr.gigpress-header',
#      'element': {Node(tag='tr', doc_order=88, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e657fb88>),
#       Node(tag='tr', doc_order=133, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e63e1e48>),
#       Node(tag='tr', doc_order=506, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e6510bc8>),
#       Node(tag='tr', doc_order=714, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e47f0d48>),
#       Node(tag='tr', doc_order=1128, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e62b4a88>),
#       Node(tag='tr', doc_order=1423, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e6326e88>),
#       Node(tag='tr', doc_order=1472, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7f95dbc88>),
#       Node(tag='tr', doc_order=1801, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e6aea2c8>),
#       Node(tag='tr', doc_order=2303, child_position=1, attribs={'class': 'gigpress-header'}, element=<Element tr at 0x7fd7e640a588>)},
#      'children': [{'tag': 'th.gigpress-city',
#        'element': {Node(tag='th', doc_order=90, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e657fc88>),
#         Node(tag='th', doc_order=135, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e63e1dc8>),
#         Node(tag='th', doc_order=508, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e6510cc8>),
#         Node(tag='th', doc_order=716, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e47f0b88>),
#         Node(tag='th', doc_order=1130, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e62b4e08>),
#         Node(tag='th', doc_order=1425, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e6326ec8>),
#         Node(tag='th', doc_order=1474, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e63b47c8>),
#         Node(tag='th', doc_order=1803, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e6aea348>),
#         Node(tag='th', doc_order=2305, child_position=2, attribs={'scope': 'col', 'class': 'gigpress-city'}, element=<Element th at 0x7fd7e640ab08>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-country',
#        'element': {Node(tag='th', doc_order=92, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e657ff48>),
#         Node(tag='th', doc_order=137, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e63e1908>),
#         Node(tag='th', doc_order=510, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e6510d48>),
#         Node(tag='th', doc_order=718, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e47f0dc8>),
#         Node(tag='th', doc_order=1132, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e62b4048>),
#         Node(tag='th', doc_order=1427, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e63260c8>),
#         Node(tag='th', doc_order=1476, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e63b4e48>),
#         Node(tag='th', doc_order=1805, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e6aea188>),
#         Node(tag='th', doc_order=2307, child_position=4, attribs={'scope': 'col', 'class': 'gigpress-country'}, element=<Element th at 0x7fd7e640ae88>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-date',
#        'element': {Node(tag='th', doc_order=89, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e657fbc8>),
#         Node(tag='th', doc_order=134, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e63e1c48>),
#         Node(tag='th', doc_order=507, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e6510a08>),
#         Node(tag='th', doc_order=715, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e47f0b48>),
#         Node(tag='th', doc_order=1129, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e62b4a48>),
#         Node(tag='th', doc_order=1424, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e6326448>),
#         Node(tag='th', doc_order=1473, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7f95db6c8>),
#         Node(tag='th', doc_order=1802, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e6aea208>),
#         Node(tag='th', doc_order=2304, child_position=1, attribs={'scope': 'col', 'class': 'gigpress-date'}, element=<Element th at 0x7fd7e640aa48>)},
#        'children': [],
#        'word_finished': True},
#       {'tag': 'th.gigpress-venue',
#        'element': {Node(tag='th', doc_order=91, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e657fe08>),
#         Node(tag='th', doc_order=136, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e63e1f88>),
#         Node(tag='th', doc_order=509, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e6510d88>),
#         Node(tag='th', doc_order=717, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e47f0a88>),
#         Node(tag='th', doc_order=1131, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e62b46c8>),
#         Node(tag='th', doc_order=1426, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e6326648>),
#         Node(tag='th', doc_order=1475, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e63b4488>),
#         Node(tag='th', doc_order=1804, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e6aeae08>),
#         Node(tag='th', doc_order=2306, child_position=3, attribs={'scope': 'col', 'class': 'gigpress-venue'}, element=<Element th at 0x7fd7e640a0c8>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False},
#     {'tag': 'tr.active.gigpress-info',
#      'element': {Node(tag='tr', doc_order=100, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63dd808>),
#       Node(tag='tr', doc_order=118, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e64dfec8>),
#       Node(tag='tr', doc_order=145, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e662d308>),
#       Node(tag='tr', doc_order=162, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6488f48>),
#       Node(tag='tr', doc_order=183, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e64f6848>),
#       Node(tag='tr', doc_order=203, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63d9408>),
#       Node(tag='tr', doc_order=223, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e65eb888>),
#       Node(tag='tr', doc_order=243, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e64fe2c8>),
#       Node(tag='tr', doc_order=263, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95f0688>),
#       Node(tag='tr', doc_order=283, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e62c1f08>),
#       Node(tag='tr', doc_order=302, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95e4548>),
#       Node(tag='tr', doc_order=322, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e64a1ec8>),
#       Node(tag='tr', doc_order=342, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e64a1a48>),
#       Node(tag='tr', doc_order=362, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6358d48>),
#       Node(tag='tr', doc_order=381, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63c1588>),
#       Node(tag='tr', doc_order=399, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63e9fc8>),
#       Node(tag='tr', doc_order=418, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63e1808>),
#       Node(tag='tr', doc_order=435, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6a24fc8>),
#       Node(tag='tr', doc_order=455, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e65b5448>),
#       Node(tag='tr', doc_order=474, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e652d688>),
#       Node(tag='tr', doc_order=491, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e64d2c08>),
#       Node(tag='tr', doc_order=518, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6510e08>),
#       Node(tag='tr', doc_order=538, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6464808>),
#       Node(tag='tr', doc_order=558, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6464d08>),
#       Node(tag='tr', doc_order=577, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63edb88>),
#       Node(tag='tr', doc_order=597, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6355ac8>),
#       Node(tag='tr', doc_order=617, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6611408>),
#       Node(tag='tr', doc_order=637, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6402f88>),
#       Node(tag='tr', doc_order=657, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63b1ac8>),
#       Node(tag='tr', doc_order=677, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6447cc8>),
#       Node(tag='tr', doc_order=697, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6447a48>),
#       Node(tag='tr', doc_order=726, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e47f0ec8>),
#       Node(tag='tr', doc_order=745, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e646b788>),
#       Node(tag='tr', doc_order=765, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e646b1c8>),
#       Node(tag='tr', doc_order=785, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e644d048>),
#       Node(tag='tr', doc_order=805, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95df848>),
#       Node(tag='tr', doc_order=826, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7f95dfa48>),
#       Node(tag='tr', doc_order=845, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e64574c8>),
#       Node(tag='tr', doc_order=865, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6621e88>),
#       Node(tag='tr', doc_order=883, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e65c9688>),
#       Node(tag='tr', doc_order=903, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e65c9a48>),
#       Node(tag='tr', doc_order=922, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e65bd348>),
#       Node(tag='tr', doc_order=942, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e65bd708>),
#       Node(tag='tr', doc_order=961, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6a3a8c8>),
#       Node(tag='tr', doc_order=980, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7f96a8c48>),
#       Node(tag='tr', doc_order=999, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6632b48>),
#       Node(tag='tr', doc_order=1017, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6632c08>),
#       Node(tag='tr', doc_order=1037, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6398248>),
#       Node(tag='tr', doc_order=1057, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7f95e0688>),
#       Node(tag='tr', doc_order=1076, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95e0d88>),
#       Node(tag='tr', doc_order=1095, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e632e288>),
#       Node(tag='tr', doc_order=1113, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e632ecc8>),
#       Node(tag='tr', doc_order=1140, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e62b4cc8>),
#       Node(tag='tr', doc_order=1159, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e632b988>),
#       Node(tag='tr', doc_order=1178, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e632b848>),
#       Node(tag='tr', doc_order=1196, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63cd908>),
#       Node(tag='tr', doc_order=1214, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63cdf08>),
#       Node(tag='tr', doc_order=1232, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6614a88>),
#       Node(tag='tr', doc_order=1252, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6614188>),
#       Node(tag='tr', doc_order=1272, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e643ae08>),
#       Node(tag='tr', doc_order=1291, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e643a448>),
#       Node(tag='tr', doc_order=1311, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7f95d6f08>),
#       Node(tag='tr', doc_order=1329, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e648b588>),
#       Node(tag='tr', doc_order=1347, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63f5cc8>),
#       Node(tag='tr', doc_order=1366, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63f5608>),
#       Node(tag='tr', doc_order=1386, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e65c3e08>),
#       Node(tag='tr', doc_order=1406, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6326b48>),
#       Node(tag='tr', doc_order=1435, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95db5c8>),
#       Node(tag='tr', doc_order=1455, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7f95db9c8>),
#       Node(tag='tr', doc_order=1484, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63b4d88>),
#       Node(tag='tr', doc_order=1504, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63b4d48>),
#       Node(tag='tr', doc_order=1524, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f95daa88>),
#       Node(tag='tr', doc_order=1544, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e649d288>),
#       Node(tag='tr', doc_order=1564, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e649d648>),
#       Node(tag='tr', doc_order=1584, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63f1288>),
#       Node(tag='tr', doc_order=1604, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63a04c8>),
#       Node(tag='tr', doc_order=1624, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e62b6548>),
#       Node(tag='tr', doc_order=1644, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e4789208>),
#       Node(tag='tr', doc_order=1664, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e4789848>),
#       Node(tag='tr', doc_order=1684, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e4789488>),
#       Node(tag='tr', doc_order=1704, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6361208>),
#       Node(tag='tr', doc_order=1724, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e65ce208>),
#       Node(tag='tr', doc_order=1744, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e65ce108>),
#       Node(tag='tr', doc_order=1764, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6ac62c8>),
#       Node(tag='tr', doc_order=1784, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6aea6c8>),
#       Node(tag='tr', doc_order=1813, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6aeae88>),
#       Node(tag='tr', doc_order=1832, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6aeaf08>),
#       Node(tag='tr', doc_order=1851, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e63b8408>),
#       Node(tag='tr', doc_order=1871, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e65b97c8>),
#       Node(tag='tr', doc_order=1890, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6495d88>),
#       Node(tag='tr', doc_order=1909, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e64957c8>),
#       Node(tag='tr', doc_order=1929, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e47b8148>),
#       Node(tag='tr', doc_order=1947, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e47b8888>),
#       Node(tag='tr', doc_order=1967, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6609148>),
#       Node(tag='tr', doc_order=1987, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd804de4cc8>),
#       Node(tag='tr', doc_order=2007, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6469e48>),
#       Node(tag='tr', doc_order=2027, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e64d6708>),
#       Node(tag='tr', doc_order=2047, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e662a108>),
#       Node(tag='tr', doc_order=2067, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e675c508>),
#       Node(tag='tr', doc_order=2087, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e64913c8>),
#       Node(tag='tr', doc_order=2107, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6491f48>),
#       Node(tag='tr', doc_order=2127, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f9639d88>),
#       Node(tag='tr', doc_order=2147, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e635b788>),
#       Node(tag='tr', doc_order=2167, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6321948>),
#       Node(tag='tr', doc_order=2187, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6321a88>),
#       Node(tag='tr', doc_order=2207, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e631dac8>),
#       Node(tag='tr', doc_order=2226, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6600ac8>),
#       Node(tag='tr', doc_order=2246, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e4791988>),
#       Node(tag='tr', doc_order=2266, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e4791788>),
#       Node(tag='tr', doc_order=2286, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e640a9c8>),
#       Node(tag='tr', doc_order=2315, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e640a708>),
#       Node(tag='tr', doc_order=2335, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e661a888>),
#       Node(tag='tr', doc_order=2355, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e661afc8>),
#       Node(tag='tr', doc_order=2376, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e661eb48>),
#       Node(tag='tr', doc_order=2395, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e496b188>),
#       Node(tag='tr', doc_order=2414, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e496b388>),
#       Node(tag='tr', doc_order=2433, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e496b048>),
#       Node(tag='tr', doc_order=2452, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e6408508>),
#       Node(tag='tr', doc_order=2470, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7e6656e48>),
#       Node(tag='tr', doc_order=2489, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e63506c8>),
#       Node(tag='tr', doc_order=2509, child_position=2, attribs={'class': 'gigpress-info active'}, element=<Element tr at 0x7fd7f9640148>),
#       Node(tag='tr', doc_order=2529, child_position=2, attribs={'class': 'gigpress-info active gigpress-alt'}, element=<Element tr at 0x7fd7e630b908>)},
#      'children': [{'tag': 'td/span.gigpress-info-item',
#        'element': {Node(tag='span', doc_order=173, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65f7388>),
#         Node(tag='span', doc_order=174, child_position=2, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65f75c8>),
#         Node(tag='span', doc_order=194, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64f6108>),
#         Node(tag='span', doc_order=214, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e630f608>),
#         Node(tag='span', doc_order=234, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6a10588>),
#         Node(tag='span', doc_order=254, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e637e4c8>),
#         Node(tag='span', doc_order=274, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7ea39fe88>),
#         Node(tag='span', doc_order=294, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e62c1e48>),
#         Node(tag='span', doc_order=313, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64e3908>),
#         Node(tag='span', doc_order=333, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64a1308>),
#         Node(tag='span', doc_order=353, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64a1c08>),
#         Node(tag='span', doc_order=373, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6358dc8>),
#         Node(tag='span', doc_order=410, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd821178288>),
#         Node(tag='span', doc_order=446, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65b5dc8>),
#         Node(tag='span', doc_order=466, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65b5608>),
#         Node(tag='span', doc_order=529, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6464388>),
#         Node(tag='span', doc_order=549, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64649c8>),
#         Node(tag='span', doc_order=569, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6a4dd88>),
#         Node(tag='span', doc_order=588, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e645f088>),
#         Node(tag='span', doc_order=608, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64c8c08>),
#         Node(tag='span', doc_order=628, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6611648>),
#         Node(tag='span', doc_order=648, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6402908>),
#         Node(tag='span', doc_order=668, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6447548>),
#         Node(tag='span', doc_order=688, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64479c8>),
#         Node(tag='span', doc_order=708, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e64aa208>),
#         Node(tag='span', doc_order=737, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e646b8c8>),
#         Node(tag='span', doc_order=756, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e646b308>),
#         Node(tag='span', doc_order=776, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e644dd48>),
#         Node(tag='span', doc_order=796, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e644dc48>),
#         Node(tag='span', doc_order=816, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7f95df9c8>),
#         Node(tag='span', doc_order=817, child_position=2, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7f95dfd48>),
#         Node(tag='span', doc_order=837, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6457308>),
#         Node(tag='span', doc_order=856, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6621dc8>),
#         Node(tag='span', doc_order=894, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65c9d48>),
#         Node(tag='span', doc_order=914, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65bd288>),
#         Node(tag='span', doc_order=933, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e65bdb88>),
#         Node(tag='span', doc_order=953, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6a3ab08>),
#         Node(tag='span', doc_order=972, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6a49b08>),
#         Node(tag='span', doc_order=991, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7f96a8708>),
#         Node(tag='span', doc_order=1028, child_position=1, attribs={'class': 'gigpress-info-item'}, element=<Element span at 0x7fd7e6632f08>),
# ...
#         Node(tag='td', doc_order=222, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65ebec8>),
#         Node(tag='td', doc_order=242, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64f3e08>),
#         Node(tag='td', doc_order=262, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95f0c48>),
#         Node(tag='td', doc_order=282, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e62c1e88>),
#         Node(tag='td', doc_order=301, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95e4948>),
#         Node(tag='td', doc_order=321, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64a19c8>),
#         Node(tag='td', doc_order=341, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64a1b08>),
#         Node(tag='td', doc_order=361, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6358b88>),
#         Node(tag='td', doc_order=380, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63c1748>),
#         Node(tag='td', doc_order=398, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63e9dc8>),
#         Node(tag='td', doc_order=417, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6659288>),
#         Node(tag='td', doc_order=434, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd821206c08>),
#         Node(tag='td', doc_order=454, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65b58c8>),
#         Node(tag='td', doc_order=473, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e652d488>),
#         Node(tag='td', doc_order=490, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64d2f88>),
#         Node(tag='td', doc_order=517, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6510a88>),
#         Node(tag='td', doc_order=537, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6464d88>),
#         Node(tag='td', doc_order=557, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6464b08>),
#         Node(tag='td', doc_order=576, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63ede48>),
#         Node(tag='td', doc_order=596, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6355688>),
#         Node(tag='td', doc_order=616, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6611548>),
#         Node(tag='td', doc_order=636, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6402d48>),
#         Node(tag='td', doc_order=656, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63b1e88>),
#         Node(tag='td', doc_order=676, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6447308>),
#         Node(tag='td', doc_order=696, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6447648>),
#         Node(tag='td', doc_order=725, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e47f0248>),
#         Node(tag='td', doc_order=744, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e646b808>),
#         Node(tag='td', doc_order=764, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e646bec8>),
#         Node(tag='td', doc_order=784, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e644d108>),
#         Node(tag='td', doc_order=804, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95df708>),
#         Node(tag='td', doc_order=825, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95df148>),
#         Node(tag='td', doc_order=844, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6457988>),
#         Node(tag='td', doc_order=864, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e66214c8>),
#         Node(tag='td', doc_order=882, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6621b48>),
#         Node(tag='td', doc_order=902, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65c9508>),
#         Node(tag='td', doc_order=921, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65bd188>),
#         Node(tag='td', doc_order=941, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65bde88>),
#         Node(tag='td', doc_order=960, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6a3a048>),
#         Node(tag='td', doc_order=979, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f96a8c08>),
#         Node(tag='td', doc_order=998, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f96a89c8>),
#         Node(tag='td', doc_order=1016, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e66321c8>),
#         Node(tag='td', doc_order=1036, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6398f08>),
#         Node(tag='td', doc_order=1056, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95e0788>),
#         Node(tag='td', doc_order=1075, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95e0208>),
#         Node(tag='td', doc_order=1094, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e632ee08>),
#         Node(tag='td', doc_order=1112, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e632e988>),
#         Node(tag='td', doc_order=1139, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e62b4408>),
#         Node(tag='td', doc_order=1158, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e632b308>),
#         Node(tag='td', doc_order=1177, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e632b748>),
#         Node(tag='td', doc_order=1195, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63cd888>),
#         Node(tag='td', doc_order=1213, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63cd108>),
#         Node(tag='td', doc_order=1231, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6614948>),
#         Node(tag='td', doc_order=1251, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6614108>),
#         Node(tag='td', doc_order=1271, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e643ac88>),
#         Node(tag='td', doc_order=1290, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e643a1c8>),
#         Node(tag='td', doc_order=1310, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95d6808>),
#         Node(tag='td', doc_order=1328, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e648bf88>),
#         Node(tag='td', doc_order=1346, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63f5808>),
#         Node(tag='td', doc_order=1365, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63f5488>),
#         Node(tag='td', doc_order=1385, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65c3608>),
#         Node(tag='td', doc_order=1405, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6326708>),
#         Node(tag='td', doc_order=1434, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95db0c8>),
#         Node(tag='td', doc_order=1454, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95dbac8>),
#         Node(tag='td', doc_order=1483, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63b4848>),
#         Node(tag='td', doc_order=1503, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63b46c8>),
#         Node(tag='td', doc_order=1523, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f95dafc8>),
#         Node(tag='td', doc_order=1543, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e649d5c8>),
#         Node(tag='td', doc_order=1563, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e649de88>),
#         Node(tag='td', doc_order=1583, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63f1908>),
#         Node(tag='td', doc_order=1603, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63a0208>),
#         Node(tag='td', doc_order=1623, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e62b67c8>),
#         Node(tag='td', doc_order=1643, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e4789088>),
#         Node(tag='td', doc_order=1663, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e47890c8>),
#         Node(tag='td', doc_order=1683, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e4789b88>),
#         Node(tag='td', doc_order=1703, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6361788>),
#         Node(tag='td', doc_order=1723, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65ce248>),
#         Node(tag='td', doc_order=1743, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65ce748>),
#         Node(tag='td', doc_order=1763, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6ac66c8>),
#         Node(tag='td', doc_order=1783, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6aea3c8>),
#         Node(tag='td', doc_order=1812, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6aeab08>),
#         Node(tag='td', doc_order=1831, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6aea108>),
#         Node(tag='td', doc_order=1850, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e63b8348>),
#         Node(tag='td', doc_order=1870, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e65b93c8>),
#         Node(tag='td', doc_order=1889, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6495148>),
#         Node(tag='td', doc_order=1908, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64958c8>),
#         Node(tag='td', doc_order=1928, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e47b8708>),
#         Node(tag='td', doc_order=1946, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e47b8548>),
#         Node(tag='td', doc_order=1966, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6609208>),
#         Node(tag='td', doc_order=1986, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6609c08>),
#         Node(tag='td', doc_order=2006, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6469a88>),
#         Node(tag='td', doc_order=2026, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64d6448>),
#         Node(tag='td', doc_order=2046, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e662a2c8>),
#         Node(tag='td', doc_order=2066, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e675c748>),
#         Node(tag='td', doc_order=2086, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e64912c8>),
#         Node(tag='td', doc_order=2106, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6491448>),
#         Node(tag='td', doc_order=2126, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f9639188>),
#         Node(tag='td', doc_order=2146, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e635b0c8>),
#         Node(tag='td', doc_order=2166, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6321108>),
#         Node(tag='td', doc_order=2186, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6321b48>),
#         Node(tag='td', doc_order=2206, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e631dfc8>),
#         Node(tag='td', doc_order=2225, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6600708>),
#         Node(tag='td', doc_order=2245, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e4791908>),
#         Node(tag='td', doc_order=2265, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e47918c8>),
#         Node(tag='td', doc_order=2285, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e640a988>),
#         Node(tag='td', doc_order=2314, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e640af08>),
#         Node(tag='td', doc_order=2334, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e661a908>),
#         Node(tag='td', doc_order=2354, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e661af88>),
#         Node(tag='td', doc_order=2375, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e661eec8>),
#         Node(tag='td', doc_order=2394, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e496b108>),
#         Node(tag='td', doc_order=2413, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e496b2c8>),
#         Node(tag='td', doc_order=2432, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e496b648>),
#         Node(tag='td', doc_order=2451, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6408b88>),
#         Node(tag='td', doc_order=2469, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6656708>),
#         Node(tag='td', doc_order=2488, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e6350648>),
#         Node(tag='td', doc_order=2508, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7f9640388>),
#         Node(tag='td', doc_order=2528, child_position=4, attribs={'class': 'gigpress-country'}, element=<Element td at 0x7fd7e640f448>)},
#        'children': [],
#        'word_finished': True}],
#      'word_finished': False}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# ## Re-creating data hierarchy
#
# Below is the most interesting bit: how to re-create a dict/JSON document from repeating tagpaths.
#
# Using the trie, from the root of the tree, we loop over all HTML elements of a trie node, and recursively collect data from its children:

# %%
from collections import defaultdict
from operator import itemgetter
from lxml.html import tostring


def hydrate(node, docorder_min, docorder_max=None, include_html=False):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []

    for i, element in enumerate(elements, start=1):
        
        # filter out elements that are not within the parent document order range
        if not (docorder_min < element.doc_order):
            continue
        if (docorder_max is not None) and (element.doc_order > docorder_max):
            continue
        
        # here's where you extract data from the element
        # 1. node representation including tag and classes can tell us a bit about what it's about
        # 2. document order is purely informational
        # 3. child text nodes usually contain much of the information we want
        # 4. element attributes also can be useful (URL, data-* etc.)
        e = {'tnode': node.char_repr,
             'htag': _node_repr(element),
             '_doc_order': element.doc_order}
        
        # textual information
        _t = list(filter(bool, [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]))
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        _html = tostring(element.element, encoding='unicode')
        if _html:
            #e['html'] = _html
            pass
            
        _attrib = dict(element.element.attrib)
        if 'class' in _attrib:
            _attrib.pop('class')
        if _attrib:
            e['_attr'] = _attrib
        
        # loop through sub-nodes that are between the current node and the next one
        # Warning: recursivity!
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate(child, _order_min, _order_max)]))
        if children:
            children = sorted(children, key=itemgetter('_doc_order'))
            e['_num_children'] = len(children)
            e['children'] = children
            #e['children'] = children
        
        # if there's not "valuable" information, might as well skip the element
        if 'children' not in e and not(any(e.get(k) for k in ['text', '_attr'])):
            continue

        output.append(e)
        
    #return sorted(output, key=itemgetter('_doc_order'))
    return output

output = hydrate(root, 0)
pp(output)
# Out:
# [{'_doc_order': 83,
#   '_num_children': 140,
#   'children': [{'_attr': {'href': 'https://www.paperandironbooking.com/andy-jenkins'},
#                 '_doc_order': 85,
#                 'htag': 'a',
#                 'text': 'Andy Jenkins',
#                 'tnode': 'h3.gigpress-artist-heading/a'},
#                {'_doc_order': 87,
#                 '_num_children': 1,
#                 'children': [{'_doc_order': 88,
#                               '_num_children': 4,
#                               'children': [{'_attr': {'scope': 'col'},
#                                             '_doc_order': 89,
#                                             'htag': 'th.gigpress-date',
#                                             'text': 'Date',
#                                             'tnode': 'th.gigpress-date'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 90,
#                                             'htag': 'th.gigpress-city',
#                                             'text': 'City',
#                                             'tnode': 'th.gigpress-city'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 91,
#                                             'htag': 'th.gigpress-venue',
#                                             'text': 'Venue',
#                                             'tnode': 'th.gigpress-venue'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 92,
#                                             'htag': 'th.gigpress-country',
#                                             'text': 'Country',
#                                             'tnode': 'th.gigpress-country'}],
#                               'htag': 'tr.gigpress-header',
#                               'tnode': 'tr.gigpress-header'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 93,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 94,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 95,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '25/01/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 96,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Copenhagen (DK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 97,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.huset-kbh.dk/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 98,
#                                                           'htag': 'a',
#                                                           'text': 'Huset',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 99,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'Denmark',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 100,
#                               '_num_children': 1,
#                               'children': [{'_doc_order': 102,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4666'},
#                                                           '_doc_order': 103,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Andy+Jenkins+at+Huset&dates=20190125/20190125&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Andy+Jenkins&location=Huset%2C+Copenhagen+%28DK%29%2C+DK&details=&trp=true;'},
#                                                           '_doc_order': 107,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4666'},
#                                                           '_doc_order': 109,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 111,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 112,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 113,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '29/01/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 114,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Glasgow (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 115,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.facebook.com/TheHugandPint',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 116,
#                                                           'htag': 'a',
#                                                           'text': 'The Hug & '
#                                                                   'Pint',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 117,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 118,
#                               '_num_children': 1,
#                               'children': [{'_doc_order': 120,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4667'},
#                                                           '_doc_order': 121,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Andy+Jenkins+at+The+Hug+%26+Pint&dates=20190129/20190129&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Andy+Jenkins&location=The+Hug+%26+Pint%2C+Glasgow+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 125,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4667'},
#                                                           '_doc_order': 127,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_attr': {'href': 'http://www.paperandironbooking.com/roster/anna-st-louis/'},
#                 '_doc_order': 130,
#                 'htag': 'a',
#                 'text': 'Anna St. Louis',
#                 'tnode': 'h3.gigpress-artist-heading/a'},
#                {'_doc_order': 132,
#                 '_num_children': 1,
#                 'children': [{'_doc_order': 133,
#                               '_num_children': 4,
#                               'children': [{'_attr': {'scope': 'col'},
#                                             '_doc_order': 134,
#                                             'htag': 'th.gigpress-date',
#                                             'text': 'Date',
#                                             'tnode': 'th.gigpress-date'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 135,
#                                             'htag': 'th.gigpress-city',
#                                             'text': 'City',
#                                             'tnode': 'th.gigpress-city'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 136,
#                                             'htag': 'th.gigpress-venue',
#                                             'text': 'Venue',
#                                             'tnode': 'th.gigpress-venue'},
#                                            {'_attr': {'scope': 'col'},
#                                             '_doc_order': 137,
#                                             'htag': 'th.gigpress-country',
#                                             'text': 'Country',
#                                             'tnode': 'th.gigpress-country'}],
#                               'htag': 'tr.gigpress-header',
#                               'tnode': 'tr.gigpress-header'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 138,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 139,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 140,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '13/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 141,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Sheffield',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 142,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://picture-house-social.com/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 143,
#                                                           'htag': 'a',
#                                                           'text': 'Picture '
#                                                                   'House '
#                                                                   'Social',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 144,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 145,
#                               '_num_children': 1,
#                               'children': [{'_doc_order': 147,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4720'},
#                                                           '_doc_order': 148,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Picture+House+Social&dates=20190413/20190413&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Picture+House+Social%2C+Sheffield%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 152,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4720'},
#                                                           '_doc_order': 154,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 156,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 157,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 158,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '14/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 159,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Bristol (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 160,
#                                             'htag': 'td.gigpress-venue',
#                                             'text': 'Hy Brasil Music Club',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 161,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 162,
#                               '_num_children': 3,
#                               'children': [{'_doc_order': 164,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4721'},
#                                                           '_doc_order': 165,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Hy+Brasil+Music+Club&dates=20190414/20190414&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Hy+Brasil+Music+Club%2C+Bristol+%28UK%29%2C+UK&details=Notes%3A+Free+&trp=true;'},
#                                                           '_doc_order': 169,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4721'},
#                                                           '_doc_order': 171,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 173,
#                                             'htag': 'span.gigpress-info-item',
#                                             'text': 'Free',
#                                             'tnode': 'td/span.gigpress-info-item'},
#                                            {'_doc_order': 174,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://hdfst.uk/E50140',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 175,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 176,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 177,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 178,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '15/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 179,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Glasgow (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 180,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.facebook.com/TheHugandPint',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 181,
#                                                           'htag': 'a',
#                                                           'text': 'The Hug & '
#                                                                   'Pint',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 182,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 183,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 185,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4706'},
#                                                           '_doc_order': 186,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+The+Hug+%26+Pint&dates=20190415/20190415&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=The+Hug+%26+Pint%2C+Glasgow+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 190,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4706'},
#                                                           '_doc_order': 192,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 194,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.thehugandpint.com/events/3990c120-c3fb-0136-57a0-564c66862112',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 195,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 196,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 197,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 198,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '16/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 199,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Leeds',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 200,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.hydeparkbookclub.co.uk/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 201,
#                                                           'htag': 'a',
#                                                           'text': 'Hyde Park '
#                                                                   'Book Club',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 202,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 203,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 205,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4707'},
#                                                           '_doc_order': 206,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Hyde+Park+Book+Club&dates=20190416/20190416&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Hyde+Park+Book+Club%2C+Leeds%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 210,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4707'},
#                                                           '_doc_order': 212,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 214,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.lunatickets.co.uk/event/anna-st-louis/hyde-park-book-club/1291530',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 215,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 216,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 217,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 218,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '17/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 219,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Brighton (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 220,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.drinkinbrighton.co.uk/hope',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 221,
#                                                           'htag': 'a',
#                                                           'text': 'The Hope & '
#                                                                   'Ruin',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 222,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 223,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 225,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4708'},
#                                                           '_doc_order': 226,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+The+Hope+%26+Ruin&dates=20190417/20190417&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=The+Hope+%26+Ruin%2C+Brighton+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 230,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4708'},
#                                                           '_doc_order': 232,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 234,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://bit.ly/AStLouis',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 235,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 236,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 237,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 238,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '18/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 239,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'London (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 240,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.theslaughteredlambpub.com/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 241,
#                                                           'htag': 'a',
#                                                           'text': 'Slaughtered '
#                                                                   'Lamb',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 242,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 243,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 245,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4709'},
#                                                           '_doc_order': 246,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Slaughtered+Lamb&dates=20190418/20190418&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Slaughtered+Lamb%2C+London+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 250,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4709'},
#                                                           '_doc_order': 252,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 254,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://rockfeedback.seetickets.com/event/anna-st-louis/the-slaughtered-lamb/1292908',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 255,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 256,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 257,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 258,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '18/04/19\t\t\t - 20/04/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 259,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Rotterdam (NL)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 260,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.motelmozaique.nl/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 261,
#                                                           'htag': 'a',
#                                                           'text': 'Motel '
#                                                                   'Mozaique',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 262,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'Netherlands',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 263,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 265,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4705'},
#                                                           '_doc_order': 266,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Anna+St.+Louis+at+Motel+Mozaique&dates=20190418/20190421&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Anna+St.+Louis&location=Motel+Mozaique%2C+Rotterdam+%28NL%29%2C+NL&details=&trp=true;'},
#                                                           '_doc_order': 270,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
# ...
#                                                           'text': 'Brasserie '
#                                                                   'de La Houpe',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 2488,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'Belgium',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 2489,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 2491,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4744'},
#                                                           '_doc_order': 2492,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Tanukichan+at+Brasserie+de+La+Houpe&dates=20190216/20190216&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Tanukichan&location=Brasserie+de+La+Houpe%2C+Namur%2C+BE&details=&trp=true;'},
#                                                           '_doc_order': 2496,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4744'},
#                                                           '_doc_order': 2498,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 2500,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.eventbrite.fr/e/billets-tanukichan-us-seno-nudo-53810407377',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 2501,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 2502,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 2503,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 2504,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '17/02/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 2505,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'London (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 2506,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'http://www.birdonthewire.net/',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 2507,
#                                                           'htag': 'a',
#                                                           'text': 'Sebright '
#                                                                   'Arms',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 2508,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 2509,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 2511,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4677'},
#                                                           '_doc_order': 2512,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Tanukichan+at+Sebright+Arms&dates=20190217/20190217&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Tanukichan&location=Sebright+Arms%2C+London+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 2516,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4677'},
#                                                           '_doc_order': 2518,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 2520,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://rockfeedback.seetickets.com/event/tanukichan/sebright-arms/1287515',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 2521,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'},
#                {'_doc_order': 2522,
#                 '_num_children': 2,
#                 'children': [{'_doc_order': 2523,
#                               '_num_children': 4,
#                               'children': [{'_doc_order': 2524,
#                                             'htag': 'td.gigpress-date',
#                                             'text': '18/02/19',
#                                             'tnode': 'td.gigpress-date'},
#                                            {'_doc_order': 2525,
#                                             'htag': 'td.gigpress-city',
#                                             'text': 'Brighton (UK)',
#                                             'tnode': 'td.gigpress-city'},
#                                            {'_doc_order': 2526,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.facebook.com/ThePrinceAlbert',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 2527,
#                                                           'htag': 'a',
#                                                           'text': 'Prince '
#                                                                   'Albert',
#                                                           'tnode': 'a'}],
#                                             'htag': 'td.gigpress-venue',
#                                             'tnode': 'td.gigpress-venue'},
#                                            {'_doc_order': 2528,
#                                             'htag': 'td.gigpress-country',
#                                             'text': 'United Kingdom',
#                                             'tnode': 'td.gigpress-country'}],
#                               'htag': 'tr.active.gigpress-row',
#                               'tnode': 'tr.active.gigpress-row'},
#                              {'_doc_order': 2529,
#                               '_num_children': 2,
#                               'children': [{'_doc_order': 2531,
#                                             '_num_children': 3,
#                                             'children': [{'_attr': {'href': '#calendar-links-4678'},
#                                                           '_doc_order': 2532,
#                                                           'htag': 'a.gigpress-links-toggle',
#                                                           'text': 'Add',
#                                                           'tnode': 'a.gigpress-links-toggle'},
#                                                          {'_attr': {'href': 'http://www.google.com/calendar/event?action=TEMPLATE&text=Tanukichan+at+Prince+Albert&dates=20190218/20190218&sprop=website:http%3A%2F%2Fwww.paperandironbooking.com%2Fdates%2F&sprop=name:Tanukichan&location=Prince+Albert%2C+Brighton+%28UK%29%2C+UK&details=&trp=true;'},
#                                                           '_doc_order': 2536,
#                                                           'htag': 'a',
#                                                           'text': 'Add to '
#                                                                   'Google '
#                                                                   'Calendar',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'},
#                                                          {'_attr': {'href': 'http://www.paperandironbooking.com/?feed=gigpress-ical&show_id=4678'},
#                                                           '_doc_order': 2538,
#                                                           'htag': 'a',
#                                                           'text': 'Download '
#                                                                   'iCal',
#                                                           'tnode': 'div.gigpress-calendar-links/div.gigpress-calendar-links-inner/span/a'}],
#                                             'htag': 'div.gigpress-calendar-add',
#                                             'tnode': 'td.gigpress-links-cell/div.gigpress-calendar-add'},
#                                            {'_doc_order': 2540,
#                                             '_num_children': 1,
#                                             'children': [{'_attr': {'href': 'https://www.seetickets.com/event/tanukichan/the-prince-albert/1288052',
#                                                                     'target': '_blank'},
#                                                           '_doc_order': 2541,
#                                                           'htag': 'a.gigpress-tickets-link',
#                                                           'text': 'Buy Tickets',
#                                                           'tnode': 'a.gigpress-tickets-link'}],
#                                             'htag': 'span.gigpress-info-item',
#                                             'tnode': 'td/span.gigpress-info-item'}],
#                               'htag': 'tr.active.gigpress-info',
#                               'tnode': 'tr.active.gigpress-info'}],
#                 'htag': 'tbody',
#                 'tnode': 'table.gigpress-table.upcoming/tbody'}],
#   'htag': 'div.et_pb_text_inner',
#   'tnode': '/html/body.et-db.et_bloom.et_color_scheme_green.et_cover_background.et_divi_theme.et_fixed_nav.et_full_width_page.et_header_style_left.et_minified_css.et_minified_js.et_monarch.et_pb_button_helper_class.et_pb_footer_columns1.et_pb_gutters3.et_pb_pagebuilder_layout.et_primary_nav_dropdown_animation_flip.et_secondary_nav_dropdown_animation_fade.et_show_nav.et_smooth_scroll.page.page-id-82.page-template-default/div/div/div/article.hentry.page.post-82.status-publish.type-page/div.entry-content/div.et-boc/div.et_builder_inner_content.et_pb_gutters3/div.et_pb_section.et_pb_section_0.et_section_regular/div.et_pb_row.et_pb_row_0/div.et-last-child.et_pb_column.et_pb_column_0.et_pb_column_4_4.et_pb_css_mix_blend_mode_passthrough/div.et_pb_bg_layout_light.et_pb_module.et_pb_text.et_pb_text_0.et_pb_text_align_left/div.et_pb_text_inner'}]

# %% [markdown]
# The output data seems to present all the data we'd need for something like PyVideo.org.
#
# Let's just save for further processing.

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('pydata-berlin-2015.speakers.json', 'w') as fp:
    json.dump(output, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %% [markdown]
# ## Is there a way to automatically chose clusters?
#
# Spectral clustering does not always give the "best" results. It may be due to the similarity function, or some other parameters, I don't know yet really.
#
# Below is a just to see if hierarchical clustering of tagpaths would do a better job.

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter

import numpy as np

tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([237, 156, 236, 235, 245, 241, 147, 215, 231, 137, 229, 234, 167,
#        233, 126, 232, 227, 228, 230, 145, 190, 244, 193, 243, 242, 141,
#        214, 217, 212, 194, 218, 211, 186, 219, 209, 220, 160, 195, 124,
#        189, 221, 201, 222, 142, 196, 185, 223, 208, 224,  97, 192, 225,
#        210, 226, 110, 148, 216, 176, 107, 104, 213, 182, 240, 120, 136,
#        199, 173, 135, 207, 150, 127, 200,  94, 203, 191, 204, 171, 198,
#        205, 184, 164, 169, 206, 105,  99, 202,  92, 100,  96, 197, 116,
#        172, 109, 151, 179, 188, 187, 183,  91,  93, 163, 149, 159, 175,
#        181,  87, 180, 146,  89,  67, 165, 106, 177, 162, 178, 166, 123,
#        174, 102, 158,  86, 238,  85,  98, 117, 170, 138,  84,  73, 168,
#        132,  83,  95, 118, 103,  81, 112, 239, 161,  82,  80,  68,  79,
#        115,  39, 157, 140, 129, 154,  90, 155,  57,  77,  52,  44, 143,
#        139,  49, 131, 153,  58,  48, 101,  42, 152,  51,  75, 114,  74,
#         45,  36, 122, 121,  50, 111,  78,  69,  46,  72,  41, 144, 113,
#         20,  71,  24, 108,  40,  76,  88, 119,  43,  37,  35,  47,  21,
#         28,  70,  53,  34,  33,  38, 128, 133,  60,  54,  63,  59,  19,
#        134,  17,  55,  16,  66,  22,  25, 130,  56,  10,  65,  18,  27,
#         64,  23,  31,  61,  26,  32,  13,  15,   9,   8,   7,  29,   4,
#        125,  11,  12,  62,   3,  30,  14,   6,   5,   2,   1,   0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                , leaf_font_size=8
               )
