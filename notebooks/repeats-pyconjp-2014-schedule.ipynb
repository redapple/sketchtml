# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re

import lxml.html
import numpy as np
from sketchtml.repeats import TagPathClustering

# %%
import requests

#page = requests.get('https://pycon.jp/2014/schedule/talks/list/')
#page_content = page.text
page_content = open('samples/Conference Schedule | PyCon JP 2014 in TOKYO.html').read()

# %%
from collections import Counter

clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False)
clustering._build_tagpaths()

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 1:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# ( 43) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr
# ( 43) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.time
# ( 36) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk
# ( 36) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title
# ( 36) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title/a
# ( 36) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.speaker
# ( 36) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/div.badges
# ( 19) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu/li
# ( 19) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu/li/a
# ( 19) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Break
# ( 12) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr/th
# (  7) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.active.dropdown/ul.dropdown-menu/li
# (  7) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.active.dropdown/ul.dropdown-menu/li/a
# (  7) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-lightning
# (  6) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Other
# (  5) /html/body/div/footer/div.container/div.footer-content/p/a
# (  4) /html/head/meta
# (  4) /html/head/link
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/a.dropdown-toggle
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/a.dropdown-toggle/b.caret
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li
# (  4) /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li/a
# (  4) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Lunch
# (  3) /html/body/div/footer/div.container/div.footer-content/p
# (  2) /html/body/div/div/div.page-content/div.container/div.content-box
# (  2) /html/body/div/div/div.page-content/div.container/div.content-box/div.markdown
# (  2) /html/body/div/div/div.page-content/div.container/h3
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr/th.time
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td
# (  2) /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-posters
# (  2) /html/body/div/footer/div.container/div.footer-content/p.sns/a
# (  2) /html/body/div/footer/div.container/div.footer-content/p.sns/a/img

# %%
clusters = clustering.clusters()
#clusters

# %%
#clustering.simhelper.plot_signals()

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li/a'],
#              1: ['/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr/th',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-lightning',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Other',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Lunch',
#                  '/html/body/div/div/div.page-content/div.container/h3',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr/th.time',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td'],
#              2: ['/html/body/div/footer/div.container/div.footer-content/p.sns/a',
#                  '/html/body/div/footer/div.container/div.footer-content/p.sns/a/img'],
#              3: ['/html/body/div/footer/div.container/div.footer-content/p/a',
#                  '/html/head/meta',
#                  '/html/head/link',
#                  '/html/body/div/footer/div.container/div.footer-content/p'],
#              4: ['/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.active.dropdown/ul.dropdown-menu/li',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.active.dropdown/ul.dropdown-menu/li/a'],
#              5: ['/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu/li',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu/li/a',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/a.dropdown-toggle',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/a.dropdown-toggle/b.caret',
#                  '/html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu'],
#              6: ['/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Break',
#                  '/html/body/div/div/div.page-content/div.container/div.content-box',
#                  '/html/body/div/div/div.page-content/div.container/div.content-box/div.markdown'],
#              7: ['/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.time',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title/a',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.speaker',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/div.badges',
#                  '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-posters']})

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1
    
    def __repr__(self):
        return pformat(eval(pformat(dict(char_repr=self.char_repr, elements=len(set(self.elements)), children=self.children))))

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = [
    #'/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.time',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title/a',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.speaker',
                 '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/div.badges',
                 #'/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-posters'
]
for tp in tps: #clusters[7]:
    steps = tp.lstrip('/').split('/')
    #print(len(steps), tp)
    for nl in nodelists[tp][:]:
        #print(len(nl), [(n.element.tag, n.doc_order) for n in nl])
        add(root, nl)
    #print()

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
root
# Out:
# {'char_repr': '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk',
#  'children': [{'char_repr': 'span.title/a', 'children': [], 'elements': 36},
#               {'char_repr': 'span.speaker', 'children': [], 'elements': 36},
#               {'char_repr': 'div.badges', 'children': [], 'elements': 36}],
#  'elements': 36}

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('./text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)
                #if t or attribs:
                if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass
# Out:
# ---- Cluster #1 ----
# ---
# /html/body/div/div/div.page-content/div.container/h3
# (121, 'Sept. 13, 2014', {})
# (303, 'Sept. 14, 2014', {})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Lunch
# (186, 'Lunch', {'colspan': '2', 'rowspan': '2'})
# (190, 'Lunch', {'colspan': '1', 'rowspan': '1'})
# (331, 'Lunch', {'colspan': '1', 'rowspan': '2'})
# (334, 'Lunch', {'colspan': '2', 'rowspan': '1'})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Other
# (163, 'Office Hour', {'colspan': '1', 'rowspan': '10'})
# (187, 'Lunch Discussion & Community Booth', {'colspan': '2', 'rowspan': '9'})
# (352, 'Open Spaces', {'colspan': '1', 'rowspan': '5'})
# (353, 'Open Spaces', {'colspan': '1', 'rowspan': '10'})
# (354, 'Office Hour', {'colspan': '1', 'rowspan': '5'})
# (418, 'PyCon JP Committee meeting', {'colspan': '1', 'rowspan': '1'})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-lightning
# (138, 'Opening', {'colspan': '0', 'rowspan': '1'})
# (141, 'Keynote: Kenneth Reitz\n(en/ja 同時通訳)', {'colspan': '0', 'rowspan': '1'})
# (296, 'Lightning Talks', {'colspan': '0', 'rowspan': '1'})
# (320, 'Opening', {'colspan': '0', 'rowspan': '1'})
# (323, 'Keynote: Hirokazu Nishio (ja/en Simultaneous interpretation)', {'colspan': '0', 'rowspan': '1'})
# (444, 'Lightning Talks', {'colspan': '0', 'rowspan': '1'})
# (447, 'Closing', {'colspan': '0', 'rowspan': '1'})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/thead/tr/th
# (126, 'Conference Hall', {})
# (127, 'Media Hall', {})
# (128, 'Conference Room 1', {})
# (129, 'Conference Room 2', {})
# (130, 'Conference Room 3', {})
# (131, 'Conference Room 4/5', {})
# (308, 'Conference Hall', {})
# (309, 'Media Hall', {})
# (310, 'Conference Room 1', {})
# (311, 'Conference Room 2', {})
#
# ---- Cluster #3 ----
# ---
# /html/body/div/footer/div.container/div.footer-content/p
# (464, 'PyCon JP 2014 in Tokyo is a production of the .', {})
# (466, 'Site forked from the site built by using .', {})
# (470, 'Questions? Comments? Contact', {})
#
# ---
# /html/body/div/footer/div.container/div.footer-content/p/a
# (465, 'PyCon JP Management Team', {'href': 'http://www.pycon.jp/'})
# (467, 'PyCon 2014', {'href': 'http://us.pycon.jp/2014'})
# (468, 'Caktus Consulting Group, LLC.', {'href': 'http://caktusgroup.com'})
# (469, 'Symposion', {'href': 'http://eldarion.com/symposion/', 'title': 'Symposion — An Open Platform for Conference Websites'})
# (471, '2014@pycon.jp', {'href': 'mailto:2014@pycon.jp'})
#
# ---- Cluster #5 ----
# ---
# /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/a.dropdown-toggle
# (31, 'About', {'href': '/2014/about/what-is-pycon/', 'data-toggle': 'dropdown'})
# (67, 'Sponsors', {'href': '/2014/sponsors/', 'data-toggle': 'dropdown'})
# (79, 'Participants', {'href': '/2014/registration/', 'data-toggle': 'dropdown'})
# (91, 'Reports', {'href': '/2014/reports/', 'data-toggle': 'dropdown'})
#
# ---
# /html/body/div/header.main/div.container/nav/div.container/div.navbar.navbar-inverse/div.navbar-inner/ul.nav/li.dropdown/ul.dropdown-menu/li/a
# (35, 'About PyCon JP', {'href': '/2014/about/what-is-pycon/'})
# (37, 'Conference Details', {'href': '/2014/about/summary/'})
# (39, 'Code of Conduct', {'href': '/2014/about/code-of-conduct/'})
# (41, 'Staff Information', {'href': '/2014/about/staff/'})
# (43, 'Staff List', {'href': '/2014/about/staff-list/'})
# (45, 'Sitemap', {'href': '/2014/sitemap/'})
# (71, 'PyCon JP Sponsors', {'href': '/2014/sponsors/'})
# (73, 'PyCon JP Jobs Fair', {'href': '/2014/sponsors/jobs/'})
# (75, 'Sponsorship Prospectus', {'href': '/2014/sponsors/prospectus/'})
# (77, 'Sponsorship Application', {'href': '/2014/sponsors/apply/'})
#
# ---- Cluster #6 ----
# ---
# /html/body/div/div/div.page-content/div.container/div.content-box/div.markdown
# (120, '* [Poster Session](https://pycon.jp/2014/schedule/posters/list/) \n* [Job Fair](https://pycon.jp/2014/jobfair/)\n* [Call for Lightning Talks](https://pycon.jp/2014/speaking/cfp/)\n* [Slides & Video](https://pycon.jp/2014/reports/slides/)', {})
# (453, 'The conference schedule may be changed without notification.', {})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-Break
# (135, 'Door Open', {'colspan': '0', 'rowspan': '1'})
# (250, 'Break', {'colspan': '1', 'rowspan': '2'})
# (253, 'Break', {'colspan': '2', 'rowspan': '1'})
#
# ---- Cluster #7 ----
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-posters
# (327, 'Job Fair', {'colspan': '1', 'rowspan': '2'})
# (328, 'Poster Session', {'colspan': '1', 'rowspan': '2'})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.speaker
# (151, 'Yuichi Nakazawa, Kazuhiko Kakita', {})
# (156, 'Hideki Tanaka', {})
# (161, 'Nathan Scott', {})
# (172, 'Hiroki KIYOHARA', {})
# (177, 'torajiro aida', {})
# (182, 'Benoit Chesneau', {})
# (196, 'MASATO NAKAMURA', {})
# (201, 'Shinji Iwaki', {})
# (206, '柿迫 純一', {})
# (216, 'Manabu TERADA', {})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk/span.title/a
# (150, 'Djangoによるスマホアプリバックエンドの実装 (ja)', {'href': '/2014/schedule/presentation/15/', 'title': 'Djangoによるスマホアプリバックエンドの実装について事例を元に紹介します。また、開発時に使用したミドルウェア・ライブラリについても合わせてご紹介します。'})
# (155, 'Deep Learning for Image Recognition in Python (ja)', {'href': '/2014/schedule/presentation/20/', 'title': 'ディープラーニングによる画像認識を活用したアプリケーションについて紹介します。'})
# (160, 'Programming the Performance Co-Pilot toolkit (en)', {'href': '/2014/schedule/presentation/7/', 'title': 'This talk will describe the Performance Co-Pilot project and covers how python tools can be used to customise it for your own environment.  A practical introduction will be given showing how to write python tools to export real-time performance metrics from arbitrary system components so that the data is available for live and retrospective analysis, using other python tools.'})
# (171, 'Djangoアプリケーション、パフォーマンスチューニング (ja)', {'href': '/2014/schedule/presentation/13/', 'title': 'Webアプリケーションを作る。それだけで終わっていませんか？十分なパフォーマンスはでていますか？\nそんなWebアプリケーション開発者の皆様にDjangoアプリケーションのパフォーマンスチューングの紹介です。\nどうすれば高速に作れるか。なにが速度を低下させているのか。そもそもどうパフォーマンスを計測すればいいのか。それらの疑問に答えます。\nこのセッションを見終わったとき、あなたは今すぐにでも業務アプリケーションをチューニングしたくなるでしょう。'})
# (176, 'The esperanto generator (ja)', {'href': '/2014/schedule/presentation/32/', 'title': 'そう、作るの。エスペラント。いや、作らせるの。エスペラント。\nということで、Pythonにエスペラントを作ってもらおう、という事です。Pyevolveという遺伝的アルゴリズムを動かせるライブラリと、Pybrainというニューラルネットワークを構築してくれるライブラリを使って、新たな言語を作ります。\nさらに、プログラム上の数値をどのように調整すれば、どのようにに言語が変わって行くのかを観察します。\nNLTKという自然言語処理のライブラリも使って、言語を観察したりします。\n言語についてよく知ってる人、GAとかNNとかに詳しい人、ツッコミ大歓迎です！'})
# (181, 'Gunicorn, the thundering herd and other concurrency programming challenges (en)', {'href': '/2014/schedule/presentation/26/', 'title': 'Gunicorn design has not changed much since the project started. With the increasing number of cores and new concurrency solutions that appeared in python, it is about time to face to new challenges. This talk will show how we are solving the thundering herd problem and how most of our concurrency needs in Python 3 or 2 are now covered.'})
# (195, 'Pythonの実装系総ざらい (ja)', {'href': '/2014/schedule/presentation/33/', 'title': '実際にPythonを業務で使う場合、CPython2,3を使うことが多いでしょう。CPython以外にも、Pythonには PyPy, Jython, IronPython, Pystonなどの実装系があり、各々のメリット、デメリットがあります。この話を通して、CPython以外の実装系についてまとめます'})
# (200, 'Data collection, analysis and optimization with python (en)', {'href': '/2014/schedule/presentation/36/', 'title': 'In this session, you learn how to collect data from the web, how to analyze them, and, if needed, how to make and solve linear optimization problem.\nI am planning to use some interesting data on the web, five years of past TV program, so it will also be fun to see some trends in TV industry.'})
# (205, 'Python, Raspberry Pi, Arduinoで作る消費電力モニタリングシステム (ja)', {'href': '/2014/schedule/presentation/27/', 'title': '家庭の消費電力をモニタリングするシステムをPythonを用いて実装した事例を紹介します。\nシステムは「Raspberry Pi」をサーバー、「Arduino」を電力量センサーデバイスとして構築しています。\nハードウェアは敷居が高いという印象をうけますが、最近はずいぶん簡単に扱うことができるようになりました。\nPythonとハードウェアでPythonの可能性を再発見する手助けとなれば幸いです。'})
# (215, '最新リリースCMSツール Plone 5 のモダンUIとテクノロジーの進化 (ja)', {'href': '/2014/schedule/presentation/24/', 'title': '4年ぶりのメジャーバージョンアップが行われるPlone 5について技術面から紹介します。Python製エンタープライズCMSツールとして、Zopeをベースに構築され10年以上バージョンアップが継続的にされています。ユーザインターフェースを一新しモダンなUIの採用を行っています。それだけではなく、内部的な構造の全面的な見直しが行われ今後もスタンダードな存在となりうるツールになっています。'})
#
# ---
# /html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.time
# (134, '09:00AM', {})
# (137, '09:30AM', {})
# (140, '10:00AM', {})
# (143, '10:40AM', {})
# (147, '10:50AM', {})
# (165, '11:20AM', {})
# (168, '11:30AM', {})
# (185, '12:00PM', {})
# (189, '12:15PM', {})
# (192, '01:20PM', {})

# %%
def hydrate_trie(node):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=set(node.elements),
        children=[hydrate_trie(c) for c in node.children]
    )
hydrate_trie(root)
# Out:
# {'tag': '/html/body/div/div/div.page-content/div.container/table.calendar.table.table-bordered/tbody/tr/td.slot.slot-talk',
#  'element': {Node(tag='td', doc_order=148, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b385c08>),
#   Node(tag='td', doc_order=153, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b385a08>),
#   Node(tag='td', doc_order=158, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b385948>),
#   Node(tag='td', doc_order=169, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '2'}, element=<Element td at 0x7fc52b385608>),
#   Node(tag='td', doc_order=174, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3850c8>),
#   Node(tag='td', doc_order=179, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b385208>),
#   Node(tag='td', doc_order=193, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3e1d48>),
#   Node(tag='td', doc_order=198, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3e1ec8>),
#   Node(tag='td', doc_order=203, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3e1a48>),
#   Node(tag='td', doc_order=213, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc53cce1208>),
#   Node(tag='td', doc_order=218, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b4a7a48>),
#   Node(tag='td', doc_order=223, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b4a7988>),
#   Node(tag='td', doc_order=233, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '2'}, element=<Element td at 0x7fc52eea7188>),
#   Node(tag='td', doc_order=238, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '2'}, element=<Element td at 0x7fc52eea72c8>),
#   Node(tag='td', doc_order=243, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52eea7408>),
#   Node(tag='td', doc_order=256, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52eea7748>),
#   Node(tag='td', doc_order=261, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39a088>),
#   Node(tag='td', doc_order=266, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39a1c8>),
#   Node(tag='td', doc_order=276, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39a448>),
#   Node(tag='td', doc_order=281, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39a588>),
#   Node(tag='td', doc_order=286, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39a6c8>),
#   Node(tag='td', doc_order=337, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39d3c8>),
#   Node(tag='td', doc_order=342, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39d508>),
#   Node(tag='td', doc_order=347, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39d648>),
#   Node(tag='td', doc_order=360, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39d988>),
#   Node(tag='td', doc_order=365, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39dac8>),
#   Node(tag='td', doc_order=370, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39dc08>),
#   Node(tag='td', doc_order=380, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '2'}, element=<Element td at 0x7fc52b39de88>),
#   Node(tag='td', doc_order=385, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b39dfc8>),
#   Node(tag='td', doc_order=390, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b397148>),
#   Node(tag='td', doc_order=403, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b397488>),
#   Node(tag='td', doc_order=408, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3975c8>),
#   Node(tag='td', doc_order=413, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b397708>),
#   Node(tag='td', doc_order=424, child_position=2, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b3979c8>),
#   Node(tag='td', doc_order=429, child_position=3, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b397b08>),
#   Node(tag='td', doc_order=434, child_position=4, attribs={'class': 'slot slot-talk', 'colspan': '1', 'rowspan': '1'}, element=<Element td at 0x7fc52b397c48>)},
#  'children': [{'tag': 'span.title/a',
#    'element': {Node(tag='a', doc_order=150, child_position=1, attribs={'href': '/2014/schedule/presentation/15/', 'title': 'Djangoによるスマホアプリバックエンドの実装について事例を元に紹介します。また、開発時に使用したミドルウェア・ライブラリについても合わせてご紹介します。'}, element=<Element a at 0x7fc52b385a88>),
#     Node(tag='a', doc_order=155, child_position=1, attribs={'href': '/2014/schedule/presentation/20/', 'title': 'ディープラーニングによる画像認識を活用したアプリケーションについて紹介します。'}, element=<Element a at 0x7fc52b385cc8>),
#     Node(tag='a', doc_order=160, child_position=1, attribs={'href': '/2014/schedule/presentation/7/', 'title': 'This talk will describe the Performance Co-Pilot project and covers how python tools can be used to customise it for your own environment.  A practical introduction will be given showing how to write python tools to export real-time performance metrics from arbitrary system components so that the data is available for live and retrospective analysis, using other python tools.'}, element=<Element a at 0x7fc52b385888>),
#     Node(tag='a', doc_order=171, child_position=1, attribs={'href': '/2014/schedule/presentation/13/', 'title': 'Webアプリケーションを作る。それだけで終わっていませんか？十分なパフォーマンスはでていますか？\nそんなWebアプリケーション開発者の皆様にDjangoアプリケーションのパフォーマンスチューングの紹介です。\nどうすれば高速に作れるか。なにが速度を低下させているのか。そもそもどうパフォーマンスを計測すればいいのか。それらの疑問に答えます。\nこのセッションを見終わったとき、あなたは今すぐにでも業務アプリケーションをチューニングしたくなるでしょう。'}, element=<Element a at 0x7fc52b385448>),
#     Node(tag='a', doc_order=176, child_position=1, attribs={'href': '/2014/schedule/presentation/32/', 'title': 'そう、作るの。エスペラント。いや、作らせるの。エスペラント。\nということで、Pythonにエスペラントを作ってもらおう、という事です。Pyevolveという遺伝的アルゴリズムを動かせるライブラリと、Pybrainというニューラルネットワークを構築してくれるライブラリを使って、新たな言語を作ります。\nさらに、プログラム上の数値をどのように調整すれば、どのようにに言語が変わって行くのかを観察します。\nNLTKという自然言語処理のライブラリも使って、言語を観察したりします。\n言語についてよく知ってる人、GAとかNNとかに詳しい人、ツッコミ大歓迎です！'}, element=<Element a at 0x7fc52b385148>),
#     Node(tag='a', doc_order=181, child_position=1, attribs={'href': '/2014/schedule/presentation/26/', 'title': 'Gunicorn design has not changed much since the project started. With the increasing number of cores and new concurrency solutions that appeared in python, it is about time to face to new challenges. This talk will show how we are solving the thundering herd problem and how most of our concurrency needs in Python 3 or 2 are now covered.'}, element=<Element a at 0x7fc52b385248>),
#     Node(tag='a', doc_order=195, child_position=1, attribs={'href': '/2014/schedule/presentation/33/', 'title': '実際にPythonを業務で使う場合、CPython2,3を使うことが多いでしょう。CPython以外にも、Pythonには PyPy, Jython, IronPython, Pystonなどの実装系があり、各々のメリット、デメリットがあります。この話を通して、CPython以外の実装系についてまとめます'}, element=<Element a at 0x7fc52b3e1c88>),
#     Node(tag='a', doc_order=200, child_position=1, attribs={'href': '/2014/schedule/presentation/36/', 'title': 'In this session, you learn how to collect data from the web, how to analyze them, and, if needed, how to make and solve linear optimization problem.\nI am planning to use some interesting data on the web, five years of past TV program, so it will also be fun to see some trends in TV industry.'}, element=<Element a at 0x7fc52b3e1b88>),
#     Node(tag='a', doc_order=205, child_position=1, attribs={'href': '/2014/schedule/presentation/27/', 'title': '家庭の消費電力をモニタリングするシステムをPythonを用いて実装した事例を紹介します。\nシステムは「Raspberry Pi」をサーバー、「Arduino」を電力量センサーデバイスとして構築しています。\nハードウェアは敷居が高いという印象をうけますが、最近はずいぶん簡単に扱うことができるようになりました。\nPythonとハードウェアでPythonの可能性を再発見する手助けとなれば幸いです。'}, element=<Element a at 0x7fc53ccdf688>),
#     Node(tag='a', doc_order=215, child_position=1, attribs={'href': '/2014/schedule/presentation/24/', 'title': '4年ぶりのメジャーバージョンアップが行われるPlone 5について技術面から紹介します。Python製エンタープライズCMSツールとして、Zopeをベースに構築され10年以上バージョンアップが継続的にされています。ユーザインターフェースを一新しモダンなUIの採用を行っています。それだけではなく、内部的な構造の全面的な見直しが行われ今後もスタンダードな存在となりうるツールになっています。'}, element=<Element a at 0x7fc52b4a7e48>),
#     Node(tag='a', doc_order=220, child_position=1, attribs={'href': '/2014/schedule/presentation/18/', 'title': 'This talk explores case studies of effective usage of Numpy/Scipy and\nshows that the computational speed sometimes improves drastically with\nthe appropriate derivation of formulas and performance-conscious\nimplementation. I especially focus on scipy.sparse, the module for\nsparse matrices, which is often useful in the areas of machine\nlearning and natural language processing.\n'}, element=<Element a at 0x7fc52b4a7dc8>),
#     Node(tag='a', doc_order=225, child_position=1, attribs={'href': '/2014/schedule/presentation/40/', 'title': 'Micro Python は、マイコンの上で動くことを考えた Python です。\nKICKSTARTER で多数の投資を集めて開発され、注目されています。\n非常に軽量で、少ないメモリや遅い速度のマイコン上で Python を使うことが出来ます。\nMicro Python を利用する方法と、その動作例を紹介します。'}, element=<Element a at 0x7fc52b4a7908>),
#     Node(tag='a', doc_order=235, child_position=1, attribs={'href': '/2014/schedule/presentation/5/', 'title': 'Pythonでの開発をサポートするエディタや統合環境はたくさんありますが、その中でもPyCharmは使いやすく必要十分な機能をカスタマイズなしに提供してくれるPythonのための統合開発環境です。PyCharmは特別目立つ機能があるわけでもなく、キャッチーなユーザー体験を提供してくれるわけでもありません。カスタマイズはあきらめた方が良いでしょう。しかし、使っていくとだんだんと良さが分かってきます。そんなPyCharmの機能の美味しいところを紹介します。'}, element=<Element a at 0x7fc52eea7208>),
#     Node(tag='a', doc_order=240, child_position=1, attribs={'href': '/2014/schedule/presentation/8/', 'title': 'Python is enhanced by a large set of scientific libraries that are being actively developed.\nThese libraries, such as ipython, numpy, pandas, scipy, scikit-learn, provide an efficient and functional environment to solve scientific problems.\nThe aim of this talk is to describe the most popular tools followed by a demonstration of these tools.'}, element=<Element a at 0x7fc52eea7348>),
#     Node(tag='a', doc_order=245, child_position=1, attribs={'href': '/2014/schedule/presentation/29/', 'title': 'Python標準ライブラリには数多くの有用な機能が含まれていて、いわゆる「電池付属なのですぐに遊べるよ！」を体現しているわけです。中でもXML-RPCライブラリは、その機能と応用範囲において突出しているものの１つですが、いまいち知名度が高くないようにも見えます。このセッションではPythonに付属するXML-RPCライブラリの使い所、実際にこれを使用したシステムを開発・稼働させているシステム開発者の視点からのTipsや改造方法、具体的なシステムの構築事例を紹介します。'}, element=<Element a at 0x7fc52eea7488>),
#     Node(tag='a', doc_order=258, child_position=1, attribs={'href': '/2014/schedule/presentation/28/', 'title': 'コードを綺麗にしてくれるのに一役買ってくれるツール/ライブラリをまとめて紹介します。'}, element=<Element a at 0x7fc52eea77c8>),
#     Node(tag='a', doc_order=263, child_position=1, attribs={'href': '/2014/schedule/presentation/41/', 'title': "In Taiwan, we always have low quality roadways to go. To prevent and improve this situation, we've created a website which called OpenRoads @ TW. Users can report and vote the bad restrictions, bad qualities and bad designs for the roads."}, element=<Element a at 0x7fc52b39a0c8>),
#     Node(tag='a', doc_order=268, child_position=1, attribs={'href': '/2014/schedule/presentation/12/', 'title': '現在、ウェブサイト www.python.jp は 静的なウェブサイト構築ツール Pelican(http://docs.getpelican.com) で構築されている。本セッションでは、Pelicanを使ったPythonとreStructuredTextによるサイト構築手法を解説する。'}, element=<Element a at 0x7fc52b39a248>),
#     Node(tag='a', doc_order=278, child_position=1, attribs={'href': '/2014/schedule/presentation/34/', 'title': 'ディスクリプタは、 Python の至るところで使われている強力な多目的のプロトコルです。プロパティ、メソッド、静的メソッド、クラスメソッド、 super() の背後にある機構として用いられています。ディスクリプタについて学ぶことにより、新しいツールセットが使えるようになるというだけでなく、 Python の仕組みや、洗練された設計のアプリケーションについてのより深い理解が得られます。本発表では、 Python 公式ドキュメントの内容を元に、ディスクリプタの概要、 Python でどのようにディスクリプタが使われているか、ディスクリプタを使ってできることなどを解説します。'}, element=<Element a at 0x7fc52b39a4c8>),
#     Node(tag='a', doc_order=283, child_position=1, attribs={'href': '/2014/schedule/presentation/37/', 'title': "In this session, you would learn how to build a web application that would parse the incoming stream of tweets using Python's NLTK. This session would start with introducing the problem space, then covering fundamentals , and finally looking at the NaiveBayesClassifier that does the job. We would also talk about an open source Python library called TextBlob that builds on top of NLTK."}, element=<Element a at 0x7fc52b39a608>),
#     Node(tag='a', doc_order=288, child_position=1, attribs={'href': '/2014/schedule/presentation/14/', 'title': 'Pyramidは柔軟で自由度が高いWebアプリケーションフレームワークです。\nPyramidのチュートリアル以降の、さまざまなアドオンやライブラリとの連携やテスト、デバッグ、デプロイなど、実際の開発に必要な知識など解説します。'}, element=<Element a at 0x7fc52b39a748>),
#     Node(tag='a', doc_order=339, child_position=1, attribs={'href': '/2014/schedule/presentation/17/', 'title': "Oktavia is a full text search engine designed for browsers. In this session, I will describe Oktavia's algorithm, structure, future plan."}, element=<Element a at 0x7fc52b39d448>),
#     Node(tag='a', doc_order=344, child_position=1, attribs={'href': '/2014/schedule/presentation/21/', 'title': 'This introduces a system that builds documents automatically and publish it online. The system uses several components around Python; Django, Celery, GitHub,  GitPython, Docker, Calibre, TexLive, and Re:VIEW.  After the successful maintenance for over a year, the speaker would like to share several observations he made during the period, and discuss them with the other Python hackers.'}, element=<Element a at 0x7fc52b39d588>),
#     Node(tag='a', doc_order=349, child_position=1, attribs={'href': '/2014/schedule/presentation/9/', 'title': 'OpenCVのpythonインターフェースの初心者向けチュートリアルです。画像や動画を入力とした処理全般を指す「コンピュータビジョン」の各種処理を行うための大規模ライブラリである「OpenCV(Open Computer Vision)」は、pythonから使用することが可能です。この講演では、そのOpenCVをpythonから使ってみたい方むけに「OpenCVライブラリの概要」と「Computer Visionとはどういうものか」の概要をお話しします。pythonでOpenCVを使うメリットや、その他の科学技術計算ライブラリとのnumpyを通した連携性についても話します。'}, element=<Element a at 0x7fc52b39d6c8>),
#     Node(tag='a', doc_order=362, child_position=1, attribs={'href': '/2014/schedule/presentation/39/', 'title': 'This lecture describes a journey guided by hardcore gaming experiences from the past and how that lead to development of PyNES. What started as a Python ASM compiler for Nintendo 8 bits and is now evolving as a Python programming for Nintendo 8 bits. All the hacks and drawbacks faced will be shown. Told as an epic tale, that should encourage others to fulfil the same path.'}, element=<Element a at 0x7fc52b39da08>),
#     Node(tag='a', doc_order=367, child_position=1, attribs={'href': '/2014/schedule/presentation/19/', 'title': 'Python 3.4から、新しい非同期I/Oフレームワークのasyncioが標準ライブラリとして追加されました。このセッションでは、asyncioの概要、API、使い方などを紹介し、実例を交えながら、非同期のプログラミングモデル、デザインパターンなどについて解説します。'}, element=<Element a at 0x7fc52b39db48>),
#     Node(tag='a', doc_order=372, child_position=1, attribs={'href': '/2014/schedule/presentation/22/', 'title': '近年、スパムフィルタリング、レコメンデーション、画像認識、検索エンジン、広告配信システムなど、様々な分野で機械学習の技術が利用されています。\n機械学習のアルゴリズムは正しく利用すれば大きな効果が期待できますが、アルゴリズムは理論的に高度なものが多く、正しく実装することは容易ではありません。\nしかし、Pythonにはscikit-learnと呼ばれる機械学習ライブラリが用意されており、scikit-learnを利用することで、複雑なアルゴリズムを手軽に利用することが可能です。\n本セッションでは、機械学習およびscikit-learnの紹介を行い、さらにスパムフィルタの理論的な解説とともに、Pythonとscikit-learnを利用したスパムフィルタの実装例を示します。'}, element=<Element a at 0x7fc52b39dc88>),
#     Node(tag='a', doc_order=382, child_position=1, attribs={'href': '/2014/schedule/presentation/25/', 'title': 'Overview of the current options for doing static analysis on Python projects,\nincluding existing tools, tools under development, and common difficulties.\nChallenges to introducing static analysis to an existing project and ways to\novercome them.        '}, element=<Element a at 0x7fc52b39df08>),
#     Node(tag='a', doc_order=387, child_position=1, attribs={'href': '/2014/schedule/presentation/31/', 'title': 'KanmuではPythonとAmazon Elastic MapReduce上のHiveを利用してアプリケーション上でのユーザ行動履歴を集計しています。人的リソース、金銭的リソースの制約をある程度前提に置いた状態で、ユーザ行動を集計する際の設計的工夫、実装的工夫、利用ライブラリを紹介します。\n'}, element=<Element a at 0x7fc52b397088>),
#     Node(tag='a', doc_order=392, child_position=1, attribs={'href': '/2014/schedule/presentation/23/', 'title': 'カックロや数独など、いろいろなパズルを数理最適化の手法を使って解いていきます'}, element=<Element a at 0x7fc52b3971c8>),
#     Node(tag='a', doc_order=405, child_position=1, attribs={'href': '/2014/schedule/presentation/10/', 'title': 'CRMやマーケティングに活用できる実践的なデータ分析とはどのようなものなのか、データ分析の実例を交えつつ、データ分析関連のPythonのライブラリ（Pandas, Scipy, scikit-learn など）をダイジェストで紹介します。\n- Python3.4（Statistics Method / 統計関数）\n- Pandas（Crosstab / クロス集計）\n- Scipy（K-means Clustering / 非階層クラスタリング）\n- scikit-learn'}, element=<Element a at 0x7fc52b397508>),
#     Node(tag='a', doc_order=410, child_position=1, attribs={'href': '/2014/schedule/presentation/11/', 'title': '昨年の「パッケージングの今と未来」続報として、関連PEPの動向、ツールの状況について解説します。'}, element=<Element a at 0x7fc52b397648>),
#     Node(tag='a', doc_order=415, child_position=1, attribs={'href': '/2014/schedule/presentation/6/', 'title': 'When it comes to WebSocket programming, people generally go with the combination of Node.js and Socket.io. It does not seem a bad  combo. However, Node.js is not well-known for backward compatibility which causes pain and tear to any DevOps team. I will help you explore the way to develop a WebSocket application purely with Python as a backend tier.'}, element=<Element a at 0x7fc52b397788>),
#     Node(tag='a', doc_order=426, child_position=1, attribs={'href': '/2014/schedule/presentation/30/', 'title': '野球選手・チームを統計学的に分析、可視化を行う「セイバーメトリクス」をPythonで行う方法を紹介します。'}, element=<Element a at 0x7fc52b397a48>),
#     Node(tag='a', doc_order=431, child_position=1, attribs={'href': '/2014/schedule/presentation/35/', 'title': '日本では2013年末ごろ、PerlやRubyやJavaScriptのユーザを中心に、プログラミング言語における「正規表現リテラルの必要性」が多くの支持を集めました。これに対し、Pythonはコア言語仕様として正規表現リテラルを持ちませんが、Pythonが文字列処理や正規表現機能に関して大きな不満もなく使えているのも事実です。\n\nそこで本発表では、プログラミング言語において正規表現リテラルは「あれば便利だけどなくても困らない（ライブラリでカバーできる）」ものであることを、Pythonを使って説明します。具体的には、他言語ユーザが持っている「正規表現リテラルのほうが便利」「動作が高速」「バックスラッシュを二重に書くの面倒」といった誤解を解消することを目指します。\n\nまたこれに付随して、Python標準の正規表現ライブラリが抱える問題点についても、その解決策とともに説明します。\n'}, element=<Element a at 0x7fc52b397b88>),
#     Node(tag='a', doc_order=436, child_position=1, attribs={'href': '/2014/schedule/presentation/16/', 'title': 'With context switching between everyone’s “gotta learn to code, gotta learn to code.” and traditional education as current trend: here I’d love to present some quests on teaching and learning Python around Taiwan Python community.\nIncluding: 1. Changes, chances, and challenges. 2. What’re we proposing. 3. How’re we doing. 4. From here import future.'}, element=<Element a at 0x7fc52b397cc8>)},
#    'children': []},
#   {'tag': 'span.speaker',
#    'element': {Node(tag='span', doc_order=151, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b385b08>),
#     Node(tag='span', doc_order=156, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b385988>),
#     Node(tag='span', doc_order=161, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b385848>),
#     Node(tag='span', doc_order=172, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3853c8>),
#     Node(tag='span', doc_order=177, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b385088>),
#     Node(tag='span', doc_order=182, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b385308>),
#     Node(tag='span', doc_order=196, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3e1d08>),
#     Node(tag='span', doc_order=201, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3e1bc8>),
#     Node(tag='span', doc_order=206, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc53ccdf1c8>),
#     Node(tag='span', doc_order=216, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b4a7f88>),
#     Node(tag='span', doc_order=221, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b4a7948>),
#     Node(tag='span', doc_order=226, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b4a7a88>),
#     Node(tag='span', doc_order=236, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52eea7248>),
#     Node(tag='span', doc_order=241, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52eea7388>),
#     Node(tag='span', doc_order=246, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52eea74c8>),
#     Node(tag='span', doc_order=259, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3ed308>),
#     Node(tag='span', doc_order=264, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39a148>),
#     Node(tag='span', doc_order=269, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39a288>),
#     Node(tag='span', doc_order=279, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39a508>),
#     Node(tag='span', doc_order=284, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39a648>),
#     Node(tag='span', doc_order=289, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39a788>),
#     Node(tag='span', doc_order=340, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39d488>),
#     Node(tag='span', doc_order=345, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39d5c8>),
#     Node(tag='span', doc_order=350, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39d708>),
#     Node(tag='span', doc_order=363, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39da48>),
#     Node(tag='span', doc_order=368, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39db88>),
#     Node(tag='span', doc_order=373, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39dcc8>),
#     Node(tag='span', doc_order=383, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b39df48>),
#     Node(tag='span', doc_order=388, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3970c8>),
#     Node(tag='span', doc_order=393, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397208>),
#     Node(tag='span', doc_order=406, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397548>),
#     Node(tag='span', doc_order=411, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397688>),
#     Node(tag='span', doc_order=416, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b3977c8>),
#     Node(tag='span', doc_order=427, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397a88>),
#     Node(tag='span', doc_order=432, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397bc8>),
#     Node(tag='span', doc_order=437, child_position=2, attribs={'class': 'speaker'}, element=<Element span at 0x7fc52b397d08>)},
#    'children': []},
#   {'tag': 'div.badges',
#    'element': {Node(tag='div', doc_order=152, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b385ac8>),
#     Node(tag='div', doc_order=157, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b3859c8>),
#     Node(tag='div', doc_order=162, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b385808>),
#     Node(tag='div', doc_order=173, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b385108>),
#     Node(tag='div', doc_order=178, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b385288>),
#     Node(tag='div', doc_order=183, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b385348>),
#     Node(tag='div', doc_order=197, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b3e1dc8>),
#     Node(tag='div', doc_order=202, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b3e19c8>),
#     Node(tag='div', doc_order=207, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc53ccdf088>),
#     Node(tag='div', doc_order=217, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b4a7f08>),
#     Node(tag='div', doc_order=222, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b4a7cc8>),
#     Node(tag='div', doc_order=227, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b4a7ec8>),
#     Node(tag='div', doc_order=237, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52eea7288>),
#     Node(tag='div', doc_order=242, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52eea73c8>),
#     Node(tag='div', doc_order=247, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52eea7508>),
#     Node(tag='div', doc_order=260, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a048>),
#     Node(tag='div', doc_order=265, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a188>),
#     Node(tag='div', doc_order=270, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a2c8>),
#     Node(tag='div', doc_order=280, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a548>),
#     Node(tag='div', doc_order=285, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a688>),
#     Node(tag='div', doc_order=290, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39a7c8>),
#     Node(tag='div', doc_order=341, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39d4c8>),
#     Node(tag='div', doc_order=346, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39d608>),
#     Node(tag='div', doc_order=351, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39d748>),
#     Node(tag='div', doc_order=364, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39da88>),
#     Node(tag='div', doc_order=369, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39dbc8>),
#     Node(tag='div', doc_order=374, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39dd08>),
#     Node(tag='div', doc_order=384, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b39df88>),
#     Node(tag='div', doc_order=389, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397108>),
#     Node(tag='div', doc_order=394, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397248>),
#     Node(tag='div', doc_order=407, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397588>),
#     Node(tag='div', doc_order=412, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b3976c8>),
#     Node(tag='div', doc_order=417, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397808>),
#     Node(tag='div', doc_order=428, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397ac8>),
#     Node(tag='div', doc_order=433, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397c08>),
#     Node(tag='div', doc_order=438, child_position=1, attribs={'class': 'badges'}, element=<Element div at 0x7fc52b397d48>)},
#    'children': []}]}

# %%
from collections import defaultdict
from operator import itemgetter

def hydrate_trie2(node, docorder_min, docorder_max=None):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []
    for i, element in enumerate(elements, start=1):
        if not (docorder_min < element.doc_order):
            continue
        if docorder_max is not None and (element.doc_order > docorder_max):
            continue
        e = {'tag': _node_repr(element),
             'doc_order': element.doc_order}
        _t = [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        #print((element, _order_min, _order_max))
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate_trie2(child, _order_min, _order_max)]))
        if children:
            e['children'] = sorted(children, key=itemgetter('doc_order'))
            
        if 'children' not in e and 'text' not in e:
            continue
        #if len(children) == 1:
            #e = children[0]
            #e['tag'] = '{}/{}'.format(_node_repr(element), e['tag'])
        output.append(e)
    #if len(output) == 1:
    #    return output[0]
    return sorted(output, key=itemgetter('doc_order'))
pp(hydrate_trie2(root, 0))
# Out:
# [{'children': [{'doc_order': 150,
#                 'tag': 'a',
#                 'text': 'Djangoによるスマホアプリバックエンドの実装 (ja)'},
#                {'doc_order': 151,
#                 'tag': 'span.speaker',
#                 'text': 'Yuichi Nakazawa, Kazuhiko Kakita'}],
#   'doc_order': 148,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 155,
#                 'tag': 'a',
#                 'text': 'Deep Learning for Image Recognition in Python (ja)'},
#                {'doc_order': 156,
#                 'tag': 'span.speaker',
#                 'text': 'Hideki Tanaka'}],
#   'doc_order': 153,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 160,
#                 'tag': 'a',
#                 'text': 'Programming the Performance Co-Pilot toolkit (en)'},
#                {'doc_order': 161,
#                 'tag': 'span.speaker',
#                 'text': 'Nathan Scott'}],
#   'doc_order': 158,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 171,
#                 'tag': 'a',
#                 'text': 'Djangoアプリケーション、パフォーマンスチューニング (ja)'},
#                {'doc_order': 172,
#                 'tag': 'span.speaker',
#                 'text': 'Hiroki KIYOHARA'}],
#   'doc_order': 169,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 176,
#                 'tag': 'a',
#                 'text': 'The esperanto generator (ja)'},
#                {'doc_order': 177,
#                 'tag': 'span.speaker',
#                 'text': 'torajiro aida'}],
#   'doc_order': 174,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 181,
#                 'tag': 'a',
#                 'text': 'Gunicorn, the thundering herd and other concurrency '
#                         'programming challenges (en)'},
#                {'doc_order': 182,
#                 'tag': 'span.speaker',
#                 'text': 'Benoit Chesneau'}],
#   'doc_order': 179,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 195, 'tag': 'a', 'text': 'Pythonの実装系総ざらい (ja)'},
#                {'doc_order': 196,
#                 'tag': 'span.speaker',
#                 'text': 'MASATO NAKAMURA'}],
#   'doc_order': 193,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 200,
#                 'tag': 'a',
#                 'text': 'Data collection, analysis and optimization with '
#                         'python (en)'},
#                {'doc_order': 201,
#                 'tag': 'span.speaker',
#                 'text': 'Shinji Iwaki'}],
#   'doc_order': 198,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 205,
#                 'tag': 'a',
#                 'text': 'Python, Raspberry Pi, Arduinoで作る消費電力モニタリングシステム (ja)'},
#                {'doc_order': 206, 'tag': 'span.speaker', 'text': '柿迫 純一'}],
#   'doc_order': 203,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 215,
#                 'tag': 'a',
#                 'text': '最新リリースCMSツール Plone 5 のモダンUIとテクノロジーの進化 (ja)'},
#                {'doc_order': 216,
#                 'tag': 'span.speaker',
#                 'text': 'Manabu TERADA'}],
#   'doc_order': 213,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 220,
#                 'tag': 'a',
#                 'text': 'Effective numerical computation in Numpy and Scipy '
#                         '(en)'},
#                {'doc_order': 221,
#                 'tag': 'span.speaker',
#                 'text': 'Kimikazu Kato'}],
#   'doc_order': 218,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 225,
#                 'tag': 'a',
#                 'text': 'Micro Python で組み込み Python (ja)'},
#                {'doc_order': 226,
#                 'tag': 'span.speaker',
#                 'text': 'Hirotaka Kawata'}],
#   'doc_order': 223,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 235, 'tag': 'a', 'text': 'PyCharm活用術 (ja)'},
#                {'doc_order': 236,
#                 'tag': 'span.speaker',
#                 'text': 'Takayuki Shimizukawa'}],
#   'doc_order': 233,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 240,
#                 'tag': 'a',
#                 'text': 'Introduction to scientific programming in python '
#                         '(en)'},
#                {'doc_order': 241,
#                 'tag': 'span.speaker',
#                 'text': 'Olivier Hervieu'}],
#   'doc_order': 238,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 245,
#                 'tag': 'a',
#                 'text': 'XML-RPC : Pythonが「電池付属」と呼ばれる理由 (ja)'},
#                {'doc_order': 246, 'tag': 'span.speaker', 'text': 'Ransui Iso'}],
#   'doc_order': 243,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 258,
#                 'tag': 'a',
#                 'text': 'リファクタリングツールあれこれ (May the force be with you)  (ja)'},
#                {'doc_order': 259, 'tag': 'span.speaker', 'text': 'tell k'}],
#   'doc_order': 256,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 263,
#                 'tag': 'a',
#                 'text': "Open Data for Taiwan's Roadways (en)"},
#                {'doc_order': 264, 'tag': 'span.speaker', 'text': 'Andre Lee'}],
#   'doc_order': 261,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 268,
#                 'tag': 'a',
#                 'text': 'Pelicanによる静的ウェブサイトの構築 - www.python.jp サイトの仕組みと構造 '
#                         '(ja)'},
#                {'doc_order': 269,
#                 'tag': 'span.speaker',
#                 'text': 'atsuo ishimoto'}],
#   'doc_order': 266,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 278,
#                 'tag': 'a',
#                 'text': 'Python を支える技術: ディスクリプタ編 (ja)'},
#                {'doc_order': 279,
#                 'tag': 'span.speaker',
#                 'text': 'Nozomu Kaneko'}],
#   'doc_order': 276,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 283,
#                 'tag': 'a',
#                 'text': 'Mining sentiments in tweets using Python (en)'},
#                {'doc_order': 284,
#                 'tag': 'span.speaker',
#                 'text': 'Shekhar Gulati'}],
#   'doc_order': 281,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 288, 'tag': 'a', 'text': 'Pyramid入門 (ja)'},
#                {'doc_order': 289,
#                 'tag': 'span.speaker',
#                 'text': 'Atsushi Odagiri'}],
#   'doc_order': 286,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 339,
#                 'tag': 'a',
#                 'text': 'Oktavia - Search Engine (en)'},
#                {'doc_order': 340,
#                 'tag': 'span.speaker',
#                 'text': 'Yoshiki Shibukawa'}],
#   'doc_order': 337,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 344,
#                 'tag': 'a',
#                 'text': '"Continuous Publication" with Python: Another '
#                         'Approach (ja)'},
#                {'doc_order': 345,
#                 'tag': 'span.speaker',
#                 'text': 'Daisuke Miyakawa'}],
#   'doc_order': 342,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 349,
#                 'tag': 'a',
#                 'text': 'OpenCVのpythonインターフェース入門 (ja)'},
#                {'doc_order': 350,
#                 'tag': 'span.speaker',
#                 'text': 'Masaki  Hayashi'}],
#   'doc_order': 347,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 362,
#                 'tag': 'a',
#                 'text': 'PyNES: Python programming for Nintendo 8 bits. (en)'},
#                {'doc_order': 363, 'tag': 'span.speaker', 'text': 'Guto Maia'}],
#   'doc_order': 360,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 367,
#                 'tag': 'a',
#                 'text': 'Pythonによる非同期プログラミング入門 (ja)'},
#                {'doc_order': 368,
#                 'tag': 'span.speaker',
#                 'text': 'Hironori Sekine'}],
#   'doc_order': 365,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 372,
#                 'tag': 'a',
#                 'text': 'Pythonとscikit-learnではじめる機械学習 (ja)'},
#                {'doc_order': 373, 'tag': 'span.speaker', 'text': 'やまかつ'}],
#   'doc_order': 370,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 382,
#                 'tag': 'a',
#                 'text': 'Improving code quality through static analysis for '
#                         'Python (en)'},
#                {'doc_order': 383,
#                 'tag': 'span.speaker',
#                 'text': 'Daniel Izquierdo'}],
#   'doc_order': 380,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 387,
#                 'tag': 'a',
#                 'text': 'Python + Hive on AWS EMRで貧者のログ集計 (ja)'},
#                {'doc_order': 388,
#                 'tag': 'span.speaker',
#                 'text': 'Akira Chiku'}],
#   'doc_order': 385,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 392, 'tag': 'a', 'text': '数理最適化によるパズルの解法 (ja)'},
#                {'doc_order': 393,
#                 'tag': 'span.speaker',
#                 'text': 'Tsutomu Saito'}],
#   'doc_order': 390,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 405,
#                 'tag': 'a',
#                 'text': 'データ分析の世界へようこそ！ ～マーケティングに活かせるPythonライブラリ～ (ja)'},
#                {'doc_order': 406, 'tag': 'span.speaker', 'text': '池内 孝啓'}],
#   'doc_order': 403,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 410, 'tag': 'a', 'text': 'パッケージングの今 (ja)'},
#                {'doc_order': 411,
#                 'tag': 'span.speaker',
#                 'text': 'Atsushi Odagiri'}],
#   'doc_order': 408,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 415,
#                 'tag': 'a',
#                 'text': 'WebSocket 101 in Python (en)'},
#                {'doc_order': 416,
#                 'tag': 'span.speaker',
#                 'text': 'Juti Noppornpitak'}],
#   'doc_order': 413,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 426,
#                 'tag': 'a',
#                 'text': 'Pythonではじめる野球プログラミング (ja)'},
#                {'doc_order': 427,
#                 'tag': 'span.speaker',
#                 'text': 'Shinichi Nakagawa'}],
#   'doc_order': 424,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 431,
#                 'tag': 'a',
#                 'text': '正規表現リテラルは本当に必要なのか？ (ja)'},
#                {'doc_order': 432,
#                 'tag': 'span.speaker',
#                 'text': 'Makoto Kuwata'}],
#   'doc_order': 429,
#   'tag': 'td.slot.slot-talk'},
#  {'children': [{'doc_order': 436,
#                 'tag': 'a',
#                 'text': 'Python Quest in Taiwan (en)'},
#                {'doc_order': 437, 'tag': 'span.speaker', 'text': 'Keith Yang'}],
#   'doc_order': 434,
#   'tag': 'td.slot.slot-talk'}]

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter


tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([21, 25, 24, 22, 23, 14, 19, 15, 10, 26, 16,  7, 17, 12, 11, 18,  8,
#        20, 13,  6,  3,  9,  4,  5,  1,  2,  0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                #, leaf_font_size=8
               )

# %%
root = TrieNode()

# %%
# borrowed from https://stackoverflow.com/questions/8484943/construct-a-tree-from-list-os-file-paths-python-performance-dependent
from collections import defaultdict

FILE_MARKER = '<files>'

def attach(branch, trunk):
    '''
    Insert a branch of directories on its trunk.
    '''
    parts = branch.split('/', 1)
    if len(parts) == 1:  # branch is a file
        trunk[FILE_MARKER].append(parts[0])
        return trunk
    else:
        node, others = parts
        if node not in trunk:
            trunk[node] = defaultdict(dict, ((FILE_MARKER, []), ('<paths>', []), ('<texts>', [])))
        return attach(others, trunk[node])

def prettify(d, indent=0):
    '''
    Print the file tree structure with proper indentation.
    '''
    for key, value in d.items():
        if key == FILE_MARKER:
            if value:
                print('  ' * indent + str(value))
        elif key in ('<paths>', '<texts>'):
            if value:
                print('\n'.join('  ' * indent + v for v in value))
        else:
            print('  ' * indent + str(key))
            if isinstance(value, dict):
                prettify(value, indent+1)
            else:
                print('  ' * (indent+1) + str(value))

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue
    print('-------')
    print('Cluster #{}'.format(n))
    tree = defaultdict(dict, ((FILE_MARKER, []),))
    for tp in cluster:
        branch = attach(tp, tree)
        branch['<paths>'].append(tp)
        for nodepath in clustering.tagpath_nodes[tp][:10]:
            node = nodepath[-1]
            
            e = node.element
            texts = [s.strip() for s in e.xpath('./text()[normalize-space()]')]
            attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
            t = ' '.join(texts)
            if t.strip():
                branch['<texts>'].append(t)
    prettify(tree)
# Out:
# -------
# Cluster #1
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table.dataframe
#             tbody
#               tr
#                 td
#                   ['br', 'a', 'b']
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/br
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/a
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td/b
#                   How to drive business decisions with AI
#                   Python in medicine: signal processing - learning and visualization of temporal data
#                   Felix Wick
#                   Annalisa Barla
# -------
# Cluster #2
#
#   html
#     head
#       ['link', 'meta']
#       /html/head/link
#       /html/head/meta
#     body
#       div.row
#         div.columns.large-9
#           ['h3', 'p']
#           /html/body/div.row/div.columns.large-9/h3
#           /html/body/div.row/div.columns.large-9/p
#           Program
#           Tuesday, 28 August
#           Wednesday, 29 August
#           Thursday, 30 August
#           Friday, 31 August
#           Tutorials last either 90 minutes or 180 minutes. In the latter case, they are split in two sessions.
# The exact hours are subject to change to account for the logistics of coffee and lunch
# breaks.
# Tutorial istructions can be found under
#           table.dataframe
#             tbody
#               ['td']
#               /html/body/div.row/div.columns.large-9/table.dataframe/tbody/td
#               16:00
#               Lightning Talks
# -------
# Cluster #3
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           ['table.dataframe']
#           /html/body/div.row/div.columns.large-9/table.dataframe
#           table.dataframe
#             ['thead', 'tbody']
#             /html/body/div.row/div.columns.large-9/table.dataframe/thead
#             /html/body/div.row/div.columns.large-9/table.dataframe/tbody
#             thead
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table.dataframe/thead/tr
#               tr
#                 ['th']
#                 /html/body/div.row/div.columns.large-9/table.dataframe/thead/tr/th
#                 Time
#                 Track 1
#                 Track 2
#                 Time
#                 Track 1
#                 Track 2
# -------
# Cluster #4
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table
#             ['tbody']
#             /html/body/div.row/div.columns.large-9/table/tbody
#             tbody
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table/tbody/tr
#               tr
#                 ['td']
#                 /html/body/div.row/div.columns.large-9/table/tbody/tr/td
#                 9:00
#                 Introduction to Jupyter, M. Muller
#                 Databases for Scientists / SQL Intro, Alexander CS Hendorf
#                 Doing bioinformatics with scikit-bio and BioPython, Joris Vankerschaver
#                 10:30
#                 Coffee Break
#                 Coffee Break
#                 Coffee Break
#                 11:00
#                 Introduction to Python, M. Rastgoo & G. Lemaitre
# -------
# Cluster #6
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           table.dataframe
#             tbody
#               tr
#                 ['td.has-link']
#                 /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link
#                 Scikit-learn and tabular data: closing the gap
#                 Deep Learning for Human Pose Estimation
#                 Numpy - where we are and where we want to be
#                 GMDH Neural Network for Short-term Electricity Load Forecasting
#                 Extending Python 3.7s Data Classes
#                 modAL: A modular active learning framework for Python
#                 Searching efficiently through (genomic) sequences with vantage point trees
#                 Imbalanced-learn: a scikit-learn-contrib to tackle learning from imbalanced data set
#                 ModelXplore, a python based model exploration
#                 Efficient Biomedical Named Entity Recognition in Python
#                 td.has-link
#                   ['br', 'i']
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br
#                   /html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i
#                   Joris Van den Bossche
#                   Ale Solano
#                   Matti Picus
#                   Kostas Passadis
#                   Geir Arne Hjelle
#                   Tivadar Danka
#                   Joris Vankerschaver
#                   Guillaume Lemaitre
#                   Nicolas Cellier
#                   Tilia Ellendorff
# -------
# Cluster #7
#
#   html
#     body
#       div.row
#         div.columns.large-9
#           ['table']
#           /html/body/div.row/div.columns.large-9/table
#           table
#             ['thead']
#             /html/body/div.row/div.columns.large-9/table/thead
#             thead
#               ['tr']
#               /html/body/div.row/div.columns.large-9/table/thead/tr
#               tr
#                 ['th']
#                 /html/body/div.row/div.columns.large-9/table/thead/tr/th
#                 Time
#                 Introductory
#                 Advanced
#                 Applications
#                 Time
#                 Introductory
#                 Advanced
#                 Applications

# %%
from collections import defaultdict, Counter
from functools import partial
import hashlib

import pygtrie
from pprint import pprint as pp
from pprint import pformat as pf

from html2text import html2text
from lxml.html import tostring
from slugify import slugify
import html_text

tohtml = partial(tostring, encoding='unicode')
totxt = html_text.extract_text

def hydrate(tree, doc, parent_path, merge_keys=True):
    relative_path = '>'.join(
        tree['_path'][len(parent_path):]
    ).lstrip('>')
    data = []
    _key = None
    for e in doc.cssselect(relative_path):
        if _key is None:
            _key = slugify(' '.join(filter(bool, [e.tag] + [re.sub(r'[\-\d]+', '', a)
                                                            for a in e.attrib.get('class', '').split()])), to_lower=True, separator='_')
            _key = relative_path.split('>')[-1]
            h = hashlib.sha256()
            h.update(_key.encode('utf8'))
            _key = '{}_{}'.format(e.tag, h.hexdigest()[:4])
        record = {}
        children_groups = list(filter(bool, [
                hydrate(child, e, tree['_path'], merge_keys=merge_keys)
                for child in tree['_children']
            ]))
        if children_groups:
            if merge_keys:
                for group in children_groups:
                    children = defaultdict(list)
                    for child in group:
                        key = child.pop('_key')
                        _attr = child.get('_attribs')
                        if _attr:
                            _cls = _attr.get('class')
                            if _cls:
                                _attr.pop('class')
                                key = _cls
                            child.update(child.pop('_attribs'))
                        children[key].append(child)
                    record.update(children)
            else:
                record['_children'] = children_groups
        if tree['_value']:
            _t = ' '.join([re.sub(r'\s+', ' ', s)
                           for s in e.xpath('self::*[not(self::script) and not(self::style)]/text()[normalize-space()]')]).strip()
            #_t = totxt(tohtml(e))
            if _t:
                record['_text'] = _t
            #elif not record.get('_children'):
            elif not children_groups:
                #_t = '__NO-CHILDREN__'+e.xpath('normalize-space()').strip()
                _t = ' '.join([re.sub(r'\s+', ' ', s)
                    for s in e.xpath('self::*[not(self::script) and not(self::style)]/text()[normalize-space()]')]).strip()+_t
                #_t = totxt(tohtml(e))
                if _t:
                    if len(_t) > 50:
                        record['_text'] = _t[:50]+'...'
                    else:
                        record['_text'] = _t
            _a = {k: re.sub('\s+', ' ', v.strip())
                                      for k, v in e.attrib.items()
                                      if k not in  (
                                          #'class',
                                          'style',
                                      )}
            if _a:
                record['_attribs'] = _a
        if record:
            record['_key'] = _key
            data.append(record)
    #if data and len(data) == 1:
    #    return data[0]
    return data
    #return {d.pop('_key'): d for d in data}

def make(path_conv, path, children, value=None):
    children = list(children)
    if value is None and len(children) == 1:
        # There is only one prefix.
        return children[0]
    else:
        return {'_children': children,
                #'_value': value[:64]+'...'+value[-64:] if value else value,
                '_value': value,
                '_path': path}

# %%
for i, cluster in clusters.items():
    print('Cluster {}'.format(i))
    #print()
    c = Counter([len(tp.split('/')) for tp in cluster])
    #print(dict(c))
    print('Cluster size: {}, cluster depths: {} ({}), depth_diff={}'.format(len(cluster), c, len(c), (max(c) - min(c))))
    print()
# Out:
# Cluster 4
# Cluster size: 3, cluster depths: Counter({9: 1, 8: 1, 7: 1}) (3), depth_diff=2
#
# Cluster 5
# Cluster size: 2, cluster depths: Counter({9: 1, 8: 1}) (2), depth_diff=1
#
# Cluster 6
# Cluster size: 3, cluster depths: Counter({10: 2, 9: 1}) (2), depth_diff=1
#
# Cluster 7
# Cluster size: 4, cluster depths: Counter({9: 1, 6: 1, 7: 1, 8: 1}) (4), depth_diff=3
#
# Cluster 0
# Cluster size: 2, cluster depths: Counter({8: 1, 9: 1}) (2), depth_diff=1
#
# Cluster 3
# Cluster size: 5, cluster depths: Counter({7: 2, 9: 1, 6: 1, 8: 1}) (4), depth_diff=3
#
# Cluster 2
# Cluster size: 5, cluster depths: Counter({4: 2, 6: 2, 8: 1}) (3), depth_diff=4
#
# Cluster 1
# Cluster size: 3, cluster depths: Counter({10: 3}) (1), depth_diff=0

# %%
doc = lxml.html.fromstring(page_content)
for n, cluster in sorted(clusters.items()):
    size = len(cluster)
    #if size < 2 and size > 30:
    #    continue
    c = Counter([len(tp.split('/')) for tp in cluster])
    depth_diff = max(c) - min(c)
    #if depth_diff > 10:
    #    continue
    print("Cluster {}".format(n))
    tagpaths_trie = pygtrie.Trie()
    for tp in cluster:
        tagpaths_trie[tp.split('/')] = tp
        
    r = tagpaths_trie.traverse(make)
    
    o = hydrate(r, doc, '', merge_keys=False)
    print('Size {}'.format(len(o)))
    s = pf(o)
    print(s)

# %%
doc = lxml.html.fromstring(page_content)
tagpaths_trie = pygtrie.Trie()
for tp in clusters[6]:
    tagpaths_trie[tp.split('/')] = tp
additional_tps = [
    '/html/body/div.row/div.columns.large-9/h3',
]
for tp in additional_tps: 
    tagpaths_trie[tp.split('/')] = tp
    pass

r = tagpaths_trie.traverse(make)

o = hydrate(r, doc, '', merge_keys=True)
s = pf(o)

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('test.euroscipy2018.json', 'w') as fp:
    json.dump(o, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %%
def pretty(path_conv, path, children, value=None):
    print((path_conv, path, children, value))

tagpaths_trie.traverse(pretty)
# Out:
# (<bound method Trie._key_from_path of Trie(((('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link', 'br'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'table.dataframe', 'tbody', 'tr', 'td.has-link', 'i'), '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i'), (('', 'html', 'body', 'div.row', 'div.columns.large-9', 'h3'), '/html/body/div.row/div.columns.large-9/h3'),))>, (), <generator object _Node.traverse.<locals>.children at 0x7f6652efb0f8>, None)

# %%
def make2(path_conv, path, children, value=None):
    #print(path_conv)
    children = list(children)
    if value is None and len(children) == 1:
        # There is only one prefix.
        return children[0]
    else:
        o = {}
        if children:
            o['_children'] = children
        if value:
            o['_value'] = value
        return o
        return {
                #'_value': value[:64]+'...'+value[-64:] if value else value,
                '_value': value,
                '_path': '/'.join(path)}
    
pp(tagpaths_trie.traverse(make2))
# Out:
# {'_children': [{'_children': [{'_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/br'},
#                               {'_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link/i'}],
#                 '_value': '/html/body/div.row/div.columns.large-9/table.dataframe/tbody/tr/td.has-link'},
#                {'_value': '/html/body/div.row/div.columns.large-9/h3'}]}

# %%
p = '>'.join(additional_tps[0].split('/')).lstrip('>')
doc.cssselect(p)
# Out:
# [<Element img at 0x7f0efbc88a98>,
#  <Element img at 0x7f0efbc88278>,
#  <Element img at 0x7f0efbc88228>,
#  <Element img at 0x7f0efbb4b638>,
#  <Element img at 0x7f0efbb4b5e8>,
#  <Element img at 0x7f0efbb4b688>,
#  <Element img at 0x7f0efbb4b6d8>,
#  <Element img at 0x7f0efbb4b728>,
#  <Element img at 0x7f0efbb4b778>,
#  <Element img at 0x7f0efbb4b7c8>,
#  <Element img at 0x7f0efbb4b818>,
#  <Element img at 0x7f0efbb4b868>,
#  <Element img at 0x7f0efbb4b8b8>,
#  <Element img at 0x7f0efbb4b908>,
#  <Element img at 0x7f0efbb4b958>,
#  <Element img at 0x7f0efbb4b9a8>,
#  <Element img at 0x7f0efbb4b9f8>,
#  <Element img at 0x7f0efbb4ba48>,
#  <Element img at 0x7f0efbb4ba98>,
#  <Element img at 0x7f0efbb4bae8>]
