# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Fist, get the HTML

# %%
#import requests
#page = requests.get('http://www.alias-production.fr/agenda/')
#page_content = page.text
page_content = open('samples/betjemanandbarton.com.Thés classiques, Darjeeling, Ceylan, Chine, Japon - Betjeman & Barton.html').read()

# %% [markdown]
# We can list the repeating tagpaths, with or without classes or HTML IDs:

# %%
from collections import Counter
from sketchtml.repeats import TagPathClustering


clustering = TagPathClustering(page_content,
                               with_id=False,
                               with_classes=True,
                               strip_digits=False,
                               ignore_classes=('last-in-line',),
                              )
clustering._build_tagpaths(textonly=False)

for tp, cnt in Counter(clustering.tagpaths).most_common():
    if cnt > 1:
        print('({:3d}) {}'.format(cnt, tp))
# Out:
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link/img
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align/a
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.product-description
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p
# (107) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/a.ajax_add_to_cart_button.button.exclusive
# (104) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p/span.price-qty
# ( 26) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li
# ( 26) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/a
# ( 11) /html/head/link
# (  9) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category
# (  9) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul
# (  9) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last
# (  9) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last/a
# (  8) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/a
# (  8) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li
# (  8) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li/a
# (  5) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category.last/ul/li
# (  5) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category.last/ul/li/a
# (  5) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/form/div.select-box/p.select/select/option
# (  5) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.best
# (  5) /html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-left/li
# (  5) /html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-left/li/a
# (  4) /html/head/meta
# (  4) /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li
# (  4) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option
# (  4) /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li
# (  4) /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a
# (  4) /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a/span.color-red.font-bold.font-small.title
# (  3) /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a
# (  3) /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a/span.font-xs-small.title
# (  3) /html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-right/li
# (  3) /html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-right/li/a
# (  2) /html/body/section/header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input
# (  2) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul
# (  2) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last
# (  2) /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last/a
# (  2) /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters

# %% [markdown]
# ## Clustering of tagpaths
#
# Perform spectral clustering using the methom from ["Extracting Data Records from the Web Using Tag Path Clustering", 2009](http://www2009.wwwconference.org/proceedings/pdf/p981.pdf).
#
# > Miao, Gengxin & Tatemura, Junichi & Hsiung, Wang-Pin & Sawires, Arsany & Moser, Louise. (2009).
# > **Extracting data records from the Web using tag path clustering**. ACM WWW. 981-990. 10.1145/1526709.1526841.

# %%
clusters = clustering.clusters()

# %% [markdown]
# ## Plotting tagpaths "signals" can help chosing better `with_classes`, `with_ids` parameters

# %%
clustering.simhelper.plot_signals()

# %%
from pprint import pprint as pp

pp(clusters)
# Out:
# defaultdict(<class 'list'>,
#             {0: ['/html/body/section/header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/form/div.select-box/p.select/select/option',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link/img',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/a.ajax_add_to_cart_button.button.exclusive',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p/span.price-qty',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align/a',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.best',
#                  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.product-description',
#                  '/html/head/link',
#                  '/html/head/meta'],
#              1: ['/html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-left/li',
#                  '/html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-left/li/a'],
#              2: ['/html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li',
#                  '/html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a',
#                  '/html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a/span.font-xs-small.title'],
#              3: ['/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category.last/ul/li',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category.last/ul/li/a'],
#              4: ['/html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li',
#                  '/html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a',
#                  '/html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a/span.color-red.font-bold.font-small.title'],
#              5: ['/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/a',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last/a'],
#              6: ['/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/a',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last/a',
#                  '/html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li/a'],
#              7: ['/html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-right/li',
#                  '/html/body/section/footer.footer/div.bg-grey.block.h58/ul.font-xxs-small.links.pull-right/li/a']})

# %% [markdown]
# ## Let's build a trie to reconstruct the layout from a tagpath list (from one or more clusters or a chosen subset of tagpaths)

# %%
from functools import partial
from typing import Tuple
from pprint import pformat

_node_repr = partial(TagPathClustering.node_repr,
                             with_classes=True,
                             with_id=False,
                             with_attr_names=False,
                             strip_digits=False)
_node_repr = clustering._node_repr
# This if borrowed from https://towardsdatascience.com/implementing-a-trie-data-structure-in-python-in-less-than-100-lines-of-code-a877ea23c1a1

class TrieNode(object):
    """
    Our trie node implementation. Very basic. but does the job
    """
    
    def __init__(self, char_repr):
        self.char_repr = char_repr
        self.elements = set()
        self.children = []
        # Is it the last character of the word.`
        self.word_finished = False
        # How many times this character appeared in the addition process
        self.counter = 1

def add(root, word):
    """
    Adding a word in the trie structure
    """
    node = root
    #print('Root: {}, Word: {}'.format(root, word))
    for char in word:
        char_repr = _node_repr(char)
        #print('Char: {}'.format(char_repr))
        found_in_child = False
        # Search for the character in the children of the present `node`
        for child in node.children:
            if child.char_repr == char_repr:
                # We found it, increase the counter by 1 to keep track that another
                # word has it as well
                child.counter += 1
                # And point the node to the child that contains this char
                node = child
                found_in_child = True
                #print('Child found.')
                node.elements.add(char)
                break
        # We did not find it so add a new chlid
        if not found_in_child:
            new_node = TrieNode(char_repr)
            new_node.elements.add(char)
            node.children.append(new_node)
            # And then point node to the new child
            node = new_node
            #print('Child NOT found. Creating new TrieNode({})'.format(char))
    # Everything finished. Mark it as the end of a word.
    node.word_finished = True

# %% [markdown]
# To help chose the clusters we need, we can print out some of the text data for each tagpath in each cluster.

# %%
from pprint import pprint

for n, cluster in sorted(clusters.items()):
    if len(cluster) < 3:
        continue

    print('---- Cluster #{} ----'.format(n))
    for tp in sorted(cluster, key=lambda tp: tp.split('/')):
        to_print = []
        try:
            for nodepath in clustering.tagpath_nodes[tp][:10]:
                node = nodepath[-1]
                e = node.element
                texts = [s.strip() for s in e.xpath('.//text()[normalize-space()]')]
                attribs = {k: v for k, v in e.attrib.items() if k not in ['class']}
                t = ' '.join(texts)[:100]
                if t or attribs:
                #if t:
                    to_print.append((node.doc_order, t, attribs))
            if to_print:
                print('---\n'+tp)
                for e in to_print:
                    print(e)
                print()
        except Exception as e:
            print(str(e))
            pass
# Out:
# ---- Cluster #0 ----
# ---
# /html/body/section/header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input
# (74, '', {'type': 'hidden', 'name': 'orderby', 'value': 'position'})
# (75, '', {'type': 'hidden', 'name': 'orderway', 'value': 'desc'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters
# (234, "//<![CDATA[\n\n$(document).ready(function()\n{\n\t$('#selectPrductSort').change(function()\n\t{\n\t\tvar reque", {})
# (1534, 'produits 12 24 48 51 Aller en haut', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option
# (1543, '12', {'value': '12'})
# (1544, '24', {'value': '24'})
# (1545, '48', {'value': '48'})
# (1546, '51', {'value': '51'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/form/div.select-box/p.select/select/option
# (241, '--', {'value': 'name:asc', 'selected': 'selected'})
# (242, 'Le moins cher', {'value': 'price:asc'})
# (243, 'Le plus cher', {'value': 'price:desc'})
# (244, 'De A à Z', {'value': 'name:asc', 'selected': 'selected'})
# (245, 'De Z à A', {'value': 'name:desc'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item
# (248, 'SÉLECTION DU MOIS Darjeeling Ambootia Blanc au Safran - Darjeeling dédié à la maison Betjeman and Ba', {})
# (261, 'SÉLECTION DU MOIS Darjeeling Castelton - Darjeeling doux et fleuri - \n  Ce thé Darjeeling, au... 12,', {})
# (274, 'SÉLECTION DU MOIS Thé du Japon Genmaicha - Thé vert légèrement salé\ufeff\ufeff - \n  Ce thé du Japon est... 9,', {})
# (287, 'SÉLECTION DU MOIS Thé du Vietnam Oolong - Thé bleu-vert du Vietnam très rafraîchissant\ufeff\ufeff\ufeff -... 15,68', {})
# (300, 'SÉLECTION DU MOIS Thé noir Grand Yunnan - Thé noir à la saveur corsée\ufeff - \n  Ce thé noir du... 10,08 ', {})
# (313, 'Dégustation Pour vous faire découvrir nos thés, nous vous proposons... 10,00 € Commander', {})
# (324, "Afternoon Dream - Mélange de thés noirs de Ceylan, Chine et d'Inde\ufeff -... 4,24 € / 100gr Commander", {})
# (336, "Assam BOP - Thé d'Inde aux notes corsées\ufeff - \n \xa0 \n Ce thé noir... 4,87 € / 100gr Commander", {})
# (348, "Assam Greenwood - Thé d'Inde long en bouche\ufeff - \n \xa0 \n Ce thé d'Assam... 7,17 € / 100gr Commander", {})
# (360, "Assam Keelung - Thé d'Inde entre puissance et raffinement\ufeff -... 11,95 € / 100gr Commander", {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link
# (249, '', {'href': 'https://betjemanandbarton.com/fr/darjeeling/734-darjeeling-ambotia-blanc-au-safran.html', 'title': 'Darjeeling Ambootia Blanc au Safran'})
# (262, '', {'href': 'https://betjemanandbarton.com/fr/darjeeling/48-darjeeling-castleton.html', 'title': 'Darjeeling Castelton'})
# (275, '', {'href': 'https://betjemanandbarton.com/fr/japon/169-japon-genmaicha.html', 'title': 'Thé du Japon Genmaicha'})
# (288, '', {'href': 'https://betjemanandbarton.com/fr/autres-origines/655-the-du-vietnam-oolong.html', 'title': 'Thé du Vietnam Oolong'})
# (301, '', {'href': 'https://betjemanandbarton.com/fr/chine-noirs/133-the-noir-grand-yunnan.html', 'title': 'Thé noir Grand Yunnan'})
# (314, '', {'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/564-lot-echantillons.html', 'title': ' Dégustation'})
# (325, '', {'href': 'https://betjemanandbarton.com/fr/blends/175-afternoon-dream.html', 'title': 'Afternoon Dream'})
# (337, '', {'href': 'https://betjemanandbarton.com/fr/assam/115-assam-bop.html', 'title': 'Assam BOP'})
# (349, '', {'href': 'https://betjemanandbarton.com/fr/assam/116-assam-greenwood.html', 'title': 'Assam Greenwood'})
# (361, '', {'href': 'https://betjemanandbarton.com/fr/assam/117-assam-keelung.html', 'title': 'Assam Keelung'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link/img
# (250, '', {'src': 'https://betjemanandbarton.com/734-1110-large/darjeeling-ambotia-blanc-au-safran.jpg', 'alt': 'Darjeeling Ambootia Blanc au Safran', 'width': '215px', 'height': '215px'})
# (263, '', {'src': 'https://betjemanandbarton.com/48-1109-large/darjeeling-castleton.jpg', 'alt': 'Darjeeling Castleton', 'width': '215px', 'height': '215px'})
# (276, '', {'src': 'https://betjemanandbarton.com/169-1151-large/japon-genmaicha.jpg', 'alt': 'Thé Japon Genmaicha', 'width': '215px', 'height': '215px'})
# (289, '', {'src': 'https://betjemanandbarton.com/655-1084-large/the-du-vietnam-oolong.jpg', 'alt': 'Thé du Vietnam Oolong', 'width': '215px', 'height': '215px'})
# (302, '', {'src': 'https://betjemanandbarton.com/133-1122-large/the-noir-grand-yunnan.jpg', 'alt': 'Chine Grand Yunnan', 'width': '215px', 'height': '215px'})
# (315, '', {'src': 'https://betjemanandbarton.com/564-826-large/lot-echantillons.jpg', 'alt': ' Dégustation', 'width': '215px', 'height': '215px'})
# (326, '', {'src': 'https://betjemanandbarton.com/175-1182-large/afternoon-dream.jpg', 'alt': 'Afternoon Dream', 'width': '215px', 'height': '215px'})
# (338, '', {'src': 'https://betjemanandbarton.com/115-1064-large/assam-bop.jpg', 'alt': 'Assam BOP', 'width': '215px', 'height': '215px'})
# (350, '', {'src': 'https://betjemanandbarton.com/116-1065-large/assam-greenwood.jpg', 'alt': 'Assam Greenwood', 'width': '215px', 'height': '215px'})
# (362, '', {'src': 'https://betjemanandbarton.com/117-1066-large/assam-keelung.jpg', 'alt': 'Assam Keelung', 'width': '215px', 'height': '215px'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info
# (251, 'SÉLECTION DU MOIS Darjeeling Ambootia Blanc au Safran - Darjeeling dédié à la maison Betjeman and Ba', {})
# (264, 'SÉLECTION DU MOIS Darjeeling Castelton - Darjeeling doux et fleuri - \n  Ce thé Darjeeling, au... 12,', {})
# (277, 'SÉLECTION DU MOIS Thé du Japon Genmaicha - Thé vert légèrement salé\ufeff\ufeff - \n  Ce thé du Japon est... 9,', {})
# (290, 'SÉLECTION DU MOIS Thé du Vietnam Oolong - Thé bleu-vert du Vietnam très rafraîchissant\ufeff\ufeff\ufeff -... 15,68', {})
# (303, 'SÉLECTION DU MOIS Thé noir Grand Yunnan - Thé noir à la saveur corsée\ufeff - \n  Ce thé noir du... 10,08 ', {})
# (316, 'Dégustation Pour vous faire découvrir nos thés, nous vous proposons... 10,00 € Commander', {})
# (327, "Afternoon Dream - Mélange de thés noirs de Ceylan, Chine et d'Inde\ufeff -... 4,24 € / 100gr Commander", {})
# (339, "Assam BOP - Thé d'Inde aux notes corsées\ufeff - \n \xa0 \n Ce thé noir... 4,87 € / 100gr Commander", {})
# (351, "Assam Greenwood - Thé d'Inde long en bouche\ufeff - \n \xa0 \n Ce thé d'Assam... 7,17 € / 100gr Commander", {})
# (363, "Assam Keelung - Thé d'Inde entre puissance et raffinement\ufeff -... 11,95 € / 100gr Commander", {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price
# (257, '42,50 € / 100gr Commander', {})
# (270, '12,86 € / 100gr Commander', {})
# (283, '9,22 € / 100gr Commander', {})
# (296, '15,68 € / 100gr Commander', {})
# (309, '10,08 € / 100gr Commander', {})
# (321, '10,00 € Commander', {})
# (332, '4,24 € / 100gr Commander', {})
# (344, '4,87 € / 100gr Commander', {})
# (356, '7,17 € / 100gr Commander', {})
# (368, '11,95 € / 100gr Commander', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/a.ajax_add_to_cart_button.button.exclusive
# (260, 'Commander', {'rel': 'ajax_id_product_734', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=734&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (273, 'Commander', {'rel': 'ajax_id_product_48', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=48&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (286, 'Commander', {'rel': 'ajax_id_product_169', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=169&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (299, 'Commander', {'rel': 'ajax_id_product_655', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=655&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (312, 'Commander', {'rel': 'ajax_id_product_133', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=133&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (323, 'Commander', {'rel': 'ajax_id_product_564', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=564&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (335, 'Commander', {'rel': 'ajax_id_product_175', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=175&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (347, 'Commander', {'rel': 'ajax_id_product_115', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=115&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (359, 'Commander', {'rel': 'ajax_id_product_116', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=116&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
# (371, 'Commander', {'rel': 'ajax_id_product_117', 'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=117&token=cdd92df3b95c524da21f30ab7d81afbd', 'title': 'Commander'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p
# (258, '42,50 € / 100gr', {})
# (271, '12,86 € / 100gr', {})
# (284, '9,22 € / 100gr', {})
# (297, '15,68 € / 100gr', {})
# (310, '10,08 € / 100gr', {})
# (322, '10,00 €', {})
# (333, '4,24 € / 100gr', {})
# (345, '4,87 € / 100gr', {})
# (357, '7,17 € / 100gr', {})
# (369, '11,95 € / 100gr', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p/span.price-qty
# (259, '/ 100gr', {})
# (272, '/ 100gr', {})
# (285, '/ 100gr', {})
# (298, '/ 100gr', {})
# (311, '/ 100gr', {})
# (334, '/ 100gr', {})
# (346, '/ 100gr', {})
# (358, '/ 100gr', {})
# (370, '/ 100gr', {})
# (382, '/ 100gr', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table
# (253, 'Darjeeling Ambootia Blanc au Safran', {})
# (266, 'Darjeeling Castelton', {})
# (279, 'Thé du Japon Genmaicha', {})
# (292, 'Thé du Vietnam Oolong', {})
# (305, 'Thé noir Grand Yunnan', {})
# (317, 'Dégustation', {})
# (328, 'Afternoon Dream', {})
# (340, 'Assam BOP', {})
# (352, 'Assam Greenwood', {})
# (364, 'Assam Keelung', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align
# (254, 'Darjeeling Ambootia Blanc au Safran', {})
# (267, 'Darjeeling Castelton', {})
# (280, 'Thé du Japon Genmaicha', {})
# (293, 'Thé du Vietnam Oolong', {})
# (306, 'Thé noir Grand Yunnan', {})
# (318, 'Dégustation', {})
# (329, 'Afternoon Dream', {})
# (341, 'Assam BOP', {})
# (353, 'Assam Greenwood', {})
# (365, 'Assam Keelung', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align/a
# (255, 'Darjeeling Ambootia Blanc au Safran', {'href': 'https://betjemanandbarton.com/fr/darjeeling/734-darjeeling-ambotia-blanc-au-safran.html', 'title': 'Darjeeling Ambootia Blanc au Safran'})
# (268, 'Darjeeling Castelton', {'href': 'https://betjemanandbarton.com/fr/darjeeling/48-darjeeling-castleton.html', 'title': 'Darjeeling Castelton'})
# (281, 'Thé du Japon Genmaicha', {'href': 'https://betjemanandbarton.com/fr/japon/169-japon-genmaicha.html', 'title': 'Thé du Japon Genmaicha'})
# (294, 'Thé du Vietnam Oolong', {'href': 'https://betjemanandbarton.com/fr/autres-origines/655-the-du-vietnam-oolong.html', 'title': 'Thé du Vietnam Oolong'})
# (307, 'Thé noir Grand Yunnan', {'href': 'https://betjemanandbarton.com/fr/chine-noirs/133-the-noir-grand-yunnan.html', 'title': 'Thé noir Grand Yunnan'})
# (319, 'Dégustation', {'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/564-lot-echantillons.html', 'title': ' Dégustation'})
# (330, 'Afternoon Dream', {'href': 'https://betjemanandbarton.com/fr/blends/175-afternoon-dream.html', 'title': 'Afternoon Dream'})
# (342, 'Assam BOP', {'href': 'https://betjemanandbarton.com/fr/assam/115-assam-bop.html', 'title': 'Assam BOP'})
# (354, 'Assam Greenwood', {'href': 'https://betjemanandbarton.com/fr/assam/116-assam-greenwood.html', 'title': 'Assam Greenwood'})
# (366, 'Assam Keelung', {'href': 'https://betjemanandbarton.com/fr/assam/117-assam-keelung.html', 'title': 'Assam Keelung'})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.best
# (252, 'SÉLECTION DU MOIS', {})
# (265, 'SÉLECTION DU MOIS', {})
# (278, 'SÉLECTION DU MOIS', {})
# (291, 'SÉLECTION DU MOIS', {})
# (304, 'SÉLECTION DU MOIS', {})
#
# ---
# /html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.product-description
# (256, '- Darjeeling dédié à la maison Betjeman and Barton -...', {})
# (269, '- Darjeeling doux et fleuri - \n  Ce thé Darjeeling, au...', {})
# (282, '- Thé vert légèrement salé\ufeff\ufeff - \n  Ce thé du Japon est...', {})
# (295, '- Thé bleu-vert du Vietnam très rafraîchissant\ufeff\ufeff\ufeff -...', {})
# (308, '- Thé noir à la saveur corsée\ufeff - \n  Ce thé noir du...', {})
# (320, 'Pour vous faire découvrir nos thés, nous vous proposons...', {})
# (331, "- Mélange de thés noirs de Ceylan, Chine et d'Inde\ufeff -...", {})
# (343, "- Thé d'Inde aux notes corsées\ufeff - \n \xa0 \n Ce thé noir...", {})
# (355, "- Thé d'Inde long en bouche\ufeff - \n \xa0 \n Ce thé d'Assam...", {})
# (367, "- Thé d'Inde entre puissance et raffinement\ufeff -...", {})
#
# ---
# /html/head/link
# (9, '', {'rel': 'icon', 'type': 'image/vnd.microsoft.icon', 'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831'})
# (10, '', {'rel': 'shortcut icon', 'type': 'image/x-icon', 'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831'})
# (12, '', {'href': 'https://betjemanandbarton.com/themes/betjemanandbarton/cache/f42c4adfa76388ceb6e7468f084dbe62_all.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'})
# (13, '', {'href': '/themes/betjemanandbarton/css/theme.css', 'rel': 'stylesheet', 'type': 'text/css'})
# (14, '', {'href': '/themes/betjemanandbarton/css/temp.css', 'rel': 'stylesheet', 'type': 'text/css'})
# (15, '', {'href': '/themes/betjemanandbarton/css/jqtransform.css', 'rel': 'stylesheet', 'type': 'text/css'})
# (16, '', {'href': 'https://fonts.googleapis.com/css?family=EB+Garamond', 'rel': 'stylesheet', 'type': 'text/css'})
# (20, '', {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/jquery.rating.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'})
# (21, '', {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/advancedfeedback.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'})
# (22, '', {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/pm_advancedfeedback_global.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'})
#
# ---
# /html/head/meta
# (5, '', {'name': 'description', 'content': "Les thés classiques par Betjeman & Barton: une sélection des meilleurs thés de Chine, du Japon et du Monde. Livraison gratuite en France dès 45€ d'achat"})
# (6, '', {'http-equiv': 'Content-Type', 'content': 'application/xhtml+xml; charset=utf-8'})
# (7, '', {'name': 'generator', 'content': 'PrestaShop'})
# (8, '', {'name': 'robots', 'content': 'index,follow'})
#
# ---- Cluster #2 ----
# ---
# /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li
# (45, 'Points de Vente', {})
# (49, 'Notre bar a thé', {})
# (53, 'Nous connaître', {})
# (57, "var CUSTOMIZE_TEXTFIELD = 1;\nvar customizationIdMessage = 'Customization #';\nvar removingLinkText = ", {})
#
# ---
# /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a
# (46, 'Points de Vente', {'href': 'https://betjemanandbarton.com/cms.php?id_cms_category=2'})
# (50, 'Notre bar a thé', {'href': 'https://betjemanandbarton.com/cms.php?id_cms=18'})
# (54, 'Nous connaître', {'href': 'https://betjemanandbarton.com/cms.php?id_cms_category=3'})
#
# ---
# /html/body/section/header.clearfix.header/ul.pull-right.secondary-links/li/a/span.font-xs-small.title
# (48, 'Points de Vente', {})
# (52, 'Notre bar a thé', {})
# (56, 'Nous connaître', {})
#
# ---- Cluster #4 ----
# ---
# /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li
# (1566, 'Bar a thé', {})
# (1570, 'À Paris', {})
# (1574, 'En province', {})
# (1578, 'Dans le monde', {})
#
# ---
# /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a
# (1567, 'Bar a thé', {'href': 'https://betjemanandbarton.com/cms.php?id_cms=18'})
# (1571, 'À Paris', {'href': 'https://betjemanandbarton.com/cms.php?id_cms=7'})
# (1575, 'En province', {'href': 'https://betjemanandbarton.com/cms.php?id_cms=8'})
# (1579, 'Dans le monde', {'href': 'https://betjemanandbarton.com/cms.php?id_cms=23'})
#
# ---
# /html/body/section/footer.footer/div.locations.margin-b-20.pull-right/ul.secondary-links/li/a/span.color-red.font-bold.font-small.title
# (1568, 'Bar a thé', {})
# (1572, 'À Paris', {})
# (1576, 'En province', {})
# (1580, 'Dans le monde', {})
#
# ---- Cluster #5 ----
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category
# (90, "Noël Thés Boîtes, accessoires, douceurs Coffrets Cadeaux d'exception", {})
# (101, 'Les thés classiques Assam Ceylan Darjeeling Thés noirs de Chine Thés verts de Chine Thés blancs de C', {})
# (126, 'Les thés parfumés Les thés noirs Les Fruités Les Fleurs Les Epicés Les Douceurs Les Agrumes Les thés', {})
# (161, 'NOUVEAU ! Les thés glacés Les thés Les boîtes 125g', {})
# (168, 'Les boîtes et sachets de thé Les boîtes 125 grs Les boîtes de 25 sachets Les boîtes de 48 sachets', {})
# (177, 'Les boîtes à thé vides Boîtes 125g Boîtes 250g Boîtes 500g Boîtes 1kg', {})
# (188, 'Les coffrets de thé Les Coffrets de thé', {})
# (193, 'Accessoires Gourmandises Gourmandises Accessoires Théières fonte', {})
# (202, 'Les tisanes et infusions de fruits (Eaux de Fruits) Les tisanes Les infusions de fruits (Eaux de Fru', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/a
# (91, 'Noël', {'href': 'https://www.betjemanandbarton.com/fr/69-noel', 'title': "Retrouvez notre sélection de thés, boîtes, coffrets et autres cadeaux d'exception, pour célébrer le plus beau des Noëls..."})
# (127, 'Les thés parfumés', {'href': 'https://www.betjemanandbarton.com/fr/8-les-thes-parfumes', 'title': 'Des mélanges de thé vert, thé noir, thé rouge agrémenté de fleurs, de pétales, de morceaux de fruits, d’huiles essentielles….\nDes recettes inédites qui font la réputation de notre maison depuis 1919.\nNos thés parfumés ont tous une histoire.'})
# (162, 'NOUVEAU ! Les thés glacés', {'href': 'https://www.betjemanandbarton.com/fr/85-les-thes-glaces', 'title': "Découvrez notre sélection de thés et infusions à savourer glacés. \nThés verts, thés noirs, thés d'origine ou créations originales, tisanes ou infusions, lequel sera votre préféré pour cet été ? "})
# (169, 'Les boîtes et sachets de thé', {'href': 'https://www.betjemanandbarton.com/fr/9-les-boites-et-sachets-the', 'title': 'Découvrez nos meilleurs thés présentés dans de jolies boîtes ! Elles sont gaies et composent l’essentiel de notre gamme.\nEt pour ceux qui apprécient le côté pratique, vous avez toujours le choix des sachets de thé. Le « vrac emprisonné » comme on le nomme.'})
# (178, 'Les boîtes à thé vides', {'href': 'https://www.betjemanandbarton.com/fr/60-boite-a-the', 'title': 'Large choix de boîtes à thé vides.\nFleurie, rayée, zébrée, ornée de la Tour Eiffel ou de Queen Elizabeth, en 125g, 250g ou 500g, quelle sera votre boîte à thé préférée ?\nExclusivités Betjeman and Barton.'})
# (189, 'Les coffrets de thé', {'href': 'https://www.betjemanandbarton.com/fr/10-les-coffrets-de-the', 'title': 'Voici une multitude d’idées cadeaux. Pour les amateurs confirmés ou les débutants, nous avons composé des coffrets de thé à offrir.\nNotre univers à portée de mains.'})
# (194, 'Accessoires Gourmandises', {'href': 'https://www.betjemanandbarton.com/fr/11-accessoires-gourmandises', 'title': 'Théières, boîtes à thé, filtres à thé, boules à thé… Tout est là ! N’oublions pas les douceurs.\nLes essentiels pour vous permettre de déguster au mieux vos thés !'})
# (203, 'Les tisanes et infusions de fruits (Eaux de Fruits)', {'href': 'https://www.betjemanandbarton.com/fr/12-les-tisanes', 'title': 'Les tisanes et Eaux de Fruits que nous avons sélectionnées pour vous sont disponibles en vrac ou en sachets.'})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul
# (92, "Thés Boîtes, accessoires, douceurs Coffrets Cadeaux d'exception", {})
# (103, 'Assam Ceylan Darjeeling Thés noirs de Chine Thés verts de Chine Thés blancs de Chine Formose Japon A', {})
# (128, 'Les thés noirs Les Fruités Les Fleurs Les Epicés Les Douceurs Les Agrumes Les thés verts Les Fruités', {})
# (163, 'Les thés Les boîtes 125g', {})
# (170, 'Les boîtes 125 grs Les boîtes de 25 sachets Les boîtes de 48 sachets', {})
# (179, 'Boîtes 125g Boîtes 250g Boîtes 500g Boîtes 1kg', {})
# (190, 'Les Coffrets de thé', {})
# (195, 'Gourmandises Accessoires Théières fonte', {})
# (204, 'Les tisanes Les infusions de fruits (Eaux de Fruits)', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last
# (99, "Cadeaux d'exception", {})
# (124, 'Thés façonnés et divers', {})
# (159, 'Les Bergamote', {})
# (166, 'Les boîtes 125g', {})
# (175, 'Les boîtes de 48 sachets', {})
# (186, 'Boîtes 1kg', {})
# (191, 'Les Coffrets de thé', {})
# (200, 'Théières fonte', {})
# (207, 'Les infusions de fruits (Eaux de Fruits)', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li.last/a
# (100, "Cadeaux d'exception", {'href': 'https://www.betjemanandbarton.com/fr/73-cadeaux-d-exception', 'title': "Caves à thé, thés rares et précieux... Retrouvez les plus beaux et les plus luxueux produits de la maison Betjeman and Barton dans cette sélection de cadeaux d'exception. "})
# (125, 'Thés façonnés et divers', {'href': 'https://www.betjemanandbarton.com/fr/75-thes-faconnes', 'title': 'Découvrez notre sélection de thés façonnés, à mi-chemin entre délice et beauté. Ces thés sont travaillés de manière très soignée, presque sculptés, pour le bonheur des yeux et du palais. '})
# (160, 'Les Bergamote', {'href': 'https://www.betjemanandbarton.com/fr/24-les-bergamote', 'title': 'Retrouvez ici nos meilleurs thés aromatisés à la bergamote.'})
# (167, 'Les boîtes 125g', {'href': 'https://www.betjemanandbarton.com/fr/86-boites-125g', 'title': "Découvrez notre sélection de thés et infusions à savourer glacés, conditionnés dans de jolies boîtes à thé en métal.\nThés verts, thés noirs, thés d'origine ou créations originales, tisanes ou infusions, lequel sera votre préféré pour cet été ? "})
# (176, 'Les boîtes de 48 sachets', {'href': 'https://www.betjemanandbarton.com/fr/21-les-boites-de-48-sachets', 'title': 'Sélection de thés en boîtes de 48 sachets. \nDoses individuelles emballées séparément, pour mieux préserver les arômes de votre thé préféré.'})
# (187, 'Boîtes 1kg', {'href': 'https://www.betjemanandbarton.com/fr/84-boites-1kg', 'title': 'Voici nos boîtes à thé vides pouvant contenir 1kg de votre thé préféré.\nDes idées cadeau pour tous les goûts !'})
# (192, 'Les Coffrets de thé', {'href': 'https://www.betjemanandbarton.com/fr/17-les-coffrets', 'title': 'Voici une multitude d’idées cadeaux. Pour les amateurs confirmés ou les débutants, nous avons composé des coffrets de thé à offrir.\nNotre univers à portée de mains.'})
# (201, 'Théières fonte', {'href': 'https://www.betjemanandbarton.com/fr/40-theieres-fonte', 'title': 'Sélection de théières en fonte en provenance directe des meilleurs ateliers du Japon. '})
# (208, 'Les infusions de fruits (Eaux de Fruits)', {'href': 'https://www.betjemanandbarton.com/fr/39-les-eaux-de-fruits', 'title': 'En exclusivité, la Maison Betjeman and Barton vous propose de découvrir ses créations exclusives d’Eaux de fruits. \nA savourer chaudes, ou glacées.'})
#
# ---- Cluster #6 ----
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li
# (93, 'Thés', {})
# (95, 'Boîtes, accessoires, douceurs', {})
# (97, 'Coffrets', {})
# (104, 'Assam', {})
# (106, 'Ceylan', {})
# (108, 'Darjeeling', {})
# (110, 'Thés noirs de Chine', {})
# (112, 'Thés verts de Chine', {})
# (114, 'Thés blancs de Chine', {})
# (116, 'Formose', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/a
# (94, 'Thés', {'href': 'https://www.betjemanandbarton.com/fr/70-thes', 'title': 'Découvrez notre sélection de thés de Noël à mettre au pied du sapin.'})
# (96, 'Boîtes, accessoires, douceurs', {'href': 'https://www.betjemanandbarton.com/fr/71-boites-accessoires-douceurs', 'title': "Découvrez notre sélection de boîtes à thé vides, d'accessoires ou encore de douceurs pour accompagner votre thé préféré. Des idées de cadeaux à offrir (ou à s'offrir)."})
# (98, 'Coffrets', {'href': 'https://www.betjemanandbarton.com/fr/72-coffrets', 'title': 'Voici une multitude d’idées cadeaux. Pour les amateurs confirmés ou les débutants, nous avons composé des coffrets de thé à offrir.'})
# (105, 'Assam', {'href': 'https://www.betjemanandbarton.com/fr/6-assam', 'title': 'Sélection de thés Assam, en provenance des plus beaux jardins d’Inde.'})
# (107, 'Ceylan', {'href': 'https://www.betjemanandbarton.com/fr/7-ceylan', 'title': 'Large choix de thés de Ceylan, en provenance du Sri Lanka.'})
# (109, 'Darjeeling', {'href': 'https://www.betjemanandbarton.com/fr/30-darjeeling', 'title': 'Le Darjeeling est une variété de thés indiens reconnus comme les plus prisés des thés noirs. \nLa maison Betjeman and Barton vous propose ici une sélection de thés Darjeeling raffinés, légers et riches en arômes.'})
# (111, 'Thés noirs de Chine', {'href': 'https://www.betjemanandbarton.com/fr/31-chine-noirs', 'title': 'Nous avons sélectionné pour vous les meilleurs thés noirs de Chine.\nSavourez le traditionnel Pu-Er, le mythique Grand Yunnan, L’Impérial Or, ainsi que nos thés façonnés.'})
# (113, 'Thés verts de Chine', {'href': 'https://www.betjemanandbarton.com/fr/32-chine-verts', 'title': 'Nous avons sélectionné pour vous les meilleurs thés verts de Chine.\nDécouvrez le traditionnel Lung Ching, ainsi que nos thés fermentés Wulong.'})
# (115, 'Thés blancs de Chine', {'href': 'https://www.betjemanandbarton.com/fr/33-chine-blancs', 'title': 'Nous avons sélectionné pour vous les meilleurs thés blancs de Chine.'})
# (117, 'Formose', {'href': 'https://www.betjemanandbarton.com/fr/34-formose', 'title': 'Sélection des meilleurs thés de Formose, en provenance de Taïwan.'})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul
# (131, 'Les Fruités Les Fleurs Les Epicés Les Douceurs Les Agrumes', {})
# (144, 'Les Fruités Les Fleurs Les Epicés Les Douceurs Les Agrumes', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li
# (132, 'Les Fruités', {})
# (134, 'Les Fleurs', {})
# (136, 'Les Epicés', {})
# (138, 'Les Douceurs', {})
# (145, 'Les Fruités', {})
# (147, 'Les Fleurs', {})
# (149, 'Les Epicés', {})
# (151, 'Les Douceurs', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li/a
# (133, 'Les Fruités', {'href': 'https://www.betjemanandbarton.com/fr/44-les-fruites', 'title': 'Thés noirs du monde aux arômes de fruits.'})
# (135, 'Les Fleurs', {'href': 'https://www.betjemanandbarton.com/fr/46-les-fleurs', 'title': 'Thés noirs du monde aux notes de fleurs.'})
# (137, 'Les Epicés', {'href': 'https://www.betjemanandbarton.com/fr/49-les-epices', 'title': 'Thés noirs du monde aux notes épicées.'})
# (139, 'Les Douceurs', {'href': 'https://www.betjemanandbarton.com/fr/50-les-douceurs', 'title': 'Thés noirs du monde aromatisés offrant une tasse douce et parfumée.'})
# (146, 'Les Fruités', {'href': 'https://www.betjemanandbarton.com/fr/45-les-fruites', 'title': 'Sélection de thés verts aux arômes de fruits.'})
# (148, 'Les Fleurs', {'href': 'https://www.betjemanandbarton.com/fr/47-les-fleurs', 'title': 'Sélection de thés verts aux notes de fleurs.'})
# (150, 'Les Epicés', {'href': 'https://www.betjemanandbarton.com/fr/48-les-epices', 'title': 'Sélection de thés verts aux notes épicées.'})
# (152, 'Les Douceurs', {'href': 'https://www.betjemanandbarton.com/fr/51-les-douceurs', 'title': 'Sélection de thés verts aromatisés offrant une tasse douce et parfumée.'})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last
# (140, 'Les Agrumes', {})
# (153, 'Les Agrumes', {})
#
# ---
# /html/body/section/section.clearfix.content/aside.sidebar/div.block.test/div.block_content/ul.dhtml.tree/li.head_category/ul/li/ul/li.last/a
# (141, 'Les Agrumes', {'href': 'https://www.betjemanandbarton.com/fr/52-les-agrumes', 'title': 'Thés noirs du monde aux arômes d’agrumes.'})
# (154, 'Les Agrumes', {'href': 'https://www.betjemanandbarton.com/fr/53-les-a', 'title': 'Sélection de thés verts aux arômes d’agrumes.'})

# %%
root = TrieNode('')
nodelists = clustering.tagpath_nodes
tps = []
for i in [0]:
    for tp in clusters[i]:
        tps.append(tp)
tps
# Out:
# ['/html/body/section/header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.filters/form/div.select-box/p.select/select/option',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/a.product_img_link/img',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/a.ajax_add_to_cart_button.button.exclusive',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.price/p/span.price-qty',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/div.table/h2.product-title.vertical-align/a',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.best',
#  '/html/body/section/section.clearfix.content/section.main/section.product-listing/div.products/ul.clear.product-list/li.ajax_block_product.item/div.produc-info/p.product-description',
#  '/html/head/link',
#  '/html/head/meta']

# %%
tps = '''
'''.splitlines()

# %% [markdown]
# Now let's insert them into the trie:

# %%
root = TrieNode('')
for tp in tps:
    steps = tp.lstrip('/').split('/')
    for nl in nodelists[tp][:]:
        add(root, nl)

# %%
def layout(node, summary=True):
    return dict(
        tag=node.char_repr if node.char_repr else node.char_repr,
        element=len(set(node.elements)) if summary else set(node.elements),
        children=[layout(c, summary=summary) for c in node.children],
        word_finished=node.word_finished
    )

# %% [markdown]
# If we check the general structure of the trie, we can notice that some levels only have 1 child.

# %%
def collapse(trienode):
    for c in trienode.children:
        collapse(c)
    if len(trienode.children) == 1 and not trienode.word_finished:
        trienode.char_repr += '/'+trienode.children[0].char_repr
        trienode.elements = trienode.children[0].elements
        
        trienode.children = trienode.children[0].children

# %%
collapse(root)
layout(root)
# Out:
# {'tag': '/html',
#  'element': 1,
#  'children': [{'tag': 'body/section',
#    'element': 1,
#    'children': [{'tag': 'header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input',
#      'element': 2,
#      'children': [],
#      'word_finished': False},
#     {'tag': 'section.clearfix.content/section.main/section.product-listing',
#      'element': 1,
#      'children': [{'tag': 'div.filters',
#        'element': 2,
#        'children': [{'tag': 'div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option',
#          'element': 4,
#          'children': [],
#          'word_finished': False},
#         {'tag': 'form/div.select-box/p.select/select/option',
#          'element': 5,
#          'children': [],
#          'word_finished': False}],
#        'word_finished': True},
#       {'tag': 'div.products/ul.clear.product-list/li.ajax_block_product.item',
#        'element': 107,
#        'children': [{'tag': 'a.product_img_link',
#          'element': 107,
#          'children': [{'tag': 'img',
#            'element': 107,
#            'children': [],
#            'word_finished': True}],
#          'word_finished': True},
#         {'tag': 'div.produc-info',
#          'element': 107,
#          'children': [{'tag': 'div.price',
#            'element': 107,
#            'children': [{'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#              'element': 107,
#              'children': [],
#              'word_finished': True},
#             {'tag': 'p',
#              'element': 107,
#              'children': [{'tag': 'span.price-qty',
#                'element': 104,
#                'children': [],
#                'word_finished': True}],
#              'word_finished': True}],
#            'word_finished': True},
#           {'tag': 'div.table',
#            'element': 107,
#            'children': [{'tag': 'h2.product-title.vertical-align',
#              'element': 107,
#              'children': [{'tag': 'a',
#                'element': 107,
#                'children': [],
#                'word_finished': True}],
#              'word_finished': True}],
#            'word_finished': True},
#           {'tag': 'p.best',
#            'element': 5,
#            'children': [],
#            'word_finished': True},
#           {'tag': 'p.product-description',
#            'element': 107,
#            'children': [],
#            'word_finished': True}],
#          'word_finished': True}],
#        'word_finished': False}],
#      'word_finished': False}],
#    'word_finished': False},
#   {'tag': 'head',
#    'element': 1,
#    'children': [{'tag': 'link',
#      'element': 11,
#      'children': [],
#      'word_finished': True},
#     {'tag': 'meta', 'element': 4, 'children': [], 'word_finished': True}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# We can collapse those branches:

# %% [markdown]
# The trie also keeps references to individual HTML nodes, with their document order so that we can re-build the data hierarchy:

# %%
layout(root, summary=False)
# Out:
# {'tag': '/html',
#  'element': {Node(tag='html', doc_order=2, child_position=1, attribs={'xmlns': 'http://www.w3.org/1999/xhtml', 'xml:lang': 'fr'}, element=<Element html at 0x7f6243eeb148>)},
#  'children': [{'tag': 'body/section',
#    'element': {Node(tag='section', doc_order=36, child_position=1, attribs={'id': 'page'}, element=<Element section at 0x7f6232bd0d88>)},
#    'children': [{'tag': 'header.clearfix.header/div.bg-grey.block.clearfix.h35/div.block.exclusive.pull-right/form/p.block_content/input',
#      'element': {Node(tag='input', doc_order=74, child_position=1, attribs={'type': 'hidden', 'name': 'orderby', 'value': 'position'}, element=<Element input at 0x7f623432b448>),
#       Node(tag='input', doc_order=75, child_position=2, attribs={'type': 'hidden', 'name': 'orderway', 'value': 'desc'}, element=<Element input at 0x7f623432b508>)},
#      'children': [],
#      'word_finished': False},
#     {'tag': 'section.clearfix.content/section.main/section.product-listing',
#      'element': {Node(tag='section', doc_order=233, child_position=1, attribs={'class': 'product-listing'}, element=<Element section at 0x7f6234325808>)},
#      'children': [{'tag': 'div.filters',
#        'element': {Node(tag='div', doc_order=234, child_position=1, attribs={'class': 'filters'}, element=<Element div at 0x7f623433e7c8>),
#         Node(tag='div', doc_order=1534, child_position=3, attribs={'class': 'filters'}, element=<Element div at 0x7f6232cbefc8>)},
#        'children': [{'tag': 'div.pagination/div.products-per-page/form.pagination/div.select-box/p.select/select/option',
#          'element': {Node(tag='option', doc_order=1543, child_position=1, attribs={'value': '12'}, element=<Element option at 0x7f6232cbeb08>),
#           Node(tag='option', doc_order=1544, child_position=2, attribs={'value': '24'}, element=<Element option at 0x7f6232cbed08>),
#           Node(tag='option', doc_order=1545, child_position=3, attribs={'value': '48'}, element=<Element option at 0x7f6232cbe908>),
#           Node(tag='option', doc_order=1546, child_position=4, attribs={'value': '51'}, element=<Element option at 0x7f6232cbe288>)},
#          'children': [],
#          'word_finished': False},
#         {'tag': 'form/div.select-box/p.select/select/option',
#          'element': {Node(tag='option', doc_order=241, child_position=1, attribs={'value': 'name:asc', 'selected': 'selected'}, element=<Element option at 0x7f623433ee08>),
#           Node(tag='option', doc_order=242, child_position=2, attribs={'value': 'price:asc'}, element=<Element option at 0x7f623433e9c8>),
#           Node(tag='option', doc_order=243, child_position=3, attribs={'value': 'price:desc'}, element=<Element option at 0x7f623433e348>),
#           Node(tag='option', doc_order=244, child_position=4, attribs={'value': 'name:asc', 'selected': 'selected'}, element=<Element option at 0x7f623433e448>),
#           Node(tag='option', doc_order=245, child_position=5, attribs={'value': 'name:desc'}, element=<Element option at 0x7f623433e188>)},
#          'children': [],
#          'word_finished': False}],
#        'word_finished': True},
#       {'tag': 'div.products/ul.clear.product-list/li.ajax_block_product.item',
#        'element': {Node(tag='li', doc_order=248, child_position=1, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623433e0c8>),
#         Node(tag='li', doc_order=261, child_position=2, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62342ef148>),
#         Node(tag='li', doc_order=274, child_position=3, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233e91ac8>),
#         Node(tag='li', doc_order=287, child_position=4, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232c5d2c8>),
#         Node(tag='li', doc_order=300, child_position=5, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232c5d148>),
#         Node(tag='li', doc_order=313, child_position=6, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234035ec8>),
#         Node(tag='li', doc_order=324, child_position=7, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234035b88>),
#         Node(tag='li', doc_order=336, child_position=8, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232ab7188>),
#         Node(tag='li', doc_order=348, child_position=9, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232ab7708>),
#         Node(tag='li', doc_order=360, child_position=10, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232ab7108>),
#         Node(tag='li', doc_order=372, child_position=11, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232ab7308>),
#         Node(tag='li', doc_order=384, child_position=12, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232ab7b88>),
#         Node(tag='li', doc_order=396, child_position=13, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62342f4108>),
#         Node(tag='li', doc_order=408, child_position=14, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62342f4b08>),
#         Node(tag='li', doc_order=420, child_position=15, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62342f49c8>),
#         Node(tag='li', doc_order=432, child_position=16, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232a93388>),
#         Node(tag='li', doc_order=444, child_position=17, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232a93d88>),
#         Node(tag='li', doc_order=455, child_position=18, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232a93e88>),
#         Node(tag='li', doc_order=467, child_position=19, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232a93288>),
#         Node(tag='li', doc_order=479, child_position=20, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232a93508>),
#         Node(tag='li', doc_order=491, child_position=21, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62343092c8>),
#         Node(tag='li', doc_order=503, child_position=22, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e96a08>),
#         Node(tag='li', doc_order=515, child_position=23, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e96948>),
#         Node(tag='li', doc_order=527, child_position=24, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232e96888>),
#         Node(tag='li', doc_order=539, child_position=25, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e96848>),
#         Node(tag='li', doc_order=551, child_position=26, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234208608>),
#         Node(tag='li', doc_order=563, child_position=27, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234208348>),
#         Node(tag='li', doc_order=575, child_position=28, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623422f908>),
#         Node(tag='li', doc_order=587, child_position=29, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e95c48>),
#         Node(tag='li', doc_order=599, child_position=30, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232e953c8>),
#         Node(tag='li', doc_order=611, child_position=31, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e95d48>),
#         Node(tag='li', doc_order=623, child_position=32, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232e95fc8>),
#         Node(tag='li', doc_order=635, child_position=33, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232e95388>),
#         Node(tag='li', doc_order=647, child_position=34, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cc5e48>),
#         Node(tag='li', doc_order=659, child_position=35, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cc59c8>),
#         Node(tag='li', doc_order=671, child_position=36, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232cc5708>),
#         Node(tag='li', doc_order=683, child_position=37, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cc5a88>),
#         Node(tag='li', doc_order=695, child_position=38, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234220508>),
#         Node(tag='li', doc_order=707, child_position=39, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234186a88>),
#         Node(tag='li', doc_order=719, child_position=40, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62341865c8>),
#         Node(tag='li', doc_order=731, child_position=41, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623415c4c8>),
#         Node(tag='li', doc_order=743, child_position=42, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f623416f148>),
#         Node(tag='li', doc_order=755, child_position=43, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62340d4848>),
#         Node(tag='li', doc_order=767, child_position=44, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62340f3dc8>),
#         Node(tag='li', doc_order=779, child_position=45, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62340f38c8>),
#         Node(tag='li', doc_order=791, child_position=46, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234250f48>),
#         Node(tag='li', doc_order=803, child_position=47, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233ee1d48>),
#         Node(tag='li', doc_order=815, child_position=48, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233ee14c8>),
#         Node(tag='li', doc_order=827, child_position=49, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233ee1e08>),
#         Node(tag='li', doc_order=839, child_position=50, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233ed63c8>),
#         Node(tag='li', doc_order=851, child_position=51, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233ed6188>),
#         Node(tag='li', doc_order=863, child_position=52, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233ed68c8>),
#         Node(tag='li', doc_order=875, child_position=53, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233ed6c48>),
#         Node(tag='li', doc_order=887, child_position=54, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62342535c8>),
#         Node(tag='li', doc_order=899, child_position=55, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234253208>),
#         Node(tag='li', doc_order=911, child_position=56, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234066408>),
#         Node(tag='li', doc_order=923, child_position=57, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62342c8888>),
#         Node(tag='li', doc_order=934, child_position=58, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62342c89c8>),
#         Node(tag='li', doc_order=946, child_position=59, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234338bc8>),
#         Node(tag='li', doc_order=958, child_position=60, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f623430e948>),
#         Node(tag='li', doc_order=970, child_position=61, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623430e808>),
#         Node(tag='li', doc_order=982, child_position=62, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623430ef48>),
#         Node(tag='li', doc_order=994, child_position=63, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f623402bec8>),
#         Node(tag='li', doc_order=1006, child_position=64, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62343157c8>),
#         Node(tag='li', doc_order=1018, child_position=65, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234315b08>),
#         Node(tag='li', doc_order=1030, child_position=66, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233ea08c8>),
#         Node(tag='li', doc_order=1042, child_position=67, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234345208>),
#         Node(tag='li', doc_order=1054, child_position=68, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62342dca88>),
#         Node(tag='li', doc_order=1066, child_position=69, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62342dc748>),
#         Node(tag='li', doc_order=1078, child_position=70, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cc4108>),
#         Node(tag='li', doc_order=1090, child_position=71, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234304348>),
#         Node(tag='li', doc_order=1102, child_position=72, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234304648>),
#         Node(tag='li', doc_order=1114, child_position=73, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234304888>),
#         Node(tag='li', doc_order=1126, child_position=74, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234332848>),
#         Node(tag='li', doc_order=1138, child_position=75, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234332d08>),
#         Node(tag='li', doc_order=1150, child_position=76, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234084bc8>),
#         Node(tag='li', doc_order=1162, child_position=77, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623400b748>),
#         Node(tag='li', doc_order=1174, child_position=78, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233fc7cc8>),
#         Node(tag='li', doc_order=1186, child_position=79, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233fc7b08>),
#         Node(tag='li', doc_order=1198, child_position=80, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233eed248>),
#         Node(tag='li', doc_order=1210, child_position=81, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233eed788>),
#         Node(tag='li', doc_order=1222, child_position=82, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233eed988>),
#         Node(tag='li', doc_order=1234, child_position=83, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234058d88>),
#         Node(tag='li', doc_order=1246, child_position=84, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6234050cc8>),
#         Node(tag='li', doc_order=1258, child_position=85, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbc808>),
#         Node(tag='li', doc_order=1270, child_position=86, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbc8c8>),
#         Node(tag='li', doc_order=1282, child_position=87, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232cbca48>),
#         Node(tag='li', doc_order=1294, child_position=88, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbc408>),
#         Node(tag='li', doc_order=1306, child_position=89, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbc948>),
#         Node(tag='li', doc_order=1318, child_position=90, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233eddc88>),
#         Node(tag='li', doc_order=1330, child_position=91, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233edd288>),
#         Node(tag='li', doc_order=1342, child_position=92, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233edd588>),
#         Node(tag='li', doc_order=1354, child_position=93, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6233edd808>),
#         Node(tag='li', doc_order=1366, child_position=94, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234258d48>),
#         Node(tag='li', doc_order=1378, child_position=95, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6233f8a408>),
#         Node(tag='li', doc_order=1390, child_position=96, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f623405dc88>),
#         Node(tag='li', doc_order=1402, child_position=97, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f62340550c8>),
#         Node(tag='li', doc_order=1414, child_position=98, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6234004d08>),
#         Node(tag='li', doc_order=1426, child_position=99, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f62341991c8>),
#         Node(tag='li', doc_order=1438, child_position=100, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232c04748>),
#         Node(tag='li', doc_order=1450, child_position=101, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232c04a08>),
#         Node(tag='li', doc_order=1462, child_position=102, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232c52f08>),
#         Node(tag='li', doc_order=1474, child_position=103, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232c52348>),
#         Node(tag='li', doc_order=1486, child_position=104, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbfec8>),
#         Node(tag='li', doc_order=1498, child_position=105, attribs={'class': 'ajax_block_product item last-in-line'}, element=<Element li at 0x7f6232cbf408>),
#         Node(tag='li', doc_order=1510, child_position=106, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f623403a308>),
#         Node(tag='li', doc_order=1522, child_position=107, attribs={'class': 'ajax_block_product item '}, element=<Element li at 0x7f6232cbe988>)},
#        'children': [{'tag': 'a.product_img_link',
#          'element': {Node(tag='a', doc_order=249, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/734-darjeeling-ambotia-blanc-au-safran.html', 'class': 'product_img_link', 'title': 'Darjeeling Ambootia Blanc au Safran'}, element=<Element a at 0x7f623433eec8>),
#           Node(tag='a', doc_order=262, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/48-darjeeling-castleton.html', 'class': 'product_img_link', 'title': 'Darjeeling Castelton'}, element=<Element a at 0x7f62342eff88>),
#           Node(tag='a', doc_order=275, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/169-japon-genmaicha.html', 'class': 'product_img_link', 'title': 'Thé du Japon Genmaicha'}, element=<Element a at 0x7f6233e91c08>),
#           Node(tag='a', doc_order=288, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/655-the-du-vietnam-oolong.html', 'class': 'product_img_link', 'title': 'Thé du Vietnam Oolong'}, element=<Element a at 0x7f6232c5d948>),
#           Node(tag='a', doc_order=301, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/133-the-noir-grand-yunnan.html', 'class': 'product_img_link', 'title': 'Thé noir Grand Yunnan'}, element=<Element a at 0x7f6232c5d088>),
#           Node(tag='a', doc_order=314, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/564-lot-echantillons.html', 'class': 'product_img_link', 'title': ' Dégustation'}, element=<Element a at 0x7f6234035c08>),
#           Node(tag='a', doc_order=325, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/175-afternoon-dream.html', 'class': 'product_img_link', 'title': 'Afternoon Dream'}, element=<Element a at 0x7f6234035c88>),
#           Node(tag='a', doc_order=337, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/115-assam-bop.html', 'class': 'product_img_link', 'title': 'Assam BOP'}, element=<Element a at 0x7f6232ab7d48>),
#           Node(tag='a', doc_order=349, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/116-assam-greenwood.html', 'class': 'product_img_link', 'title': 'Assam Greenwood'}, element=<Element a at 0x7f6232ab71c8>),
#           Node(tag='a', doc_order=361, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/117-assam-keelung.html', 'class': 'product_img_link', 'title': 'Assam Keelung'}, element=<Element a at 0x7f6232ab76c8>),
#           Node(tag='a', doc_order=373, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/119-assam-mangalam.html', 'class': 'product_img_link', 'title': 'Assam Mangalam'}, element=<Element a at 0x7f6232ab7248>),
#           Node(tag='a', doc_order=385, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/356-assam-mokalbari-east.html', 'class': 'product_img_link', 'title': 'Assam Mokalbari East'}, element=<Element a at 0x7f6232ab7588>),
#           Node(tag='a', doc_order=397, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/824-assam-nonaipara.html', 'class': 'product_img_link', 'title': 'Assam Nonaipara'}, element=<Element a at 0x7f62342f4b88>),
#           Node(tag='a', doc_order=409, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/695-assam-oolong-doomni-imperial.html', 'class': 'product_img_link', 'title': 'Assam Oolong Doomni Imperial'}, element=<Element a at 0x7f62342f4888>),
#           Node(tag='a', doc_order=421, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/assam/118-assam-thowra.html', 'class': 'product_img_link', 'title': 'Assam Thowra'}, element=<Element a at 0x7f62342f4a88>),
#           Node(tag='a', doc_order=433, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/176-breakfast-royal.html', 'class': 'product_img_link', 'title': 'Breakfast Royal'}, element=<Element a at 0x7f6232a93788>),
#           Node(tag='a', doc_order=445, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/thes-faconnes/136-chine-brique-de-the.html', 'class': 'product_img_link', 'title': 'Brique de thé noir de Chine'}, element=<Element a at 0x7f6232a934c8>),
#           Node(tag='a', doc_order=456, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/177-brunch-tea.html', 'class': 'product_img_link', 'title': 'Brunch Tea'}, element=<Element a at 0x7f6232a93208>),
#           Node(tag='a', doc_order=468, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/89-ceylan-dellawa.html', 'class': 'product_img_link', 'title': 'Ceylan Dellawa'}, element=<Element a at 0x7f6232a93488>),
#           Node(tag='a', doc_order=480, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/87-ceylan-detheine.html', 'class': 'product_img_link', 'title': 'Ceylan déthéiné'}, element=<Element a at 0x7f6232a93b08>),
#           Node(tag='a', doc_order=492, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/88-ceylan-dyagama.html', 'class': 'product_img_link', 'title': 'Ceylan Dyagama'}, element=<Element a at 0x7f6234309fc8>),
#           Node(tag='a', doc_order=504, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/90-ceylan-kalleboka.html', 'class': 'product_img_link', 'title': 'Ceylan Kalleboka'}, element=<Element a at 0x7f6232e964c8>),
#           Node(tag='a', doc_order=516, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/91-ceylan-kenilworth.html', 'class': 'product_img_link', 'title': 'Ceylan Kenilworth'}, element=<Element a at 0x7f6232e96688>),
#           Node(tag='a', doc_order=528, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/94-ceylan-pettiagalla.html', 'class': 'product_img_link', 'title': 'Ceylan Pettiagalla'}, element=<Element a at 0x7f6232e96dc8>),
#           Node(tag='a', doc_order=540, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/95-ceylan-roehampton.html', 'class': 'product_img_link', 'title': 'Ceylan Roehampton'}, element=<Element a at 0x7f6232e96bc8>),
#           Node(tag='a', doc_order=552, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/96-ceylan-st-james-fannings.html', 'class': 'product_img_link', 'title': 'Ceylan St James Fannings'}, element=<Element a at 0x7f6234208708>),
#           Node(tag='a', doc_order=564, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/97-ceylan-st-james-fp.html', 'class': 'product_img_link', 'title': 'Ceylan St James FP'}, element=<Element a at 0x7f6234208e48>),
#           Node(tag='a', doc_order=576, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/99-ceylan-uva-highlands.html', 'class': 'product_img_link', 'title': 'Ceylan Uva Highlands'}, element=<Element a at 0x7f623422f6c8>),
#           Node(tag='a', doc_order=588, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/ceylan/796-ceylan-vert-cannelle.html', 'class': 'product_img_link', 'title': 'Ceylan Vert Cannelle'}, element=<Element a at 0x7f6232e95788>),
#           Node(tag='a', doc_order=600, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/178-china-blend.html', 'class': 'product_img_link', 'title': 'China Blend'}, element=<Element a at 0x7f6232e95ec8>),
#           Node(tag='a', doc_order=612, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/100-darjeeling-bloomfield.html', 'class': 'product_img_link', 'title': 'Darjeeling Bloomfield'}, element=<Element a at 0x7f6232e95e48>),
#           Node(tag='a', doc_order=624, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/101-darjeeling-gielle.html', 'class': 'product_img_link', 'title': 'Darjeeling Gielle'}, element=<Element a at 0x7f6232e95508>),
#           Node(tag='a', doc_order=636, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/102-darjeeling-jungpana.html', 'class': 'product_img_link', 'title': 'Darjeeling Jungpana'}, element=<Element a at 0x7f6232e95208>),
#           Node(tag='a', doc_order=648, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/103-darjeeling-makaibari.html', 'class': 'product_img_link', 'title': 'Darjeeling Makaibari'}, element=<Element a at 0x7f6232cc5ec8>),
#           Node(tag='a', doc_order=660, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/104-darjeeling-margarets-hope.html', 'class': 'product_img_link', 'title': "Darjeeling Margaret's Hope"}, element=<Element a at 0x7f6232cc5b08>),
#           Node(tag='a', doc_order=672, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/105-darjeeling-namring.html', 'class': 'product_img_link', 'title': 'Darjeeling Namring'}, element=<Element a at 0x7f6232cc5988>),
#           Node(tag='a', doc_order=684, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/106-darjeeling-risheehat.html', 'class': 'product_img_link', 'title': 'Darjeeling Risheehat'}, element=<Element a at 0x7f6232cc5e08>),
#           Node(tag='a', doc_order=696, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/107-darjeeling-seeyock.html', 'class': 'product_img_link', 'title': 'Darjeeling Seeyok'}, element=<Element a at 0x7f6234220588>),
#           Node(tag='a', doc_order=708, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/16-darjeeling-sikkim-temmi.html', 'class': 'product_img_link', 'title': 'Darjeeling Sikkim Temi'}, element=<Element a at 0x7f62341866c8>),
#           Node(tag='a', doc_order=720, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/109-darjeeling-singbulli.html', 'class': 'product_img_link', 'title': 'Darjeeling Singbulli'}, element=<Element a at 0x7f6234186bc8>),
#           Node(tag='a', doc_order=732, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/110-darjeeling-sington.html', 'class': 'product_img_link', 'title': 'Darjeeling Sington'}, element=<Element a at 0x7f623415c5c8>),
#           Node(tag='a', doc_order=744, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/111-darjeeling-testa-valley.html', 'class': 'product_img_link', 'title': 'Darjeeling Testa Valley'}, element=<Element a at 0x7f623416fc08>),
#           Node(tag='a', doc_order=756, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/darjeeling/112-darjeeling-tukvar.html', 'class': 'product_img_link', 'title': 'Darjeeling Tukvar'}, element=<Element a at 0x7f62340d4fc8>),
#           Node(tag='a', doc_order=768, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/179-daybreak.html', 'class': 'product_img_link', 'title': 'Daybreak'}, element=<Element a at 0x7f62340f3e88>),
#           Node(tag='a', doc_order=780, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/thes-faconnes/748-fleurs-the-galet.html', 'class': 'product_img_link', 'title': 'Fleurs de thé forme galet'}, element=<Element a at 0x7f62340f3ac8>),
#           Node(tag='a', doc_order=792, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/779-formose-dark-pearl.html', 'class': 'product_img_link', 'title': 'Formose Dark Pearl'}, element=<Element a at 0x7f6234250888>),
#           Node(tag='a', doc_order=804, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/162-formose-dragon-noir.html', 'class': 'product_img_link', 'title': 'Formose Dragon Noir'}, element=<Element a at 0x7f6233ee1648>),
#           Node(tag='a', doc_order=816, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/164-formose-grand-oolong.html', 'class': 'product_img_link', 'title': 'Formose Grand Oolong'}, element=<Element a at 0x7f6233ee1888>),
#           Node(tag='a', doc_order=828, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/778-formose-honey-orchid.html', 'class': 'product_img_link', 'title': 'Formose Honey Orchid'}, element=<Element a at 0x7f6233ee1908>),
#           Node(tag='a', doc_order=840, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/165-formose-lapsang-crocodile.html', 'class': 'product_img_link', 'title': 'Formose Lapsang Crocodile'}, element=<Element a at 0x7f6233ed64c8>),
#           Node(tag='a', doc_order=852, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/829-formose-peche.html', 'class': 'product_img_link', 'title': 'Formose Pêche'}, element=<Element a at 0x7f6233ed62c8>),
#           Node(tag='a', doc_order=864, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/166-formose-pouchong.html', 'class': 'product_img_link', 'title': 'Formose Pouchong'}, element=<Element a at 0x7f6233ed6808>),
#           Node(tag='a', doc_order=876, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/formose/167-formose-vert-jade.html', 'class': 'product_img_link', 'title': 'Formose Vert Jade'}, element=<Element a at 0x7f6233ed6448>),
#           Node(tag='a', doc_order=888, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/821-honeybush-nougat.html', 'class': 'product_img_link', 'title': 'Honeybush nougat'}, element=<Element a at 0x7f6234253f88>),
#           Node(tag='a', doc_order=900, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/21-mate-vert.html', 'class': 'product_img_link', 'title': 'Maté vert'}, element=<Element a at 0x7f6234253ac8>),
#           Node(tag='a', doc_order=912, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/180-morning-kick.html', 'class': 'product_img_link', 'title': 'Morning Kick'}, element=<Element a at 0x7f6234066e48>),
#           Node(tag='a', doc_order=924, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/thes-faconnes/24-natte-de-the.html', 'class': 'product_img_link', 'title': 'Natte de thé'}, element=<Element a at 0x7f62342c8c08>),
#           Node(tag='a', doc_order=935, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/654-nothing-hill.html', 'class': 'product_img_link', 'title': 'Notting Hill'}, element=<Element a at 0x7f62342c8b48>),
#           Node(tag='a', doc_order=947, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/65-rooibush.html', 'class': 'product_img_link', 'title': 'Rooibush'}, element=<Element a at 0x7f6234338fc8>),
#           Node(tag='a', doc_order=959, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-blancs/355-the-blanc-pai-mu-tan-printemps.html', 'class': 'product_img_link', 'title': 'Thé blanc Pai Mu Tan printemps'}, element=<Element a at 0x7f623430e148>),
#           Node(tag='a', doc_order=971, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-blancs/749-the-blanc-moonlight.html', 'class': 'product_img_link', 'title': "Thé blanc Pu'er Moonlight"}, element=<Element a at 0x7f623430e6c8>),
#           Node(tag='a', doc_order=983, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/141-the-blanc-white-monkey.html', 'class': 'product_img_link', 'title': 'Thé blanc White Monkey'}, element=<Element a at 0x7f623430edc8>),
#           Node(tag='a', doc_order=995, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-blancs/286-the-blanc-white-pearl.html', 'class': 'product_img_link', 'title': 'Thé blanc White Pearl'}, element=<Element a at 0x7f623402b0c8>),
#           Node(tag='a', doc_order=1007, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-blancs/266-the-blanc-yin-zhen.html', 'class': 'product_img_link', 'title': 'Thé blanc Yin Zhen'}, element=<Element a at 0x7f6234315d88>),
#           Node(tag='a', doc_order=1019, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/780-the-de-coree-oolong-dragon.html', 'class': 'product_img_link', 'title': 'Thé de Corée Oolong Dragon'}, element=<Element a at 0x7f6234315988>),
#           Node(tag='a', doc_order=1031, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/751-the-woojeon-bio.html', 'class': 'product_img_link', 'title': 'Thé de Corée Woojeon '}, element=<Element a at 0x7f6233ea0c08>),
#           Node(tag='a', doc_order=1043, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/693-the-de-nouvelle-zelande-oolong-pearl.html', 'class': 'product_img_link', 'title': 'Thé de Nouvelle Zélande Oolong Pearl'}, element=<Element a at 0x7f62343452c8>),
#           Node(tag='a', doc_order=1055, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/586-the-de-thailande-oolong-jing-shuan.html', 'class': 'product_img_link', 'title': 'Thé de Thaïlande Oolong Jing Shuan'}, element=<Element a at 0x7f62342dc488>),
#           Node(tag='a', doc_order=1067, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/170-the-du-japon-gyokuro.html', 'class': 'product_img_link', 'title': 'Thé du Japon Gyokuro'}, element=<Element a at 0x7f62342dc948>),
#           Node(tag='a', doc_order=1079, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/168-the-du-japon-hojicha.html', 'class': 'product_img_link', 'title': 'Thé du Japon Hojicha'}, element=<Element a at 0x7f6232cc4308>),
#           Node(tag='a', doc_order=1091, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/424-the-du-japon-karigane.html', 'class': 'product_img_link', 'title': 'Thé du Japon Karigane'}, element=<Element a at 0x7f6234304508>),
#           Node(tag='a', doc_order=1103, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/258-the-du-japon-matcha.html', 'class': 'product_img_link', 'title': 'Thé du Japon Matcha'}, element=<Element a at 0x7f6234304ac8>),
#           Node(tag='a', doc_order=1115, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/172-the-du-japon-sencha-natural-leaf.html', 'class': 'product_img_link', 'title': 'Thé du Japon Sencha Natural Leaf'}, element=<Element a at 0x7f62353a2b48>),
#           Node(tag='a', doc_order=1127, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/japon/20-japon-tamaryokucha.html', 'class': 'product_img_link', 'title': 'Thé du Japon Tamaryokucha'}, element=<Element a at 0x7f6234332e88>),
#           Node(tag='a', doc_order=1139, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/173-kenya-milima.html', 'class': 'product_img_link', 'title': 'Thé du Kenya Milima'}, element=<Element a at 0x7f6234332b08>),
#           Node(tag='a', doc_order=1151, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/174-nepal-antu-valley.html', 'class': 'product_img_link', 'title': 'Thé du Népal Antu Valley'}, element=<Element a at 0x7f6234084dc8>),
#           Node(tag='a', doc_order=1163, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/autres-origines/774-nepal-shangri-la.html', 'class': 'product_img_link', 'title': 'Thé du Népal Shangri La'}, element=<Element a at 0x7f623400b708>),
#           Node(tag='a', doc_order=1175, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/120-the-noir-caravane.html', 'class': 'product_img_link', 'title': 'Thé noir Caravane'}, element=<Element a at 0x7f6233fc7088>),
#           Node(tag='a', doc_order=1187, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/121-the-noir-ching-woo.html', 'class': 'product_img_link', 'title': 'Thé noir Ching Woo'}, element=<Element a at 0x7f6233fc7d08>),
#           Node(tag='a', doc_order=1199, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/125-the-noir-grand-keemun.html', 'class': 'product_img_link', 'title': 'Thé noir Grand Keemun'}, element=<Element a at 0x7f6233eed2c8>),
#           Node(tag='a', doc_order=1211, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/129-the-noir-grand-szechwan.html', 'class': 'product_img_link', 'title': 'Thé noir Grand Szechwan'}, element=<Element a at 0x7f6233eed7c8>),
#           Node(tag='a', doc_order=1223, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/122-the-noir-imperial-or.html', 'class': 'product_img_link', 'title': 'Thé noir Impérial Or'}, element=<Element a at 0x7f6233eed9c8>),
#           Node(tag='a', doc_order=1235, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/373-the-noir-jin-meo.html', 'class': 'product_img_link', 'title': 'Thé noir Jin Meo'}, element=<Element a at 0x7f6234058f88>),
#           Node(tag='a', doc_order=1247, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/123-the-noir-keemun.html', 'class': 'product_img_link', 'title': 'Thé noir Keemun'}, element=<Element a at 0x7f6234000988>),
#           Node(tag='a', doc_order=1259, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/124-the-noir-keemun-congou.html', 'class': 'product_img_link', 'title': 'Thé noir Keemun Congou'}, element=<Element a at 0x7f6232cbc5c8>),
#           Node(tag='a', doc_order=1271, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/126-the-noir-lapsang-souchong.html', 'class': 'product_img_link', 'title': 'Thé noir Lapsang Souchong'}, element=<Element a at 0x7f6232cbc908>),
#           Node(tag='a', doc_order=1283, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/127-the-noir-panyong-golden.html', 'class': 'product_img_link', 'title': 'Thé noir Panyong Golden'}, element=<Element a at 0x7f6232cbc288>),
#           Node(tag='a', doc_order=1295, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/128-the-noir-pointes-blanches.html', 'class': 'product_img_link', 'title': 'Thé noir Pointes Blanches'}, element=<Element a at 0x7f6232cbc848>),
#           Node(tag='a', doc_order=1307, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/135-the-noir-pu-er.html', 'class': 'product_img_link', 'title': 'Thé noir Pu-Er'}, element=<Element a at 0x7f6232cbce48>),
#           Node(tag='a', doc_order=1319, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/756-the-noir-pu-er-golden.html', 'class': 'product_img_link', 'title': 'Thé noir Pu-Er Golden'}, element=<Element a at 0x7f6233eddd88>),
#           Node(tag='a', doc_order=1331, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/130-the-noir-tarry-souchong.html', 'class': 'product_img_link', 'title': 'Thé noir Tarry Souchong'}, element=<Element a at 0x7f6233edd1c8>),
#           Node(tag='a', doc_order=1343, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/568-the-noir-wulong-milky.html', 'class': 'product_img_link', 'title': 'Thé noir Wulong Milky'}, element=<Element a at 0x7f6233edd388>),
#           Node(tag='a', doc_order=1355, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/132-the-noir-yunnan.html', 'class': 'product_img_link', 'title': 'Thé noir Yunnan'}, element=<Element a at 0x7f6233fd7f88>),
#           Node(tag='a', doc_order=1367, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/134-the-noir-yunnan-celeste.html', 'class': 'product_img_link', 'title': 'Thé noir Yunnan Céleste'}, element=<Element a at 0x7f6234258188>),
#           Node(tag='a', doc_order=1379, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-noirs/131-the-noir-yunnan-dian-hong.html', 'class': 'product_img_link', 'title': 'Thé noir Yunnan Dian Hong'}, element=<Element a at 0x7f6233f8a8c8>),
#           Node(tag='a', doc_order=1391, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/398-the-vert-gu-zhang-mao-jian.html', 'class': 'product_img_link', 'title': 'Thé vert Gu Zhang Mao Jian'}, element=<Element a at 0x7f623405dd08>),
#           Node(tag='a', doc_order=1403, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/144-the-vert-gunpowder.html', 'class': 'product_img_link', 'title': 'Thé vert Gunpowder'}, element=<Element a at 0x7f6234055508>),
#           Node(tag='a', doc_order=1415, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/19-the-vert-lan-xi.html', 'class': 'product_img_link', 'title': 'Thé vert Lan Xi'}, element=<Element a at 0x7f6234004688>),
#           Node(tag='a', doc_order=1427, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/148-chine-vert-lu-wu.html', 'class': 'product_img_link', 'title': 'Thé vert Lu Wu'}, element=<Element a at 0x7f62341992c8>),
#           Node(tag='a', doc_order=1439, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/149-the-vert-lung-ching.html', 'class': 'product_img_link', 'title': 'Thé vert Lung Ching'}, element=<Element a at 0x7f6232c04f88>),
#           Node(tag='a', doc_order=1451, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/599-the-vert-magnolia.html', 'class': 'product_img_link', 'title': 'Thé vert Magnolia'}, element=<Element a at 0x7f6232c04f08>),
#           Node(tag='a', doc_order=1463, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/156-the-vert-mao-feng.html', 'class': 'product_img_link', 'title': 'Thé vert Mao Feng'}, element=<Element a at 0x7f6232c52f88>),
#           Node(tag='a', doc_order=1475, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/585-the-vert-pi-lo-chun.html', 'class': 'product_img_link', 'title': 'Thé vert Pi Lo Chun'}, element=<Element a at 0x7f6232c523c8>),
#           Node(tag='a', doc_order=1487, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/746-the-vert-taiping-houkui.html', 'class': 'product_img_link', 'title': 'Thé vert Taiping Houkui'}, element=<Element a at 0x7f6232cbff08>),
#           Node(tag='a', doc_order=1499, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/chine-verts/159-the-vert-yunnan.html', 'class': 'product_img_link', 'title': 'Thé vert Yunnan'}, element=<Element a at 0x7f6232cbf688>),
#           Node(tag='a', doc_order=1511, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/181-winter-blend.html', 'class': 'product_img_link', 'title': 'Winter Blend'}, element=<Element a at 0x7f623403aec8>),
#           Node(tag='a', doc_order=1523, child_position=1, attribs={'href': 'https://betjemanandbarton.com/fr/blends/182-yunnan-darjeeling.html', 'class': 'product_img_link', 'title': 'Yunnan-Darjeeling'}, element=<Element a at 0x7f6232cbef08>)},
#          'children': [{'tag': 'img',
#            'element': {Node(tag='img', doc_order=250, child_position=1, attribs={'src': 'https://betjemanandbarton.com/734-1110-large/darjeeling-ambotia-blanc-au-safran.jpg', 'alt': 'Darjeeling Ambootia Blanc au Safran', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f6233d235c8>),
#             Node(tag='img', doc_order=263, child_position=1, attribs={'src': 'https://betjemanandbarton.com/48-1109-large/darjeeling-castleton.jpg', 'alt': 'Darjeeling Castleton', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f62342efc48>),
#             Node(tag='img', doc_order=276, child_position=1, attribs={'src': 'https://betjemanandbarton.com/169-1151-large/japon-genmaicha.jpg', 'alt': 'Thé Japon Genmaicha', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f6233e91b08>),
#             Node(tag='img', doc_order=289, child_position=1, attribs={'src': 'https://betjemanandbarton.com/655-1084-large/the-du-vietnam-oolong.jpg', 'alt': 'Thé du Vietnam Oolong', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f6232c5da08>),
#             Node(tag='img', doc_order=302, child_position=1, attribs={'src': 'https://betjemanandbarton.com/133-1122-large/the-noir-grand-yunnan.jpg', 'alt': 'Chine Grand Yunnan', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f6232c5d0c8>),
#             Node(tag='img', doc_order=315, child_position=1, attribs={'src': 'https://betjemanandbarton.com/564-826-large/lot-echantillons.jpg', 'alt': ' Dégustation', 'width': '215px', 'height': '215px'}, element=<Element img at 0x7f6234035088>),
# ...
#             Node(tag='p', doc_order=522, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e96a48>),
#             Node(tag='p', doc_order=534, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e969c8>),
#             Node(tag='p', doc_order=546, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e96988>),
#             Node(tag='p', doc_order=558, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234208288>),
#             Node(tag='p', doc_order=570, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623422f088>),
#             Node(tag='p', doc_order=582, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623422fa48>),
#             Node(tag='p', doc_order=594, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e95248>),
#             Node(tag='p', doc_order=606, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e95448>),
#             Node(tag='p', doc_order=618, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e95a88>),
#             Node(tag='p', doc_order=630, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e954c8>),
#             Node(tag='p', doc_order=642, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232e95c88>),
#             Node(tag='p', doc_order=654, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cc5c48>),
#             Node(tag='p', doc_order=666, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cc5408>),
#             Node(tag='p', doc_order=678, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cc5c08>),
#             Node(tag='p', doc_order=690, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234220ac8>),
#             Node(tag='p', doc_order=702, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234220c08>),
#             Node(tag='p', doc_order=714, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234186f88>),
#             Node(tag='p', doc_order=726, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623415cf88>),
#             Node(tag='p', doc_order=738, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623415c508>),
#             Node(tag='p', doc_order=750, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623416f0c8>),
#             Node(tag='p', doc_order=762, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62340f3b88>),
#             Node(tag='p', doc_order=774, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62340f3e48>),
#             Node(tag='p', doc_order=786, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234250448>),
#             Node(tag='p', doc_order=798, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234250d88>),
#             Node(tag='p', doc_order=810, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ee1c48>),
#             Node(tag='p', doc_order=822, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ee19c8>),
#             Node(tag='p', doc_order=834, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ee1e48>),
#             Node(tag='p', doc_order=846, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ed6f48>),
#             Node(tag='p', doc_order=858, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ed6cc8>),
#             Node(tag='p', doc_order=870, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ed6048>),
#             Node(tag='p', doc_order=882, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234253748>),
#             Node(tag='p', doc_order=894, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234253788>),
#             Node(tag='p', doc_order=906, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234066f48>),
#             Node(tag='p', doc_order=918, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232b9ab48>),
#             Node(tag='p', doc_order=930, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62342c80c8>),
#             Node(tag='p', doc_order=941, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232c19488>),
#             Node(tag='p', doc_order=953, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234338708>),
#             Node(tag='p', doc_order=965, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623430e608>),
#             Node(tag='p', doc_order=977, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623430e388>),
#             Node(tag='p', doc_order=989, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623430e988>),
#             Node(tag='p', doc_order=1001, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234315908>),
#             Node(tag='p', doc_order=1013, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234315708>),
#             Node(tag='p', doc_order=1025, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ea0ac8>),
#             Node(tag='p', doc_order=1037, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233ea0588>),
#             Node(tag='p', doc_order=1049, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234345d88>),
#             Node(tag='p', doc_order=1061, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62342dc848>),
#             Node(tag='p', doc_order=1073, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234061808>),
#             Node(tag='p', doc_order=1085, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234304d88>),
#             Node(tag='p', doc_order=1097, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234304988>),
#             Node(tag='p', doc_order=1109, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62343044c8>),
#             Node(tag='p', doc_order=1121, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233fec088>),
#             Node(tag='p', doc_order=1133, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234332fc8>),
#             Node(tag='p', doc_order=1145, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62340845c8>),
#             Node(tag='p', doc_order=1157, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6238ecc2c8>),
#             Node(tag='p', doc_order=1169, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233fc2c08>),
#             Node(tag='p', doc_order=1181, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233fc78c8>),
#             Node(tag='p', doc_order=1193, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f62340bfdc8>),
#             Node(tag='p', doc_order=1205, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233eed8c8>),
#             Node(tag='p', doc_order=1217, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233eedd48>),
#             Node(tag='p', doc_order=1229, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233eedd88>),
#             Node(tag='p', doc_order=1241, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234043688>),
#             Node(tag='p', doc_order=1253, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbccc8>),
#             Node(tag='p', doc_order=1265, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbcac8>),
#             Node(tag='p', doc_order=1277, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbcb88>),
#             Node(tag='p', doc_order=1289, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbc0c8>),
#             Node(tag='p', doc_order=1301, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbce08>),
#             Node(tag='p', doc_order=1313, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6238a2f188>),
#             Node(tag='p', doc_order=1325, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233edde88>),
#             Node(tag='p', doc_order=1337, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233eddf48>),
#             Node(tag='p', doc_order=1349, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233edd648>),
#             Node(tag='p', doc_order=1361, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234258c88>),
#             Node(tag='p', doc_order=1373, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233f8a948>),
#             Node(tag='p', doc_order=1385, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6233f8a208>),
#             Node(tag='p', doc_order=1397, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623405d548>),
#             Node(tag='p', doc_order=1409, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234004848>),
#             Node(tag='p', doc_order=1421, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234199108>),
#             Node(tag='p', doc_order=1433, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6234199948>),
#             Node(tag='p', doc_order=1445, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232c046c8>),
#             Node(tag='p', doc_order=1457, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232c52888>),
#             Node(tag='p', doc_order=1469, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232c52508>),
#             Node(tag='p', doc_order=1481, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbff48>),
#             Node(tag='p', doc_order=1493, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbf9c8>),
#             Node(tag='p', doc_order=1505, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f623403a288>),
#             Node(tag='p', doc_order=1517, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbeb48>),
#             Node(tag='p', doc_order=1529, child_position=1, attribs={'class': 'product-description'}, element=<Element p at 0x7f6232cbec08>)},
#            'children': [],
#            'word_finished': True}],
#          'word_finished': True}],
#        'word_finished': False}],
#      'word_finished': False}],
#    'word_finished': False},
#   {'tag': 'head',
#    'element': {Node(tag='head', doc_order=3, child_position=1, attribs={}, element=<Element head at 0x7f623402f688>)},
#    'children': [{'tag': 'link',
#      'element': {Node(tag='link', doc_order=9, child_position=1, attribs={'rel': 'icon', 'type': 'image/vnd.microsoft.icon', 'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831'}, element=<Element link at 0x7f623402f488>),
#       Node(tag='link', doc_order=10, child_position=2, attribs={'rel': 'shortcut icon', 'type': 'image/x-icon', 'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831'}, element=<Element link at 0x7f623402f248>),
#       Node(tag='link', doc_order=12, child_position=3, attribs={'href': 'https://betjemanandbarton.com/themes/betjemanandbarton/cache/f42c4adfa76388ceb6e7468f084dbe62_all.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'}, element=<Element link at 0x7f623402fe88>),
#       Node(tag='link', doc_order=13, child_position=4, attribs={'href': '/themes/betjemanandbarton/css/theme.css', 'rel': 'stylesheet', 'type': 'text/css'}, element=<Element link at 0x7f623402f3c8>),
#       Node(tag='link', doc_order=14, child_position=5, attribs={'href': '/themes/betjemanandbarton/css/temp.css', 'rel': 'stylesheet', 'type': 'text/css'}, element=<Element link at 0x7f623402fac8>),
#       Node(tag='link', doc_order=15, child_position=6, attribs={'href': '/themes/betjemanandbarton/css/jqtransform.css', 'rel': 'stylesheet', 'type': 'text/css'}, element=<Element link at 0x7f623402f588>),
#       Node(tag='link', doc_order=16, child_position=7, attribs={'href': 'https://fonts.googleapis.com/css?family=EB+Garamond', 'rel': 'stylesheet', 'type': 'text/css'}, element=<Element link at 0x7f623402f888>),
#       Node(tag='link', doc_order=20, child_position=8, attribs={'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/jquery.rating.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'}, element=<Element link at 0x7f623402f048>),
#       Node(tag='link', doc_order=21, child_position=9, attribs={'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/advancedfeedback.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'}, element=<Element link at 0x7f6233f4b588>),
#       Node(tag='link', doc_order=22, child_position=10, attribs={'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/pm_advancedfeedback_global.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'}, element=<Element link at 0x7f6233f4b508>),
#       Node(tag='link', doc_order=23, child_position=11, attribs={'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/pm_advancedfeedback_advanced.css', 'rel': 'stylesheet', 'type': 'text/css', 'media': 'all'}, element=<Element link at 0x7f6233f4b988>)},
#      'children': [],
#      'word_finished': True},
#     {'tag': 'meta',
#      'element': {Node(tag='meta', doc_order=5, child_position=1, attribs={'name': 'description', 'content': "Les thés classiques par Betjeman & Barton: une sélection des meilleurs thés de Chine, du Japon et du Monde. Livraison gratuite en France dès 45€ d'achat"}, element=<Element meta at 0x7f623402f848>),
#       Node(tag='meta', doc_order=6, child_position=2, attribs={'http-equiv': 'Content-Type', 'content': 'application/xhtml+xml; charset=utf-8'}, element=<Element meta at 0x7f623402ff08>),
#       Node(tag='meta', doc_order=7, child_position=3, attribs={'name': 'generator', 'content': 'PrestaShop'}, element=<Element meta at 0x7f623402f708>),
#       Node(tag='meta', doc_order=8, child_position=4, attribs={'name': 'robots', 'content': 'index,follow'}, element=<Element meta at 0x7f623402f608>)},
#      'children': [],
#      'word_finished': True}],
#    'word_finished': False}],
#  'word_finished': False}

# %% [markdown]
# ## Re-creating data hierarchy
#
# Below is the most interesting bit: how to re-create a dict/JSON document from repeating tagpaths.
#
# Using the trie, from the root of the tree, we loop over all HTML elements of a trie node, and recursively collect data from its children:

# %%
from collections import defaultdict
from operator import itemgetter
from lxml.html import tostring


def hydrate(node, docorder_min, docorder_max=None, include_html=False):
    elements = sorted(set(node.elements), key=lambda n: n.doc_order)
    output = []

    for i, element in enumerate(elements, start=1):
        
        # filter out elements that are not within the parent document order range
        if not (docorder_min < element.doc_order):
            continue
        if (docorder_max is not None) and (element.doc_order > docorder_max):
            continue
        
        # here's where you extract data from the element
        # 1. node representation including tag and classes can tell us a bit about what it's about
        # 2. document order is purely informational
        # 3. child text nodes usually contain much of the information we want
        # 4. element attributes also can be useful (URL, data-* etc.)
        e = {'tag': _node_repr(element),
             '_doc_order': element.doc_order}
        
        # textual information
        _t = list(filter(bool, [t.strip() for t in element.element.xpath('./text()[normalize-space()]')]))
        if _t:
            e['text'] = _t[0] if len(_t) == 1 else _t
        _html = tostring(element.element, encoding='unicode')
        if _html:
            #e['html'] = _html
            pass
            
        _attrib = dict(element.element.attrib)
        if 'class' in _attrib:
            _attrib.pop('class')
        if _attrib:
            e['_attr'] = _attrib
        
        # loop through sub-nodes that are between the current node and the next one
        # Warning: recursivity!
        _order_min = element.doc_order
        if i < len(elements):
            _order_max = elements[i].doc_order
        else:
            _order_max = None
        children = list(filter(bool, [c for child in node.children
                                      for c in hydrate(child, _order_min, _order_max)]))
        if children:
            e['children'] = sorted(children, key=itemgetter('_doc_order'))
            #e['children'] = children
        
        # if there's not "valuable" information, might as well skip the element
        if 'children' not in e and not(any(e.get(k) for k in ['text', '_attr'])):
            continue

        output.append(e)
        
    #return sorted(output, key=itemgetter('_doc_order'))
    return output

output = hydrate(root, 0)
pp(output)
# Out:
# [{'_attr': {'xml:lang': 'fr', 'xmlns': 'http://www.w3.org/1999/xhtml'},
#   '_doc_order': 2,
#   'children': [{'_doc_order': 3,
#                 'children': [{'_attr': {'content': 'Les thés classiques par '
#                                                    'Betjeman & Barton: une '
#                                                    'sélection des meilleurs '
#                                                    'thés de Chine, du Japon et '
#                                                    'du Monde. Livraison '
#                                                    'gratuite en France dès 45€ '
#                                                    "d'achat",
#                                         'name': 'description'},
#                               '_doc_order': 5,
#                               'tag': 'meta'},
#                              {'_attr': {'content': 'application/xhtml+xml; '
#                                                    'charset=utf-8',
#                                         'http-equiv': 'Content-Type'},
#                               '_doc_order': 6,
#                               'tag': 'meta'},
#                              {'_attr': {'content': 'PrestaShop',
#                                         'name': 'generator'},
#                               '_doc_order': 7,
#                               'tag': 'meta'},
#                              {'_attr': {'content': 'index,follow',
#                                         'name': 'robots'},
#                               '_doc_order': 8,
#                               'tag': 'meta'},
#                              {'_attr': {'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831',
#                                         'rel': 'icon',
#                                         'type': 'image/vnd.microsoft.icon'},
#                               '_doc_order': 9,
#                               'tag': 'link'},
#                              {'_attr': {'href': 'https://betjemanandbarton.com/img/favicon.ico?1533824831',
#                                         'rel': 'shortcut icon',
#                                         'type': 'image/x-icon'},
#                               '_doc_order': 10,
#                               'tag': 'link'},
#                              {'_attr': {'href': 'https://betjemanandbarton.com/themes/betjemanandbarton/cache/f42c4adfa76388ceb6e7468f084dbe62_all.css',
#                                         'media': 'all',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 12,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/css/theme.css',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 13,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/css/temp.css',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 14,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/css/jqtransform.css',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 15,
#                               'tag': 'link'},
#                              {'_attr': {'href': 'https://fonts.googleapis.com/css?family=EB+Garamond',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 16,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/jquery.rating.css',
#                                         'media': 'all',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 20,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/advancedfeedback.css',
#                                         'media': 'all',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 21,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/pm_advancedfeedback_global.css',
#                                         'media': 'all',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 22,
#                               'tag': 'link'},
#                              {'_attr': {'href': '/themes/betjemanandbarton/modules/pm_advancedfeedback/css/pm_advancedfeedback_advanced.css',
#                                         'media': 'all',
#                                         'rel': 'stylesheet',
#                                         'type': 'text/css'},
#                               '_doc_order': 23,
#                               'tag': 'link'}],
#                 'tag': 'head'},
#                {'_attr': {'id': 'page'},
#                 '_doc_order': 36,
#                 'children': [{'_attr': {'name': 'orderby',
#                                         'type': 'hidden',
#                                         'value': 'position'},
#                               '_doc_order': 74,
#                               'tag': 'input'},
#                              {'_attr': {'name': 'orderway',
#                                         'type': 'hidden',
#                                         'value': 'desc'},
#                               '_doc_order': 75,
#                               'tag': 'input'},
#                              {'_doc_order': 233,
#                               'children': [{'_doc_order': 234,
#                                             'children': [{'_attr': {'selected': 'selected',
#                                                                     'value': 'name:asc'},
#                                                           '_doc_order': 241,
#                                                           'tag': 'option',
#                                                           'text': '--'},
#                                                          {'_attr': {'value': 'price:asc'},
#                                                           '_doc_order': 242,
#                                                           'tag': 'option',
#                                                           'text': 'Le moins '
#                                                                   'cher'},
#                                                          {'_attr': {'value': 'price:desc'},
#                                                           '_doc_order': 243,
#                                                           'tag': 'option',
#                                                           'text': 'Le plus '
#                                                                   'cher'},
#                                                          {'_attr': {'selected': 'selected',
#                                                                     'value': 'name:asc'},
#                                                           '_doc_order': 244,
#                                                           'tag': 'option',
#                                                           'text': 'De A à Z'},
#                                                          {'_attr': {'value': 'name:desc'},
#                                                           '_doc_order': 245,
#                                                           'tag': 'option',
#                                                           'text': 'De Z à A'}],
#                                             'tag': 'div.filters'},
#                                            {'_doc_order': 248,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/darjeeling/734-darjeeling-ambotia-blanc-au-safran.html',
#                                                                     'title': 'Darjeeling '
#                                                                              'Ambootia '
#                                                                              'Blanc '
#                                                                              'au '
#                                                                              'Safran'},
#                                                           '_doc_order': 249,
#                                                           'children': [{'_attr': {'alt': 'Darjeeling '
#                                                                                          'Ambootia '
#                                                                                          'Blanc '
#                                                                                          'au '
#                                                                                          'Safran',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/734-1110-large/darjeeling-ambotia-blanc-au-safran.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 250,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 251,
#                                                           'children': [{'_doc_order': 252,
#                                                                         'tag': 'p.best',
#                                                                         'text': 'SÉLECTION '
#                                                                                 'DU '
#                                                                                 'MOIS'},
#                                                                        {'_doc_order': 253,
#                                                                         'children': [{'_doc_order': 254,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/darjeeling/734-darjeeling-ambotia-blanc-au-safran.html',
#                                                                                                               'title': 'Darjeeling '
#                                                                                                                        'Ambootia '
#                                                                                                                        'Blanc '
#                                                                                                                        'au '
#                                                                                                                        'Safran'},
#                                                                                                     '_doc_order': 255,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Darjeeling '
#                                                                                                             'Ambootia '
#                                                                                                             'Blanc '
#                                                                                                             'au '
#                                                                                                             'Safran'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 256,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Darjeeling '
#                                                                                 'dédié '
#                                                                                 'à '
#                                                                                 'la '
#                                                                                 'maison '
#                                                                                 'Betjeman '
#                                                                                 'and '
#                                                                                 'Barton '
#                                                                                 '-...'},
#                                                                        {'_doc_order': 257,
#                                                                         'children': [{'_doc_order': 258,
#                                                                                       'children': [{'_doc_order': 259,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '42,50 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=734&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_734',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 260,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 261,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/darjeeling/48-darjeeling-castleton.html',
#                                                                     'title': 'Darjeeling '
#                                                                              'Castelton'},
#                                                           '_doc_order': 262,
#                                                           'children': [{'_attr': {'alt': 'Darjeeling '
#                                                                                          'Castleton',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/48-1109-large/darjeeling-castleton.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 263,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 264,
#                                                           'children': [{'_doc_order': 265,
#                                                                         'tag': 'p.best',
#                                                                         'text': 'SÉLECTION '
#                                                                                 'DU '
#                                                                                 'MOIS'},
#                                                                        {'_doc_order': 266,
#                                                                         'children': [{'_doc_order': 267,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/darjeeling/48-darjeeling-castleton.html',
#                                                                                                               'title': 'Darjeeling '
#                                                                                                                        'Castelton'},
#                                                                                                     '_doc_order': 268,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Darjeeling '
#                                                                                                             'Castelton'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 269,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Darjeeling '
#                                                                                 'doux '
#                                                                                 'et '
#                                                                                 'fleuri '
#                                                                                 '- \n'
#                                                                                 '  '
#                                                                                 'Ce '
#                                                                                 'thé '
#                                                                                 'Darjeeling, '
#                                                                                 'au...'},
#                                                                        {'_doc_order': 270,
#                                                                         'children': [{'_doc_order': 271,
#                                                                                       'children': [{'_doc_order': 272,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '12,86 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=48&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_48',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 273,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 274,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/japon/169-japon-genmaicha.html',
#                                                                     'title': 'Thé '
#                                                                              'du '
#                                                                              'Japon '
#                                                                              'Genmaicha'},
#                                                           '_doc_order': 275,
#                                                           'children': [{'_attr': {'alt': 'Thé '
#                                                                                          'Japon '
#                                                                                          'Genmaicha',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/169-1151-large/japon-genmaicha.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 276,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 277,
#                                                           'children': [{'_doc_order': 278,
#                                                                         'tag': 'p.best',
#                                                                         'text': 'SÉLECTION '
#                                                                                 'DU '
#                                                                                 'MOIS'},
#                                                                        {'_doc_order': 279,
#                                                                         'children': [{'_doc_order': 280,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/japon/169-japon-genmaicha.html',
#                                                                                                               'title': 'Thé '
#                                                                                                                        'du '
#                                                                                                                        'Japon '
#                                                                                                                        'Genmaicha'},
#                                                                                                     '_doc_order': 281,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Thé '
#                                                                                                             'du '
#                                                                                                             'Japon '
#                                                                                                             'Genmaicha'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 282,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Thé '
#                                                                                 'vert '
#                                                                                 'légèrement '
#                                                                                 'salé\ufeff\ufeff '
#                                                                                 '- \n'
#                                                                                 '  '
#                                                                                 'Ce '
#                                                                                 'thé '
#                                                                                 'du '
#                                                                                 'Japon '
#                                                                                 'est...'},
#                                                                        {'_doc_order': 283,
#                                                                         'children': [{'_doc_order': 284,
#                                                                                       'children': [{'_doc_order': 285,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '9,22 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=169&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_169',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 286,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 287,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/autres-origines/655-the-du-vietnam-oolong.html',
#                                                                     'title': 'Thé '
#                                                                              'du '
#                                                                              'Vietnam '
#                                                                              'Oolong'},
#                                                           '_doc_order': 288,
#                                                           'children': [{'_attr': {'alt': 'Thé '
#                                                                                          'du '
#                                                                                          'Vietnam '
#                                                                                          'Oolong',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/655-1084-large/the-du-vietnam-oolong.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 289,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 290,
#                                                           'children': [{'_doc_order': 291,
#                                                                         'tag': 'p.best',
#                                                                         'text': 'SÉLECTION '
#                                                                                 'DU '
#                                                                                 'MOIS'},
#                                                                        {'_doc_order': 292,
#                                                                         'children': [{'_doc_order': 293,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/autres-origines/655-the-du-vietnam-oolong.html',
#                                                                                                               'title': 'Thé '
#                                                                                                                        'du '
#                                                                                                                        'Vietnam '
#                                                                                                                        'Oolong'},
#                                                                                                     '_doc_order': 294,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Thé '
#                                                                                                             'du '
#                                                                                                             'Vietnam '
#                                                                                                             'Oolong'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 295,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Thé '
#                                                                                 'bleu-vert '
#                                                                                 'du '
#                                                                                 'Vietnam '
#                                                                                 'très '
#                                                                                 'rafraîchissant\ufeff\ufeff\ufeff '
#                                                                                 '-...'},
#                                                                        {'_doc_order': 296,
#                                                                         'children': [{'_doc_order': 297,
#                                                                                       'children': [{'_doc_order': 298,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '15,68 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=655&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_655',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 299,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 300,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/chine-noirs/133-the-noir-grand-yunnan.html',
#                                                                     'title': 'Thé '
#                                                                              'noir '
#                                                                              'Grand '
#                                                                              'Yunnan'},
#                                                           '_doc_order': 301,
#                                                           'children': [{'_attr': {'alt': 'Chine '
#                                                                                          'Grand '
#                                                                                          'Yunnan',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/133-1122-large/the-noir-grand-yunnan.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 302,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 303,
#                                                           'children': [{'_doc_order': 304,
#                                                                         'tag': 'p.best',
#                                                                         'text': 'SÉLECTION '
#                                                                                 'DU '
#                                                                                 'MOIS'},
#                                                                        {'_doc_order': 305,
#                                                                         'children': [{'_doc_order': 306,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/chine-noirs/133-the-noir-grand-yunnan.html',
#                                                                                                               'title': 'Thé '
#                                                                                                                        'noir '
#                                                                                                                        'Grand '
#                                                                                                                        'Yunnan'},
#                                                                                                     '_doc_order': 307,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Thé '
#                                                                                                             'noir '
#                                                                                                             'Grand '
#                                                                                                             'Yunnan'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 308,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Thé '
#                                                                                 'noir '
#                                                                                 'à '
#                                                                                 'la '
#                                                                                 'saveur '
#                                                                                 'corsée\ufeff '
#                                                                                 '- \n'
#                                                                                 '  '
#                                                                                 'Ce '
#                                                                                 'thé '
#                                                                                 'noir '
#                                                                                 'du...'},
#                                                                        {'_doc_order': 309,
#                                                                         'children': [{'_doc_order': 310,
#                                                                                       'children': [{'_doc_order': 311,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '10,08 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=133&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_133',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 312,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 313,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/564-lot-echantillons.html',
#                                                                     'title': ' '
#                                                                              'Dégustation'},
#                                                           '_doc_order': 314,
#                                                           'children': [{'_attr': {'alt': ' '
#                                                                                          'Dégustation',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/564-826-large/lot-echantillons.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 315,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 316,
#                                                           'children': [{'_doc_order': 317,
#                                                                         'children': [{'_doc_order': 318,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/les-thes-classiques/564-lot-echantillons.html',
#                                                                                                               'title': ' '
#                                                                                                                        'Dégustation'},
#                                                                                                     '_doc_order': 319,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Dégustation'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 320,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': 'Pour '
#                                                                                 'vous '
#                                                                                 'faire '
#                                                                                 'découvrir '
#                                                                                 'nos '
#                                                                                 'thés, '
#                                                                                 'nous '
#                                                                                 'vous '
#                                                                                 'proposons...'},
#                                                                        {'_doc_order': 321,
#                                                                         'children': [{'_doc_order': 322,
#                                                                                       'tag': 'p',
#                                                                                       'text': '10,00 '
#                                                                                               '€'},
# ...
#                                                                         'text': '- '
#                                                                                 'Thé '
#                                                                                 'vert '
#                                                                                 'à '
#                                                                                 'la '
#                                                                                 'liqueur '
#                                                                                 'corsée\ufeff '
#                                                                                 '- \n'
#                                                                                 '  '
#                                                                                 'Ce '
#                                                                                 'thé '
#                                                                                 'vert '
#                                                                                 'pousse...'},
#                                                                        {'_doc_order': 1506,
#                                                                         'children': [{'_doc_order': 1507,
#                                                                                       'children': [{'_doc_order': 1508,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '5,87 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=159&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_159',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 1509,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 1510,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/blends/181-winter-blend.html',
#                                                                     'title': 'Winter '
#                                                                              'Blend'},
#                                                           '_doc_order': 1511,
#                                                           'children': [{'_attr': {'alt': 'Winter '
#                                                                                          'Blend',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/181-1188-large/winter-blend.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 1512,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 1513,
#                                                           'children': [{'_doc_order': 1514,
#                                                                         'children': [{'_doc_order': 1515,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/blends/181-winter-blend.html',
#                                                                                                               'title': 'Winter '
#                                                                                                                        'Blend'},
#                                                                                                     '_doc_order': 1516,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Winter '
#                                                                                                             'Blend'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 1517,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Mélange '
#                                                                                 'de '
#                                                                                 'thés '
#                                                                                 'noirs '
#                                                                                 'de '
#                                                                                 'Yunnan, '
#                                                                                 'Darjeeling '
#                                                                                 'and '
#                                                                                 'Assam\ufeff...'},
#                                                                        {'_doc_order': 1518,
#                                                                         'children': [{'_doc_order': 1519,
#                                                                                       'children': [{'_doc_order': 1520,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '7,85 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=181&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_181',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 1521,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 1522,
#                                             'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/blends/182-yunnan-darjeeling.html',
#                                                                     'title': 'Yunnan-Darjeeling'},
#                                                           '_doc_order': 1523,
#                                                           'children': [{'_attr': {'alt': 'Yunnan-Darjeeling',
#                                                                                   'height': '215px',
#                                                                                   'src': 'https://betjemanandbarton.com/182-1190-large/yunnan-darjeeling.jpg',
#                                                                                   'width': '215px'},
#                                                                         '_doc_order': 1524,
#                                                                         'tag': 'img'}],
#                                                           'tag': 'a.product_img_link'},
#                                                          {'_doc_order': 1525,
#                                                           'children': [{'_doc_order': 1526,
#                                                                         'children': [{'_doc_order': 1527,
#                                                                                       'children': [{'_attr': {'href': 'https://betjemanandbarton.com/fr/blends/182-yunnan-darjeeling.html',
#                                                                                                               'title': 'Yunnan-Darjeeling'},
#                                                                                                     '_doc_order': 1528,
#                                                                                                     'tag': 'a',
#                                                                                                     'text': 'Yunnan-Darjeeling'}],
#                                                                                       'tag': 'h2.product-title.vertical-align'}],
#                                                                         'tag': 'div.table'},
#                                                                        {'_doc_order': 1529,
#                                                                         'tag': 'p.product-description',
#                                                                         'text': '- '
#                                                                                 'Mélange '
#                                                                                 'de '
#                                                                                 'thés '
#                                                                                 'noirs '
#                                                                                 'de '
#                                                                                 'Darjeeling '
#                                                                                 'et '
#                                                                                 'Yunnan\ufeff '
#                                                                                 '-...'},
#                                                                        {'_doc_order': 1530,
#                                                                         'children': [{'_doc_order': 1531,
#                                                                                       'children': [{'_doc_order': 1532,
#                                                                                                     'tag': 'span.price-qty',
#                                                                                                     'text': '/ '
#                                                                                                             '100gr'}],
#                                                                                       'tag': 'p',
#                                                                                       'text': '7,61 '
#                                                                                               '€'},
#                                                                                      {'_attr': {'href': 'https://betjemanandbarton.com/fr/panier?add&id_product=182&token=cdd92df3b95c524da21f30ab7d81afbd',
#                                                                                                 'rel': 'ajax_id_product_182',
#                                                                                                 'title': 'Commander'},
#                                                                                       '_doc_order': 1533,
#                                                                                       'tag': 'a.ajax_add_to_cart_button.button.exclusive',
#                                                                                       'text': 'Commander'}],
#                                                                         'tag': 'div.price'}],
#                                                           'tag': 'div.produc-info'}],
#                                             'tag': 'li.ajax_block_product.item'},
#                                            {'_doc_order': 1534,
#                                             'children': [{'_attr': {'value': '12'},
#                                                           '_doc_order': 1543,
#                                                           'tag': 'option',
#                                                           'text': '12'},
#                                                          {'_attr': {'value': '24'},
#                                                           '_doc_order': 1544,
#                                                           'tag': 'option',
#                                                           'text': '24'},
#                                                          {'_attr': {'value': '48'},
#                                                           '_doc_order': 1545,
#                                                           'tag': 'option',
#                                                           'text': '48'},
#                                                          {'_attr': {'value': '51'},
#                                                           '_doc_order': 1546,
#                                                           'tag': 'option',
#                                                           'text': '51'}],
#                                             'tag': 'div.filters'}],
#                               'tag': 'section.product-listing'}],
#                 'tag': 'section'}],
#   'tag': 'html'}]

# %% [markdown]
# The output data seems to present all the data we'd need for something like PyVideo.org.
#
# Let's just save for further processing.

# %%
import json

JSON_FORMAT_KWARGS = {
    'indent': 2,
    'separators': (',', ': '),
    'sort_keys': True,
}
with open('pydata-berlin-2015.speakers.json', 'w') as fp:
    json.dump(output, fp, **JSON_FORMAT_KWARGS)
    fp.write("\n")

# %% [markdown]
# ## Is there a way to automatically chose clusters?
#
# Spectral clustering does not always give the "best" results. It may be due to the similarity function, or some other parameters, I don't know yet really.
#
# Below is a just to see if hierarchical clustering of tagpaths would do a better job.

# %%
simhelper = clustering.simhelper

# %%
from itertools import zip_longest, combinations
from collections import Counter

import numpy as np

tagpaths = [
    tp for tp, cnt in Counter(clustering.tagpaths).most_common()
    if cnt > 1
]

l = len(tagpaths)
matrix = np.zeros((l, l))

for a, b in combinations(tagpaths, 2):
    ia, ib = tagpaths.index(a), tagpaths.index(b)
    try:
        matrix[ia, ib] = 1 - simhelper.similarity(a, b, epsilon=10)
    except:
        matrix[ia, ib] = 1
    matrix[ib, ia] = matrix[ia, ib]
    matrix[ia, ia] = 0
    matrix[ib, ib] = 0

# %%
from sklearn.cluster import AgglomerativeClustering

clustering2 = AgglomerativeClustering(n_clusters=l, affinity='precomputed', linkage='average')

clustering2.fit_predict(matrix)
# Out:
# array([237, 156, 236, 235, 245, 241, 147, 215, 231, 137, 229, 234, 167,
#        233, 126, 232, 227, 228, 230, 145, 190, 244, 193, 243, 242, 141,
#        214, 217, 212, 194, 218, 211, 186, 219, 209, 220, 160, 195, 124,
#        189, 221, 201, 222, 142, 196, 185, 223, 208, 224,  97, 192, 225,
#        210, 226, 110, 148, 216, 176, 107, 104, 213, 182, 240, 120, 136,
#        199, 173, 135, 207, 150, 127, 200,  94, 203, 191, 204, 171, 198,
#        205, 184, 164, 169, 206, 105,  99, 202,  92, 100,  96, 197, 116,
#        172, 109, 151, 179, 188, 187, 183,  91,  93, 163, 149, 159, 175,
#        181,  87, 180, 146,  89,  67, 165, 106, 177, 162, 178, 166, 123,
#        174, 102, 158,  86, 238,  85,  98, 117, 170, 138,  84,  73, 168,
#        132,  83,  95, 118, 103,  81, 112, 239, 161,  82,  80,  68,  79,
#        115,  39, 157, 140, 129, 154,  90, 155,  57,  77,  52,  44, 143,
#        139,  49, 131, 153,  58,  48, 101,  42, 152,  51,  75, 114,  74,
#         45,  36, 122, 121,  50, 111,  78,  69,  46,  72,  41, 144, 113,
#         20,  71,  24, 108,  40,  76,  88, 119,  43,  37,  35,  47,  21,
#         28,  70,  53,  34,  33,  38, 128, 133,  60,  54,  63,  59,  19,
#        134,  17,  55,  16,  66,  22,  25, 130,  56,  10,  65,  18,  27,
#         64,  23,  31,  61,  26,  32,  13,  15,   9,   8,   7,  29,   4,
#        125,  11,  12,  62,   3,  30,  14,   6,   5,   2,   1,   0])

# %%
# Authors: Mathew Kallada
# License: BSD 3 clause
"""
=========================================
Plot Hierarachical Clustering Dendrogram 
=========================================

This example plots the corresponding dendrogram of a hierarchical clustering
using AgglomerativeClustering and the dendrogram method available in scipy.
"""

import numpy as np

from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram
from sklearn.datasets import load_iris
from sklearn.cluster import AgglomerativeClustering

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)

# %%
ax = plt.plot()
plot_dendrogram(clustering2, labels=tagpaths, orientation='left'
                , leaf_font_size=8
               )
